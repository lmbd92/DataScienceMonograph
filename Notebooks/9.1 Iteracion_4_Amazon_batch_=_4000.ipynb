# %% [markdown]
# # Paso 1: Importar Librerías de Python

# %%
#pip install scikit-surprise
# Out:
# Collecting scikit-surprise
#   Downloading scikit-surprise-1.1.3.tar.gz (771 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 772.0/772.0 kB 9.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: joblib>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.3.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.11.3)
# Building wheels for collected packages: scikit-surprise
#   Building wheel for scikit-surprise (setup.py) ... done
#   Created wheel for scikit-surprise: filename=scikit_surprise-1.1.3-cp310-cp310-linux_x86_64.whl size=3163500 sha256=8e96dce2bc9d9f957642379f97020582421ebbcc00109c67af0cddc955992dab
#   Stored in directory: /root/.cache/pip/wheels/a5/ca/a8/4e28def53797fdc4363ca4af740db15a9c2f1595ebc51fb445
# Successfully built scikit-surprise
# Installing collected packages: scikit-surprise
# Successfully installed scikit-surprise-1.1.3

# %%
# Análisis de datos y manipulación
import pandas as pd
import numpy as np
import random

# Visualización de datos
import matplotlib.pyplot as plt
import seaborn as sns

# Utilidades de fechas
from datetime import datetime

# Integración con Google Colab
from google.colab import drive

# Machine Learning: Preprocesamiento y división de datos
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# Machine Learning: Métricas
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.metrics.pairwise import cosine_similarity

# Machine Learning: Modelado y validación
from surprise import SVD, Reader, Dataset, accuracy
from surprise.model_selection import train_test_split, GridSearchCV


# Deep Learning: Construcción de modelos y capas
from keras.models import Model
from keras.layers import Input, Embedding, Flatten, Concatenate, Dense, Dropout, Dot

# Deep Learning: Optimización y regularización
from keras.optimizers import Adam
from keras.regularizers import l2

# Deep Learning: Callbacks
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Paso 2: Lectura del Dataset

# %%
# Suponiendo que tu DataFrame se llama df
df = pd.read_csv('/content/drive/MyDrive/EspecializacionA&DS/Monografia/2doSemestre/DataFinal_Amazon.csv')  # Descomenta y proporciona la ruta si estás cargando un archivo CSV
# Out:
# <ipython-input-5-1f8e3361d82a>:2: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/drive/MyDrive/EspecializacionA&DS/Monografia/2doSemestre/DataFinal_Amazon.csv')  # Descomenta y proporciona la ruta si estás cargando un archivo CSV

# %%
df.shape
# Out:
# (4800571, 10)

# %% [markdown]
# # Modelo de Filtrado Colaborativo usando Embedding con Keras:

# %% [markdown]
# Funcionamiento:
#
# Los embeddings son representaciones vectoriales densas y de baja dimensión de ítems y/o usuarios. Estas representaciones capturan relaciones semánticas entre ítems o entre usuarios.
#
# Un método popular para generar embeddings es la factorización de matrices, como la descomposición en valores singulares (SVD). En el contexto de sistemas de recomendación, se busca factorizar la matriz de interacciones usuario-ítem en dos matrices más pequeñas (una para los usuarios y otra para los ítems) cuyo producto aproximado reproduce la matriz original lo mejor posible.
#
# Una vez que se han obtenido los embeddings, la predicción de una calificación o interacción entre un usuario e ítem se realiza tomando el producto escalar entre sus embeddings respectivos.
#
# Ventajas:
#
# Simplicidad y eficiencia en términos computacionales.
#
# Puede manejar grandes conjuntos de datos debido a su naturaleza de baja dimensión.
#
# Es efectivo para capturar patrones subyacentes en los datos.
#
# Desventajas:
#
# No tiene en cuenta características adicionales de usuarios o ítems.
#
# Dificultades para manejar nuevos ítems o usuarios (problema de arranque en frío).

# %% [markdown]
# El código ahora incluye regularización en los embeddings, un callback para detener el entrenamiento si no hay mejoras (early stopping) y otro para reducir la tasa de aprendizaje si el error de validación no mejora (reduce learning rate on plateau).

# %%
data = df

# %%
# Crear un LabelEncoder para cada columna
reviewerID_encoder = LabelEncoder()
asin_encoder = LabelEncoder()

# Ajustar y transformar las columnas
data['reviewerID_encoded'] = reviewerID_encoder.fit_transform(data['reviewerID'])
data['asin_encoded'] = asin_encoder.fit_transform(data['asin'])

# Número de usuarios únicos y número de ítems únicos
n_users = len(np.unique(data['reviewerID_encoded']))
n_items = len(np.unique(data['asin_encoded']))

# Dimensiones del embedding
embedding_dim = 10

# Entradas
user_input = Input(shape=(1,))
item_input = Input(shape=(1,))

# Embeddings con regularización
user_embedding = Embedding(n_users, embedding_dim, embeddings_regularizer=l2(1e-6))(user_input)
item_embedding = Embedding(n_items, embedding_dim, embeddings_regularizer=l2(1e-6))(item_input)

# Producto punto para predecir la valoración/rating
merged = Dot(axes=2)([user_embedding, item_embedding])
merged = Flatten()(merged)

# Modelo
model = Model(inputs=[user_input, item_input], outputs=merged)
model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# %% [markdown]
# verbose=0: No muestra ninguna barra de progreso ni métricas.
#
# verbose=1: Muestra una barra de progreso y actualiza las métricas después de cada lote.
#
# verbose=2: Muestra las métricas después de cada época, pero no muestra la barra de progreso.

# %%
from sklearn.model_selection import train_test_split

# Crear los arrays con los datos
user_ids = data['reviewerID_encoded'].values
item_ids = data['asin_encoded'].values
ratings = data['overall'].values

# División en entrenamiento y prueba
(user_ids_temp, user_ids_test, item_ids_temp, item_ids_test, ratings_temp, ratings_test) = train_test_split(
    user_ids, item_ids, ratings, test_size=0.2, random_state=42)

# División del conjunto de entrenamiento en entrenamiento y validación
(user_ids_train, user_ids_val, item_ids_train, item_ids_val, ratings_train, ratings_val) = train_test_split(
    user_ids_temp, item_ids_temp, ratings_temp, test_size=0.25, random_state=42)  # 0.25 x 0.8 = 0.2

# %%
# Callbacks
early_stop = EarlyStopping(monitor='val_loss', patience=50)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=50, min_lr=1e-5)

# %%
# %%time
# Entrenar el modelo con el conjunto de entrenamiento
model.fit([user_ids_train, item_ids_train], ratings_train, validation_data=([user_ids_val, item_ids_val], ratings_val),
          epochs=500, batch_size=4000, verbose=1, callbacks=[early_stop, reduce_lr])
# Out:
# Epoch 1/500
# 721/721 [==============================] - 11s 9ms/step - loss: 19.4953 - mae: 4.2578 - val_loss: 19.4614 - val_mae: 4.2541 - lr: 0.0010
# Epoch 2/500
# 721/721 [==============================] - 6s 8ms/step - loss: 19.1797 - mae: 4.2157 - val_loss: 19.0950 - val_mae: 4.1992 - lr: 0.0010
# Epoch 3/500
# 721/721 [==============================] - 6s 8ms/step - loss: 18.3436 - mae: 4.0925 - val_loss: 18.6756 - val_mae: 4.1205 - lr: 0.0010
# Epoch 4/500
# 721/721 [==============================] - 6s 8ms/step - loss: 17.1323 - mae: 3.9056 - val_loss: 18.3119 - val_mae: 4.0416 - lr: 0.0010
# Epoch 5/500
# 721/721 [==============================] - 6s 8ms/step - loss: 15.7272 - mae: 3.6796 - val_loss: 18.0067 - val_mae: 3.9656 - lr: 0.0010
# Epoch 6/500
# 721/721 [==============================] - 6s 8ms/step - loss: 14.2799 - mae: 3.4328 - val_loss: 17.7490 - val_mae: 3.8926 - lr: 0.0010
# Epoch 7/500
# 721/721 [==============================] - 6s 8ms/step - loss: 12.8891 - mae: 3.1788 - val_loss: 17.5255 - val_mae: 3.8218 - lr: 0.0010
# Epoch 8/500
# 721/721 [==============================] - 6s 8ms/step - loss: 11.6085 - mae: 2.9280 - val_loss: 17.3256 - val_mae: 3.7533 - lr: 0.0010
# Epoch 9/500
# 721/721 [==============================] - 6s 8ms/step - loss: 10.4617 - mae: 2.6881 - val_loss: 17.1419 - val_mae: 3.6872 - lr: 0.0010
# Epoch 10/500
# 721/721 [==============================] - 6s 8ms/step - loss: 9.4528 - mae: 2.4643 - val_loss: 16.9701 - val_mae: 3.6238 - lr: 0.0010
# Epoch 11/500
# 721/721 [==============================] - 6s 8ms/step - loss: 8.5753 - mae: 2.2584 - val_loss: 16.8083 - val_mae: 3.5633 - lr: 0.0010
# Epoch 12/500
# 721/721 [==============================] - 6s 8ms/step - loss: 7.8174 - mae: 2.0707 - val_loss: 16.6550 - val_mae: 3.5058 - lr: 0.0010
# Epoch 13/500
# 721/721 [==============================] - 6s 8ms/step - loss: 7.1662 - mae: 1.9006 - val_loss: 16.5098 - val_mae: 3.4514 - lr: 0.0010
# Epoch 14/500
# 721/721 [==============================] - 6s 8ms/step - loss: 6.6086 - mae: 1.7474 - val_loss: 16.3722 - val_mae: 3.4002 - lr: 0.0010
# Epoch 15/500
# 721/721 [==============================] - 6s 8ms/step - loss: 6.1321 - mae: 1.6094 - val_loss: 16.2407 - val_mae: 3.3521 - lr: 0.0010
# Epoch 16/500
# 721/721 [==============================] - 6s 8ms/step - loss: 5.7258 - mae: 1.4856 - val_loss: 16.1148 - val_mae: 3.3070 - lr: 0.0010
# Epoch 17/500
# 721/721 [==============================] - 6s 8ms/step - loss: 5.3800 - mae: 1.3748 - val_loss: 15.9934 - val_mae: 3.2649 - lr: 0.0010
# Epoch 18/500
# 721/721 [==============================] - 6s 8ms/step - loss: 5.0862 - mae: 1.2763 - val_loss: 15.8764 - val_mae: 3.2255 - lr: 0.0010
# Epoch 19/500
# 721/721 [==============================] - 6s 8ms/step - loss: 4.8367 - mae: 1.1885 - val_loss: 15.7626 - val_mae: 3.1886 - lr: 0.0010
# Epoch 20/500
# 721/721 [==============================] - 6s 8ms/step - loss: 4.6250 - mae: 1.1105 - val_loss: 15.6511 - val_mae: 3.1541 - lr: 0.0010
# Epoch 21/500
# 721/721 [==============================] - 6s 8ms/step - loss: 4.4456 - mae: 1.0413 - val_loss: 15.5430 - val_mae: 3.1218 - lr: 0.0010
# Epoch 22/500
# 721/721 [==============================] - 6s 8ms/step - loss: 4.2934 - mae: 0.9800 - val_loss: 15.4355 - val_mae: 3.0913 - lr: 0.0010
# Epoch 23/500
# 721/721 [==============================] - 6s 8ms/step - loss: 4.1644 - mae: 0.9257 - val_loss: 15.3298 - val_mae: 3.0627 - lr: 0.0010
# Epoch 24/500
# 721/721 [==============================] - 6s 8ms/step - loss: 4.0549 - mae: 0.8776 - val_loss: 15.2241 - val_mae: 3.0356 - lr: 0.0010
# Epoch 25/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.9621 - mae: 0.8354 - val_loss: 15.1195 - val_mae: 3.0099 - lr: 0.0010
# Epoch 26/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.8829 - mae: 0.7979 - val_loss: 15.0147 - val_mae: 2.9855 - lr: 0.0010
# Epoch 27/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.8156 - mae: 0.7649 - val_loss: 14.9101 - val_mae: 2.9624 - lr: 0.0010
# Epoch 28/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.7581 - mae: 0.7360 - val_loss: 14.8054 - val_mae: 2.9401 - lr: 0.0010
# Epoch 29/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.7088 - mae: 0.7104 - val_loss: 14.7002 - val_mae: 2.9187 - lr: 0.0010
# Epoch 30/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.6664 - mae: 0.6879 - val_loss: 14.5947 - val_mae: 2.8981 - lr: 0.0010
# Epoch 31/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.6297 - mae: 0.6681 - val_loss: 14.4890 - val_mae: 2.8782 - lr: 0.0010
# Epoch 32/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.5979 - mae: 0.6508 - val_loss: 14.3834 - val_mae: 2.8589 - lr: 0.0010
# Epoch 33/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.5700 - mae: 0.6355 - val_loss: 14.2782 - val_mae: 2.8403 - lr: 0.0010
# Epoch 34/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.5455 - mae: 0.6220 - val_loss: 14.1729 - val_mae: 2.8222 - lr: 0.0010
# Epoch 35/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.5239 - mae: 0.6101 - val_loss: 14.0681 - val_mae: 2.8044 - lr: 0.0010
# Epoch 36/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.5047 - mae: 0.5996 - val_loss: 13.9635 - val_mae: 2.7872 - lr: 0.0010
# Epoch 37/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.4874 - mae: 0.5903 - val_loss: 13.8600 - val_mae: 2.7704 - lr: 0.0010
# Epoch 38/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.4719 - mae: 0.5820 - val_loss: 13.7566 - val_mae: 2.7538 - lr: 0.0010
# Epoch 39/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.4577 - mae: 0.5747 - val_loss: 13.6549 - val_mae: 2.7377 - lr: 0.0010
# Epoch 40/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.4449 - mae: 0.5683 - val_loss: 13.5535 - val_mae: 2.7219 - lr: 0.0010
# Epoch 41/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.4330 - mae: 0.5625 - val_loss: 13.4532 - val_mae: 2.7063 - lr: 0.0010
# Epoch 42/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.4221 - mae: 0.5573 - val_loss: 13.3544 - val_mae: 2.6910 - lr: 0.0010
# Epoch 43/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.4119 - mae: 0.5527 - val_loss: 13.2570 - val_mae: 2.6761 - lr: 0.0010
# Epoch 44/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.4024 - mae: 0.5485 - val_loss: 13.1608 - val_mae: 2.6614 - lr: 0.0010
# Epoch 45/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.3935 - mae: 0.5448 - val_loss: 13.0667 - val_mae: 2.6470 - lr: 0.0010
# Epoch 46/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.3851 - mae: 0.5413 - val_loss: 12.9734 - val_mae: 2.6329 - lr: 0.0010
# Epoch 47/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.3772 - mae: 0.5383 - val_loss: 12.8824 - val_mae: 2.6191 - lr: 0.0010
# Epoch 48/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.3697 - mae: 0.5354 - val_loss: 12.7926 - val_mae: 2.6054 - lr: 0.0010
# Epoch 49/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.3627 - mae: 0.5329 - val_loss: 12.7049 - val_mae: 2.5921 - lr: 0.0010
# Epoch 50/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.3560 - mae: 0.5307 - val_loss: 12.6184 - val_mae: 2.5789 - lr: 0.0010
# Epoch 51/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.3495 - mae: 0.5285 - val_loss: 12.5347 - val_mae: 2.5662 - lr: 0.0010
# Epoch 52/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.3434 - mae: 0.5266 - val_loss: 12.4515 - val_mae: 2.5534 - lr: 0.0010
# Epoch 53/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.3375 - mae: 0.5248 - val_loss: 12.3716 - val_mae: 2.5413 - lr: 0.0010
# Epoch 54/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.3319 - mae: 0.5231 - val_loss: 12.2927 - val_mae: 2.5291 - lr: 0.0010
# Epoch 55/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.3266 - mae: 0.5216 - val_loss: 12.2159 - val_mae: 2.5172 - lr: 0.0010
# Epoch 56/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.3214 - mae: 0.5202 - val_loss: 12.1412 - val_mae: 2.5056 - lr: 0.0010
# Epoch 57/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.3164 - mae: 0.5189 - val_loss: 12.0678 - val_mae: 2.4942 - lr: 0.0010
# Epoch 58/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.3116 - mae: 0.5175 - val_loss: 11.9963 - val_mae: 2.4830 - lr: 0.0010
# Epoch 59/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.3072 - mae: 0.5165 - val_loss: 11.9275 - val_mae: 2.4722 - lr: 0.0010
# Epoch 60/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.3027 - mae: 0.5154 - val_loss: 11.8596 - val_mae: 2.4616 - lr: 0.0010
# Epoch 61/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.2985 - mae: 0.5145 - val_loss: 11.7938 - val_mae: 2.4512 - lr: 0.0010
# Epoch 62/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.2944 - mae: 0.5135 - val_loss: 11.7297 - val_mae: 2.4410 - lr: 0.0010
# Epoch 63/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.2904 - mae: 0.5126 - val_loss: 11.6673 - val_mae: 2.4310 - lr: 0.0010
# Epoch 64/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.2867 - mae: 0.5117 - val_loss: 11.6070 - val_mae: 2.4214 - lr: 0.0010
# Epoch 65/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.2830 - mae: 0.5109 - val_loss: 11.5483 - val_mae: 2.4120 - lr: 0.0010
# Epoch 66/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.2795 - mae: 0.5102 - val_loss: 11.4906 - val_mae: 2.4026 - lr: 0.0010
# Epoch 67/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.2761 - mae: 0.5095 - val_loss: 11.4347 - val_mae: 2.3935 - lr: 0.0010
# Epoch 68/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.2728 - mae: 0.5089 - val_loss: 11.3805 - val_mae: 2.3846 - lr: 0.0010
# Epoch 69/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.2697 - mae: 0.5082 - val_loss: 11.3281 - val_mae: 2.3760 - lr: 0.0010
# Epoch 70/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.2666 - mae: 0.5075 - val_loss: 11.2771 - val_mae: 2.3676 - lr: 0.0010
# Epoch 71/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.2637 - mae: 0.5070 - val_loss: 11.2278 - val_mae: 2.3595 - lr: 0.0010
# Epoch 72/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.2609 - mae: 0.5067 - val_loss: 11.1797 - val_mae: 2.3515 - lr: 0.0010
# Epoch 73/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.2580 - mae: 0.5059 - val_loss: 11.1326 - val_mae: 2.3437 - lr: 0.0010
# Epoch 74/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.2554 - mae: 0.5055 - val_loss: 11.0870 - val_mae: 2.3361 - lr: 0.0010
# Epoch 75/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.2529 - mae: 0.5052 - val_loss: 11.0433 - val_mae: 2.3287 - lr: 0.0010
# Epoch 76/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.2503 - mae: 0.5045 - val_loss: 11.0007 - val_mae: 2.3214 - lr: 0.0010
# Epoch 77/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.2479 - mae: 0.5040 - val_loss: 10.9590 - val_mae: 2.3143 - lr: 0.0010
# Epoch 78/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.2457 - mae: 0.5038 - val_loss: 10.9187 - val_mae: 2.3075 - lr: 0.0010
# Epoch 79/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.2434 - mae: 0.5033 - val_loss: 10.8796 - val_mae: 2.3009 - lr: 0.0010
# Epoch 80/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.2412 - mae: 0.5029 - val_loss: 10.8416 - val_mae: 2.2943 - lr: 0.0010
# Epoch 81/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.2391 - mae: 0.5026 - val_loss: 10.8045 - val_mae: 2.2879 - lr: 0.0010
# Epoch 82/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.2371 - mae: 0.5022 - val_loss: 10.7690 - val_mae: 2.2818 - lr: 0.0010
# Epoch 83/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.2351 - mae: 0.5019 - val_loss: 10.7339 - val_mae: 2.2756 - lr: 0.0010
# Epoch 84/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.2332 - mae: 0.5015 - val_loss: 10.7003 - val_mae: 2.2699 - lr: 0.0010
# Epoch 85/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.2314 - mae: 0.5012 - val_loss: 10.6671 - val_mae: 2.2640 - lr: 0.0010
# Epoch 86/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.2295 - mae: 0.5008 - val_loss: 10.6353 - val_mae: 2.2585 - lr: 0.0010
# Epoch 87/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.2279 - mae: 0.5007 - val_loss: 10.6041 - val_mae: 2.2529 - lr: 0.0010
# Epoch 88/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.2261 - mae: 0.5003 - val_loss: 10.5737 - val_mae: 2.2475 - lr: 0.0010
# Epoch 89/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.2245 - mae: 0.5000 - val_loss: 10.5450 - val_mae: 2.2424 - lr: 0.0010
# Epoch 90/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.2230 - mae: 0.4998 - val_loss: 10.5163 - val_mae: 2.2374 - lr: 0.0010
# Epoch 91/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.2214 - mae: 0.4995 - val_loss: 10.4887 - val_mae: 2.2324 - lr: 0.0010
# Epoch 92/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.2199 - mae: 0.4991 - val_loss: 10.4619 - val_mae: 2.2276 - lr: 0.0010
# Epoch 93/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.2184 - mae: 0.4989 - val_loss: 10.4359 - val_mae: 2.2230 - lr: 0.0010
# Epoch 94/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.2170 - mae: 0.4986 - val_loss: 10.4105 - val_mae: 2.2185 - lr: 0.0010
# Epoch 95/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.2157 - mae: 0.4985 - val_loss: 10.3856 - val_mae: 2.2139 - lr: 0.0010
# Epoch 96/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.2143 - mae: 0.4982 - val_loss: 10.3616 - val_mae: 2.2095 - lr: 0.0010
# Epoch 97/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.2130 - mae: 0.4979 - val_loss: 10.3383 - val_mae: 2.2053 - lr: 0.0010
# Epoch 98/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.2119 - mae: 0.4979 - val_loss: 10.3157 - val_mae: 2.2011 - lr: 0.0010
# Epoch 99/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.2106 - mae: 0.4976 - val_loss: 10.2942 - val_mae: 2.1971 - lr: 0.0010
# Epoch 100/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.2095 - mae: 0.4974 - val_loss: 10.2723 - val_mae: 2.1931 - lr: 0.0010
# Epoch 101/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.2083 - mae: 0.4971 - val_loss: 10.2519 - val_mae: 2.1894 - lr: 0.0010
# Epoch 102/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.2072 - mae: 0.4970 - val_loss: 10.2314 - val_mae: 2.1856 - lr: 0.0010
# Epoch 103/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.2060 - mae: 0.4966 - val_loss: 10.2114 - val_mae: 2.1819 - lr: 0.0010
# Epoch 104/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.2050 - mae: 0.4965 - val_loss: 10.1918 - val_mae: 2.1782 - lr: 0.0010
# Epoch 105/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.2040 - mae: 0.4963 - val_loss: 10.1736 - val_mae: 2.1748 - lr: 0.0010
# Epoch 106/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.2030 - mae: 0.4961 - val_loss: 10.1551 - val_mae: 2.1715 - lr: 0.0010
# Epoch 107/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.2020 - mae: 0.4959 - val_loss: 10.1374 - val_mae: 2.1681 - lr: 0.0010
# Epoch 108/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.2010 - mae: 0.4957 - val_loss: 10.1205 - val_mae: 2.1649 - lr: 0.0010
# Epoch 109/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.2001 - mae: 0.4955 - val_loss: 10.1040 - val_mae: 2.1620 - lr: 0.0010
# Epoch 110/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1992 - mae: 0.4954 - val_loss: 10.0871 - val_mae: 2.1587 - lr: 0.0010
# Epoch 111/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1983 - mae: 0.4952 - val_loss: 10.0712 - val_mae: 2.1557 - lr: 0.0010
# Epoch 112/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1974 - mae: 0.4950 - val_loss: 10.0557 - val_mae: 2.1528 - lr: 0.0010
# Epoch 113/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1966 - mae: 0.4949 - val_loss: 10.0406 - val_mae: 2.1499 - lr: 0.0010
# Epoch 114/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1958 - mae: 0.4947 - val_loss: 10.0257 - val_mae: 2.1471 - lr: 0.0010
# Epoch 115/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1950 - mae: 0.4945 - val_loss: 10.0111 - val_mae: 2.1443 - lr: 0.0010
# Epoch 116/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1942 - mae: 0.4943 - val_loss: 9.9973 - val_mae: 2.1417 - lr: 0.0010
# Epoch 117/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1934 - mae: 0.4942 - val_loss: 9.9832 - val_mae: 2.1389 - lr: 0.0010
# Epoch 118/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1927 - mae: 0.4941 - val_loss: 9.9700 - val_mae: 2.1364 - lr: 0.0010
# Epoch 119/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1919 - mae: 0.4938 - val_loss: 9.9566 - val_mae: 2.1339 - lr: 0.0010
# Epoch 120/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1912 - mae: 0.4937 - val_loss: 9.9442 - val_mae: 2.1316 - lr: 0.0010
# Epoch 121/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1906 - mae: 0.4936 - val_loss: 9.9315 - val_mae: 2.1291 - lr: 0.0010
# Epoch 122/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1899 - mae: 0.4934 - val_loss: 9.9195 - val_mae: 2.1268 - lr: 0.0010
# Epoch 123/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1892 - mae: 0.4933 - val_loss: 9.9075 - val_mae: 2.1245 - lr: 0.0010
# Epoch 124/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1885 - mae: 0.4932 - val_loss: 9.8961 - val_mae: 2.1223 - lr: 0.0010
# Epoch 125/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1879 - mae: 0.4930 - val_loss: 9.8846 - val_mae: 2.1201 - lr: 0.0010
# Epoch 126/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1873 - mae: 0.4929 - val_loss: 9.8735 - val_mae: 2.1178 - lr: 0.0010
# Epoch 127/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1867 - mae: 0.4927 - val_loss: 9.8627 - val_mae: 2.1158 - lr: 0.0010
# Epoch 128/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1860 - mae: 0.4924 - val_loss: 9.8523 - val_mae: 2.1137 - lr: 0.0010
# Epoch 129/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1855 - mae: 0.4925 - val_loss: 9.8418 - val_mae: 2.1118 - lr: 0.0010
# Epoch 130/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1849 - mae: 0.4923 - val_loss: 9.8318 - val_mae: 2.1098 - lr: 0.0010
# Epoch 131/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1843 - mae: 0.4922 - val_loss: 9.8217 - val_mae: 2.1078 - lr: 0.0010
# Epoch 132/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1838 - mae: 0.4919 - val_loss: 9.8125 - val_mae: 2.1059 - lr: 0.0010
# Epoch 133/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1833 - mae: 0.4919 - val_loss: 9.8029 - val_mae: 2.1041 - lr: 0.0010
# Epoch 134/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1827 - mae: 0.4917 - val_loss: 9.7938 - val_mae: 2.1023 - lr: 0.0010
# Epoch 135/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1822 - mae: 0.4917 - val_loss: 9.7844 - val_mae: 2.1005 - lr: 0.0010
# Epoch 136/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1817 - mae: 0.4914 - val_loss: 9.7760 - val_mae: 2.0988 - lr: 0.0010
# Epoch 137/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1812 - mae: 0.4913 - val_loss: 9.7672 - val_mae: 2.0972 - lr: 0.0010
# Epoch 138/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1807 - mae: 0.4912 - val_loss: 9.7587 - val_mae: 2.0954 - lr: 0.0010
# Epoch 139/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1802 - mae: 0.4911 - val_loss: 9.7503 - val_mae: 2.0938 - lr: 0.0010
# Epoch 140/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1797 - mae: 0.4909 - val_loss: 9.7425 - val_mae: 2.0923 - lr: 0.0010
# Epoch 141/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1793 - mae: 0.4909 - val_loss: 9.7343 - val_mae: 2.0906 - lr: 0.0010
# Epoch 142/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1788 - mae: 0.4908 - val_loss: 9.7267 - val_mae: 2.0890 - lr: 0.0010
# Epoch 143/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1784 - mae: 0.4906 - val_loss: 9.7188 - val_mae: 2.0875 - lr: 0.0010
# Epoch 144/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1780 - mae: 0.4905 - val_loss: 9.7114 - val_mae: 2.0861 - lr: 0.0010
# Epoch 145/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1775 - mae: 0.4902 - val_loss: 9.7039 - val_mae: 2.0845 - lr: 0.0010
# Epoch 146/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1771 - mae: 0.4903 - val_loss: 9.6969 - val_mae: 2.0831 - lr: 0.0010
# Epoch 147/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1766 - mae: 0.4900 - val_loss: 9.6900 - val_mae: 2.0818 - lr: 0.0010
# Epoch 148/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1762 - mae: 0.4899 - val_loss: 9.6830 - val_mae: 2.0804 - lr: 0.0010
# Epoch 149/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1759 - mae: 0.4899 - val_loss: 9.6764 - val_mae: 2.0791 - lr: 0.0010
# Epoch 150/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1755 - mae: 0.4897 - val_loss: 9.6698 - val_mae: 2.0778 - lr: 0.0010
# Epoch 151/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1751 - mae: 0.4897 - val_loss: 9.6631 - val_mae: 2.0765 - lr: 0.0010
# Epoch 152/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1747 - mae: 0.4895 - val_loss: 9.6567 - val_mae: 2.0751 - lr: 0.0010
# Epoch 153/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1743 - mae: 0.4894 - val_loss: 9.6505 - val_mae: 2.0740 - lr: 0.0010
# Epoch 154/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1739 - mae: 0.4893 - val_loss: 9.6444 - val_mae: 2.0727 - lr: 0.0010
# Epoch 155/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1736 - mae: 0.4892 - val_loss: 9.6381 - val_mae: 2.0714 - lr: 0.0010
# Epoch 156/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1732 - mae: 0.4891 - val_loss: 9.6326 - val_mae: 2.0702 - lr: 0.0010
# Epoch 157/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1729 - mae: 0.4890 - val_loss: 9.6267 - val_mae: 2.0691 - lr: 0.0010
# Epoch 158/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1725 - mae: 0.4888 - val_loss: 9.6212 - val_mae: 2.0680 - lr: 0.0010
# Epoch 159/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1722 - mae: 0.4888 - val_loss: 9.6155 - val_mae: 2.0668 - lr: 0.0010
# Epoch 160/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1718 - mae: 0.4885 - val_loss: 9.6099 - val_mae: 2.0657 - lr: 0.0010
# Epoch 161/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1715 - mae: 0.4885 - val_loss: 9.6045 - val_mae: 2.0646 - lr: 0.0010
# Epoch 162/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1712 - mae: 0.4884 - val_loss: 9.5993 - val_mae: 2.0636 - lr: 0.0010
# Epoch 163/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1709 - mae: 0.4884 - val_loss: 9.5941 - val_mae: 2.0625 - lr: 0.0010
# Epoch 164/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1706 - mae: 0.4882 - val_loss: 9.5892 - val_mae: 2.0616 - lr: 0.0010
# Epoch 165/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1703 - mae: 0.4882 - val_loss: 9.5839 - val_mae: 2.0604 - lr: 0.0010
# Epoch 166/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1699 - mae: 0.4880 - val_loss: 9.5791 - val_mae: 2.0595 - lr: 0.0010
# Epoch 167/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1697 - mae: 0.4880 - val_loss: 9.5740 - val_mae: 2.0584 - lr: 0.0010
# Epoch 168/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1693 - mae: 0.4879 - val_loss: 9.5697 - val_mae: 2.0576 - lr: 0.0010
# Epoch 169/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1691 - mae: 0.4877 - val_loss: 9.5647 - val_mae: 2.0565 - lr: 0.0010
# Epoch 170/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1687 - mae: 0.4876 - val_loss: 9.5602 - val_mae: 2.0556 - lr: 0.0010
# Epoch 171/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1685 - mae: 0.4875 - val_loss: 9.5553 - val_mae: 2.0546 - lr: 0.0010
# Epoch 172/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1682 - mae: 0.4874 - val_loss: 9.5512 - val_mae: 2.0539 - lr: 0.0010
# Epoch 173/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1679 - mae: 0.4874 - val_loss: 9.5466 - val_mae: 2.0529 - lr: 0.0010
# Epoch 174/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1676 - mae: 0.4872 - val_loss: 9.5429 - val_mae: 2.0521 - lr: 0.0010
# Epoch 175/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1674 - mae: 0.4871 - val_loss: 9.5384 - val_mae: 2.0512 - lr: 0.0010
# Epoch 176/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1671 - mae: 0.4871 - val_loss: 9.5342 - val_mae: 2.0503 - lr: 0.0010
# Epoch 177/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1668 - mae: 0.4870 - val_loss: 9.5301 - val_mae: 2.0494 - lr: 0.0010
# Epoch 178/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1666 - mae: 0.4868 - val_loss: 9.5263 - val_mae: 2.0487 - lr: 0.0010
# Epoch 179/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1663 - mae: 0.4867 - val_loss: 9.5219 - val_mae: 2.0478 - lr: 0.0010
# Epoch 180/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1661 - mae: 0.4867 - val_loss: 9.5182 - val_mae: 2.0470 - lr: 0.0010
# Epoch 181/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1658 - mae: 0.4866 - val_loss: 9.5140 - val_mae: 2.0462 - lr: 0.0010
# Epoch 182/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1656 - mae: 0.4865 - val_loss: 9.5106 - val_mae: 2.0455 - lr: 0.0010
# Epoch 183/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1653 - mae: 0.4864 - val_loss: 9.5069 - val_mae: 2.0448 - lr: 0.0010
# Epoch 184/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1651 - mae: 0.4863 - val_loss: 9.5030 - val_mae: 2.0439 - lr: 0.0010
# Epoch 185/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1649 - mae: 0.4863 - val_loss: 9.4994 - val_mae: 2.0432 - lr: 0.0010
# Epoch 186/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1646 - mae: 0.4861 - val_loss: 9.4958 - val_mae: 2.0424 - lr: 0.0010
# Epoch 187/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1644 - mae: 0.4861 - val_loss: 9.4924 - val_mae: 2.0417 - lr: 0.0010
# Epoch 188/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1641 - mae: 0.4860 - val_loss: 9.4890 - val_mae: 2.0410 - lr: 0.0010
# Epoch 189/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1639 - mae: 0.4859 - val_loss: 9.4855 - val_mae: 2.0403 - lr: 0.0010
# Epoch 190/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1637 - mae: 0.4858 - val_loss: 9.4825 - val_mae: 2.0397 - lr: 0.0010
# Epoch 191/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1635 - mae: 0.4857 - val_loss: 9.4789 - val_mae: 2.0390 - lr: 0.0010
# Epoch 192/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1633 - mae: 0.4857 - val_loss: 9.4754 - val_mae: 2.0383 - lr: 0.0010
# Epoch 193/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1631 - mae: 0.4856 - val_loss: 9.4728 - val_mae: 2.0376 - lr: 0.0010
# Epoch 194/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1628 - mae: 0.4854 - val_loss: 9.4692 - val_mae: 2.0369 - lr: 0.0010
# Epoch 195/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1627 - mae: 0.4854 - val_loss: 9.4663 - val_mae: 2.0363 - lr: 0.0010
# Epoch 196/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1624 - mae: 0.4854 - val_loss: 9.4631 - val_mae: 2.0357 - lr: 0.0010
# Epoch 197/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1622 - mae: 0.4852 - val_loss: 9.4599 - val_mae: 2.0349 - lr: 0.0010
# Epoch 198/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1620 - mae: 0.4851 - val_loss: 9.4568 - val_mae: 2.0344 - lr: 0.0010
# Epoch 199/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1618 - mae: 0.4850 - val_loss: 9.4538 - val_mae: 2.0337 - lr: 0.0010
# Epoch 200/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1616 - mae: 0.4850 - val_loss: 9.4510 - val_mae: 2.0331 - lr: 0.0010
# Epoch 201/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1614 - mae: 0.4849 - val_loss: 9.4478 - val_mae: 2.0325 - lr: 0.0010
# Epoch 202/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1613 - mae: 0.4849 - val_loss: 9.4453 - val_mae: 2.0319 - lr: 0.0010
# Epoch 203/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1610 - mae: 0.4847 - val_loss: 9.4426 - val_mae: 2.0314 - lr: 0.0010
# Epoch 204/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1608 - mae: 0.4847 - val_loss: 9.4398 - val_mae: 2.0308 - lr: 0.0010
# Epoch 205/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1607 - mae: 0.4847 - val_loss: 9.4372 - val_mae: 2.0302 - lr: 0.0010
# Epoch 206/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1604 - mae: 0.4844 - val_loss: 9.4345 - val_mae: 2.0297 - lr: 0.0010
# Epoch 207/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1603 - mae: 0.4845 - val_loss: 9.4318 - val_mae: 2.0291 - lr: 0.0010
# Epoch 208/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1601 - mae: 0.4843 - val_loss: 9.4292 - val_mae: 2.0286 - lr: 0.0010
# Epoch 209/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1599 - mae: 0.4843 - val_loss: 9.4267 - val_mae: 2.0281 - lr: 0.0010
# Epoch 210/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1598 - mae: 0.4842 - val_loss: 9.4244 - val_mae: 2.0276 - lr: 0.0010
# Epoch 211/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1596 - mae: 0.4842 - val_loss: 9.4218 - val_mae: 2.0270 - lr: 0.0010
# Epoch 212/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1594 - mae: 0.4840 - val_loss: 9.4188 - val_mae: 2.0264 - lr: 0.0010
# Epoch 213/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1593 - mae: 0.4840 - val_loss: 9.4168 - val_mae: 2.0259 - lr: 0.0010
# Epoch 214/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1591 - mae: 0.4840 - val_loss: 9.4140 - val_mae: 2.0254 - lr: 0.0010
# Epoch 215/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1589 - mae: 0.4839 - val_loss: 9.4117 - val_mae: 2.0250 - lr: 0.0010
# Epoch 216/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1587 - mae: 0.4838 - val_loss: 9.4092 - val_mae: 2.0244 - lr: 0.0010
# Epoch 217/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1586 - mae: 0.4838 - val_loss: 9.4070 - val_mae: 2.0239 - lr: 0.0010
# Epoch 218/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1584 - mae: 0.4835 - val_loss: 9.4048 - val_mae: 2.0235 - lr: 0.0010
# Epoch 219/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1583 - mae: 0.4836 - val_loss: 9.4022 - val_mae: 2.0230 - lr: 0.0010
# Epoch 220/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1581 - mae: 0.4835 - val_loss: 9.4003 - val_mae: 2.0226 - lr: 0.0010
# Epoch 221/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1579 - mae: 0.4834 - val_loss: 9.3978 - val_mae: 2.0221 - lr: 0.0010
# Epoch 222/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1578 - mae: 0.4835 - val_loss: 9.3959 - val_mae: 2.0217 - lr: 0.0010
# Epoch 223/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1576 - mae: 0.4833 - val_loss: 9.3933 - val_mae: 2.0211 - lr: 0.0010
# Epoch 224/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1574 - mae: 0.4831 - val_loss: 9.3914 - val_mae: 2.0207 - lr: 0.0010
# Epoch 225/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1573 - mae: 0.4833 - val_loss: 9.3893 - val_mae: 2.0203 - lr: 0.0010
# Epoch 226/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1571 - mae: 0.4831 - val_loss: 9.3869 - val_mae: 2.0197 - lr: 0.0010
# Epoch 227/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1569 - mae: 0.4829 - val_loss: 9.3847 - val_mae: 2.0193 - lr: 0.0010
# Epoch 228/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1568 - mae: 0.4830 - val_loss: 9.3829 - val_mae: 2.0189 - lr: 0.0010
# Epoch 229/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1567 - mae: 0.4829 - val_loss: 9.3806 - val_mae: 2.0184 - lr: 0.0010
# Epoch 230/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1565 - mae: 0.4827 - val_loss: 9.3787 - val_mae: 2.0180 - lr: 0.0010
# Epoch 231/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1565 - mae: 0.4829 - val_loss: 9.3768 - val_mae: 2.0177 - lr: 0.0010
# Epoch 232/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1562 - mae: 0.4826 - val_loss: 9.3750 - val_mae: 2.0173 - lr: 0.0010
# Epoch 233/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1561 - mae: 0.4827 - val_loss: 9.3728 - val_mae: 2.0168 - lr: 0.0010
# Epoch 234/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1560 - mae: 0.4825 - val_loss: 9.3709 - val_mae: 2.0163 - lr: 0.0010
# Epoch 235/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1558 - mae: 0.4825 - val_loss: 9.3691 - val_mae: 2.0160 - lr: 0.0010
# Epoch 236/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1557 - mae: 0.4823 - val_loss: 9.3673 - val_mae: 2.0157 - lr: 0.0010
# Epoch 237/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1555 - mae: 0.4824 - val_loss: 9.3654 - val_mae: 2.0152 - lr: 0.0010
# Epoch 238/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1554 - mae: 0.4823 - val_loss: 9.3636 - val_mae: 2.0148 - lr: 0.0010
# Epoch 239/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1553 - mae: 0.4821 - val_loss: 9.3616 - val_mae: 2.0145 - lr: 0.0010
# Epoch 240/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1552 - mae: 0.4822 - val_loss: 9.3596 - val_mae: 2.0140 - lr: 0.0010
# Epoch 241/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1550 - mae: 0.4820 - val_loss: 9.3580 - val_mae: 2.0137 - lr: 0.0010
# Epoch 242/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1549 - mae: 0.4821 - val_loss: 9.3565 - val_mae: 2.0134 - lr: 0.0010
# Epoch 243/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1547 - mae: 0.4820 - val_loss: 9.3546 - val_mae: 2.0131 - lr: 0.0010
# Epoch 244/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1546 - mae: 0.4819 - val_loss: 9.3530 - val_mae: 2.0126 - lr: 0.0010
# Epoch 245/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1545 - mae: 0.4818 - val_loss: 9.3510 - val_mae: 2.0122 - lr: 0.0010
# Epoch 246/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1544 - mae: 0.4818 - val_loss: 9.3494 - val_mae: 2.0118 - lr: 0.0010
# Epoch 247/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1542 - mae: 0.4818 - val_loss: 9.3476 - val_mae: 2.0115 - lr: 0.0010
# Epoch 248/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1541 - mae: 0.4817 - val_loss: 9.3457 - val_mae: 2.0110 - lr: 0.0010
# Epoch 249/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1540 - mae: 0.4816 - val_loss: 9.3446 - val_mae: 2.0109 - lr: 0.0010
# Epoch 250/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1539 - mae: 0.4816 - val_loss: 9.3427 - val_mae: 2.0104 - lr: 0.0010
# Epoch 251/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1537 - mae: 0.4815 - val_loss: 9.3411 - val_mae: 2.0101 - lr: 0.0010
# Epoch 252/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1536 - mae: 0.4814 - val_loss: 9.3397 - val_mae: 2.0099 - lr: 0.0010
# Epoch 253/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1535 - mae: 0.4813 - val_loss: 9.3377 - val_mae: 2.0095 - lr: 0.0010
# Epoch 254/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1534 - mae: 0.4814 - val_loss: 9.3362 - val_mae: 2.0091 - lr: 0.0010
# Epoch 255/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1532 - mae: 0.4813 - val_loss: 9.3349 - val_mae: 2.0089 - lr: 0.0010
# Epoch 256/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1531 - mae: 0.4812 - val_loss: 9.3331 - val_mae: 2.0085 - lr: 0.0010
# Epoch 257/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1530 - mae: 0.4812 - val_loss: 9.3316 - val_mae: 2.0081 - lr: 0.0010
# Epoch 258/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1529 - mae: 0.4811 - val_loss: 9.3299 - val_mae: 2.0077 - lr: 0.0010
# Epoch 259/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1527 - mae: 0.4811 - val_loss: 9.3286 - val_mae: 2.0076 - lr: 0.0010
# Epoch 260/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1527 - mae: 0.4810 - val_loss: 9.3271 - val_mae: 2.0072 - lr: 0.0010
# Epoch 261/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1526 - mae: 0.4810 - val_loss: 9.3257 - val_mae: 2.0069 - lr: 0.0010
# Epoch 262/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1524 - mae: 0.4809 - val_loss: 9.3242 - val_mae: 2.0065 - lr: 0.0010
# Epoch 263/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1523 - mae: 0.4807 - val_loss: 9.3226 - val_mae: 2.0062 - lr: 0.0010
# Epoch 264/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1522 - mae: 0.4808 - val_loss: 9.3212 - val_mae: 2.0059 - lr: 0.0010
# Epoch 265/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1521 - mae: 0.4808 - val_loss: 9.3199 - val_mae: 2.0057 - lr: 0.0010
# Epoch 266/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1520 - mae: 0.4806 - val_loss: 9.3185 - val_mae: 2.0054 - lr: 0.0010
# Epoch 267/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1519 - mae: 0.4806 - val_loss: 9.3170 - val_mae: 2.0050 - lr: 0.0010
# Epoch 268/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1517 - mae: 0.4804 - val_loss: 9.3155 - val_mae: 2.0048 - lr: 0.0010
# Epoch 269/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1517 - mae: 0.4805 - val_loss: 9.3147 - val_mae: 2.0046 - lr: 0.0010
# Epoch 270/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1516 - mae: 0.4805 - val_loss: 9.3129 - val_mae: 2.0042 - lr: 0.0010
# Epoch 271/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1515 - mae: 0.4804 - val_loss: 9.3118 - val_mae: 2.0039 - lr: 0.0010
# Epoch 272/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1513 - mae: 0.4803 - val_loss: 9.3101 - val_mae: 2.0036 - lr: 0.0010
# Epoch 273/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1512 - mae: 0.4802 - val_loss: 9.3088 - val_mae: 2.0032 - lr: 0.0010
# Epoch 274/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1512 - mae: 0.4803 - val_loss: 9.3075 - val_mae: 2.0031 - lr: 0.0010
# Epoch 275/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1511 - mae: 0.4802 - val_loss: 9.3062 - val_mae: 2.0028 - lr: 0.0010
# Epoch 276/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1509 - mae: 0.4801 - val_loss: 9.3048 - val_mae: 2.0025 - lr: 0.0010
# Epoch 277/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1508 - mae: 0.4801 - val_loss: 9.3036 - val_mae: 2.0022 - lr: 0.0010
# Epoch 278/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1507 - mae: 0.4801 - val_loss: 9.3023 - val_mae: 2.0020 - lr: 0.0010
# Epoch 279/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1506 - mae: 0.4799 - val_loss: 9.3012 - val_mae: 2.0017 - lr: 0.0010
# Epoch 280/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1505 - mae: 0.4799 - val_loss: 9.2997 - val_mae: 2.0014 - lr: 0.0010
# Epoch 281/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1504 - mae: 0.4798 - val_loss: 9.2984 - val_mae: 2.0010 - lr: 0.0010
# Epoch 282/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1503 - mae: 0.4798 - val_loss: 9.2973 - val_mae: 2.0009 - lr: 0.0010
# Epoch 283/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1502 - mae: 0.4797 - val_loss: 9.2963 - val_mae: 2.0007 - lr: 0.0010
# Epoch 284/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1502 - mae: 0.4798 - val_loss: 9.2949 - val_mae: 2.0004 - lr: 0.0010
# Epoch 285/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1501 - mae: 0.4796 - val_loss: 9.2936 - val_mae: 2.0001 - lr: 0.0010
# Epoch 286/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1500 - mae: 0.4797 - val_loss: 9.2927 - val_mae: 1.9999 - lr: 0.0010
# Epoch 287/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1498 - mae: 0.4796 - val_loss: 9.2913 - val_mae: 1.9996 - lr: 0.0010
# Epoch 288/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1498 - mae: 0.4796 - val_loss: 9.2902 - val_mae: 1.9993 - lr: 0.0010
# Epoch 289/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1496 - mae: 0.4794 - val_loss: 9.2889 - val_mae: 1.9990 - lr: 0.0010
# Epoch 290/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1496 - mae: 0.4794 - val_loss: 9.2878 - val_mae: 1.9988 - lr: 0.0010
# Epoch 291/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1494 - mae: 0.4793 - val_loss: 9.2866 - val_mae: 1.9986 - lr: 0.0010
# Epoch 292/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1494 - mae: 0.4792 - val_loss: 9.2855 - val_mae: 1.9983 - lr: 0.0010
# Epoch 293/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1493 - mae: 0.4792 - val_loss: 9.2843 - val_mae: 1.9981 - lr: 0.0010
# Epoch 294/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1492 - mae: 0.4793 - val_loss: 9.2833 - val_mae: 1.9979 - lr: 0.0010
# Epoch 295/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1491 - mae: 0.4792 - val_loss: 9.2821 - val_mae: 1.9976 - lr: 0.0010
# Epoch 296/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1490 - mae: 0.4791 - val_loss: 9.2810 - val_mae: 1.9973 - lr: 0.0010
# Epoch 297/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1489 - mae: 0.4790 - val_loss: 9.2798 - val_mae: 1.9971 - lr: 0.0010
# Epoch 298/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1488 - mae: 0.4791 - val_loss: 9.2789 - val_mae: 1.9970 - lr: 0.0010
# Epoch 299/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1488 - mae: 0.4790 - val_loss: 9.2779 - val_mae: 1.9967 - lr: 0.0010
# Epoch 300/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1487 - mae: 0.4790 - val_loss: 9.2769 - val_mae: 1.9965 - lr: 0.0010
# Epoch 301/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1486 - mae: 0.4789 - val_loss: 9.2757 - val_mae: 1.9962 - lr: 0.0010
# Epoch 302/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1485 - mae: 0.4788 - val_loss: 9.2746 - val_mae: 1.9960 - lr: 0.0010
# Epoch 303/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1485 - mae: 0.4789 - val_loss: 9.2736 - val_mae: 1.9957 - lr: 0.0010
# Epoch 304/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1483 - mae: 0.4788 - val_loss: 9.2725 - val_mae: 1.9956 - lr: 0.0010
# Epoch 305/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1483 - mae: 0.4788 - val_loss: 9.2717 - val_mae: 1.9954 - lr: 0.0010
# Epoch 306/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1481 - mae: 0.4786 - val_loss: 9.2703 - val_mae: 1.9951 - lr: 0.0010
# Epoch 307/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1481 - mae: 0.4786 - val_loss: 9.2693 - val_mae: 1.9949 - lr: 0.0010
# Epoch 308/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1480 - mae: 0.4786 - val_loss: 9.2684 - val_mae: 1.9947 - lr: 0.0010
# Epoch 309/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1479 - mae: 0.4786 - val_loss: 9.2672 - val_mae: 1.9944 - lr: 0.0010
# Epoch 310/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1478 - mae: 0.4785 - val_loss: 9.2664 - val_mae: 1.9943 - lr: 0.0010
# Epoch 311/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1477 - mae: 0.4784 - val_loss: 9.2654 - val_mae: 1.9941 - lr: 0.0010
# Epoch 312/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1477 - mae: 0.4784 - val_loss: 9.2645 - val_mae: 1.9938 - lr: 0.0010
# Epoch 313/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1476 - mae: 0.4784 - val_loss: 9.2631 - val_mae: 1.9935 - lr: 0.0010
# Epoch 314/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1475 - mae: 0.4783 - val_loss: 9.2626 - val_mae: 1.9934 - lr: 0.0010
# Epoch 315/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1474 - mae: 0.4783 - val_loss: 9.2612 - val_mae: 1.9932 - lr: 0.0010
# Epoch 316/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1473 - mae: 0.4782 - val_loss: 9.2603 - val_mae: 1.9930 - lr: 0.0010
# Epoch 317/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1473 - mae: 0.4782 - val_loss: 9.2593 - val_mae: 1.9927 - lr: 0.0010
# Epoch 318/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1472 - mae: 0.4782 - val_loss: 9.2583 - val_mae: 1.9926 - lr: 0.0010
# Epoch 319/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1471 - mae: 0.4782 - val_loss: 9.2575 - val_mae: 1.9924 - lr: 0.0010
# Epoch 320/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1470 - mae: 0.4780 - val_loss: 9.2564 - val_mae: 1.9921 - lr: 0.0010
# Epoch 321/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1470 - mae: 0.4781 - val_loss: 9.2555 - val_mae: 1.9919 - lr: 0.0010
# Epoch 322/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1469 - mae: 0.4780 - val_loss: 9.2547 - val_mae: 1.9918 - lr: 0.0010
# Epoch 323/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1467 - mae: 0.4779 - val_loss: 9.2536 - val_mae: 1.9915 - lr: 0.0010
# Epoch 324/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1467 - mae: 0.4779 - val_loss: 9.2530 - val_mae: 1.9914 - lr: 0.0010
# Epoch 325/500
# ...
# Epoch 394/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1421 - mae: 0.4752 - val_loss: 9.1984 - val_mae: 1.9797 - lr: 0.0010
# Epoch 395/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1420 - mae: 0.4752 - val_loss: 9.1973 - val_mae: 1.9794 - lr: 0.0010
# Epoch 396/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1420 - mae: 0.4752 - val_loss: 9.1971 - val_mae: 1.9793 - lr: 0.0010
# Epoch 397/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1419 - mae: 0.4752 - val_loss: 9.1963 - val_mae: 1.9791 - lr: 0.0010
# Epoch 398/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1419 - mae: 0.4752 - val_loss: 9.1957 - val_mae: 1.9791 - lr: 0.0010
# Epoch 399/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1418 - mae: 0.4751 - val_loss: 9.1949 - val_mae: 1.9789 - lr: 0.0010
# Epoch 400/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1418 - mae: 0.4752 - val_loss: 9.1944 - val_mae: 1.9788 - lr: 0.0010
# Epoch 401/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1417 - mae: 0.4751 - val_loss: 9.1933 - val_mae: 1.9785 - lr: 0.0010
# Epoch 402/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1417 - mae: 0.4750 - val_loss: 9.1931 - val_mae: 1.9786 - lr: 0.0010
# Epoch 403/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1416 - mae: 0.4750 - val_loss: 9.1926 - val_mae: 1.9785 - lr: 0.0010
# Epoch 404/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1417 - mae: 0.4751 - val_loss: 9.1918 - val_mae: 1.9782 - lr: 0.0010
# Epoch 405/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1415 - mae: 0.4750 - val_loss: 9.1914 - val_mae: 1.9782 - lr: 0.0010
# Epoch 406/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1415 - mae: 0.4749 - val_loss: 9.1907 - val_mae: 1.9779 - lr: 0.0010
# Epoch 407/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1414 - mae: 0.4748 - val_loss: 9.1900 - val_mae: 1.9779 - lr: 0.0010
# Epoch 408/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1414 - mae: 0.4748 - val_loss: 9.1893 - val_mae: 1.9778 - lr: 0.0010
# Epoch 409/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1413 - mae: 0.4749 - val_loss: 9.1887 - val_mae: 1.9775 - lr: 0.0010
# Epoch 410/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1413 - mae: 0.4747 - val_loss: 9.1882 - val_mae: 1.9775 - lr: 0.0010
# Epoch 411/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1412 - mae: 0.4747 - val_loss: 9.1875 - val_mae: 1.9772 - lr: 0.0010
# Epoch 412/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1412 - mae: 0.4748 - val_loss: 9.1872 - val_mae: 1.9773 - lr: 0.0010
# Epoch 413/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1411 - mae: 0.4747 - val_loss: 9.1861 - val_mae: 1.9770 - lr: 0.0010
# Epoch 414/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1411 - mae: 0.4747 - val_loss: 9.1856 - val_mae: 1.9768 - lr: 0.0010
# Epoch 415/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1410 - mae: 0.4746 - val_loss: 9.1849 - val_mae: 1.9767 - lr: 0.0010
# Epoch 416/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1409 - mae: 0.4745 - val_loss: 9.1842 - val_mae: 1.9765 - lr: 0.0010
# Epoch 417/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1409 - mae: 0.4746 - val_loss: 9.1837 - val_mae: 1.9764 - lr: 0.0010
# Epoch 418/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1408 - mae: 0.4745 - val_loss: 9.1831 - val_mae: 1.9764 - lr: 0.0010
# Epoch 419/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1408 - mae: 0.4745 - val_loss: 9.1825 - val_mae: 1.9762 - lr: 0.0010
# Epoch 420/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1407 - mae: 0.4745 - val_loss: 9.1818 - val_mae: 1.9760 - lr: 0.0010
# Epoch 421/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1407 - mae: 0.4744 - val_loss: 9.1812 - val_mae: 1.9760 - lr: 0.0010
# Epoch 422/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1407 - mae: 0.4744 - val_loss: 9.1806 - val_mae: 1.9758 - lr: 0.0010
# Epoch 423/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1406 - mae: 0.4744 - val_loss: 9.1800 - val_mae: 1.9756 - lr: 0.0010
# Epoch 424/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1406 - mae: 0.4744 - val_loss: 9.1793 - val_mae: 1.9755 - lr: 0.0010
# Epoch 425/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1405 - mae: 0.4743 - val_loss: 9.1787 - val_mae: 1.9754 - lr: 0.0010
# Epoch 426/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1404 - mae: 0.4742 - val_loss: 9.1782 - val_mae: 1.9752 - lr: 0.0010
# Epoch 427/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1404 - mae: 0.4743 - val_loss: 9.1775 - val_mae: 1.9751 - lr: 0.0010
# Epoch 428/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1404 - mae: 0.4743 - val_loss: 9.1771 - val_mae: 1.9750 - lr: 0.0010
# Epoch 429/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1403 - mae: 0.4742 - val_loss: 9.1764 - val_mae: 1.9749 - lr: 0.0010
# Epoch 430/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1402 - mae: 0.4742 - val_loss: 9.1759 - val_mae: 1.9748 - lr: 0.0010
# Epoch 431/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1402 - mae: 0.4742 - val_loss: 9.1752 - val_mae: 1.9746 - lr: 0.0010
# Epoch 432/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1402 - mae: 0.4741 - val_loss: 9.1748 - val_mae: 1.9746 - lr: 0.0010
# Epoch 433/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1401 - mae: 0.4742 - val_loss: 9.1743 - val_mae: 1.9745 - lr: 0.0010
# Epoch 434/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1401 - mae: 0.4740 - val_loss: 9.1733 - val_mae: 1.9741 - lr: 0.0010
# Epoch 435/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1400 - mae: 0.4740 - val_loss: 9.1731 - val_mae: 1.9742 - lr: 0.0010
# Epoch 436/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1399 - mae: 0.4740 - val_loss: 9.1725 - val_mae: 1.9740 - lr: 0.0010
# Epoch 437/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1399 - mae: 0.4739 - val_loss: 9.1717 - val_mae: 1.9739 - lr: 0.0010
# Epoch 438/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1399 - mae: 0.4740 - val_loss: 9.1713 - val_mae: 1.9738 - lr: 0.0010
# Epoch 439/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1398 - mae: 0.4739 - val_loss: 9.1709 - val_mae: 1.9737 - lr: 0.0010
# Epoch 440/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1397 - mae: 0.4738 - val_loss: 9.1700 - val_mae: 1.9736 - lr: 0.0010
# Epoch 441/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1398 - mae: 0.4739 - val_loss: 9.1695 - val_mae: 1.9734 - lr: 0.0010
# Epoch 442/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1397 - mae: 0.4738 - val_loss: 9.1689 - val_mae: 1.9732 - lr: 0.0010
# Epoch 443/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1396 - mae: 0.4737 - val_loss: 9.1683 - val_mae: 1.9731 - lr: 0.0010
# Epoch 444/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1396 - mae: 0.4738 - val_loss: 9.1678 - val_mae: 1.9730 - lr: 0.0010
# Epoch 445/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1395 - mae: 0.4738 - val_loss: 9.1672 - val_mae: 1.9728 - lr: 0.0010
# Epoch 446/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1394 - mae: 0.4736 - val_loss: 9.1669 - val_mae: 1.9728 - lr: 0.0010
# Epoch 447/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1394 - mae: 0.4737 - val_loss: 9.1660 - val_mae: 1.9726 - lr: 0.0010
# Epoch 448/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1394 - mae: 0.4736 - val_loss: 9.1655 - val_mae: 1.9725 - lr: 0.0010
# Epoch 449/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1394 - mae: 0.4737 - val_loss: 9.1652 - val_mae: 1.9724 - lr: 0.0010
# Epoch 450/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1393 - mae: 0.4735 - val_loss: 9.1646 - val_mae: 1.9724 - lr: 0.0010
# Epoch 451/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1392 - mae: 0.4736 - val_loss: 9.1640 - val_mae: 1.9722 - lr: 0.0010
# Epoch 452/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1392 - mae: 0.4735 - val_loss: 9.1633 - val_mae: 1.9721 - lr: 0.0010
# Epoch 453/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1392 - mae: 0.4735 - val_loss: 9.1629 - val_mae: 1.9720 - lr: 0.0010
# Epoch 454/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1391 - mae: 0.4735 - val_loss: 9.1622 - val_mae: 1.9719 - lr: 0.0010
# Epoch 455/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1391 - mae: 0.4735 - val_loss: 9.1617 - val_mae: 1.9717 - lr: 0.0010
# Epoch 456/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1390 - mae: 0.4734 - val_loss: 9.1612 - val_mae: 1.9715 - lr: 0.0010
# Epoch 457/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1390 - mae: 0.4735 - val_loss: 9.1605 - val_mae: 1.9714 - lr: 0.0010
# Epoch 458/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1389 - mae: 0.4733 - val_loss: 9.1602 - val_mae: 1.9714 - lr: 0.0010
# Epoch 459/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1389 - mae: 0.4733 - val_loss: 9.1596 - val_mae: 1.9713 - lr: 0.0010
# Epoch 460/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1389 - mae: 0.4734 - val_loss: 9.1590 - val_mae: 1.9712 - lr: 0.0010
# Epoch 461/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1388 - mae: 0.4733 - val_loss: 9.1587 - val_mae: 1.9711 - lr: 0.0010
# Epoch 462/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1388 - mae: 0.4733 - val_loss: 9.1580 - val_mae: 1.9708 - lr: 0.0010
# Epoch 463/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1387 - mae: 0.4732 - val_loss: 9.1572 - val_mae: 1.9706 - lr: 0.0010
# Epoch 464/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1387 - mae: 0.4733 - val_loss: 9.1569 - val_mae: 1.9707 - lr: 0.0010
# Epoch 465/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1386 - mae: 0.4731 - val_loss: 9.1561 - val_mae: 1.9705 - lr: 0.0010
# Epoch 466/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1386 - mae: 0.4733 - val_loss: 9.1558 - val_mae: 1.9704 - lr: 0.0010
# Epoch 467/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1385 - mae: 0.4731 - val_loss: 9.1551 - val_mae: 1.9702 - lr: 0.0010
# Epoch 468/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1385 - mae: 0.4732 - val_loss: 9.1549 - val_mae: 1.9702 - lr: 0.0010
# Epoch 469/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1384 - mae: 0.4731 - val_loss: 9.1542 - val_mae: 1.9701 - lr: 0.0010
# Epoch 470/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1384 - mae: 0.4731 - val_loss: 9.1536 - val_mae: 1.9699 - lr: 0.0010
# Epoch 471/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1384 - mae: 0.4731 - val_loss: 9.1533 - val_mae: 1.9699 - lr: 0.0010
# Epoch 472/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1383 - mae: 0.4730 - val_loss: 9.1527 - val_mae: 1.9697 - lr: 0.0010
# Epoch 473/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1383 - mae: 0.4730 - val_loss: 9.1524 - val_mae: 1.9697 - lr: 0.0010
# Epoch 474/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1382 - mae: 0.4729 - val_loss: 9.1516 - val_mae: 1.9695 - lr: 0.0010
# Epoch 475/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1382 - mae: 0.4730 - val_loss: 9.1511 - val_mae: 1.9694 - lr: 0.0010
# Epoch 476/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1381 - mae: 0.4729 - val_loss: 9.1506 - val_mae: 1.9692 - lr: 0.0010
# Epoch 477/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1381 - mae: 0.4729 - val_loss: 9.1499 - val_mae: 1.9691 - lr: 0.0010
# Epoch 478/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1380 - mae: 0.4728 - val_loss: 9.1496 - val_mae: 1.9690 - lr: 0.0010
# Epoch 479/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1380 - mae: 0.4728 - val_loss: 9.1491 - val_mae: 1.9689 - lr: 0.0010
# Epoch 480/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1379 - mae: 0.4728 - val_loss: 9.1484 - val_mae: 1.9688 - lr: 0.0010
# Epoch 481/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1379 - mae: 0.4727 - val_loss: 9.1481 - val_mae: 1.9688 - lr: 0.0010
# Epoch 482/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1379 - mae: 0.4728 - val_loss: 9.1476 - val_mae: 1.9686 - lr: 0.0010
# Epoch 483/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1378 - mae: 0.4727 - val_loss: 9.1470 - val_mae: 1.9685 - lr: 0.0010
# Epoch 484/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1378 - mae: 0.4727 - val_loss: 9.1467 - val_mae: 1.9683 - lr: 0.0010
# Epoch 485/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1377 - mae: 0.4726 - val_loss: 9.1458 - val_mae: 1.9682 - lr: 0.0010
# Epoch 486/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1377 - mae: 0.4727 - val_loss: 9.1455 - val_mae: 1.9681 - lr: 0.0010
# Epoch 487/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1377 - mae: 0.4726 - val_loss: 9.1451 - val_mae: 1.9681 - lr: 0.0010
# Epoch 488/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1376 - mae: 0.4726 - val_loss: 9.1443 - val_mae: 1.9679 - lr: 0.0010
# Epoch 489/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1376 - mae: 0.4726 - val_loss: 9.1437 - val_mae: 1.9677 - lr: 0.0010
# Epoch 490/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1375 - mae: 0.4725 - val_loss: 9.1435 - val_mae: 1.9677 - lr: 0.0010
# Epoch 491/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1375 - mae: 0.4725 - val_loss: 9.1428 - val_mae: 1.9676 - lr: 0.0010
# Epoch 492/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1375 - mae: 0.4726 - val_loss: 9.1426 - val_mae: 1.9675 - lr: 0.0010
# Epoch 493/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1374 - mae: 0.4724 - val_loss: 9.1419 - val_mae: 1.9674 - lr: 0.0010
# Epoch 494/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1374 - mae: 0.4724 - val_loss: 9.1416 - val_mae: 1.9673 - lr: 0.0010
# Epoch 495/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1373 - mae: 0.4724 - val_loss: 9.1407 - val_mae: 1.9671 - lr: 0.0010
# Epoch 496/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1373 - mae: 0.4724 - val_loss: 9.1405 - val_mae: 1.9670 - lr: 0.0010
# Epoch 497/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1373 - mae: 0.4724 - val_loss: 9.1398 - val_mae: 1.9668 - lr: 0.0010
# Epoch 498/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1372 - mae: 0.4723 - val_loss: 9.1393 - val_mae: 1.9668 - lr: 0.0010
# Epoch 499/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1372 - mae: 0.4724 - val_loss: 9.1388 - val_mae: 1.9667 - lr: 0.0010
# Epoch 500/500
# 721/721 [==============================] - 6s 8ms/step - loss: 3.1371 - mae: 0.4723 - val_loss: 9.1385 - val_mae: 1.9666 - lr: 0.0010
# CPU times: user 55min 5s, sys: 4min 15s, total: 59min 20s
# Wall time: 48min 56s

# %%
y_true = ratings_test
predictions = model.predict([user_ids_test, item_ids_test])
# Out:
# 30004/30004 [==============================] - 38s 1ms/step

# %%
# Evaluar el modelo con el conjunto de prueba
loss, mae = model.evaluate([user_ids_test, item_ids_test], ratings_test)
print(f'Test Loss: {loss:.4f}')
print(f'Test MAE: {mae:.4f}')
# Out:
# 30004/30004 [==============================] - 76s 3ms/step - loss: 9.1242 - mae: 1.9637
# Test Loss: 9.1242
# Test MAE: 1.9637

# %%
# MSE
mse = mean_squared_error(y_true, predictions)
print(f"MSE: {mse:.4f}")

# RMSE
rmse = np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

# MAE
mae = mean_absolute_error(y_true, predictions)
print(f"MAE: {mae:.4f}")

# MAPE (Mean Absolute Percentage Error)
mape = np.mean(np.abs((y_true - predictions.flatten()) / y_true)) * 100
print(f"MAPE: {mape:.2f}%")
# Out:
# MSE: 6.4623
# RMSE: 2.5421
# MAE: 1.9637
# MAPE: 50.38%

# %% [markdown]
# # Recomedanción

# %%
# Seleccionar un usuario al azar del conjunto de prueba
usuario_id_test_encoded = random.choice(user_ids_test)

# Decodificar el ID del usuario para obtener el ID original
usuario_id_test = reviewerID_encoder.inverse_transform([usuario_id_test_encoded])[0]

# Identificar los ítems que el usuario ha calificado en el conjunto de prueba
indices_usuario = np.where(user_ids_test == usuario_id_test_encoded)[0]
items_calificados_test_encoded = item_ids_test[indices_usuario]
calificaciones_reales_test = ratings_test[indices_usuario]

# Predecir las calificaciones para estos ítems
calificaciones_predichas = model.predict([np.array([usuario_id_test_encoded] * len(items_calificados_test_encoded)), items_calificados_test_encoded])

# Decodificar los ítems para obtener los ID originales
items_calificados_test = asin_encoder.inverse_transform(items_calificados_test_encoded)

# Comparar las calificaciones predichas con las reales
comparacion = list(zip(items_calificados_test, calificaciones_reales_test, calificaciones_predichas.flatten()))

# Mostrar las comparaciones
print(f"Recomendaciones para el usuario {usuario_id_test}:")
for item, real, predicha in comparacion:
    print(f"Ítem: {item}, Calificación Real: {real}, Calificación Predicha: {predicha}")
# Out:
# 1/1 [==============================] - 0s 23ms/step
# Recomendaciones para el usuario A31AEV5KD0F33C:
# Ítem: B00PZCGO8A, Calificación Real: 4.0, Calificación Predicha: 3.548981189727783
# Ítem: B007ETGIN8, Calificación Real: 5.0, Calificación Predicha: 1.5961138010025024

# %%
# Seleccionar un usuario al azar del conjunto de prueba
usuario_id_test_encoded = random.choice(user_ids_test)

# Decodificar el ID del usuario para obtener el ID original
usuario_id = reviewerID_encoder.inverse_transform([usuario_id_test_encoded])[0]

# Lista de todos los ítems únicos en el dataset
items_unicos = np.unique(data['asin'].values)

# Ítems que el usuario ya ha calificado
items_calificados = data[data['reviewerID_encoded'] == usuario_id_test_encoded]['asin'].tolist()

# Ítems para predecir
items_a_predecir = [item for item in items_unicos if item not in items_calificados]

# Convierte los ítems a su representación codificada
items_a_predecir_encoded = asin_encoder.transform(items_a_predecir)

# Predecir la calificación para cada ítem no calificado
predicciones = model.predict([np.array([usuario_id_test_encoded] * len(items_a_predecir_encoded)), items_a_predecir_encoded])

# Emparejar cada ítem con su predicción
items_predicciones = list(zip(items_a_predecir, predicciones.flatten()))

# Ordenar por la calificación predicha más alta
items_recomendados = sorted(items_predicciones, key=lambda x: x[1], reverse=True)

# Tomar los top N recomendaciones
top_n = 5
top_recomendaciones = items_recomendados[:top_n]

# Imprimir las recomendaciones
print(f"Recomendaciones para el usuario {usuario_id}:")
for item, calificacion in top_recomendaciones:
    print(f"Ítem: {item}, Calificación Predicha: {calificacion}")
# Out:
# 4814/4814 [==============================] - 6s 1ms/step
# Recomendaciones para el usuario A1W55Q5MSLHKXP:
# Ítem: B0011FMDU8, Calificación Predicha: 8.632620811462402
# Ítem: B00095LIP2, Calificación Predicha: 8.574142456054688
# Ítem: B004XMAVFA, Calificación Predicha: 8.56313419342041
# Ítem: B0001EL9BO, Calificación Predicha: 8.562400817871094
# Ítem: B00YBILO5M, Calificación Predicha: 8.41357135772705

# %% [markdown]
# # Modelo de Filtrado Colaborativo usando Red Neuronal Multicapa con Keras:

# %% [markdown]
# Funcionamiento:
#
# Estos sistemas toman características de los ítems y/o usuarios y las pasan a través de una o varias capas de neuronas para obtener una predicción.
# Las redes neuronales son capaces de capturar interacciones no lineales entre características, lo que las hace poderosas para tareas de modelado complejas.
#
# Ventajas:
#
# Capacidad de modelar relaciones no lineales.
#
# Flexibilidad para incorporar múltiples fuentes de datos o características.
#
# Puede manejar arranques en frío al incorporar características de nuevos ítems o usuarios.
#
# Desventajas:
#
# Mayor costo computacional en comparación con los sistemas basados únicamente en embeddings.
#
# Riesgo de sobreajuste si no se tiene un conjunto de datos lo suficientemente grande.

# %% [markdown]
# Ahora el código incluye regularización en los embeddings, early stopping para detener el entrenamiento si el modelo deja de mejorar en el conjunto de validación, y reducción de la tasa de aprendizaje si el error en el conjunto de validación no mejora después de algunas épocas. Estas adiciones deberían ayudar a mejorar la capacidad de generalización del modelo.

# %%
df['user_id'] = df['reviewerID'].astype('category').cat.codes.values
df['item_id'] = df['asin'].astype('category').cat.codes.values

# Número de usuarios e ítems
n_users = df['user_id'].nunique()
n_items = df['item_id'].nunique()

# Hiperparámetros
hidden_units = [128, 64, 32]
dropout_rate = 0.2
l2_reg = 1e-6

# Arquitectura del modelo
user_input = Input(shape=[1], name='user_input')
item_input = Input(shape=[1], name='item_input')
concat = Concatenate()([user_input, item_input])
dense = concat
for units in hidden_units:
    dense = Dense(units, activation='relu', kernel_regularizer=l2(l2_reg))(dense)
    dense = Dropout(dropout_rate)(dense)
output = Dense(1, kernel_regularizer=l2(l2_reg))(dense)  # También puedes aplicar regularización L2 aquí
model = Model(inputs=[user_input, item_input], outputs=output)
model.compile(optimizer=Adam(0.001), loss='mean_squared_error')

# %%
# Callbacks
early_stop = EarlyStopping(monitor='val_loss', patience=50)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=50, min_lr=1e-5)

# %%
# Datos para entrenamiento
user_data = df['user_id'].values
item_data = df['item_id'].values
rating_data = df['overall'].values

# División en entrenamiento y prueba
(user_ids_temp, user_ids_test, item_ids_temp, item_ids_test, ratings_temp, ratings_test) = train_test_split(
    user_ids, item_ids, ratings, test_size=0.2, random_state=42)

# División del conjunto de entrenamiento en entrenamiento y validación
(user_ids_train, user_ids_val, item_ids_train, item_ids_val, ratings_train, ratings_val) = train_test_split(
    user_ids_temp, item_ids_temp, ratings_temp, test_size=0.25, random_state=42)  # 0.25 x 0.8 = 0.2

# %%
# %%time
# Entrenamiento del modelo
history = model.fit([user_ids_train, item_ids_train], ratings_train,
    epochs=500,validation_data=([user_ids_val, item_ids_val], ratings_val),
    batch_size=4000,verbose=1,callbacks=[early_stop, reduce_lr])
# Out:
# Epoch 1/500
# 721/721 [==============================] - 5s 4ms/step - loss: 43945600.0000 - val_loss: 16.8753 - lr: 0.0010
# Epoch 2/500
# 721/721 [==============================] - 3s 4ms/step - loss: 77311.2812 - val_loss: 13.8195 - lr: 0.0010
# Epoch 3/500
# 721/721 [==============================] - 3s 4ms/step - loss: 42356.9336 - val_loss: 12.8923 - lr: 0.0010
# Epoch 4/500
# 721/721 [==============================] - 3s 4ms/step - loss: 22057.4473 - val_loss: 13.1577 - lr: 0.0010
# Epoch 5/500
# 721/721 [==============================] - 3s 4ms/step - loss: 9338.9551 - val_loss: 9.1143 - lr: 0.0010
# Epoch 6/500
# 721/721 [==============================] - 3s 4ms/step - loss: 3337.4443 - val_loss: 13.1768 - lr: 0.0010
# Epoch 7/500
# 721/721 [==============================] - 3s 4ms/step - loss: 3038.2141 - val_loss: 6.9866 - lr: 0.0010
# Epoch 8/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1930.2004 - val_loss: 8.1117 - lr: 0.0010
# Epoch 9/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1374.8021 - val_loss: 6.4667 - lr: 0.0010
# Epoch 10/500
# 721/721 [==============================] - 3s 4ms/step - loss: 854.5339 - val_loss: 8.5380 - lr: 0.0010
# Epoch 11/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1260.1899 - val_loss: 8.2179 - lr: 0.0010
# Epoch 12/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1024.1371 - val_loss: 5.8713 - lr: 0.0010
# Epoch 13/500
# 721/721 [==============================] - 3s 4ms/step - loss: 630.4005 - val_loss: 8.4055 - lr: 0.0010
# Epoch 14/500
# 721/721 [==============================] - 3s 4ms/step - loss: 573.8187 - val_loss: 10.2145 - lr: 0.0010
# Epoch 15/500
# 721/721 [==============================] - 3s 4ms/step - loss: 433.0423 - val_loss: 7.7370 - lr: 0.0010
# Epoch 16/500
# 721/721 [==============================] - 3s 4ms/step - loss: 238.1620 - val_loss: 5.4184 - lr: 0.0010
# Epoch 17/500
# 721/721 [==============================] - 3s 4ms/step - loss: 274.4493 - val_loss: 2.9881 - lr: 0.0010
# Epoch 18/500
# 721/721 [==============================] - 3s 4ms/step - loss: 83.6876 - val_loss: 2.4776 - lr: 0.0010
# Epoch 19/500
# 721/721 [==============================] - 3s 4ms/step - loss: 106.9719 - val_loss: 1.8889 - lr: 0.0010
# Epoch 20/500
# 721/721 [==============================] - 3s 4ms/step - loss: 22.7716 - val_loss: 1.5075 - lr: 0.0010
# Epoch 21/500
# 721/721 [==============================] - 3s 4ms/step - loss: 42.7709 - val_loss: 1.3826 - lr: 0.0010
# Epoch 22/500
# 721/721 [==============================] - 3s 4ms/step - loss: 24.5678 - val_loss: 1.3578 - lr: 0.0010
# Epoch 23/500
# 721/721 [==============================] - 3s 4ms/step - loss: 42.6378 - val_loss: 1.3556 - lr: 0.0010
# Epoch 24/500
# 721/721 [==============================] - 3s 4ms/step - loss: 6.9308 - val_loss: 1.3555 - lr: 0.0010
# Epoch 25/500
# 721/721 [==============================] - 3s 4ms/step - loss: 15.6515 - val_loss: 1.3555 - lr: 0.0010
# Epoch 26/500
# 721/721 [==============================] - 3s 4ms/step - loss: 208.0248 - val_loss: 1.3555 - lr: 0.0010
# Epoch 27/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.8916 - val_loss: 1.3555 - lr: 0.0010
# Epoch 28/500
# 721/721 [==============================] - 3s 4ms/step - loss: 58.9011 - val_loss: 1.3555 - lr: 0.0010
# Epoch 29/500
# 721/721 [==============================] - 3s 4ms/step - loss: 2.0904 - val_loss: 1.3555 - lr: 0.0010
# Epoch 30/500
# 721/721 [==============================] - 3s 4ms/step - loss: 444.1311 - val_loss: 1.3556 - lr: 0.0010
# Epoch 31/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3864 - val_loss: 1.3555 - lr: 0.0010
# Epoch 32/500
# 721/721 [==============================] - 3s 4ms/step - loss: 2.5110 - val_loss: 1.3555 - lr: 0.0010
# Epoch 33/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.4472 - val_loss: 1.3555 - lr: 0.0010
# Epoch 34/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3869 - val_loss: 1.3555 - lr: 0.0010
# Epoch 35/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3611 - val_loss: 1.3555 - lr: 0.0010
# Epoch 36/500
# 721/721 [==============================] - 3s 4ms/step - loss: 4.8092 - val_loss: 1.3555 - lr: 0.0010
# Epoch 37/500
# 721/721 [==============================] - 3s 4ms/step - loss: 8.1917 - val_loss: 1.3555 - lr: 0.0010
# Epoch 38/500
# 721/721 [==============================] - 3s 4ms/step - loss: 11.9340 - val_loss: 1.3555 - lr: 0.0010
# Epoch 39/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3612 - val_loss: 1.3555 - lr: 0.0010
# Epoch 40/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3621 - val_loss: 1.3555 - lr: 0.0010
# Epoch 41/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3616 - val_loss: 1.3555 - lr: 0.0010
# Epoch 42/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.6209 - val_loss: 1.3555 - lr: 0.0010
# Epoch 43/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3611 - val_loss: 1.3555 - lr: 0.0010
# Epoch 44/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.4721 - val_loss: 1.3555 - lr: 0.0010
# Epoch 45/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.4215 - val_loss: 1.3555 - lr: 0.0010
# Epoch 46/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3611 - val_loss: 1.3555 - lr: 0.0010
# Epoch 47/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.4609 - val_loss: 1.3555 - lr: 0.0010
# Epoch 48/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.4456 - val_loss: 1.3556 - lr: 0.0010
# Epoch 49/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3612 - val_loss: 1.3555 - lr: 0.0010
# Epoch 50/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3611 - val_loss: 1.3555 - lr: 0.0010
# Epoch 51/500
# 721/721 [==============================] - 3s 4ms/step - loss: 4.7909 - val_loss: 1.3556 - lr: 0.0010
# Epoch 52/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3641 - val_loss: 1.3555 - lr: 0.0010
# Epoch 53/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.5208 - val_loss: 1.3555 - lr: 0.0010
# Epoch 54/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3611 - val_loss: 1.3555 - lr: 0.0010
# Epoch 55/500
# 721/721 [==============================] - 3s 4ms/step - loss: 7.1201 - val_loss: 1.3555 - lr: 0.0010
# Epoch 56/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3613 - val_loss: 1.3555 - lr: 0.0010
# Epoch 57/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3611 - val_loss: 1.3555 - lr: 0.0010
# Epoch 58/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3611 - val_loss: 1.3555 - lr: 0.0010
# Epoch 59/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3611 - val_loss: 1.3556 - lr: 0.0010
# Epoch 60/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.6113 - val_loss: 1.3555 - lr: 0.0010
# Epoch 61/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3611 - val_loss: 1.3555 - lr: 0.0010
# Epoch 62/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3625 - val_loss: 1.3555 - lr: 0.0010
# Epoch 63/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.5692 - val_loss: 1.3555 - lr: 0.0010
# Epoch 64/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.4594 - val_loss: 1.3555 - lr: 0.0010
# Epoch 65/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3611 - val_loss: 1.3555 - lr: 0.0010
# Epoch 66/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3611 - val_loss: 1.3555 - lr: 0.0010
# Epoch 67/500
# 721/721 [==============================] - 3s 4ms/step - loss: 2.1728 - val_loss: 1.3555 - lr: 0.0010
# Epoch 68/500
# 721/721 [==============================] - 3s 4ms/step - loss: 4.6890 - val_loss: 1.3555 - lr: 0.0010
# Epoch 69/500
# 721/721 [==============================] - 3s 4ms/step - loss: 12.9733 - val_loss: 1.3555 - lr: 0.0010
# Epoch 70/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3611 - val_loss: 1.3554 - lr: 0.0010
# Epoch 71/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3611 - val_loss: 1.3555 - lr: 0.0010
# Epoch 72/500
# 721/721 [==============================] - 3s 4ms/step - loss: 2.5893 - val_loss: 1.3554 - lr: 0.0010
# Epoch 73/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3630 - val_loss: 1.3554 - lr: 0.0010
# Epoch 74/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3670 - val_loss: 1.3555 - lr: 0.0010
# Epoch 75/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3936 - val_loss: 1.3554 - lr: 0.0010
# Epoch 76/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.7007 - val_loss: 1.3554 - lr: 0.0010
# Epoch 77/500
# 721/721 [==============================] - 3s 4ms/step - loss: 2.9678 - val_loss: 1.3554 - lr: 0.0010
# Epoch 78/500
# 721/721 [==============================] - 3s 4ms/step - loss: 5.6995 - val_loss: 1.3554 - lr: 0.0010
# Epoch 79/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.7465 - val_loss: 1.3554 - lr: 0.0010
# Epoch 80/500
# 721/721 [==============================] - 3s 4ms/step - loss: 8.0215 - val_loss: 1.3561 - lr: 0.0010
# Epoch 81/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.7056 - val_loss: 1.3554 - lr: 0.0010
# Epoch 82/500
# 721/721 [==============================] - 3s 4ms/step - loss: 5.1551 - val_loss: 1.3554 - lr: 0.0010
# Epoch 83/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3612 - val_loss: 1.3554 - lr: 0.0010
# Epoch 84/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.4711 - val_loss: 1.3554 - lr: 0.0010
# Epoch 85/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3611 - val_loss: 1.3554 - lr: 0.0010
# Epoch 86/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3611 - val_loss: 1.3554 - lr: 0.0010
# Epoch 87/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3626 - val_loss: 1.3554 - lr: 0.0010
# Epoch 88/500
# 721/721 [==============================] - 3s 4ms/step - loss: 2.5601 - val_loss: 1.3554 - lr: 0.0010
# Epoch 89/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3613 - val_loss: 1.3554 - lr: 0.0010
# Epoch 90/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3611 - val_loss: 1.3554 - lr: 0.0010
# Epoch 91/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.9354 - val_loss: 1.3555 - lr: 0.0010
# Epoch 92/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3738 - val_loss: 1.3554 - lr: 0.0010
# Epoch 93/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3611 - val_loss: 1.3554 - lr: 0.0010
# Epoch 94/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3623 - val_loss: 1.3554 - lr: 0.0010
# Epoch 95/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3611 - val_loss: 1.3554 - lr: 0.0010
# Epoch 96/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3611 - val_loss: 1.3555 - lr: 0.0010
# Epoch 97/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3612 - val_loss: 1.3554 - lr: 0.0010
# Epoch 98/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3611 - val_loss: 1.3554 - lr: 0.0010
# Epoch 99/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3611 - val_loss: 1.3554 - lr: 0.0010
# Epoch 100/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3622 - val_loss: 1.3554 - lr: 0.0010
# Epoch 101/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3611 - val_loss: 1.3554 - lr: 0.0010
# Epoch 102/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3612 - val_loss: 1.3554 - lr: 0.0010
# Epoch 103/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3611 - val_loss: 1.3554 - lr: 0.0010
# Epoch 104/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3961 - val_loss: 1.3554 - lr: 0.0010
# Epoch 105/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3618 - val_loss: 1.3554 - lr: 0.0010
# Epoch 106/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3764 - val_loss: 1.3554 - lr: 0.0010
# Epoch 107/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3611 - val_loss: 1.3554 - lr: 0.0010
# Epoch 108/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3622 - val_loss: 1.3554 - lr: 0.0010
# Epoch 109/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 0.0010
# Epoch 110/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3625 - val_loss: 1.3554 - lr: 0.0010
# Epoch 111/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 0.0010
# Epoch 112/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3616 - val_loss: 1.3554 - lr: 0.0010
# Epoch 113/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 0.0010
# Epoch 114/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3697 - val_loss: 1.3554 - lr: 0.0010
# Epoch 115/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3611 - val_loss: 1.3554 - lr: 0.0010
# Epoch 116/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3611 - val_loss: 1.3554 - lr: 0.0010
# Epoch 117/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 0.0010
# Epoch 118/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3968 - val_loss: 1.3554 - lr: 0.0010
# Epoch 119/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 0.0010
# Epoch 120/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 2.0000e-04
# Epoch 121/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 2.0000e-04
# Epoch 122/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 2.0000e-04
# Epoch 123/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 2.0000e-04
# Epoch 124/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 2.0000e-04
# Epoch 125/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 2.0000e-04
# Epoch 126/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 2.0000e-04
# Epoch 127/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 2.0000e-04
# Epoch 128/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 2.0000e-04
# Epoch 129/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 2.0000e-04
# Epoch 130/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3613 - val_loss: 1.3554 - lr: 2.0000e-04
# Epoch 131/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 2.0000e-04
# Epoch 132/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 2.0000e-04
# Epoch 133/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 2.0000e-04
# Epoch 134/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 2.0000e-04
# Epoch 135/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3629 - val_loss: 1.3554 - lr: 2.0000e-04
# Epoch 136/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 2.0000e-04
# Epoch 137/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3615 - val_loss: 1.3554 - lr: 2.0000e-04
# Epoch 138/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 2.0000e-04
# Epoch 139/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 2.0000e-04
# Epoch 140/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 2.0000e-04
# Epoch 141/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 2.0000e-04
# Epoch 142/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3612 - val_loss: 1.3554 - lr: 2.0000e-04
# Epoch 143/500
# 721/721 [==============================] - 3s 4ms/step - loss: 11.9723 - val_loss: 1.3554 - lr: 2.0000e-04
# Epoch 144/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3611 - val_loss: 1.3554 - lr: 2.0000e-04
# Epoch 145/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 2.0000e-04
# Epoch 146/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3611 - val_loss: 1.3554 - lr: 2.0000e-04
# Epoch 147/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 2.0000e-04
# Epoch 148/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 2.0000e-04
# Epoch 149/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 2.0000e-04
# Epoch 150/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 2.0000e-04
# Epoch 151/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 2.0000e-04
# Epoch 152/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 2.0000e-04
# Epoch 153/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 2.0000e-04
# Epoch 154/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 2.0000e-04
# Epoch 155/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3613 - val_loss: 1.3554 - lr: 2.0000e-04
# Epoch 156/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 2.0000e-04
# Epoch 157/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 2.0000e-04
# Epoch 158/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 2.0000e-04
# Epoch 159/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 2.0000e-04
# Epoch 160/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 2.0000e-04
# Epoch 161/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 2.0000e-04
# Epoch 162/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 2.0000e-04
# Epoch 163/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 2.0000e-04
# Epoch 164/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 2.0000e-04
# Epoch 165/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 2.0000e-04
# Epoch 166/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 2.0000e-04
# Epoch 167/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 2.0000e-04
# Epoch 168/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 2.0000e-04
# Epoch 169/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 2.0000e-04
# Epoch 170/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 4.0000e-05
# Epoch 171/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 4.0000e-05
# Epoch 172/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3631 - val_loss: 1.3554 - lr: 4.0000e-05
# Epoch 173/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 4.0000e-05
# Epoch 174/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 4.0000e-05
# Epoch 175/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 4.0000e-05
# Epoch 176/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 4.0000e-05
# Epoch 177/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 4.0000e-05
# Epoch 178/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 4.0000e-05
# Epoch 179/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 4.0000e-05
# Epoch 180/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 4.0000e-05
# Epoch 181/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 4.0000e-05
# Epoch 182/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 4.0000e-05
# Epoch 183/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 4.0000e-05
# Epoch 184/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 4.0000e-05
# Epoch 185/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 4.0000e-05
# Epoch 186/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 4.0000e-05
# Epoch 187/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 4.0000e-05
# Epoch 188/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 4.0000e-05
# Epoch 189/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 4.0000e-05
# Epoch 190/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 4.0000e-05
# Epoch 191/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 4.0000e-05
# Epoch 192/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 4.0000e-05
# Epoch 193/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 4.0000e-05
# Epoch 194/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 4.0000e-05
# Epoch 195/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 4.0000e-05
# Epoch 196/500
# 721/721 [==============================] - 3s 4ms/step - loss: 1.3610 - val_loss: 1.3554 - lr: 4.0000e-05
# CPU times: user 13min 9s, sys: 1min 27s, total: 14min 36s
# Wall time: 8min 59s

# %%
# Evaluar el modelo
y_true = ratings_test
predictions = model.predict([user_ids_test, item_ids_test])
# Out:
# 30004/30004 [==============================] - 43s 1ms/step

# %%
# MSE y RMSE
mse = mean_squared_error(y_true, predictions)
rmse = np.sqrt(mse)

# MAE
mae = mean_absolute_error(y_true, predictions)

# Funciones MAPE
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    non_zero_idx = y_true != 0  # Para evitar divisiones por cero
    return np.mean(np.abs((y_true[non_zero_idx] - y_pred[non_zero_idx]) / y_true[non_zero_idx])) * 100

def compute_mape_by_batch(y_true, predictions, batch_size=50000):
    mape_sum = 0
    num_batches = int(np.ceil(len(y_true) / batch_size))

    for i in range(num_batches):
        start_idx = i * batch_size
        end_idx = start_idx + batch_size

        batch_y_true = y_true[start_idx:end_idx]
        batch_predictions = predictions[start_idx:end_idx]

        mape_sum += mean_absolute_percentage_error(batch_y_true, batch_predictions)

    return mape_sum / num_batches

# Luego llamas a la función
mape = compute_mape_by_batch(y_true, predictions)

print(f'MSE: {mse}')
print(f'RMSE: {rmse}')
print(f'MAE: {mae}')
print(f'MAPE: {mape}%')
# Out:
# MSE: 1.3623738197638655
# RMSE: 1.1672077020667169
# MAE: 0.9252364286164066
# MAPE: 38.435976147421854%

# %% [markdown]
# # Recomendación

# %%
# Seleccionar un usuario al azar del conjunto de prueba
usuario_id_test_encoded = random.choice(user_ids_test)

# Decodificar el ID del usuario para obtener el ID original
usuario_id_test = reviewerID_encoder.inverse_transform([usuario_id_test_encoded])[0]

# Identificar los ítems que el usuario ha calificado en el conjunto de prueba
indices_usuario = np.where(user_ids_test == usuario_id_test_encoded)[0]
items_calificados_test_encoded = item_ids_test[indices_usuario]
calificaciones_reales_test = ratings_test[indices_usuario]

# Predecir las calificaciones para estos ítems
calificaciones_predichas = model.predict([np.array([usuario_id_test_encoded] * len(items_calificados_test_encoded)), items_calificados_test_encoded])

# Decodificar los ítems para obtener los ID originales
items_calificados_test = asin_encoder.inverse_transform(items_calificados_test_encoded)

# Comparar las calificaciones predichas con las reales
comparacion = list(zip(items_calificados_test, calificaciones_reales_test, calificaciones_predichas.flatten()))

# Mostrar las comparaciones
print(f"Recomendaciones para el usuario {usuario_id_test}:")
for item, real, predicha in comparacion:
    print(f"Ítem: {item}, Calificación Real: {real}, Calificación Predicha: {predicha}")
# Out:
# 1/1 [==============================] - 0s 20ms/step
# Recomendaciones para el usuario A2PDHB337O69PQ:
# Ítem: B00LCFRY92, Calificación Real: 5.0, Calificación Predicha: 4.259731292724609
# Ítem: B01FD9OCUQ, Calificación Real: 5.0, Calificación Predicha: 4.259731292724609

# %%
# Seleccionar un usuario al azar del conjunto de prueba
usuario_id_test_encoded = random.choice(user_ids_test)

# Decodificar el ID del usuario para obtener el ID original
usuario_id = reviewerID_encoder.inverse_transform([usuario_id_test_encoded])[0]

# Lista de todos los ítems únicos en el dataset
items_unicos = np.unique(data['asin'].values)

# Ítems que el usuario ya ha calificado
items_calificados = data[data['reviewerID_encoded'] == usuario_id_test_encoded]['asin'].tolist()

# Ítems para predecir
items_a_predecir = [item for item in items_unicos if item not in items_calificados]

# Convierte los ítems a su representación codificada
items_a_predecir_encoded = asin_encoder.transform(items_a_predecir)

# Predecir la calificación para cada ítem no calificado
predicciones = model.predict([np.array([usuario_id_test_encoded] * len(items_a_predecir_encoded)), items_a_predecir_encoded])

# Emparejar cada ítem con su predicción
items_predicciones = list(zip(items_a_predecir, predicciones.flatten()))

# Ordenar por la calificación predicha más alta
items_recomendados = sorted(items_predicciones, key=lambda x: x[1], reverse=True)

# Tomar los top N recomendaciones
top_n = 5
top_recomendaciones = items_recomendados[:top_n]

# Imprimir las recomendaciones
print(f"Recomendaciones para el usuario {usuario_id}:")
for item, calificacion in top_recomendaciones:
    print(f"Ítem: {item}, Calificación Predicha: {calificacion}")
# Out:
# 4814/4814 [==============================] - 7s 1ms/step
# Recomendaciones para el usuario A3LHDSNP4ZLV72:
# Ítem: 0871167042, Calificación Predicha: 4.259731292724609
# Ítem: 1519588135, Calificación Predicha: 4.259731292724609
# Ítem: 1579652956, Calificación Predicha: 4.259731292724609
# Ítem: 1936023857, Calificación Predicha: 4.259731292724609
# Ítem: 5120053017, Calificación Predicha: 4.259731292724609

# %% [markdown]
# # Modelo de Filtrado Colaborativo usando Red Neuronal Multicapa y Embedding con Keras:
#
# Otra enfoque popular para filtrado colaborativo es utilizar redes neuronales multicapa, que esencialmente aprenden características no lineales de los datos. Vamos a construir un modelo que fusiona los embeddings de usuarios y artículos (por ejemplo, películas) en una red neuronal densa.
#
# Este enfoque, que combina embeddings y redes neuronales multicapa, puede capturar interacciones más complejas y no lineales entre usuarios y artículos. Sin embargo, es crucial prestar atención al sobreajuste y asegurarse de que el modelo no esté simplemente memorizando los datos. Por lo tanto, es recomendable emplear técnicas de regularización, ajustar hiperparámetros y validar el rendimiento con un conjunto de datos de validación.

# %% [markdown]
# Funcionamiento:
#
# Combina lo mejor de ambos mundos. Primero, se utilizan embeddings para convertir ítems y usuarios en representaciones vectoriales densas. Luego, estas representaciones se pasan a través de una red neuronal para hacer la predicción.
#
# El proceso generalmente comienza con capas de embedding que convierten identificadores de usuarios e ítems en vectores. Estos vectores luego se pasan a través de capas densas para obtener la predicción final.
#
# Ventajas:
#
# Capacidad de capturar patrones subyacentes en los datos mediante embeddings y modelar interacciones no lineales mediante la red neuronal.
#
# Flexibilidad para incorporar características adicionales.
#
# Potencialmente más preciso que cualquiera de los otros dos métodos por separado.
#
# Desventajas:
#
# Mayor complejidad en el modelado y entrenamiento.
#
# Mayor costo computacional.
#
# Requiere un ajuste más cuidadoso y riesgo de sobreajuste si no se gestiona adecuadamente.

# %% [markdown]
# Regularización L2: Agregar una regularización L2 a las capas de embedding y densas para prevenir el sobreajuste.
#
# Early Stopping: Añadir una callback de early stopping para detener el entrenamiento cuando no haya mejora en el conjunto de validación durante un cierto número de épocas.
#
# Ajuste de la tasa de aprendizaje: Utilizar la callback ReduceLROnPlateau para reducir la tasa de aprendizaje cuando no haya mejora en el conjunto de validación.
#
# Métricas adicionales: Puedes monitorizar otras métricas como el error absoluto medio (MAE) durante el entrenamiento.

# %%
# Convertir reviewerID y asin a índices numéricos secuenciales
df['user_id'] = df['reviewerID'].astype('category').cat.codes.values
df['item_id'] = df['asin'].astype('category').cat.codes.values

# Número de usuarios e ítems
n_users = df['user_id'].nunique()
n_items = df['item_id'].nunique()

# Hiperparámetros
n_latent_factors = 50
hidden_units = [128, 64]
dropout_rate = 0.2
l2_reg = 1e-4

# Arquitectura del modelo con regularización L2
user_embedding = Embedding(n_users, n_latent_factors, embeddings_regularizer=l2(l2_reg), name='user_embedding')(user_input)
item_embedding = Embedding(n_items, n_latent_factors, embeddings_regularizer=l2(l2_reg), name='item_embedding')(item_input)

user_vec = Flatten(name='flatten_users')(user_embedding)
item_vec = Flatten(name='flatten_items')(item_embedding)
concat = Concatenate()([user_vec, item_vec])
dense = concat
for units in hidden_units:
    dense = Dense(units, activation='relu', kernel_regularizer=l2(l2_reg))(dense)
    dense = Dropout(dropout_rate)(dense)
output = Dense(1, kernel_regularizer=l2(l2_reg))(dense)
model = Model(inputs=[user_input, item_input], outputs=output)

model.compile(optimizer=Adam(0.001), loss='mean_squared_error', metrics=['mae'])

# %%
# Callbacks
early_stop = EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=50, min_lr=1e-5)

# %%
# Entrenamiento
user_data = df['user_id'].values
item_data = df['item_id'].values
rating_data = df['overall'].values

# División en entrenamiento y prueba
(user_ids_temp, user_ids_test, item_ids_temp, item_ids_test, ratings_temp, ratings_test) = train_test_split(
    user_ids, item_ids, ratings, test_size=0.2, random_state=42)

# División del conjunto de entrenamiento en entrenamiento y validación
(user_ids_train, user_ids_val, item_ids_train, item_ids_val, ratings_train, ratings_val) = train_test_split(
    user_ids_temp, item_ids_temp, ratings_temp, test_size=0.25, random_state=42)  # 0.25 x 0.8 = 0.2

# %%
# %%time
history = model.fit([user_ids_train, item_ids_train], ratings_train,
                    epochs=500,validation_data=([user_ids_val, item_ids_val], ratings_val),
                    batch_size=4000,verbose=1,callbacks=[early_stop, reduce_lr])
# Out:
# Epoch 1/500
# 721/721 [==============================] - 26s 34ms/step - loss: 2.7947 - mae: 1.1283 - val_loss: 1.5700 - val_mae: 0.8593 - lr: 0.0010
# Epoch 2/500
# 721/721 [==============================] - 24s 33ms/step - loss: 1.7039 - mae: 0.8881 - val_loss: 1.4970 - val_mae: 0.8318 - lr: 0.0010
# Epoch 3/500
# 721/721 [==============================] - 24s 33ms/step - loss: 1.5141 - mae: 0.8270 - val_loss: 1.4844 - val_mae: 0.8250 - lr: 0.0010
# Epoch 4/500
# 721/721 [==============================] - 23s 33ms/step - loss: 1.3114 - mae: 0.7594 - val_loss: 1.5098 - val_mae: 0.8141 - lr: 0.0010
# Epoch 5/500
# 721/721 [==============================] - 23s 32ms/step - loss: 1.2134 - mae: 0.7258 - val_loss: 1.5315 - val_mae: 0.8082 - lr: 0.0010
# Epoch 6/500
# 721/721 [==============================] - 23s 33ms/step - loss: 1.1863 - mae: 0.7074 - val_loss: 1.5600 - val_mae: 0.8071 - lr: 0.0010
# Epoch 7/500
# 721/721 [==============================] - 23s 32ms/step - loss: 1.1496 - mae: 0.6931 - val_loss: 1.5601 - val_mae: 0.8238 - lr: 0.0010
# Epoch 8/500
# 721/721 [==============================] - 23s 32ms/step - loss: 1.1236 - mae: 0.6806 - val_loss: 1.5738 - val_mae: 0.8094 - lr: 0.0010
# Epoch 9/500
# 721/721 [==============================] - 23s 33ms/step - loss: 1.1053 - mae: 0.6676 - val_loss: 1.5666 - val_mae: 0.8037 - lr: 0.0010
# Epoch 10/500
# 721/721 [==============================] - 23s 32ms/step - loss: 1.0783 - mae: 0.6548 - val_loss: 1.5605 - val_mae: 0.8120 - lr: 0.0010
# Epoch 11/500
# 721/721 [==============================] - 23s 32ms/step - loss: 1.0652 - mae: 0.6450 - val_loss: 1.5641 - val_mae: 0.7992 - lr: 0.0010
# Epoch 12/500
# 721/721 [==============================] - 23s 33ms/step - loss: 1.0614 - mae: 0.6409 - val_loss: 1.5597 - val_mae: 0.8090 - lr: 0.0010
# Epoch 13/500
# 721/721 [==============================] - 23s 32ms/step - loss: 1.0546 - mae: 0.6399 - val_loss: 1.5563 - val_mae: 0.7998 - lr: 0.0010
# Epoch 14/500
# 721/721 [==============================] - 23s 33ms/step - loss: 1.0597 - mae: 0.6403 - val_loss: 1.5735 - val_mae: 0.7954 - lr: 0.0010
# Epoch 15/500
# 721/721 [==============================] - 23s 32ms/step - loss: 1.0507 - mae: 0.6400 - val_loss: 1.5722 - val_mae: 0.8024 - lr: 0.0010
# Epoch 16/500
# 721/721 [==============================] - 23s 33ms/step - loss: 1.0496 - mae: 0.6395 - val_loss: 1.5771 - val_mae: 0.7964 - lr: 0.0010
# Epoch 17/500
# 721/721 [==============================] - 23s 32ms/step - loss: 1.0486 - mae: 0.6392 - val_loss: 1.5656 - val_mae: 0.8121 - lr: 0.0010
# Epoch 18/500
# 721/721 [==============================] - 23s 32ms/step - loss: 1.0540 - mae: 0.6390 - val_loss: 1.5769 - val_mae: 0.7842 - lr: 0.0010
# Epoch 19/500
# 721/721 [==============================] - 23s 33ms/step - loss: 1.0491 - mae: 0.6383 - val_loss: 1.5605 - val_mae: 0.7916 - lr: 0.0010
# Epoch 20/500
# 721/721 [==============================] - 23s 32ms/step - loss: 1.0456 - mae: 0.6386 - val_loss: 1.5638 - val_mae: 0.8197 - lr: 0.0010
# Epoch 21/500
# 721/721 [==============================] - 23s 32ms/step - loss: 1.0489 - mae: 0.6387 - val_loss: 1.5749 - val_mae: 0.7855 - lr: 0.0010
# Epoch 22/500
# 721/721 [==============================] - 23s 32ms/step - loss: 1.0531 - mae: 0.6380 - val_loss: 1.5753 - val_mae: 0.7912 - lr: 0.0010
# Epoch 23/500
# 721/721 [==============================] - 23s 32ms/step - loss: 1.0528 - mae: 0.6384 - val_loss: 1.5799 - val_mae: 0.7921 - lr: 0.0010
# Epoch 24/500
# 721/721 [==============================] - 23s 32ms/step - loss: 1.0508 - mae: 0.6377 - val_loss: 1.5630 - val_mae: 0.7962 - lr: 0.0010
# Epoch 25/500
# 721/721 [==============================] - 23s 32ms/step - loss: 1.0501 - mae: 0.6380 - val_loss: 1.5570 - val_mae: 0.7990 - lr: 0.0010
# Epoch 26/500
# 721/721 [==============================] - 23s 32ms/step - loss: 1.0424 - mae: 0.6380 - val_loss: 1.5716 - val_mae: 0.7966 - lr: 0.0010
# Epoch 27/500
# 721/721 [==============================] - 23s 33ms/step - loss: 1.0484 - mae: 0.6380 - val_loss: 1.5836 - val_mae: 0.7955 - lr: 0.0010
# Epoch 28/500
# 721/721 [==============================] - 23s 32ms/step - loss: 1.0529 - mae: 0.6377 - val_loss: 1.5830 - val_mae: 0.8061 - lr: 0.0010
# Epoch 29/500
# 721/721 [==============================] - 23s 33ms/step - loss: 1.0553 - mae: 0.6381 - val_loss: 1.5756 - val_mae: 0.7974 - lr: 0.0010
# Epoch 30/500
# 721/721 [==============================] - 23s 32ms/step - loss: 1.0448 - mae: 0.6379 - val_loss: 1.5573 - val_mae: 0.8194 - lr: 0.0010
# Epoch 31/500
# 721/721 [==============================] - 23s 32ms/step - loss: 1.0471 - mae: 0.6379 - val_loss: 1.5836 - val_mae: 0.7944 - lr: 0.0010
# Epoch 32/500
# 721/721 [==============================] - 23s 33ms/step - loss: 1.0516 - mae: 0.6378 - val_loss: 1.5735 - val_mae: 0.7861 - lr: 0.0010
# Epoch 33/500
# 721/721 [==============================] - 23s 32ms/step - loss: 1.0501 - mae: 0.6377 - val_loss: 1.5800 - val_mae: 0.8198 - lr: 0.0010
# Epoch 34/500
# 721/721 [==============================] - 23s 33ms/step - loss: 1.0516 - mae: 0.6377 - val_loss: 1.5813 - val_mae: 0.7998 - lr: 0.0010
# Epoch 35/500
# 721/721 [==============================] - 23s 32ms/step - loss: 1.0580 - mae: 0.6376 - val_loss: 1.5954 - val_mae: 0.7816 - lr: 0.0010
# Epoch 36/500
# 721/721 [==============================] - 23s 32ms/step - loss: 1.0517 - mae: 0.6379 - val_loss: 1.5856 - val_mae: 0.7889 - lr: 0.0010
# Epoch 37/500
# 721/721 [==============================] - 23s 32ms/step - loss: 1.0523 - mae: 0.6377 - val_loss: 1.5865 - val_mae: 0.7957 - lr: 0.0010
# Epoch 38/500
# 721/721 [==============================] - 23s 32ms/step - loss: 1.0424 - mae: 0.6376 - val_loss: 1.5639 - val_mae: 0.8045 - lr: 0.0010
# Epoch 39/500
# 721/721 [==============================] - 23s 33ms/step - loss: 1.0531 - mae: 0.6376 - val_loss: 1.5780 - val_mae: 0.7951 - lr: 0.0010
# Epoch 40/500
# 721/721 [==============================] - 23s 32ms/step - loss: 1.0556 - mae: 0.6375 - val_loss: 1.5770 - val_mae: 0.7961 - lr: 0.0010
# Epoch 41/500
# 721/721 [==============================] - 23s 32ms/step - loss: 1.0613 - mae: 0.6375 - val_loss: 1.6024 - val_mae: 0.7872 - lr: 0.0010
# Epoch 42/500
# 721/721 [==============================] - 23s 32ms/step - loss: 1.0575 - mae: 0.6370 - val_loss: 1.5740 - val_mae: 0.7992 - lr: 0.0010
# Epoch 43/500
# 721/721 [==============================] - 23s 32ms/step - loss: 1.0636 - mae: 0.6371 - val_loss: 1.5953 - val_mae: 0.8038 - lr: 0.0010
# Epoch 44/500
# 721/721 [==============================] - 23s 32ms/step - loss: 1.0599 - mae: 0.6364 - val_loss: 1.5962 - val_mae: 0.7961 - lr: 0.0010
# Epoch 45/500
# 721/721 [==============================] - 23s 33ms/step - loss: 1.0604 - mae: 0.6360 - val_loss: 1.5968 - val_mae: 0.8047 - lr: 0.0010
# Epoch 46/500
# 721/721 [==============================] - 23s 32ms/step - loss: 1.0576 - mae: 0.6354 - val_loss: 1.5893 - val_mae: 0.7959 - lr: 0.0010
# Epoch 47/500
# 721/721 [==============================] - 23s 32ms/step - loss: 1.0524 - mae: 0.6343 - val_loss: 1.5940 - val_mae: 0.8225 - lr: 0.0010
# Epoch 48/500
# 721/721 [==============================] - 23s 32ms/step - loss: 1.0514 - mae: 0.6331 - val_loss: 1.6149 - val_mae: 0.7814 - lr: 0.0010
# Epoch 49/500
# 721/721 [==============================] - 23s 32ms/step - loss: 1.0531 - mae: 0.6329 - val_loss: 1.6140 - val_mae: 0.7844 - lr: 0.0010
# Epoch 50/500
# 721/721 [==============================] - 23s 33ms/step - loss: 1.0571 - mae: 0.6310 - val_loss: 1.6171 - val_mae: 0.8045 - lr: 0.0010
# Epoch 51/500
# 721/721 [==============================] - 23s 32ms/step - loss: 1.0524 - mae: 0.6300 - val_loss: 1.6238 - val_mae: 0.7827 - lr: 0.0010
# Epoch 52/500
# 721/721 [==============================] - 23s 33ms/step - loss: 1.0505 - mae: 0.6281 - val_loss: 1.6158 - val_mae: 0.7990 - lr: 0.0010
# Epoch 53/500
# 721/721 [==============================] - 24s 33ms/step - loss: 1.0548 - mae: 0.6264 - val_loss: 1.6394 - val_mae: 0.7964 - lr: 0.0010
# CPU times: user 17min 42s, sys: 42.8 s, total: 18min 25s
# Wall time: 20min 43s

# %%
# Predicciones
y_true = ratings_test
predictions = model.predict([user_ids_test, item_ids_test])
# Out:
# 30004/30004 [==============================] - 43s 1ms/step

# %%
# MSE y RMSE
mse = mean_squared_error(y_true, predictions)
rmse = np.sqrt(mse)

# MAE
mae = mean_absolute_error(y_true, predictions)

# MAPE
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    non_zero_idx = y_true != 0  # Para evitar divisiones por cero
    return np.mean(np.abs((y_true[non_zero_idx] - y_pred[non_zero_idx]) / y_true[non_zero_idx])) * 100

def compute_mape_by_batch(y_true, predictions, batch_size=50000):
    mape_sum = 0
    num_batches = int(np.ceil(len(y_true) / batch_size))

    for i in range(num_batches):
        start_idx = i * batch_size
        end_idx = start_idx + batch_size

        batch_y_true = y_true[start_idx:end_idx]
        batch_predictions = predictions[start_idx:end_idx]

        mape_sum += mean_absolute_percentage_error(batch_y_true, batch_predictions)

    return mape_sum / num_batches

# Luego llamas a la función
mape = compute_mape_by_batch(y_true, predictions)

print(f'MSE: {mse}')
print(f'RMSE: {rmse}')
print(f'MAE: {mae}')
print(f'MAPE: {mape}%')
# Out:
# MSE: 1.1993328439713224
# RMSE: 1.09514055900205
# MAE: 0.8259712378307749
# MAPE: 39.50991366979228%

# %% [markdown]
# # Recomendación

# %%
# Seleccionar un usuario al azar del conjunto de prueba
usuario_id_test_encoded = random.choice(user_ids_test)

# Decodificar el ID del usuario para obtener el ID original
usuario_id_test = reviewerID_encoder.inverse_transform([usuario_id_test_encoded])[0]

# Identificar los ítems que el usuario ha calificado en el conjunto de prueba
indices_usuario = np.where(user_ids_test == usuario_id_test_encoded)[0]
items_calificados_test_encoded = item_ids_test[indices_usuario]
calificaciones_reales_test = ratings_test[indices_usuario]

# Predecir las calificaciones para estos ítems
calificaciones_predichas = model.predict([np.array([usuario_id_test_encoded] * len(items_calificados_test_encoded)), items_calificados_test_encoded])

# Decodificar los ítems para obtener los ID originales
items_calificados_test = asin_encoder.inverse_transform(items_calificados_test_encoded)

# Comparar las calificaciones predichas con las reales
comparacion = list(zip(items_calificados_test, calificaciones_reales_test, calificaciones_predichas.flatten()))

# Mostrar las comparaciones
print(f"Recomendaciones para el usuario {usuario_id_test}:")
for item, real, predicha in comparacion:
    print(f"Ítem: {item}, Calificación Real: {real}, Calificación Predicha: {predicha}")
# Out:
# 1/1 [==============================] - 0s 18ms/step
# Recomendaciones para el usuario A3DEFR55Y8P1ZW:
# Ítem: B00LYTBMHG, Calificación Real: 2.0, Calificación Predicha: 4.490243911743164
# Ítem: B00DHO7X8S, Calificación Real: 3.0, Calificación Predicha: 4.020789623260498

# %%
# Seleccionar un usuario al azar del conjunto de prueba
usuario_id_test_encoded = random.choice(user_ids_test)

# Decodificar el ID del usuario para obtener el ID original
usuario_id = reviewerID_encoder.inverse_transform([usuario_id_test_encoded])[0]

# Lista de todos los ítems únicos en el dataset
items_unicos = np.unique(data['asin'].values)

# Ítems que el usuario ya ha calificado
items_calificados = data[data['reviewerID_encoded'] == usuario_id_test_encoded]['asin'].tolist()

# Ítems para predecir
items_a_predecir = [item for item in items_unicos if item not in items_calificados]

# Convierte los ítems a su representación codificada
items_a_predecir_encoded = asin_encoder.transform(items_a_predecir)

# Predecir la calificación para cada ítem no calificado
predicciones = model.predict([np.array([usuario_id_test_encoded] * len(items_a_predecir_encoded)), items_a_predecir_encoded])

# Emparejar cada ítem con su predicción
items_predicciones = list(zip(items_a_predecir, predicciones.flatten()))

# Ordenar por la calificación predicha más alta
items_recomendados = sorted(items_predicciones, key=lambda x: x[1], reverse=True)

# Tomar los top N recomendaciones
top_n = 5
top_recomendaciones = items_recomendados[:top_n]

# Imprimir las recomendaciones
print(f"Recomendaciones para el usuario {usuario_id}:")
for item, calificacion in top_recomendaciones:
    print(f"Ítem: {item}, Calificación Predicha: {calificacion}")
# Out:
# 4814/4814 [==============================] - 7s 1ms/step
# Recomendaciones para el usuario AV3YIEU70R9JQ:
# Ítem: B01641E5YK, Calificación Predicha: 4.863051891326904
# Ítem: B00VJHTBTE, Calificación Predicha: 4.850451469421387
# Ítem: B0149X6QKG, Calificación Predicha: 4.848025321960449
# Ítem: B002F9NH7W, Calificación Predicha: 4.82704496383667
# Ítem: B00LE97QJO, Calificación Predicha: 4.827026844024658

# %% [markdown]
# Estas métricas te ayudarán a tener una mejor idea del desempeño de tu modelo. Por ejemplo:
#
# MSE y RMSE son útiles cuando quieres penalizar grandes errores.
#
# MAE te da una idea del error medio sin considerar la dirección del error.
#
# MAPE es útil cuando quieres representar el error en términos porcentuales.
#
# Para una evaluación completa, es recomendable utilizar un conjunto de validación aparte (es decir, no solo depender del validation_split). Esto asegura que estás evaluando el desempeño en datos que el modelo nunca ha visto durante el entrenamiento.

# %% [markdown]
# En resumen, la elección del tipo de sistema de recomendación dependerá de la naturaleza del conjunto de datos, las características disponibles, las capacidades computacionales y el tipo de relaciones o interacciones que se desean capturar. A menudo, un enfoque híbrido (como el sistema que combina embeddings y redes neuronales) ofrece un buen equilibrio entre precisión y eficiencia.
