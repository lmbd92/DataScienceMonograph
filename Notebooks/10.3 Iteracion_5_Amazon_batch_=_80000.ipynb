# %% [markdown]
# # Paso 1: Importar Librerías de Python

# %%
#pip install scikit-surprise
# Out:
# Collecting scikit-surprise
#   Downloading scikit-surprise-1.1.3.tar.gz (771 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 772.0/772.0 kB 9.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: joblib>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.3.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.11.3)
# Building wheels for collected packages: scikit-surprise
#   Building wheel for scikit-surprise (setup.py) ... done
#   Created wheel for scikit-surprise: filename=scikit_surprise-1.1.3-cp310-cp310-linux_x86_64.whl size=3163479 sha256=1a0c67a0e9bfe366991a9ed3c55d4543b7cb0404dfe99400fd2240f089643788
#   Stored in directory: /root/.cache/pip/wheels/a5/ca/a8/4e28def53797fdc4363ca4af740db15a9c2f1595ebc51fb445
# Successfully built scikit-surprise
# Installing collected packages: scikit-surprise
# Successfully installed scikit-surprise-1.1.3

# %%
# Análisis de datos y manipulación
import pandas as pd
import numpy as np
import random


# Visualización de datos
import matplotlib.pyplot as plt
import seaborn as sns

# Utilidades de fechas
from datetime import datetime

# Integración con Google Colab
from google.colab import drive

# Machine Learning: Preprocesamiento y división de datos
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# Machine Learning: Métricas
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.metrics.pairwise import cosine_similarity

# Machine Learning: Modelado y validación
from surprise import SVD, Reader, Dataset, accuracy
from surprise.model_selection import train_test_split, GridSearchCV

# Deep Learning: Construcción de modelos y capas
from keras.models import Model
from keras.layers import Input, Embedding, Flatten, Concatenate, Dense, Dropout, Dot,Lambda

# Deep Learning: Optimización y regularización
from keras.optimizers import Adam
from keras.regularizers import l2

# Deep Learning: Callbacks
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Paso 2: Lectura del Dataset

# %%
df = pd.read_csv('/content/drive/MyDrive/EspecializacionA&DS/Monografia/2doSemestre/DataFinal_Amazon.csv')
# Out:
# <ipython-input-4-9e77e6115feb>:1: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/drive/MyDrive/EspecializacionA&DS/Monografia/2doSemestre/DataFinal_Amazon.csv')

# %%
df.shape
# Out:
# (4800571, 10)

# %%
sentimiento = pd.read_csv('/content/drive/MyDrive/EspecializacionA&DS/Monografia/2doSemestre/sentimientos_productos.csv')

# %%
sentimiento.shape
# Out:
# (154026, 4)

# %% [markdown]
# # Modelo de Filtrado Colaborativo usando Embedding con Keras:

# %% [markdown]
# Funcionamiento:
#
# Los embeddings son representaciones vectoriales densas y de baja dimensión de ítems y/o usuarios. Estas representaciones capturan relaciones semánticas entre ítems o entre usuarios.
#
# Un método popular para generar embeddings es la factorización de matrices, como la descomposición en valores singulares (SVD). En el contexto de sistemas de recomendación, se busca factorizar la matriz de interacciones usuario-ítem en dos matrices más pequeñas (una para los usuarios y otra para los ítems) cuyo producto aproximado reproduce la matriz original lo mejor posible.
#
# Una vez que se han obtenido los embeddings, la predicción de una calificación o interacción entre un usuario e ítem se realiza tomando el producto escalar entre sus embeddings respectivos.
#
# Ventajas:
#
# Simplicidad y eficiencia en términos computacionales.
#
# Puede manejar grandes conjuntos de datos debido a su naturaleza de baja dimensión.
#
# Es efectivo para capturar patrones subyacentes en los datos.
#
# Desventajas:
#
# No tiene en cuenta características adicionales de usuarios o ítems.
#
# Dificultades para manejar nuevos ítems o usuarios (problema de arranque en frío).

# %% [markdown]
# El código ahora incluye regularización en los embeddings, un callback para detener el entrenamiento si no hay mejoras (early stopping) y otro para reducir la tasa de aprendizaje si el error de validación no mejora (reduce learning rate on plateau).

# %%
data = df

# %%
# Crear un LabelEncoder para cada columna
reviewerID_encoder = LabelEncoder()
asin_encoder = LabelEncoder()

# Ajustar y transformar las columnas
data['reviewerID_encoded'] = reviewerID_encoder.fit_transform(data['reviewerID'])
data['asin_encoded'] = asin_encoder.fit_transform(data['asin'])

# Número de usuarios únicos y número de ítems únicos
n_users = len(np.unique(data['reviewerID_encoded']))
n_items = len(np.unique(data['asin_encoded']))

# Dimensiones del embedding
embedding_dim = 10

# Entradas
user_input = Input(shape=(1,))
item_input = Input(shape=(1,))

# Embeddings con regularización
user_embedding = Embedding(n_users, embedding_dim, embeddings_regularizer=l2(1e-6))(user_input)
item_embedding = Embedding(n_items, embedding_dim, embeddings_regularizer=l2(1e-6))(item_input)

# Producto punto para predecir la valoración/rating
merged = Dot(axes=2)([user_embedding, item_embedding])
merged = Flatten()(merged)

# Agregar una capa de activación sigmoid y escalar a [0, 5]
output = Dense(1, activation='sigmoid')(merged)  # Función de activación sigmoid
output = Lambda(lambda x: x * 5)(output)  # Escalar las predicciones al rango [0, 5]

# Modelo
model = Model(inputs=[user_input, item_input], outputs=output)
model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# %% [markdown]
# verbose=0: No muestra ninguna barra de progreso ni métricas.
#
# verbose=1: Muestra una barra de progreso y actualiza las métricas después de cada lote.
#
# verbose=2: Muestra las métricas después de cada época, pero no muestra la barra de progreso.

# %%
from sklearn.model_selection import train_test_split

# Crear los arrays con los datos
user_ids = data['reviewerID_encoded'].values
item_ids = data['asin_encoded'].values
ratings = data['overall'].values

# División en entrenamiento y prueba
(user_ids_temp, user_ids_test, item_ids_temp, item_ids_test, ratings_temp, ratings_test) = train_test_split(
    user_ids, item_ids, ratings, test_size=0.2, random_state=42)

# División del conjunto de entrenamiento en entrenamiento y validación
(user_ids_train, user_ids_val, item_ids_train, item_ids_val, ratings_train, ratings_val) = train_test_split(
    user_ids_temp, item_ids_temp, ratings_temp, test_size=0.25, random_state=42)  # 0.25 x 0.8 = 0.2

# %%
# Callbacks
early_stop = EarlyStopping(monitor='val_loss', patience=50)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=50, min_lr=1e-5)

# %%
# %%time
# Entrenar el modelo con el conjunto de entrenamiento
model.fit([user_ids_train, item_ids_train], ratings_train, validation_data=([user_ids_val, item_ids_val], ratings_val), epochs=500,
          batch_size=80000, verbose=1, callbacks=[early_stop, reduce_lr])
# Out:
# Epoch 1/500
# 37/37 [==============================] - 6s 18ms/step - loss: 4.3942 - mae: 1.9620 - val_loss: 4.3156 - val_mae: 1.9450 - lr: 0.0010
# Epoch 2/500
# 37/37 [==============================] - 0s 11ms/step - loss: 4.2341 - mae: 1.9260 - val_loss: 4.1582 - val_mae: 1.9092 - lr: 0.0010
# Epoch 3/500
# 37/37 [==============================] - 0s 11ms/step - loss: 4.0801 - mae: 1.8904 - val_loss: 4.0075 - val_mae: 1.8739 - lr: 0.0010
# Epoch 4/500
# 37/37 [==============================] - 0s 11ms/step - loss: 3.9330 - mae: 1.8554 - val_loss: 3.8638 - val_mae: 1.8392 - lr: 0.0010
# Epoch 5/500
# 37/37 [==============================] - 0s 11ms/step - loss: 3.7923 - mae: 1.8209 - val_loss: 3.7265 - val_mae: 1.8049 - lr: 0.0010
# Epoch 6/500
# 37/37 [==============================] - 0s 11ms/step - loss: 3.6573 - mae: 1.7866 - val_loss: 3.5945 - val_mae: 1.7709 - lr: 0.0010
# Epoch 7/500
# 37/37 [==============================] - 0s 11ms/step - loss: 3.5254 - mae: 1.7520 - val_loss: 3.4658 - val_mae: 1.7365 - lr: 0.0010
# Epoch 8/500
# 37/37 [==============================] - 0s 12ms/step - loss: 3.3926 - mae: 1.7159 - val_loss: 3.3385 - val_mae: 1.7012 - lr: 0.0010
# Epoch 9/500
# 37/37 [==============================] - 0s 11ms/step - loss: 3.2546 - mae: 1.6768 - val_loss: 3.2124 - val_mae: 1.6644 - lr: 0.0010
# Epoch 10/500
# 37/37 [==============================] - 0s 11ms/step - loss: 3.1084 - mae: 1.6333 - val_loss: 3.0892 - val_mae: 1.6263 - lr: 0.0010
# Epoch 11/500
# 37/37 [==============================] - 0s 11ms/step - loss: 2.9528 - mae: 1.5845 - val_loss: 2.9716 - val_mae: 1.5877 - lr: 0.0010
# Epoch 12/500
# 37/37 [==============================] - 0s 11ms/step - loss: 2.7887 - mae: 1.5305 - val_loss: 2.8626 - val_mae: 1.5499 - lr: 0.0010
# Epoch 13/500
# 37/37 [==============================] - 0s 11ms/step - loss: 2.6186 - mae: 1.4744 - val_loss: 2.7642 - val_mae: 1.5178 - lr: 0.0010
# Epoch 14/500
# 37/37 [==============================] - 0s 11ms/step - loss: 2.4466 - mae: 1.4163 - val_loss: 2.6778 - val_mae: 1.4876 - lr: 0.0010
# Epoch 15/500
# 37/37 [==============================] - 0s 11ms/step - loss: 2.2770 - mae: 1.3548 - val_loss: 2.6037 - val_mae: 1.4593 - lr: 0.0010
# Epoch 16/500
# 37/37 [==============================] - 0s 11ms/step - loss: 2.1138 - mae: 1.2914 - val_loss: 2.5415 - val_mae: 1.4331 - lr: 0.0010
# Epoch 17/500
# 37/37 [==============================] - 0s 12ms/step - loss: 1.9601 - mae: 1.2275 - val_loss: 2.4902 - val_mae: 1.4092 - lr: 0.0010
# Epoch 18/500
# 37/37 [==============================] - 0s 11ms/step - loss: 1.8182 - mae: 1.1645 - val_loss: 2.4489 - val_mae: 1.3876 - lr: 0.0010
# Epoch 19/500
# 37/37 [==============================] - 0s 12ms/step - loss: 1.6891 - mae: 1.1037 - val_loss: 2.4163 - val_mae: 1.3682 - lr: 0.0010
# Epoch 20/500
# 37/37 [==============================] - 0s 11ms/step - loss: 1.5728 - mae: 1.0458 - val_loss: 2.3911 - val_mae: 1.3507 - lr: 0.0010
# Epoch 21/500
# 37/37 [==============================] - 0s 11ms/step - loss: 1.4684 - mae: 0.9911 - val_loss: 2.3717 - val_mae: 1.3351 - lr: 0.0010
# Epoch 22/500
# 37/37 [==============================] - 0s 11ms/step - loss: 1.3750 - mae: 0.9399 - val_loss: 2.3574 - val_mae: 1.3211 - lr: 0.0010
# Epoch 23/500
# 37/37 [==============================] - 0s 11ms/step - loss: 1.2918 - mae: 0.8923 - val_loss: 2.3473 - val_mae: 1.3086 - lr: 0.0010
# Epoch 24/500
# 37/37 [==============================] - 0s 11ms/step - loss: 1.2176 - mae: 0.8481 - val_loss: 2.3404 - val_mae: 1.2974 - lr: 0.0010
# Epoch 25/500
# 37/37 [==============================] - 0s 11ms/step - loss: 1.1515 - mae: 0.8072 - val_loss: 2.3364 - val_mae: 1.2873 - lr: 0.0010
# Epoch 26/500
# 37/37 [==============================] - 0s 11ms/step - loss: 1.0923 - mae: 0.7694 - val_loss: 2.3344 - val_mae: 1.2782 - lr: 0.0010
# Epoch 27/500
# 37/37 [==============================] - 0s 11ms/step - loss: 1.0394 - mae: 0.7344 - val_loss: 2.3341 - val_mae: 1.2700 - lr: 0.0010
# Epoch 28/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.9920 - mae: 0.7020 - val_loss: 2.3350 - val_mae: 1.2626 - lr: 0.0010
# Epoch 29/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.9494 - mae: 0.6720 - val_loss: 2.3368 - val_mae: 1.2558 - lr: 0.0010
# Epoch 30/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.9111 - mae: 0.6443 - val_loss: 2.3391 - val_mae: 1.2497 - lr: 0.0010
# Epoch 31/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.8765 - mae: 0.6186 - val_loss: 2.3418 - val_mae: 1.2440 - lr: 0.0010
# Epoch 32/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.8454 - mae: 0.5949 - val_loss: 2.3447 - val_mae: 1.2388 - lr: 0.0010
# Epoch 33/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.8172 - mae: 0.5730 - val_loss: 2.3478 - val_mae: 1.2340 - lr: 0.0010
# Epoch 34/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.7916 - mae: 0.5527 - val_loss: 2.3507 - val_mae: 1.2295 - lr: 0.0010
# Epoch 35/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.7684 - mae: 0.5339 - val_loss: 2.3534 - val_mae: 1.2254 - lr: 0.0010
# Epoch 36/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.7472 - mae: 0.5165 - val_loss: 2.3560 - val_mae: 1.2215 - lr: 0.0010
# Epoch 37/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.7279 - mae: 0.5003 - val_loss: 2.3582 - val_mae: 1.2179 - lr: 0.0010
# Epoch 38/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.7102 - mae: 0.4853 - val_loss: 2.3600 - val_mae: 1.2144 - lr: 0.0010
# Epoch 39/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.6940 - mae: 0.4715 - val_loss: 2.3614 - val_mae: 1.2111 - lr: 0.0010
# Epoch 40/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.6791 - mae: 0.4586 - val_loss: 2.3624 - val_mae: 1.2079 - lr: 0.0010
# Epoch 41/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.6653 - mae: 0.4466 - val_loss: 2.3629 - val_mae: 1.2048 - lr: 0.0010
# Epoch 42/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.6526 - mae: 0.4355 - val_loss: 2.3629 - val_mae: 1.2019 - lr: 0.0010
# Epoch 43/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.6408 - mae: 0.4252 - val_loss: 2.3625 - val_mae: 1.1990 - lr: 0.0010
# Epoch 44/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.6298 - mae: 0.4155 - val_loss: 2.3618 - val_mae: 1.1962 - lr: 0.0010
# Epoch 45/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.6196 - mae: 0.4066 - val_loss: 2.3605 - val_mae: 1.1935 - lr: 0.0010
# Epoch 46/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.6100 - mae: 0.3982 - val_loss: 2.3588 - val_mae: 1.1908 - lr: 0.0010
# Epoch 47/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.6010 - mae: 0.3904 - val_loss: 2.3567 - val_mae: 1.1882 - lr: 0.0010
# Epoch 48/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.5926 - mae: 0.3831 - val_loss: 2.3543 - val_mae: 1.1855 - lr: 0.0010
# Epoch 49/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.5846 - mae: 0.3762 - val_loss: 2.3514 - val_mae: 1.1829 - lr: 0.0010
# Epoch 50/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.5770 - mae: 0.3698 - val_loss: 2.3482 - val_mae: 1.1804 - lr: 0.0010
# Epoch 51/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.5699 - mae: 0.3638 - val_loss: 2.3447 - val_mae: 1.1779 - lr: 0.0010
# Epoch 52/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.5631 - mae: 0.3582 - val_loss: 2.3409 - val_mae: 1.1753 - lr: 0.0010
# Epoch 53/500
# 37/37 [==============================] - 0s 12ms/step - loss: 0.5566 - mae: 0.3529 - val_loss: 2.3367 - val_mae: 1.1728 - lr: 0.0010
# Epoch 54/500
# 37/37 [==============================] - 0s 12ms/step - loss: 0.5503 - mae: 0.3479 - val_loss: 2.3324 - val_mae: 1.1703 - lr: 0.0010
# Epoch 55/500
# 37/37 [==============================] - 0s 12ms/step - loss: 0.5444 - mae: 0.3432 - val_loss: 2.3277 - val_mae: 1.1678 - lr: 0.0010
# Epoch 56/500
# 37/37 [==============================] - 0s 12ms/step - loss: 0.5387 - mae: 0.3388 - val_loss: 2.3227 - val_mae: 1.1653 - lr: 0.0010
# Epoch 57/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.5332 - mae: 0.3346 - val_loss: 2.3176 - val_mae: 1.1629 - lr: 0.0010
# Epoch 58/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.5279 - mae: 0.3306 - val_loss: 2.3122 - val_mae: 1.1604 - lr: 0.0010
# Epoch 59/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.5228 - mae: 0.3269 - val_loss: 2.3066 - val_mae: 1.1579 - lr: 0.0010
# Epoch 60/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.5178 - mae: 0.3233 - val_loss: 2.3009 - val_mae: 1.1554 - lr: 0.0010
# Epoch 61/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.5130 - mae: 0.3199 - val_loss: 2.2950 - val_mae: 1.1529 - lr: 0.0010
# Epoch 62/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.5084 - mae: 0.3167 - val_loss: 2.2889 - val_mae: 1.1504 - lr: 0.0010
# Epoch 63/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.5038 - mae: 0.3136 - val_loss: 2.2827 - val_mae: 1.1479 - lr: 0.0010
# Epoch 64/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.4994 - mae: 0.3107 - val_loss: 2.2764 - val_mae: 1.1454 - lr: 0.0010
# Epoch 65/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.4951 - mae: 0.3079 - val_loss: 2.2698 - val_mae: 1.1429 - lr: 0.0010
# Epoch 66/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.4910 - mae: 0.3052 - val_loss: 2.2631 - val_mae: 1.1403 - lr: 0.0010
# Epoch 67/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.4869 - mae: 0.3027 - val_loss: 2.2564 - val_mae: 1.1378 - lr: 0.0010
# Epoch 68/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.4829 - mae: 0.3002 - val_loss: 2.2496 - val_mae: 1.1353 - lr: 0.0010
# Epoch 69/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.4790 - mae: 0.2978 - val_loss: 2.2427 - val_mae: 1.1327 - lr: 0.0010
# Epoch 70/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.4751 - mae: 0.2956 - val_loss: 2.2358 - val_mae: 1.1302 - lr: 0.0010
# Epoch 71/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.4714 - mae: 0.2934 - val_loss: 2.2287 - val_mae: 1.1277 - lr: 0.0010
# Epoch 72/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.4677 - mae: 0.2913 - val_loss: 2.2217 - val_mae: 1.1251 - lr: 0.0010
# Epoch 73/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.4641 - mae: 0.2892 - val_loss: 2.2145 - val_mae: 1.1226 - lr: 0.0010
# Epoch 74/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.4606 - mae: 0.2873 - val_loss: 2.2075 - val_mae: 1.1201 - lr: 0.0010
# Epoch 75/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.4571 - mae: 0.2854 - val_loss: 2.2002 - val_mae: 1.1175 - lr: 0.0010
# Epoch 76/500
# 37/37 [==============================] - 0s 12ms/step - loss: 0.4537 - mae: 0.2835 - val_loss: 2.1929 - val_mae: 1.1150 - lr: 0.0010
# Epoch 77/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.4504 - mae: 0.2817 - val_loss: 2.1856 - val_mae: 1.1124 - lr: 0.0010
# Epoch 78/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.4471 - mae: 0.2800 - val_loss: 2.1783 - val_mae: 1.1099 - lr: 0.0010
# Epoch 79/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.4438 - mae: 0.2783 - val_loss: 2.1709 - val_mae: 1.1073 - lr: 0.0010
# Epoch 80/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.4406 - mae: 0.2767 - val_loss: 2.1635 - val_mae: 1.1048 - lr: 0.0010
# Epoch 81/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.4375 - mae: 0.2751 - val_loss: 2.1562 - val_mae: 1.1022 - lr: 0.0010
# Epoch 82/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.4344 - mae: 0.2736 - val_loss: 2.1487 - val_mae: 1.0996 - lr: 0.0010
# Epoch 83/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.4313 - mae: 0.2720 - val_loss: 2.1413 - val_mae: 1.0970 - lr: 0.0010
# Epoch 84/500
# 37/37 [==============================] - 0s 12ms/step - loss: 0.4283 - mae: 0.2705 - val_loss: 2.1338 - val_mae: 1.0944 - lr: 0.0010
# Epoch 85/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.4253 - mae: 0.2691 - val_loss: 2.1263 - val_mae: 1.0918 - lr: 0.0010
# Epoch 86/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.4224 - mae: 0.2677 - val_loss: 2.1189 - val_mae: 1.0892 - lr: 0.0010
# Epoch 87/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.4195 - mae: 0.2663 - val_loss: 2.1115 - val_mae: 1.0866 - lr: 0.0010
# Epoch 88/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.4166 - mae: 0.2649 - val_loss: 2.1040 - val_mae: 1.0840 - lr: 0.0010
# Epoch 89/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.4138 - mae: 0.2637 - val_loss: 2.0966 - val_mae: 1.0814 - lr: 0.0010
# Epoch 90/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.4110 - mae: 0.2623 - val_loss: 2.0892 - val_mae: 1.0788 - lr: 0.0010
# Epoch 91/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.4083 - mae: 0.2611 - val_loss: 2.0818 - val_mae: 1.0762 - lr: 0.0010
# Epoch 92/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.4056 - mae: 0.2598 - val_loss: 2.0745 - val_mae: 1.0736 - lr: 0.0010
# Epoch 93/500
# 37/37 [==============================] - 0s 12ms/step - loss: 0.4029 - mae: 0.2586 - val_loss: 2.0671 - val_mae: 1.0710 - lr: 0.0010
# Epoch 94/500
# 37/37 [==============================] - 0s 12ms/step - loss: 0.4002 - mae: 0.2574 - val_loss: 2.0598 - val_mae: 1.0684 - lr: 0.0010
# Epoch 95/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.3976 - mae: 0.2562 - val_loss: 2.0524 - val_mae: 1.0657 - lr: 0.0010
# Epoch 96/500
# 37/37 [==============================] - 0s 12ms/step - loss: 0.3950 - mae: 0.2550 - val_loss: 2.0451 - val_mae: 1.0631 - lr: 0.0010
# Epoch 97/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.3925 - mae: 0.2539 - val_loss: 2.0378 - val_mae: 1.0605 - lr: 0.0010
# Epoch 98/500
# 37/37 [==============================] - 0s 12ms/step - loss: 0.3899 - mae: 0.2527 - val_loss: 2.0306 - val_mae: 1.0579 - lr: 0.0010
# Epoch 99/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.3874 - mae: 0.2516 - val_loss: 2.0233 - val_mae: 1.0552 - lr: 0.0010
# Epoch 100/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.3849 - mae: 0.2505 - val_loss: 2.0162 - val_mae: 1.0526 - lr: 0.0010
# Epoch 101/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.3825 - mae: 0.2494 - val_loss: 2.0090 - val_mae: 1.0500 - lr: 0.0010
# Epoch 102/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.3801 - mae: 0.2484 - val_loss: 2.0020 - val_mae: 1.0474 - lr: 0.0010
# Epoch 103/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.3777 - mae: 0.2473 - val_loss: 1.9949 - val_mae: 1.0448 - lr: 0.0010
# Epoch 104/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.3753 - mae: 0.2463 - val_loss: 1.9879 - val_mae: 1.0422 - lr: 0.0010
# Epoch 105/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.3729 - mae: 0.2452 - val_loss: 1.9808 - val_mae: 1.0395 - lr: 0.0010
# Epoch 106/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.3706 - mae: 0.2442 - val_loss: 1.9739 - val_mae: 1.0370 - lr: 0.0010
# Epoch 107/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.3683 - mae: 0.2432 - val_loss: 1.9669 - val_mae: 1.0344 - lr: 0.0010
# Epoch 108/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.3660 - mae: 0.2422 - val_loss: 1.9601 - val_mae: 1.0318 - lr: 0.0010
# Epoch 109/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.3638 - mae: 0.2412 - val_loss: 1.9532 - val_mae: 1.0292 - lr: 0.0010
# Epoch 110/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.3615 - mae: 0.2403 - val_loss: 1.9465 - val_mae: 1.0266 - lr: 0.0010
# Epoch 111/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.3593 - mae: 0.2393 - val_loss: 1.9397 - val_mae: 1.0241 - lr: 0.0010
# Epoch 112/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.3571 - mae: 0.2384 - val_loss: 1.9330 - val_mae: 1.0215 - lr: 0.0010
# Epoch 113/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.3550 - mae: 0.2374 - val_loss: 1.9264 - val_mae: 1.0189 - lr: 0.0010
# Epoch 114/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.3528 - mae: 0.2365 - val_loss: 1.9197 - val_mae: 1.0163 - lr: 0.0010
# Epoch 115/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.3507 - mae: 0.2356 - val_loss: 1.9132 - val_mae: 1.0138 - lr: 0.0010
# Epoch 116/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.3486 - mae: 0.2347 - val_loss: 1.9067 - val_mae: 1.0112 - lr: 0.0010
# Epoch 117/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.3465 - mae: 0.2338 - val_loss: 1.9003 - val_mae: 1.0086 - lr: 0.0010
# Epoch 118/500
# 37/37 [==============================] - 0s 12ms/step - loss: 0.3444 - mae: 0.2328 - val_loss: 1.8938 - val_mae: 1.0061 - lr: 0.0010
# Epoch 119/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.3424 - mae: 0.2320 - val_loss: 1.8875 - val_mae: 1.0036 - lr: 0.0010
# Epoch 120/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.3404 - mae: 0.2311 - val_loss: 1.8812 - val_mae: 1.0010 - lr: 0.0010
# Epoch 121/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.3384 - mae: 0.2302 - val_loss: 1.8749 - val_mae: 0.9985 - lr: 0.0010
# Epoch 122/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.3364 - mae: 0.2294 - val_loss: 1.8687 - val_mae: 0.9960 - lr: 0.0010
# Epoch 123/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.3344 - mae: 0.2286 - val_loss: 1.8626 - val_mae: 0.9935 - lr: 0.0010
# Epoch 124/500
# 37/37 [==============================] - 0s 12ms/step - loss: 0.3325 - mae: 0.2277 - val_loss: 1.8565 - val_mae: 0.9910 - lr: 0.0010
# Epoch 125/500
# 37/37 [==============================] - 0s 12ms/step - loss: 0.3306 - mae: 0.2269 - val_loss: 1.8504 - val_mae: 0.9885 - lr: 0.0010
# Epoch 126/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.3287 - mae: 0.2261 - val_loss: 1.8444 - val_mae: 0.9860 - lr: 0.0010
# Epoch 127/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.3268 - mae: 0.2252 - val_loss: 1.8385 - val_mae: 0.9835 - lr: 0.0010
# Epoch 128/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.3249 - mae: 0.2244 - val_loss: 1.8327 - val_mae: 0.9810 - lr: 0.0010
# Epoch 129/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.3231 - mae: 0.2236 - val_loss: 1.8269 - val_mae: 0.9786 - lr: 0.0010
# Epoch 130/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.3212 - mae: 0.2228 - val_loss: 1.8212 - val_mae: 0.9762 - lr: 0.0010
# Epoch 131/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.3194 - mae: 0.2220 - val_loss: 1.8155 - val_mae: 0.9737 - lr: 0.0010
# Epoch 132/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.3176 - mae: 0.2212 - val_loss: 1.8098 - val_mae: 0.9713 - lr: 0.0010
# Epoch 133/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.3158 - mae: 0.2205 - val_loss: 1.8043 - val_mae: 0.9689 - lr: 0.0010
# Epoch 134/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.3141 - mae: 0.2197 - val_loss: 1.7988 - val_mae: 0.9665 - lr: 0.0010
# Epoch 135/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.3123 - mae: 0.2189 - val_loss: 1.7934 - val_mae: 0.9641 - lr: 0.0010
# Epoch 136/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.3106 - mae: 0.2182 - val_loss: 1.7881 - val_mae: 0.9617 - lr: 0.0010
# Epoch 137/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.3089 - mae: 0.2175 - val_loss: 1.7828 - val_mae: 0.9594 - lr: 0.0010
# Epoch 138/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.3072 - mae: 0.2168 - val_loss: 1.7776 - val_mae: 0.9571 - lr: 0.0010
# Epoch 139/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.3055 - mae: 0.2162 - val_loss: 1.7724 - val_mae: 0.9550 - lr: 0.0010
# Epoch 140/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.3039 - mae: 0.2155 - val_loss: 1.7673 - val_mae: 0.9531 - lr: 0.0010
# Epoch 141/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.3022 - mae: 0.2148 - val_loss: 1.7622 - val_mae: 0.9512 - lr: 0.0010
# Epoch 142/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.3006 - mae: 0.2142 - val_loss: 1.7573 - val_mae: 0.9494 - lr: 0.0010
# Epoch 143/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2990 - mae: 0.2135 - val_loss: 1.7524 - val_mae: 0.9475 - lr: 0.0010
# Epoch 144/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2974 - mae: 0.2129 - val_loss: 1.7475 - val_mae: 0.9457 - lr: 0.0010
# Epoch 145/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2958 - mae: 0.2122 - val_loss: 1.7427 - val_mae: 0.9438 - lr: 0.0010
# Epoch 146/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2942 - mae: 0.2116 - val_loss: 1.7380 - val_mae: 0.9420 - lr: 0.0010
# Epoch 147/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2926 - mae: 0.2110 - val_loss: 1.7334 - val_mae: 0.9403 - lr: 0.0010
# Epoch 148/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2911 - mae: 0.2103 - val_loss: 1.7287 - val_mae: 0.9385 - lr: 0.0010
# Epoch 149/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2896 - mae: 0.2097 - val_loss: 1.7243 - val_mae: 0.9368 - lr: 0.0010
# Epoch 150/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2881 - mae: 0.2091 - val_loss: 1.7199 - val_mae: 0.9350 - lr: 0.0010
# Epoch 151/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2866 - mae: 0.2085 - val_loss: 1.7156 - val_mae: 0.9333 - lr: 0.0010
# Epoch 152/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2851 - mae: 0.2079 - val_loss: 1.7112 - val_mae: 0.9316 - lr: 0.0010
# Epoch 153/500
# 37/37 [==============================] - 0s 12ms/step - loss: 0.2836 - mae: 0.2073 - val_loss: 1.7071 - val_mae: 0.9299 - lr: 0.0010
# Epoch 154/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2822 - mae: 0.2066 - val_loss: 1.7028 - val_mae: 0.9283 - lr: 0.0010
# Epoch 155/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2808 - mae: 0.2061 - val_loss: 1.6987 - val_mae: 0.9266 - lr: 0.0010
# Epoch 156/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2793 - mae: 0.2054 - val_loss: 1.6946 - val_mae: 0.9249 - lr: 0.0010
# Epoch 157/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2779 - mae: 0.2048 - val_loss: 1.6907 - val_mae: 0.9233 - lr: 0.0010
# Epoch 158/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2765 - mae: 0.2042 - val_loss: 1.6867 - val_mae: 0.9216 - lr: 0.0010
# Epoch 159/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2751 - mae: 0.2036 - val_loss: 1.6828 - val_mae: 0.9200 - lr: 0.0010
# Epoch 160/500
# 37/37 [==============================] - 0s 12ms/step - loss: 0.2737 - mae: 0.2030 - val_loss: 1.6790 - val_mae: 0.9184 - lr: 0.0010
# Epoch 161/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2724 - mae: 0.2024 - val_loss: 1.6753 - val_mae: 0.9168 - lr: 0.0010
# Epoch 162/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2710 - mae: 0.2018 - val_loss: 1.6716 - val_mae: 0.9152 - lr: 0.0010
# Epoch 163/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2697 - mae: 0.2013 - val_loss: 1.6680 - val_mae: 0.9136 - lr: 0.0010
# Epoch 164/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2684 - mae: 0.2006 - val_loss: 1.6645 - val_mae: 0.9121 - lr: 0.0010
# Epoch 165/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2670 - mae: 0.2001 - val_loss: 1.6610 - val_mae: 0.9106 - lr: 0.0010
# Epoch 166/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2657 - mae: 0.1995 - val_loss: 1.6576 - val_mae: 0.9091 - lr: 0.0010
# Epoch 167/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2645 - mae: 0.1989 - val_loss: 1.6543 - val_mae: 0.9076 - lr: 0.0010
# Epoch 168/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2632 - mae: 0.1983 - val_loss: 1.6509 - val_mae: 0.9061 - lr: 0.0010
# Epoch 169/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2619 - mae: 0.1978 - val_loss: 1.6477 - val_mae: 0.9046 - lr: 0.0010
# Epoch 170/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2607 - mae: 0.1972 - val_loss: 1.6445 - val_mae: 0.9031 - lr: 0.0010
# Epoch 171/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2594 - mae: 0.1967 - val_loss: 1.6413 - val_mae: 0.9017 - lr: 0.0010
# Epoch 172/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2582 - mae: 0.1961 - val_loss: 1.6383 - val_mae: 0.9002 - lr: 0.0010
# Epoch 173/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2570 - mae: 0.1956 - val_loss: 1.6353 - val_mae: 0.8988 - lr: 0.0010
# Epoch 174/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2558 - mae: 0.1950 - val_loss: 1.6323 - val_mae: 0.8974 - lr: 0.0010
# Epoch 175/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2546 - mae: 0.1944 - val_loss: 1.6294 - val_mae: 0.8960 - lr: 0.0010
# Epoch 176/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2534 - mae: 0.1939 - val_loss: 1.6266 - val_mae: 0.8946 - lr: 0.0010
# Epoch 177/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2522 - mae: 0.1933 - val_loss: 1.6238 - val_mae: 0.8933 - lr: 0.0010
# Epoch 178/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2511 - mae: 0.1928 - val_loss: 1.6210 - val_mae: 0.8919 - lr: 0.0010
# Epoch 179/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2499 - mae: 0.1923 - val_loss: 1.6183 - val_mae: 0.8906 - lr: 0.0010
# Epoch 180/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2488 - mae: 0.1917 - val_loss: 1.6157 - val_mae: 0.8893 - lr: 0.0010
# Epoch 181/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2477 - mae: 0.1912 - val_loss: 1.6131 - val_mae: 0.8880 - lr: 0.0010
# Epoch 182/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2466 - mae: 0.1906 - val_loss: 1.6106 - val_mae: 0.8867 - lr: 0.0010
# Epoch 183/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2455 - mae: 0.1901 - val_loss: 1.6082 - val_mae: 0.8855 - lr: 0.0010
# Epoch 184/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2443 - mae: 0.1896 - val_loss: 1.6058 - val_mae: 0.8842 - lr: 0.0010
# Epoch 185/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2433 - mae: 0.1891 - val_loss: 1.6034 - val_mae: 0.8830 - lr: 0.0010
# Epoch 186/500
# 37/37 [==============================] - 0s 12ms/step - loss: 0.2422 - mae: 0.1886 - val_loss: 1.6011 - val_mae: 0.8818 - lr: 0.0010
# Epoch 187/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2411 - mae: 0.1881 - val_loss: 1.5988 - val_mae: 0.8805 - lr: 0.0010
# Epoch 188/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2401 - mae: 0.1876 - val_loss: 1.5966 - val_mae: 0.8793 - lr: 0.0010
# Epoch 189/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2390 - mae: 0.1870 - val_loss: 1.5945 - val_mae: 0.8781 - lr: 0.0010
# Epoch 190/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2380 - mae: 0.1865 - val_loss: 1.5923 - val_mae: 0.8769 - lr: 0.0010
# Epoch 191/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2370 - mae: 0.1861 - val_loss: 1.5903 - val_mae: 0.8758 - lr: 0.0010
# Epoch 192/500
# 37/37 [==============================] - 0s 12ms/step - loss: 0.2360 - mae: 0.1856 - val_loss: 1.5882 - val_mae: 0.8747 - lr: 0.0010
# Epoch 193/500
# 37/37 [==============================] - 0s 12ms/step - loss: 0.2350 - mae: 0.1851 - val_loss: 1.5863 - val_mae: 0.8736 - lr: 0.0010
# Epoch 194/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2340 - mae: 0.1846 - val_loss: 1.5843 - val_mae: 0.8724 - lr: 0.0010
# Epoch 195/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2330 - mae: 0.1840 - val_loss: 1.5824 - val_mae: 0.8713 - lr: 0.0010
# Epoch 196/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2320 - mae: 0.1835 - val_loss: 1.5805 - val_mae: 0.8702 - lr: 0.0010
# Epoch 197/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2310 - mae: 0.1830 - val_loss: 1.5787 - val_mae: 0.8692 - lr: 0.0010
# Epoch 198/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2301 - mae: 0.1826 - val_loss: 1.5769 - val_mae: 0.8681 - lr: 0.0010
# Epoch 199/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2291 - mae: 0.1821 - val_loss: 1.5751 - val_mae: 0.8670 - lr: 0.0010
# Epoch 200/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2282 - mae: 0.1816 - val_loss: 1.5734 - val_mae: 0.8659 - lr: 0.0010
# Epoch 201/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2272 - mae: 0.1811 - val_loss: 1.5718 - val_mae: 0.8649 - lr: 0.0010
# Epoch 202/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2263 - mae: 0.1806 - val_loss: 1.5701 - val_mae: 0.8639 - lr: 0.0010
# Epoch 203/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2254 - mae: 0.1802 - val_loss: 1.5685 - val_mae: 0.8629 - lr: 0.0010
# Epoch 204/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2244 - mae: 0.1796 - val_loss: 1.5670 - val_mae: 0.8619 - lr: 0.0010
# Epoch 205/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2235 - mae: 0.1792 - val_loss: 1.5655 - val_mae: 0.8609 - lr: 0.0010
# Epoch 206/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2226 - mae: 0.1787 - val_loss: 1.5640 - val_mae: 0.8599 - lr: 0.0010
# Epoch 207/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2217 - mae: 0.1782 - val_loss: 1.5626 - val_mae: 0.8590 - lr: 0.0010
# Epoch 208/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2209 - mae: 0.1778 - val_loss: 1.5610 - val_mae: 0.8579 - lr: 0.0010
# Epoch 209/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2200 - mae: 0.1773 - val_loss: 1.5598 - val_mae: 0.8571 - lr: 0.0010
# Epoch 210/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2191 - mae: 0.1769 - val_loss: 1.5583 - val_mae: 0.8561 - lr: 0.0010
# Epoch 211/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2183 - mae: 0.1764 - val_loss: 1.5571 - val_mae: 0.8552 - lr: 0.0010
# Epoch 212/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2174 - mae: 0.1760 - val_loss: 1.5558 - val_mae: 0.8543 - lr: 0.0010
# Epoch 213/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2166 - mae: 0.1755 - val_loss: 1.5544 - val_mae: 0.8534 - lr: 0.0010
# Epoch 214/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2157 - mae: 0.1751 - val_loss: 1.5533 - val_mae: 0.8525 - lr: 0.0010
# Epoch 215/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2149 - mae: 0.1746 - val_loss: 1.5520 - val_mae: 0.8517 - lr: 0.0010
# Epoch 216/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2141 - mae: 0.1742 - val_loss: 1.5509 - val_mae: 0.8508 - lr: 0.0010
# Epoch 217/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2133 - mae: 0.1738 - val_loss: 1.5497 - val_mae: 0.8499 - lr: 0.0010
# Epoch 218/500
# 37/37 [==============================] - 0s 12ms/step - loss: 0.2125 - mae: 0.1734 - val_loss: 1.5486 - val_mae: 0.8491 - lr: 0.0010
# Epoch 219/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2117 - mae: 0.1728 - val_loss: 1.5475 - val_mae: 0.8483 - lr: 0.0010
# Epoch 220/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2109 - mae: 0.1725 - val_loss: 1.5464 - val_mae: 0.8475 - lr: 0.0010
# Epoch 221/500
# 37/37 [==============================] - 0s 12ms/step - loss: 0.2101 - mae: 0.1720 - val_loss: 1.5454 - val_mae: 0.8467 - lr: 0.0010
# Epoch 222/500
# 37/37 [==============================] - 0s 12ms/step - loss: 0.2093 - mae: 0.1716 - val_loss: 1.5443 - val_mae: 0.8459 - lr: 0.0010
# Epoch 223/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2085 - mae: 0.1711 - val_loss: 1.5433 - val_mae: 0.8451 - lr: 0.0010
# Epoch 224/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2078 - mae: 0.1709 - val_loss: 1.5423 - val_mae: 0.8443 - lr: 0.0010
# Epoch 225/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2070 - mae: 0.1704 - val_loss: 1.5414 - val_mae: 0.8435 - lr: 0.0010
# Epoch 226/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2063 - mae: 0.1699 - val_loss: 1.5404 - val_mae: 0.8428 - lr: 0.0010
# Epoch 227/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2055 - mae: 0.1695 - val_loss: 1.5395 - val_mae: 0.8421 - lr: 0.0010
# Epoch 228/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2047 - mae: 0.1691 - val_loss: 1.5386 - val_mae: 0.8414 - lr: 0.0010
# Epoch 229/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2040 - mae: 0.1687 - val_loss: 1.5377 - val_mae: 0.8406 - lr: 0.0010
# Epoch 230/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2033 - mae: 0.1683 - val_loss: 1.5368 - val_mae: 0.8399 - lr: 0.0010
# Epoch 231/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2025 - mae: 0.1679 - val_loss: 1.5360 - val_mae: 0.8392 - lr: 0.0010
# Epoch 232/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2018 - mae: 0.1674 - val_loss: 1.5350 - val_mae: 0.8385 - lr: 0.0010
# Epoch 233/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2011 - mae: 0.1671 - val_loss: 1.5343 - val_mae: 0.8378 - lr: 0.0010
# Epoch 234/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.2004 - mae: 0.1667 - val_loss: 1.5335 - val_mae: 0.8372 - lr: 0.0010
# Epoch 235/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1997 - mae: 0.1663 - val_loss: 1.5328 - val_mae: 0.8365 - lr: 0.0010
# Epoch 236/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1990 - mae: 0.1659 - val_loss: 1.5319 - val_mae: 0.8358 - lr: 0.0010
# Epoch 237/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1983 - mae: 0.1656 - val_loss: 1.5313 - val_mae: 0.8352 - lr: 0.0010
# Epoch 238/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1976 - mae: 0.1652 - val_loss: 1.5305 - val_mae: 0.8346 - lr: 0.0010
# Epoch 239/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1970 - mae: 0.1648 - val_loss: 1.5298 - val_mae: 0.8339 - lr: 0.0010
# Epoch 240/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1963 - mae: 0.1644 - val_loss: 1.5291 - val_mae: 0.8333 - lr: 0.0010
# Epoch 241/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1956 - mae: 0.1640 - val_loss: 1.5284 - val_mae: 0.8327 - lr: 0.0010
# Epoch 242/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1949 - mae: 0.1636 - val_loss: 1.5278 - val_mae: 0.8322 - lr: 0.0010
# Epoch 243/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1943 - mae: 0.1633 - val_loss: 1.5271 - val_mae: 0.8316 - lr: 0.0010
# Epoch 244/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1936 - mae: 0.1630 - val_loss: 1.5264 - val_mae: 0.8310 - lr: 0.0010
# Epoch 245/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1930 - mae: 0.1626 - val_loss: 1.5259 - val_mae: 0.8304 - lr: 0.0010
# Epoch 246/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1923 - mae: 0.1622 - val_loss: 1.5252 - val_mae: 0.8299 - lr: 0.0010
# Epoch 247/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1917 - mae: 0.1619 - val_loss: 1.5246 - val_mae: 0.8293 - lr: 0.0010
# Epoch 248/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1910 - mae: 0.1615 - val_loss: 1.5240 - val_mae: 0.8288 - lr: 0.0010
# Epoch 249/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1904 - mae: 0.1612 - val_loss: 1.5235 - val_mae: 0.8283 - lr: 0.0010
# Epoch 250/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1898 - mae: 0.1608 - val_loss: 1.5228 - val_mae: 0.8277 - lr: 0.0010
# Epoch 251/500
# 37/37 [==============================] - 0s 12ms/step - loss: 0.1892 - mae: 0.1606 - val_loss: 1.5223 - val_mae: 0.8272 - lr: 0.0010
# Epoch 252/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1886 - mae: 0.1602 - val_loss: 1.5218 - val_mae: 0.8267 - lr: 0.0010
# Epoch 253/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1879 - mae: 0.1598 - val_loss: 1.5212 - val_mae: 0.8262 - lr: 0.0010
# Epoch 254/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1873 - mae: 0.1595 - val_loss: 1.5206 - val_mae: 0.8257 - lr: 0.0010
# Epoch 255/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1867 - mae: 0.1591 - val_loss: 1.5202 - val_mae: 0.8252 - lr: 0.0010
# Epoch 256/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1861 - mae: 0.1588 - val_loss: 1.5197 - val_mae: 0.8247 - lr: 0.0010
# Epoch 257/500
# 37/37 [==============================] - 0s 12ms/step - loss: 0.1855 - mae: 0.1584 - val_loss: 1.5192 - val_mae: 0.8242 - lr: 0.0010
# Epoch 258/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1849 - mae: 0.1581 - val_loss: 1.5186 - val_mae: 0.8236 - lr: 0.0010
# Epoch 259/500
# 37/37 [==============================] - 0s 12ms/step - loss: 0.1843 - mae: 0.1577 - val_loss: 1.5182 - val_mae: 0.8232 - lr: 0.0010
# Epoch 260/500
# 37/37 [==============================] - 0s 12ms/step - loss: 0.1837 - mae: 0.1574 - val_loss: 1.5177 - val_mae: 0.8228 - lr: 0.0010
# Epoch 261/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1831 - mae: 0.1571 - val_loss: 1.5172 - val_mae: 0.8223 - lr: 0.0010
# Epoch 262/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1826 - mae: 0.1568 - val_loss: 1.5169 - val_mae: 0.8219 - lr: 0.0010
# Epoch 263/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1820 - mae: 0.1565 - val_loss: 1.5164 - val_mae: 0.8214 - lr: 0.0010
# Epoch 264/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1814 - mae: 0.1561 - val_loss: 1.5159 - val_mae: 0.8210 - lr: 0.0010
# Epoch 265/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1809 - mae: 0.1558 - val_loss: 1.5155 - val_mae: 0.8205 - lr: 0.0010
# Epoch 266/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1803 - mae: 0.1555 - val_loss: 1.5151 - val_mae: 0.8201 - lr: 0.0010
# Epoch 267/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1797 - mae: 0.1551 - val_loss: 1.5146 - val_mae: 0.8197 - lr: 0.0010
# Epoch 268/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1792 - mae: 0.1549 - val_loss: 1.5142 - val_mae: 0.8193 - lr: 0.0010
# Epoch 269/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1786 - mae: 0.1546 - val_loss: 1.5138 - val_mae: 0.8188 - lr: 0.0010
# Epoch 270/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1781 - mae: 0.1543 - val_loss: 1.5135 - val_mae: 0.8185 - lr: 0.0010
# Epoch 271/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1776 - mae: 0.1540 - val_loss: 1.5130 - val_mae: 0.8181 - lr: 0.0010
# Epoch 272/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1770 - mae: 0.1537 - val_loss: 1.5126 - val_mae: 0.8178 - lr: 0.0010
# Epoch 273/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1765 - mae: 0.1535 - val_loss: 1.5122 - val_mae: 0.8174 - lr: 0.0010
# Epoch 274/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1760 - mae: 0.1532 - val_loss: 1.5118 - val_mae: 0.8170 - lr: 0.0010
# Epoch 275/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1754 - mae: 0.1529 - val_loss: 1.5116 - val_mae: 0.8166 - lr: 0.0010
# Epoch 276/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1749 - mae: 0.1525 - val_loss: 1.5111 - val_mae: 0.8162 - lr: 0.0010
# Epoch 277/500
# 37/37 [==============================] - 0s 12ms/step - loss: 0.1744 - mae: 0.1523 - val_loss: 1.5108 - val_mae: 0.8159 - lr: 0.0010
# Epoch 278/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1738 - mae: 0.1520 - val_loss: 1.5104 - val_mae: 0.8155 - lr: 0.0010
# Epoch 279/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1733 - mae: 0.1517 - val_loss: 1.5101 - val_mae: 0.8152 - lr: 0.0010
# Epoch 280/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1728 - mae: 0.1514 - val_loss: 1.5097 - val_mae: 0.8148 - lr: 0.0010
# Epoch 281/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1723 - mae: 0.1512 - val_loss: 1.5093 - val_mae: 0.8145 - lr: 0.0010
# Epoch 282/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1718 - mae: 0.1509 - val_loss: 1.5090 - val_mae: 0.8142 - lr: 0.0010
# Epoch 283/500
# 37/37 [==============================] - 0s 12ms/step - loss: 0.1713 - mae: 0.1506 - val_loss: 1.5086 - val_mae: 0.8139 - lr: 0.0010
# Epoch 284/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1708 - mae: 0.1503 - val_loss: 1.5083 - val_mae: 0.8135 - lr: 0.0010
# Epoch 285/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1703 - mae: 0.1501 - val_loss: 1.5080 - val_mae: 0.8131 - lr: 0.0010
# Epoch 286/500
# 37/37 [==============================] - 0s 12ms/step - loss: 0.1698 - mae: 0.1498 - val_loss: 1.5077 - val_mae: 0.8128 - lr: 0.0010
# Epoch 287/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1693 - mae: 0.1494 - val_loss: 1.5073 - val_mae: 0.8126 - lr: 0.0010
# Epoch 288/500
# 37/37 [==============================] - 0s 12ms/step - loss: 0.1688 - mae: 0.1493 - val_loss: 1.5070 - val_mae: 0.8123 - lr: 0.0010
# Epoch 289/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1684 - mae: 0.1490 - val_loss: 1.5067 - val_mae: 0.8120 - lr: 0.0010
# Epoch 290/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1679 - mae: 0.1488 - val_loss: 1.5064 - val_mae: 0.8117 - lr: 0.0010
# Epoch 291/500
# 37/37 [==============================] - 0s 12ms/step - loss: 0.1674 - mae: 0.1484 - val_loss: 1.5060 - val_mae: 0.8113 - lr: 0.0010
# Epoch 292/500
# 37/37 [==============================] - 0s 12ms/step - loss: 0.1669 - mae: 0.1482 - val_loss: 1.5058 - val_mae: 0.8111 - lr: 0.0010
# Epoch 293/500
# 37/37 [==============================] - 0s 12ms/step - loss: 0.1664 - mae: 0.1479 - val_loss: 1.5055 - val_mae: 0.8108 - lr: 0.0010
# Epoch 294/500
# 37/37 [==============================] - 0s 12ms/step - loss: 0.1659 - mae: 0.1478 - val_loss: 1.5052 - val_mae: 0.8106 - lr: 0.0010
# Epoch 295/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1655 - mae: 0.1475 - val_loss: 1.5050 - val_mae: 0.8102 - lr: 0.0010
# Epoch 296/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1650 - mae: 0.1472 - val_loss: 1.5047 - val_mae: 0.8100 - lr: 0.0010
# Epoch 297/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1646 - mae: 0.1470 - val_loss: 1.5044 - val_mae: 0.8096 - lr: 0.0010
# Epoch 298/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1641 - mae: 0.1467 - val_loss: 1.5043 - val_mae: 0.8094 - lr: 0.0010
# Epoch 299/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1636 - mae: 0.1463 - val_loss: 1.5039 - val_mae: 0.8091 - lr: 0.0010
# Epoch 300/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1632 - mae: 0.1462 - val_loss: 1.5036 - val_mae: 0.8089 - lr: 0.0010
# Epoch 301/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1627 - mae: 0.1459 - val_loss: 1.5033 - val_mae: 0.8086 - lr: 0.0010
# Epoch 302/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1623 - mae: 0.1457 - val_loss: 1.5031 - val_mae: 0.8083 - lr: 0.0010
# Epoch 303/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1618 - mae: 0.1454 - val_loss: 1.5027 - val_mae: 0.8081 - lr: 0.0010
# Epoch 304/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1614 - mae: 0.1452 - val_loss: 1.5024 - val_mae: 0.8079 - lr: 0.0010
# Epoch 305/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1609 - mae: 0.1450 - val_loss: 1.5022 - val_mae: 0.8076 - lr: 0.0010
# Epoch 306/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1605 - mae: 0.1447 - val_loss: 1.5019 - val_mae: 0.8074 - lr: 0.0010
# Epoch 307/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1601 - mae: 0.1446 - val_loss: 1.5017 - val_mae: 0.8072 - lr: 0.0010
# Epoch 308/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1596 - mae: 0.1442 - val_loss: 1.5013 - val_mae: 0.8069 - lr: 0.0010
# Epoch 309/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1592 - mae: 0.1440 - val_loss: 1.5012 - val_mae: 0.8067 - lr: 0.0010
# Epoch 310/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1587 - mae: 0.1438 - val_loss: 1.5009 - val_mae: 0.8065 - lr: 0.0010
# Epoch 311/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1583 - mae: 0.1436 - val_loss: 1.5006 - val_mae: 0.8063 - lr: 0.0010
# Epoch 312/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1579 - mae: 0.1434 - val_loss: 1.5003 - val_mae: 0.8061 - lr: 0.0010
# Epoch 313/500
# 37/37 [==============================] - 0s 12ms/step - loss: 0.1575 - mae: 0.1433 - val_loss: 1.5001 - val_mae: 0.8059 - lr: 0.0010
# Epoch 314/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1571 - mae: 0.1429 - val_loss: 1.4998 - val_mae: 0.8057 - lr: 0.0010
# Epoch 315/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1567 - mae: 0.1429 - val_loss: 1.4996 - val_mae: 0.8055 - lr: 0.0010
# Epoch 316/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1562 - mae: 0.1425 - val_loss: 1.4994 - val_mae: 0.8053 - lr: 0.0010
# Epoch 317/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1559 - mae: 0.1424 - val_loss: 1.4992 - val_mae: 0.8051 - lr: 0.0010
# Epoch 318/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1554 - mae: 0.1421 - val_loss: 1.4989 - val_mae: 0.8048 - lr: 0.0010
# Epoch 319/500
# 37/37 [==============================] - 0s 12ms/step - loss: 0.1550 - mae: 0.1419 - val_loss: 1.4987 - val_mae: 0.8047 - lr: 0.0010
# Epoch 320/500
# 37/37 [==============================] - 0s 12ms/step - loss: 0.1546 - mae: 0.1416 - val_loss: 1.4984 - val_mae: 0.8044 - lr: 0.0010
# Epoch 321/500
# 37/37 [==============================] - 0s 12ms/step - loss: 0.1542 - mae: 0.1415 - val_loss: 1.4983 - val_mae: 0.8042 - lr: 0.0010
# Epoch 322/500
# 37/37 [==============================] - 0s 12ms/step - loss: 0.1538 - mae: 0.1412 - val_loss: 1.4980 - val_mae: 0.8040 - lr: 0.0010
# Epoch 323/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1534 - mae: 0.1410 - val_loss: 1.4978 - val_mae: 0.8039 - lr: 0.0010
# Epoch 324/500
# 37/37 [==============================] - 0s 12ms/step - loss: 0.1530 - mae: 0.1408 - val_loss: 1.4975 - val_mae: 0.8037 - lr: 0.0010
# Epoch 325/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1526 - mae: 0.1405 - val_loss: 1.4973 - val_mae: 0.8035 - lr: 0.0010
# Epoch 326/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1522 - mae: 0.1404 - val_loss: 1.4971 - val_mae: 0.8033 - lr: 0.0010
# Epoch 327/500
# 37/37 [==============================] - 0s 12ms/step - loss: 0.1518 - mae: 0.1402 - val_loss: 1.4969 - val_mae: 0.8031 - lr: 0.0010
# Epoch 328/500
# ...
# Epoch 393/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1297 - mae: 0.1286 - val_loss: 1.4852 - val_mae: 0.7939 - lr: 0.0010
# Epoch 394/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1294 - mae: 0.1284 - val_loss: 1.4849 - val_mae: 0.7936 - lr: 0.0010
# Epoch 395/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1292 - mae: 0.1284 - val_loss: 1.4847 - val_mae: 0.7937 - lr: 0.0010
# Epoch 396/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1289 - mae: 0.1283 - val_loss: 1.4846 - val_mae: 0.7935 - lr: 0.0010
# Epoch 397/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1286 - mae: 0.1282 - val_loss: 1.4844 - val_mae: 0.7935 - lr: 0.0010
# Epoch 398/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1283 - mae: 0.1280 - val_loss: 1.4844 - val_mae: 0.7933 - lr: 0.0010
# Epoch 399/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1280 - mae: 0.1278 - val_loss: 1.4841 - val_mae: 0.7932 - lr: 0.0010
# Epoch 400/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1277 - mae: 0.1277 - val_loss: 1.4841 - val_mae: 0.7931 - lr: 0.0010
# Epoch 401/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1275 - mae: 0.1274 - val_loss: 1.4838 - val_mae: 0.7929 - lr: 0.0010
# Epoch 402/500
# 37/37 [==============================] - 0s 12ms/step - loss: 0.1272 - mae: 0.1275 - val_loss: 1.4839 - val_mae: 0.7929 - lr: 0.0010
# Epoch 403/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1269 - mae: 0.1271 - val_loss: 1.4835 - val_mae: 0.7926 - lr: 0.0010
# Epoch 404/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1267 - mae: 0.1271 - val_loss: 1.4835 - val_mae: 0.7927 - lr: 0.0010
# Epoch 405/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1264 - mae: 0.1269 - val_loss: 1.4832 - val_mae: 0.7925 - lr: 0.0010
# Epoch 406/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1261 - mae: 0.1268 - val_loss: 1.4832 - val_mae: 0.7924 - lr: 0.0010
# Epoch 407/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1258 - mae: 0.1266 - val_loss: 1.4831 - val_mae: 0.7922 - lr: 0.0010
# Epoch 408/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1256 - mae: 0.1265 - val_loss: 1.4829 - val_mae: 0.7921 - lr: 0.0010
# Epoch 409/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1253 - mae: 0.1263 - val_loss: 1.4828 - val_mae: 0.7921 - lr: 0.0010
# Epoch 410/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1251 - mae: 0.1263 - val_loss: 1.4825 - val_mae: 0.7921 - lr: 0.0010
# Epoch 411/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1248 - mae: 0.1261 - val_loss: 1.4823 - val_mae: 0.7920 - lr: 0.0010
# Epoch 412/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1246 - mae: 0.1261 - val_loss: 1.4820 - val_mae: 0.7919 - lr: 0.0010
# Epoch 413/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1243 - mae: 0.1260 - val_loss: 1.4820 - val_mae: 0.7919 - lr: 0.0010
# Epoch 414/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1240 - mae: 0.1258 - val_loss: 1.4819 - val_mae: 0.7917 - lr: 0.0010
# Epoch 415/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1238 - mae: 0.1256 - val_loss: 1.4818 - val_mae: 0.7916 - lr: 0.0010
# Epoch 416/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1235 - mae: 0.1255 - val_loss: 1.4818 - val_mae: 0.7915 - lr: 0.0010
# Epoch 417/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1232 - mae: 0.1252 - val_loss: 1.4816 - val_mae: 0.7913 - lr: 0.0010
# Epoch 418/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1230 - mae: 0.1252 - val_loss: 1.4817 - val_mae: 0.7912 - lr: 0.0010
# Epoch 419/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1227 - mae: 0.1249 - val_loss: 1.4814 - val_mae: 0.7910 - lr: 0.0010
# Epoch 420/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1225 - mae: 0.1249 - val_loss: 1.4814 - val_mae: 0.7911 - lr: 0.0010
# Epoch 421/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1222 - mae: 0.1247 - val_loss: 1.4810 - val_mae: 0.7908 - lr: 0.0010
# Epoch 422/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1220 - mae: 0.1248 - val_loss: 1.4810 - val_mae: 0.7908 - lr: 0.0010
# Epoch 423/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1218 - mae: 0.1245 - val_loss: 1.4809 - val_mae: 0.7906 - lr: 0.0010
# Epoch 424/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1216 - mae: 0.1244 - val_loss: 1.4807 - val_mae: 0.7906 - lr: 0.0010
# Epoch 425/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1213 - mae: 0.1243 - val_loss: 1.4805 - val_mae: 0.7905 - lr: 0.0010
# Epoch 426/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1211 - mae: 0.1243 - val_loss: 1.4804 - val_mae: 0.7904 - lr: 0.0010
# Epoch 427/500
# 37/37 [==============================] - 0s 12ms/step - loss: 0.1208 - mae: 0.1240 - val_loss: 1.4802 - val_mae: 0.7903 - lr: 0.0010
# Epoch 428/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1206 - mae: 0.1240 - val_loss: 1.4802 - val_mae: 0.7904 - lr: 0.0010
# Epoch 429/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1203 - mae: 0.1238 - val_loss: 1.4799 - val_mae: 0.7902 - lr: 0.0010
# Epoch 430/500
# 37/37 [==============================] - 0s 12ms/step - loss: 0.1201 - mae: 0.1239 - val_loss: 1.4797 - val_mae: 0.7902 - lr: 0.0010
# Epoch 431/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1198 - mae: 0.1236 - val_loss: 1.4796 - val_mae: 0.7900 - lr: 0.0010
# Epoch 432/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1196 - mae: 0.1235 - val_loss: 1.4794 - val_mae: 0.7900 - lr: 0.0010
# Epoch 433/500
# 37/37 [==============================] - 0s 12ms/step - loss: 0.1194 - mae: 0.1234 - val_loss: 1.4794 - val_mae: 0.7899 - lr: 0.0010
# Epoch 434/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1191 - mae: 0.1233 - val_loss: 1.4792 - val_mae: 0.7898 - lr: 0.0010
# Epoch 435/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1189 - mae: 0.1231 - val_loss: 1.4792 - val_mae: 0.7897 - lr: 0.0010
# Epoch 436/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1187 - mae: 0.1231 - val_loss: 1.4791 - val_mae: 0.7896 - lr: 0.0010
# Epoch 437/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1184 - mae: 0.1228 - val_loss: 1.4789 - val_mae: 0.7894 - lr: 0.0010
# Epoch 438/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1182 - mae: 0.1228 - val_loss: 1.4788 - val_mae: 0.7894 - lr: 0.0010
# Epoch 439/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1180 - mae: 0.1227 - val_loss: 1.4787 - val_mae: 0.7893 - lr: 0.0010
# Epoch 440/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1178 - mae: 0.1226 - val_loss: 1.4786 - val_mae: 0.7892 - lr: 0.0010
# Epoch 441/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1176 - mae: 0.1225 - val_loss: 1.4785 - val_mae: 0.7891 - lr: 0.0010
# Epoch 442/500
# 37/37 [==============================] - 0s 12ms/step - loss: 0.1173 - mae: 0.1223 - val_loss: 1.4783 - val_mae: 0.7890 - lr: 0.0010
# Epoch 443/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1171 - mae: 0.1222 - val_loss: 1.4782 - val_mae: 0.7890 - lr: 0.0010
# Epoch 444/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1169 - mae: 0.1221 - val_loss: 1.4779 - val_mae: 0.7889 - lr: 0.0010
# Epoch 445/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1166 - mae: 0.1220 - val_loss: 1.4780 - val_mae: 0.7889 - lr: 0.0010
# Epoch 446/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1164 - mae: 0.1218 - val_loss: 1.4777 - val_mae: 0.7886 - lr: 0.0010
# Epoch 447/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1162 - mae: 0.1217 - val_loss: 1.4778 - val_mae: 0.7886 - lr: 0.0010
# Epoch 448/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1159 - mae: 0.1215 - val_loss: 1.4776 - val_mae: 0.7884 - lr: 0.0010
# Epoch 449/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1157 - mae: 0.1214 - val_loss: 1.4774 - val_mae: 0.7884 - lr: 0.0010
# Epoch 450/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1155 - mae: 0.1213 - val_loss: 1.4774 - val_mae: 0.7883 - lr: 0.0010
# Epoch 451/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1153 - mae: 0.1212 - val_loss: 1.4772 - val_mae: 0.7882 - lr: 0.0010
# Epoch 452/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1151 - mae: 0.1211 - val_loss: 1.4770 - val_mae: 0.7881 - lr: 0.0010
# Epoch 453/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1148 - mae: 0.1211 - val_loss: 1.4769 - val_mae: 0.7881 - lr: 0.0010
# Epoch 454/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1146 - mae: 0.1210 - val_loss: 1.4767 - val_mae: 0.7880 - lr: 0.0010
# Epoch 455/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1144 - mae: 0.1208 - val_loss: 1.4766 - val_mae: 0.7879 - lr: 0.0010
# Epoch 456/500
# 37/37 [==============================] - 0s 12ms/step - loss: 0.1142 - mae: 0.1208 - val_loss: 1.4763 - val_mae: 0.7879 - lr: 0.0010
# Epoch 457/500
# 37/37 [==============================] - 0s 12ms/step - loss: 0.1140 - mae: 0.1208 - val_loss: 1.4764 - val_mae: 0.7880 - lr: 0.0010
# Epoch 458/500
# 37/37 [==============================] - 0s 12ms/step - loss: 0.1138 - mae: 0.1206 - val_loss: 1.4760 - val_mae: 0.7877 - lr: 0.0010
# Epoch 459/500
# 37/37 [==============================] - 0s 12ms/step - loss: 0.1136 - mae: 0.1206 - val_loss: 1.4762 - val_mae: 0.7878 - lr: 0.0010
# Epoch 460/500
# 37/37 [==============================] - 0s 12ms/step - loss: 0.1134 - mae: 0.1204 - val_loss: 1.4759 - val_mae: 0.7875 - lr: 0.0010
# Epoch 461/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1132 - mae: 0.1203 - val_loss: 1.4759 - val_mae: 0.7876 - lr: 0.0010
# Epoch 462/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1129 - mae: 0.1202 - val_loss: 1.4757 - val_mae: 0.7873 - lr: 0.0010
# Epoch 463/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1127 - mae: 0.1201 - val_loss: 1.4758 - val_mae: 0.7874 - lr: 0.0010
# Epoch 464/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1125 - mae: 0.1198 - val_loss: 1.4757 - val_mae: 0.7871 - lr: 0.0010
# Epoch 465/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1123 - mae: 0.1198 - val_loss: 1.4757 - val_mae: 0.7871 - lr: 0.0010
# Epoch 466/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1121 - mae: 0.1196 - val_loss: 1.4755 - val_mae: 0.7868 - lr: 0.0010
# Epoch 467/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1119 - mae: 0.1196 - val_loss: 1.4754 - val_mae: 0.7869 - lr: 0.0010
# Epoch 468/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1117 - mae: 0.1193 - val_loss: 1.4753 - val_mae: 0.7866 - lr: 0.0010
# Epoch 469/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1115 - mae: 0.1193 - val_loss: 1.4752 - val_mae: 0.7868 - lr: 0.0010
# Epoch 470/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1112 - mae: 0.1192 - val_loss: 1.4750 - val_mae: 0.7865 - lr: 0.0010
# Epoch 471/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1111 - mae: 0.1191 - val_loss: 1.4749 - val_mae: 0.7866 - lr: 0.0010
# Epoch 472/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1108 - mae: 0.1190 - val_loss: 1.4747 - val_mae: 0.7863 - lr: 0.0010
# Epoch 473/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1107 - mae: 0.1189 - val_loss: 1.4746 - val_mae: 0.7865 - lr: 0.0010
# Epoch 474/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1105 - mae: 0.1188 - val_loss: 1.4745 - val_mae: 0.7863 - lr: 0.0010
# Epoch 475/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1103 - mae: 0.1187 - val_loss: 1.4744 - val_mae: 0.7864 - lr: 0.0010
# Epoch 476/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1101 - mae: 0.1187 - val_loss: 1.4744 - val_mae: 0.7862 - lr: 0.0010
# Epoch 477/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1099 - mae: 0.1186 - val_loss: 1.4743 - val_mae: 0.7862 - lr: 0.0010
# Epoch 478/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1097 - mae: 0.1184 - val_loss: 1.4741 - val_mae: 0.7860 - lr: 0.0010
# Epoch 479/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1095 - mae: 0.1183 - val_loss: 1.4740 - val_mae: 0.7861 - lr: 0.0010
# Epoch 480/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1093 - mae: 0.1183 - val_loss: 1.4738 - val_mae: 0.7859 - lr: 0.0010
# Epoch 481/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1091 - mae: 0.1182 - val_loss: 1.4739 - val_mae: 0.7859 - lr: 0.0010
# Epoch 482/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1089 - mae: 0.1181 - val_loss: 1.4737 - val_mae: 0.7857 - lr: 0.0010
# Epoch 483/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1087 - mae: 0.1179 - val_loss: 1.4737 - val_mae: 0.7857 - lr: 0.0010
# Epoch 484/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1085 - mae: 0.1178 - val_loss: 1.4734 - val_mae: 0.7855 - lr: 0.0010
# Epoch 485/500
# 37/37 [==============================] - 0s 12ms/step - loss: 0.1083 - mae: 0.1177 - val_loss: 1.4733 - val_mae: 0.7856 - lr: 0.0010
# Epoch 486/500
# 37/37 [==============================] - 0s 12ms/step - loss: 0.1081 - mae: 0.1177 - val_loss: 1.4733 - val_mae: 0.7855 - lr: 0.0010
# Epoch 487/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1080 - mae: 0.1176 - val_loss: 1.4731 - val_mae: 0.7854 - lr: 0.0010
# Epoch 488/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1078 - mae: 0.1176 - val_loss: 1.4730 - val_mae: 0.7853 - lr: 0.0010
# Epoch 489/500
# 37/37 [==============================] - 0s 12ms/step - loss: 0.1076 - mae: 0.1174 - val_loss: 1.4730 - val_mae: 0.7852 - lr: 0.0010
# Epoch 490/500
# 37/37 [==============================] - 0s 12ms/step - loss: 0.1074 - mae: 0.1173 - val_loss: 1.4729 - val_mae: 0.7852 - lr: 0.0010
# Epoch 491/500
# 37/37 [==============================] - 0s 12ms/step - loss: 0.1072 - mae: 0.1172 - val_loss: 1.4728 - val_mae: 0.7852 - lr: 0.0010
# Epoch 492/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1070 - mae: 0.1172 - val_loss: 1.4727 - val_mae: 0.7851 - lr: 0.0010
# Epoch 493/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1069 - mae: 0.1171 - val_loss: 1.4726 - val_mae: 0.7851 - lr: 0.0010
# Epoch 494/500
# 37/37 [==============================] - 0s 12ms/step - loss: 0.1067 - mae: 0.1170 - val_loss: 1.4724 - val_mae: 0.7849 - lr: 0.0010
# Epoch 495/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1065 - mae: 0.1169 - val_loss: 1.4724 - val_mae: 0.7849 - lr: 0.0010
# Epoch 496/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1063 - mae: 0.1167 - val_loss: 1.4722 - val_mae: 0.7848 - lr: 0.0010
# Epoch 497/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1061 - mae: 0.1167 - val_loss: 1.4720 - val_mae: 0.7849 - lr: 0.0010
# Epoch 498/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1059 - mae: 0.1167 - val_loss: 1.4719 - val_mae: 0.7847 - lr: 0.0010
# Epoch 499/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1057 - mae: 0.1165 - val_loss: 1.4720 - val_mae: 0.7848 - lr: 0.0010
# Epoch 500/500
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1056 - mae: 0.1165 - val_loss: 1.4717 - val_mae: 0.7846 - lr: 0.0010
# CPU times: user 7min 42s, sys: 19.8 s, total: 8min 2s
# Wall time: 3min 37s

# %%
y_true = ratings_test
predictions = model.predict([user_ids_test, item_ids_test])
# Out:
# 30004/30004 [==============================] - 41s 1ms/step

# %%
# Evaluar el modelo con el conjunto de prueba
loss, mae = model.evaluate([user_ids_test, item_ids_test], ratings_test)
print(f'Test Loss: {loss:.4f}')
print(f'Test MAE: {mae:.4f}')
# Out:
# 30004/30004 [==============================] - 77s 3ms/step - loss: 1.4760 - mae: 0.7858
# Test Loss: 1.4760
# Test MAE: 0.7858

# %%
# MSE
mse = mean_squared_error(y_true, predictions)
print(f"MSE: {mse:.4f}")

# RMSE
rmse = np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

# MAE
mae = mean_absolute_error(y_true, predictions)
print(f"MAE: {mae:.4f}")

# MAPE (Mean Absolute Percentage Error)
mape = np.mean(np.abs((y_true - predictions.flatten()) / y_true)) * 100
print(f"MAPE: {mape:.2f}%")
# Out:
# MSE: 1.3905
# RMSE: 1.1792
# MAE: 0.7858
# MAPE: 34.94%

# %% [markdown]
# # Recomedanción

# %%
# Seleccionar un usuario al azar del conjunto de prueba
usuario_id_test_encoded = random.choice(user_ids_test)

# Decodificar el ID del usuario para obtener el ID original
usuario_id_test = reviewerID_encoder.inverse_transform([usuario_id_test_encoded])[0]

# Identificar los ítems que el usuario ha calificado en el conjunto de prueba
indices_usuario = np.where(user_ids_test == usuario_id_test_encoded)[0]
items_calificados_test_encoded = item_ids_test[indices_usuario]
calificaciones_reales_test = ratings_test[indices_usuario]

# Predecir las calificaciones para estos ítems
calificaciones_predichas = model.predict([np.array([usuario_id_test_encoded] * len(items_calificados_test_encoded)), items_calificados_test_encoded])

# Decodificar los ítems para obtener los ID originales
items_calificados_test = asin_encoder.inverse_transform(items_calificados_test_encoded)

# Comparar las calificaciones predichas con las reales
comparacion = list(zip(items_calificados_test, calificaciones_reales_test, calificaciones_predichas.flatten()))

# Suponiendo que 'items_calificados_test' contiene los IDs originales de los ítems
recomendaciones_df = pd.DataFrame({
    'asin': items_calificados_test,
    'Calificación Real': calificaciones_reales_test,
    'Calificación Predicha': calificaciones_predichas.flatten()
})

recomendaciones_df = recomendaciones_df.merge(sentimiento[['asin', 'cluster']], on='asin', how='left')
recomendaciones_df.rename(columns={'cluster': 'Sentimiento'}, inplace=True)

# Mostrar las recomendaciones
print(f"Recomendaciones para el usuario {usuario_id_test}:")
for index, row in recomendaciones_df.iterrows():
    print(f"Ítem: {row['asin']}, Calificación Real: {row['Calificación Real']}, Calificación Predicha: {row['Calificación Predicha']}, Sentimiento: {row['Sentimiento']}")
# Out:
# 1/1 [==============================] - 0s 29ms/step
# Recomendaciones para el usuario A2N3UF4KPCZFXB:
# Ítem: B0047RL1B4, Calificación Real: 3.0, Calificación Predicha: 4.322533130645752, Sentimiento: Positivo
# Ítem: B000BIGOY2, Calificación Real: 5.0, Calificación Predicha: 4.604306697845459, Sentimiento: Neutro

# %%
# Seleccionar un usuario al azar del conjunto de prueba
usuario_id_test_encoded = random.choice(user_ids_test)

# Decodificar el ID del usuario para obtener el ID original
usuario_id = reviewerID_encoder.inverse_transform([usuario_id_test_encoded])[0]

# Lista de todos los ítems únicos en el dataset
items_unicos = np.unique(data['asin'].values)

# Ítems que el usuario ya ha calificado
items_calificados = data[data['reviewerID_encoded'] == usuario_id_test_encoded]['asin'].tolist()

# Ítems para predecir
items_a_predecir = [item for item in items_unicos if item not in items_calificados]

# Convierte los ítems a su representación codificada
items_a_predecir_encoded = asin_encoder.transform(items_a_predecir)

# Predecir la calificación para cada ítem no calificado
predicciones = model.predict([np.array([usuario_id_test_encoded] * len(items_a_predecir_encoded)), items_a_predecir_encoded])

# Emparejar cada ítem con su predicción
items_predicciones = list(zip(items_a_predecir, predicciones.flatten()))

# Ordenar por la calificación predicha más alta
items_recomendados = sorted(items_predicciones, key=lambda x: x[1], reverse=True)

# Tomar los top N recomendaciones
top_n = 5
top_recomendaciones = items_recomendados[:top_n]

# Crear un DataFrame a partir de las recomendaciones
recomendaciones_df = pd.DataFrame(top_recomendaciones, columns=['asin', 'Calificación Predicha'])

# Unir con el DataFrame 'sentimiento' para obtener el sentimiento asociado a cada ítem
recomendaciones_df = recomendaciones_df.merge(sentimiento[['asin', 'cluster']], on='asin', how='left')

# Renombrar la columna 'cluster' a 'Sentimiento' para claridad
recomendaciones_df.rename(columns={'cluster': 'Sentimiento'}, inplace=True)

# Mostrar las recomendaciones con el sentimiento
print(f"Recomendaciones para el usuario {usuario_id}:")
for index, row in recomendaciones_df.iterrows():
    print(f"Ítem: {row['asin']}, Calificación Predicha: {row['Calificación Predicha']}, Sentimiento: {row['Sentimiento']}")
# Out:
# 4814/4814 [==============================] - 7s 1ms/step
# Recomendaciones para el usuario A1J9MZ1T69YPKO:
# Ítem: B002QG6P9G, Calificación Predicha: 4.981610298156738, Sentimiento: Positivo
# Ítem: B0002ZW5UQ, Calificación Predicha: 4.977645397186279, Sentimiento: Neutro
# Ítem: B0013U0EYI, Calificación Predicha: 4.976828575134277, Sentimiento: Neutro
# Ítem: B002K6F79Q, Calificación Predicha: 4.973778247833252, Sentimiento: Neutro
# Ítem: B000NG80GM, Calificación Predicha: 4.9720458984375, Sentimiento: Neutro

# %% [markdown]
# # Modelo de Filtrado Colaborativo usando Red Neuronal Multicapa con Keras:

# %% [markdown]
# Funcionamiento:
#
# Estos sistemas toman características de los ítems y/o usuarios y las pasan a través de una o varias capas de neuronas para obtener una predicción.
# Las redes neuronales son capaces de capturar interacciones no lineales entre características, lo que las hace poderosas para tareas de modelado complejas.
#
# Ventajas:
#
# Capacidad de modelar relaciones no lineales.
#
# Flexibilidad para incorporar múltiples fuentes de datos o características.
#
# Puede manejar arranques en frío al incorporar características de nuevos ítems o usuarios.
#
# Desventajas:
#
# Mayor costo computacional en comparación con los sistemas basados únicamente en embeddings.
#
# Riesgo de sobreajuste si no se tiene un conjunto de datos lo suficientemente grande.

# %% [markdown]
# Ahora el código incluye regularización en los embeddings, early stopping para detener el entrenamiento si el modelo deja de mejorar en el conjunto de validación, y reducción de la tasa de aprendizaje si el error en el conjunto de validación no mejora después de algunas épocas. Estas adiciones deberían ayudar a mejorar la capacidad de generalización del modelo.

# %%
df['user_id'] = df['reviewerID'].astype('category').cat.codes.values
df['item_id'] = df['asin'].astype('category').cat.codes.values

# Número de usuarios e ítems
n_users = df['user_id'].nunique()
n_items = df['item_id'].nunique()

# Hiperparámetros
hidden_units = [128, 64, 32]
dropout_rate = 0.2
l2_reg = 1e-6

# Arquitectura del modelo
user_input = Input(shape=[1], name='user_input')
item_input = Input(shape=[1], name='item_input')
concat = Concatenate()([user_input, item_input])
dense = concat
for units in hidden_units:
    dense = Dense(units, activation='relu', kernel_regularizer=l2(l2_reg))(dense)
    dense = Dropout(dropout_rate)(dense)

# Agregar una capa de activación sigmoid y escalar a [0, 5]
output = Dense(1, activation='sigmoid', kernel_regularizer=l2(l2_reg))(dense)  # Función de activación sigmoid
output = Lambda(lambda x: x * 5)(output)  # Escalar las predicciones al rango [0, 5]

model = Model(inputs=[user_input, item_input], outputs=output)
model.compile(optimizer=Adam(0.001), loss='mean_squared_error')

# %%
# Callbacks
early_stop = EarlyStopping(monitor='val_loss', patience=50)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=50, min_lr=1e-5)

# %%
# Datos para entrenamiento
user_data = df['user_id'].values
item_data = df['item_id'].values
rating_data = df['overall'].values

# División en entrenamiento y prueba
(user_ids_temp, user_ids_test, item_ids_temp, item_ids_test, ratings_temp, ratings_test) = train_test_split(
    user_ids, item_ids, ratings, test_size=0.2, random_state=42)

# División del conjunto de entrenamiento en entrenamiento y validación
(user_ids_train, user_ids_val, item_ids_train, item_ids_val, ratings_train, ratings_val) = train_test_split(
    user_ids_temp, item_ids_temp, ratings_temp, test_size=0.25, random_state=42)  # 0.25 x 0.8 = 0.2

# %%
# %%time
# Entrenamiento del modelo
history = model.fit([user_ids_train, item_ids_train], ratings_train,
    epochs=500,validation_data=([user_ids_val, item_ids_val], ratings_val),
    batch_size=80000,verbose=1,callbacks=[early_stop, reduce_lr])
# Out:
# Epoch 1/500
# 37/37 [==============================] - 3s 18ms/step - loss: 1.9356 - val_loss: 1.8981 - lr: 0.0010
# Epoch 2/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9094 - val_loss: 1.8981 - lr: 0.0010
# Epoch 3/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9092 - val_loss: 1.8981 - lr: 0.0010
# Epoch 4/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 5/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 0.0010
# Epoch 6/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 7/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 8/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 9/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 0.0010
# Epoch 10/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 11/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 12/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 13/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 14/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 15/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 16/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 17/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 18/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 0.0010
# Epoch 19/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 0.0010
# Epoch 20/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 21/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 22/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 0.0010
# Epoch 23/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 24/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 25/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 0.0010
# Epoch 26/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 27/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 0.0010
# Epoch 28/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 29/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 0.0010
# Epoch 30/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 0.0010
# Epoch 31/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 0.0010
# Epoch 32/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 0.0010
# Epoch 33/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 0.0010
# Epoch 34/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 0.0010
# Epoch 35/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 0.0010
# Epoch 36/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 37/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 0.0010
# Epoch 38/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 0.0010
# Epoch 39/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 0.0010
# Epoch 40/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 0.0010
# Epoch 41/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 0.0010
# Epoch 42/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 0.0010
# Epoch 43/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 0.0010
# Epoch 44/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 0.0010
# Epoch 45/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 0.0010
# Epoch 46/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 0.0010
# Epoch 47/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 0.0010
# Epoch 48/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 0.0010
# Epoch 49/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 0.0010
# Epoch 50/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 0.0010
# Epoch 51/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 0.0010
# Epoch 52/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 53/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 54/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 55/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 56/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 57/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 58/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 59/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 60/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 61/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 62/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 63/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 64/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 65/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 66/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 67/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 68/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 69/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 70/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 71/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 72/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 73/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 74/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 75/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 76/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 77/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 78/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 79/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 80/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 81/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 82/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 83/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 84/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 85/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 86/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 87/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 88/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 89/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 90/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 91/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 92/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 93/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 94/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 95/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 96/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 97/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 98/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 99/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 100/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 101/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 102/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 103/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 104/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 105/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 106/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 107/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 108/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 109/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 110/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 111/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 112/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 113/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 114/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 115/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 116/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 117/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 118/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 119/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 120/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 121/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 122/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 123/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 124/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 125/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 126/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 127/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 128/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 129/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 130/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 131/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 132/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 133/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 134/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 135/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 136/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 137/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 138/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 139/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 140/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 141/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 142/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 143/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 144/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 145/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 146/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 147/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 148/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 149/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 150/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 151/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 152/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 153/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 154/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 155/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 156/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 157/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 158/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 159/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 160/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 161/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 162/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 163/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 164/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 165/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 166/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 167/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 168/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 169/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 170/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 171/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 172/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 173/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 174/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 175/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 176/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 177/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 178/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 179/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 180/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 181/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 182/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 183/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 184/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 185/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 186/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 187/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 188/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 189/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 190/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 191/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 192/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 193/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 194/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 195/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 196/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 197/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 198/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 199/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 200/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 201/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 202/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 203/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 204/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 205/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 206/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 207/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 208/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 209/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 210/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 211/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 212/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 213/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 214/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 215/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 216/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 217/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 218/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 219/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 220/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 221/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 222/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 223/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 224/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 225/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 226/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 227/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 228/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 229/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 230/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 231/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 232/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 233/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 234/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 235/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 236/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 237/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 238/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 239/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 240/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 241/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 242/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 243/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 244/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 245/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 246/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 247/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 248/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 249/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 250/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 251/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 252/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 253/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 254/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 255/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 256/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 257/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 258/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 259/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 260/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 261/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 262/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 263/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 264/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 265/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 266/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 267/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 268/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 269/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 270/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 271/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 272/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 273/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 274/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 275/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 276/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 277/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 278/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 279/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 280/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 281/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 282/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 283/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 284/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 285/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 286/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 287/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 288/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 289/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 290/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 291/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 292/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 293/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 294/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 295/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 296/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 297/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 298/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 299/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 300/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 301/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 302/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 303/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 304/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 305/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 306/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 307/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 308/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 309/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 310/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 311/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 312/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 313/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 314/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 315/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 316/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 317/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 318/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 319/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 320/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 321/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 322/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 323/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 324/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 325/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 326/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 327/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 328/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 329/500
# 37/37 [==============================] - 0s 14ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 330/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 331/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 332/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 333/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 334/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 335/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 336/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 337/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 338/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 339/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 340/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 341/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 342/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 343/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 344/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 345/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 346/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 347/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 348/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 349/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 350/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 351/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 352/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 353/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 354/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 355/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 356/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 357/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 358/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 359/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 360/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 361/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 362/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 363/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 364/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 365/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 366/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 367/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 368/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 369/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 370/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 371/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 372/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 373/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 374/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 375/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 376/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 377/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 378/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 379/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 380/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 381/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 382/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 383/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 384/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 385/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 386/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 387/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 388/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 389/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 390/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 391/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 392/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 393/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 394/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 395/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 396/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 397/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 398/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 399/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 400/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 401/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 402/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 403/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 404/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 405/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 406/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 407/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 408/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 409/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 410/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 411/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 412/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 413/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 414/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 415/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 416/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 417/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 418/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 419/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 420/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 421/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 422/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 423/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 424/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 425/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 426/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 427/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 428/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 429/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 430/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 431/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 432/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 433/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 434/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 435/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 436/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 437/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 438/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 439/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 440/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 441/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 442/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 443/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 444/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 445/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 446/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 447/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 448/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 449/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 450/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 451/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 452/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 453/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 454/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 455/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 456/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 457/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 458/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 459/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 460/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 461/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 462/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 463/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 464/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 465/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 466/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 467/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 468/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 469/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 470/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 471/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 472/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 473/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 474/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 475/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 476/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 477/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 478/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 479/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 480/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 481/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 482/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 483/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 484/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 485/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 486/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 487/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 488/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 489/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 490/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 491/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 492/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 493/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 494/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 495/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 496/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 497/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 498/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 499/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 500/500
# 37/37 [==============================] - 0s 13ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# CPU times: user 7min, sys: 18.7 s, total: 7min 19s
# Wall time: 4min 1s

# %%
# Evaluar el modelo
y_true = ratings_test
predictions = model.predict([user_ids_test, item_ids_test])
# Out:
# 30004/30004 [==============================] - 45s 1ms/step

# %%
# MSE y RMSE
mse = mean_squared_error(y_true, predictions)
rmse = np.sqrt(mse)

# MAE
mae = mean_absolute_error(y_true, predictions)

# Funciones MAPE
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    non_zero_idx = y_true != 0  # Para evitar divisiones por cero
    return np.mean(np.abs((y_true[non_zero_idx] - y_pred[non_zero_idx]) / y_true[non_zero_idx])) * 100

def compute_mape_by_batch(y_true, predictions, batch_size=50000):
    mape_sum = 0
    num_batches = int(np.ceil(len(y_true) / batch_size))

    for i in range(num_batches):
        start_idx = i * batch_size
        end_idx = start_idx + batch_size

        batch_y_true = y_true[start_idx:end_idx]
        batch_predictions = predictions[start_idx:end_idx]

        mape_sum += mean_absolute_percentage_error(batch_y_true, batch_predictions)

    return mape_sum / num_batches

# Luego llamas a la función
mape = compute_mape_by_batch(y_true, predictions)

print(f'MSE: {mse}')
print(f'RMSE: {rmse}')
print(f'MAE: {mae}')
print(f'MAPE: {mape}%')
# Out:
# MSE: 1.91015555428256
# RMSE: 1.3820837725270345
# MAE: 0.7401227977898481
# MAPE: 40.77108911682409%

# %% [markdown]
# # Recomendación

# %%
# Seleccionar un usuario al azar del conjunto de prueba
usuario_id_test_encoded = random.choice(user_ids_test)

# Decodificar el ID del usuario para obtener el ID original
usuario_id_test = reviewerID_encoder.inverse_transform([usuario_id_test_encoded])[0]

# Identificar los ítems que el usuario ha calificado en el conjunto de prueba
indices_usuario = np.where(user_ids_test == usuario_id_test_encoded)[0]
items_calificados_test_encoded = item_ids_test[indices_usuario]
calificaciones_reales_test = ratings_test[indices_usuario]

# Predecir las calificaciones para estos ítems
calificaciones_predichas = model.predict([np.array([usuario_id_test_encoded] * len(items_calificados_test_encoded)), items_calificados_test_encoded])

# Decodificar los ítems para obtener los ID originales
items_calificados_test = asin_encoder.inverse_transform(items_calificados_test_encoded)

# Comparar las calificaciones predichas con las reales
comparacion = list(zip(items_calificados_test, calificaciones_reales_test, calificaciones_predichas.flatten()))

# Suponiendo que 'items_calificados_test' contiene los IDs originales de los ítems
recomendaciones_df = pd.DataFrame({
    'asin': items_calificados_test,
    'Calificación Real': calificaciones_reales_test,
    'Calificación Predicha': calificaciones_predichas.flatten()
})

recomendaciones_df = recomendaciones_df.merge(sentimiento[['asin', 'cluster']], on='asin', how='left')
recomendaciones_df.rename(columns={'cluster': 'Sentimiento'}, inplace=True)

# Mostrar las recomendaciones
print(f"Recomendaciones para el usuario {usuario_id_test}:")
for index, row in recomendaciones_df.iterrows():
    print(f"Ítem: {row['asin']}, Calificación Real: {row['Calificación Real']}, Calificación Predicha: {row['Calificación Predicha']}, Sentimiento: {row['Sentimiento']}")
# Out:
# 1/1 [==============================] - 0s 21ms/step
# Recomendaciones para el usuario AQZ8ATLZ889GB:
# Ítem: B00MLR65VS, Calificación Real: 3.0, Calificación Predicha: 5.0, Sentimiento: Neutro
# Ítem: B00R1OAUNA, Calificación Real: 5.0, Calificación Predicha: 5.0, Sentimiento: Neutro
# Ítem: B010TX3RBQ, Calificación Real: 5.0, Calificación Predicha: 5.0, Sentimiento: Positivo
# Ítem: B00MOIPERK, Calificación Real: 5.0, Calificación Predicha: 5.0, Sentimiento: Positivo

# %%
# Seleccionar un usuario al azar del conjunto de prueba
usuario_id_test_encoded = random.choice(user_ids_test)

# Decodificar el ID del usuario para obtener el ID original
usuario_id = reviewerID_encoder.inverse_transform([usuario_id_test_encoded])[0]

# Lista de todos los ítems únicos en el dataset
items_unicos = np.unique(data['asin'].values)

# Ítems que el usuario ya ha calificado
items_calificados = data[data['reviewerID_encoded'] == usuario_id_test_encoded]['asin'].tolist()

# Ítems para predecir
items_a_predecir = [item for item in items_unicos if item not in items_calificados]

# Convierte los ítems a su representación codificada
items_a_predecir_encoded = asin_encoder.transform(items_a_predecir)

# Predecir la calificación para cada ítem no calificado
predicciones = model.predict([np.array([usuario_id_test_encoded] * len(items_a_predecir_encoded)), items_a_predecir_encoded])

# Emparejar cada ítem con su predicción
items_predicciones = list(zip(items_a_predecir, predicciones.flatten()))

# Ordenar por la calificación predicha más alta
items_recomendados = sorted(items_predicciones, key=lambda x: x[1], reverse=True)

# Tomar los top N recomendaciones
top_n = 5
top_recomendaciones = items_recomendados[:top_n]

# Crear un DataFrame a partir de las recomendaciones
recomendaciones_df = pd.DataFrame(top_recomendaciones, columns=['asin', 'Calificación Predicha'])

# Unir con el DataFrame 'sentimiento' para obtener el sentimiento asociado a cada ítem
recomendaciones_df = recomendaciones_df.merge(sentimiento[['asin', 'cluster']], on='asin', how='left')

# Renombrar la columna 'cluster' a 'Sentimiento' para claridad
recomendaciones_df.rename(columns={'cluster': 'Sentimiento'}, inplace=True)

# Mostrar las recomendaciones con el sentimiento
print(f"Recomendaciones para el usuario {usuario_id}:")
for index, row in recomendaciones_df.iterrows():
    print(f"Ítem: {row['asin']}, Calificación Predicha: {row['Calificación Predicha']}, Sentimiento: {row['Sentimiento']}")
# Out:
# 4814/4814 [==============================] - 7s 2ms/step
# Recomendaciones para el usuario A2S0S3Z9JHPPFK:
# Ítem: 0871167042, Calificación Predicha: 5.0, Sentimiento: Positivo
# Ítem: 1519588135, Calificación Predicha: 5.0, Sentimiento: Neutro
# Ítem: 1579652956, Calificación Predicha: 5.0, Sentimiento: Positivo
# Ítem: 1936023857, Calificación Predicha: 5.0, Sentimiento: Positivo
# Ítem: 5120053017, Calificación Predicha: 5.0, Sentimiento: Neutro

# %% [markdown]
# # Modelo de Filtrado Colaborativo usando Red Neuronal Multicapa y Embedding con Keras:
#
# Otra enfoque popular para filtrado colaborativo es utilizar redes neuronales multicapa, que esencialmente aprenden características no lineales de los datos. Vamos a construir un modelo que fusiona los embeddings de usuarios y artículos (por ejemplo, películas) en una red neuronal densa.
#
# Este enfoque, que combina embeddings y redes neuronales multicapa, puede capturar interacciones más complejas y no lineales entre usuarios y artículos. Sin embargo, es crucial prestar atención al sobreajuste y asegurarse de que el modelo no esté simplemente memorizando los datos. Por lo tanto, es recomendable emplear técnicas de regularización, ajustar hiperparámetros y validar el rendimiento con un conjunto de datos de validación.

# %% [markdown]
# Funcionamiento:
#
# Combina lo mejor de ambos mundos. Primero, se utilizan embeddings para convertir ítems y usuarios en representaciones vectoriales densas. Luego, estas representaciones se pasan a través de una red neuronal para hacer la predicción.
#
# El proceso generalmente comienza con capas de embedding que convierten identificadores de usuarios e ítems en vectores. Estos vectores luego se pasan a través de capas densas para obtener la predicción final.
#
# Ventajas:
#
# Capacidad de capturar patrones subyacentes en los datos mediante embeddings y modelar interacciones no lineales mediante la red neuronal.
#
# Flexibilidad para incorporar características adicionales.
#
# Potencialmente más preciso que cualquiera de los otros dos métodos por separado.
#
# Desventajas:
#
# Mayor complejidad en el modelado y entrenamiento.
#
# Mayor costo computacional.
#
# Requiere un ajuste más cuidadoso y riesgo de sobreajuste si no se gestiona adecuadamente.

# %% [markdown]
# Regularización L2: Agregar una regularización L2 a las capas de embedding y densas para prevenir el sobreajuste.
#
# Early Stopping: Añadir una callback de early stopping para detener el entrenamiento cuando no haya mejora en el conjunto de validación durante un cierto número de épocas.
#
# Ajuste de la tasa de aprendizaje: Utilizar la callback ReduceLROnPlateau para reducir la tasa de aprendizaje cuando no haya mejora en el conjunto de validación.
#
# Métricas adicionales: Puedes monitorizar otras métricas como el error absoluto medio (MAE) durante el entrenamiento.

# %%
# Convertir reviewerID y asin a índices numéricos secuenciales
df['user_id'] = df['reviewerID'].astype('category').cat.codes.values
df['item_id'] = df['asin'].astype('category').cat.codes.values

# Número de usuarios e ítems
n_users = df['user_id'].nunique()
n_items = df['item_id'].nunique()

# Hiperparámetros
n_latent_factors = 50
hidden_units = [128, 64]
dropout_rate = 0.2
l2_reg = 1e-4

# Entradas
user_input = Input(shape=[1], name='user_input')
item_input = Input(shape=[1], name='item_input')

# Embeddings con regularización L2
user_embedding = Embedding(n_users, n_latent_factors, embeddings_regularizer=l2(l2_reg), name='user_embedding')(user_input)
item_embedding = Embedding(n_items, n_latent_factors, embeddings_regularizer=l2(l2_reg), name='item_embedding')(item_input)

user_vec = Flatten(name='flatten_users')(user_embedding)
item_vec = Flatten(name='flatten_items')(item_embedding)
concat = Concatenate()([user_vec, item_vec])

# Capas densas
dense = concat
for units in hidden_units:
    dense = Dense(units, activation='relu', kernel_regularizer=l2(l2_reg))(dense)
    dense = Dropout(dropout_rate)(dense)

# Agregar una capa de activación sigmoid y escalar a [0, 5]
output = Dense(1, activation='sigmoid', kernel_regularizer=l2(l2_reg))(dense)  # Función de activación sigmoid
output = Lambda(lambda x: x * 5)(output)  # Escalar las predicciones al rango [0, 5]

# Modelo
model = Model(inputs=[user_input, item_input], outputs=output)
model.compile(optimizer=Adam(0.001), loss='mean_squared_error', metrics=['mae'])

# %%
# Callbacks
early_stop = EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=50, min_lr=1e-5)

# %%
# Entrenamiento
user_data = df['user_id'].values
item_data = df['item_id'].values
rating_data = df['overall'].values

# División en entrenamiento y prueba
(user_ids_temp, user_ids_test, item_ids_temp, item_ids_test, ratings_temp, ratings_test) = train_test_split(
    user_ids, item_ids, ratings, test_size=0.2, random_state=42)

# División del conjunto de entrenamiento en entrenamiento y validación
(user_ids_train, user_ids_val, item_ids_train, item_ids_val, ratings_train, ratings_val) = train_test_split(
    user_ids_temp, item_ids_temp, ratings_temp, test_size=0.25, random_state=42)  # 0.25 x 0.8 = 0.2

# %%
# %%time
history = model.fit([user_ids_train, item_ids_train], ratings_train,
                    epochs=500,validation_data=([user_ids_val, item_ids_val], ratings_val),
                    batch_size=80000,verbose=1,callbacks=[early_stop, reduce_lr])
# Out:
# Epoch 1/500
# 37/37 [==============================] - 4s 67ms/step - loss: 5.9615 - mae: 1.5502 - val_loss: 2.0601 - val_mae: 0.9238 - lr: 0.0010
# Epoch 2/500
# 37/37 [==============================] - 2s 52ms/step - loss: 1.5950 - mae: 0.8480 - val_loss: 1.3922 - val_mae: 0.8746 - lr: 0.0010
# Epoch 3/500
# 37/37 [==============================] - 2s 43ms/step - loss: 1.2299 - mae: 0.7847 - val_loss: 1.4081 - val_mae: 0.8116 - lr: 0.0010
# Epoch 4/500
# 37/37 [==============================] - 2s 43ms/step - loss: 1.0883 - mae: 0.6935 - val_loss: 1.4304 - val_mae: 0.7991 - lr: 0.0010
# Epoch 5/500
# 37/37 [==============================] - 2s 43ms/step - loss: 1.0284 - mae: 0.6577 - val_loss: 1.4506 - val_mae: 0.7929 - lr: 0.0010
# Epoch 6/500
# 37/37 [==============================] - 2s 44ms/step - loss: 1.0039 - mae: 0.6384 - val_loss: 1.4697 - val_mae: 0.7905 - lr: 0.0010
# Epoch 7/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.9856 - mae: 0.6246 - val_loss: 1.4819 - val_mae: 0.7889 - lr: 0.0010
# Epoch 8/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.9664 - mae: 0.6131 - val_loss: 1.4950 - val_mae: 0.7888 - lr: 0.0010
# Epoch 9/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.9455 - mae: 0.6032 - val_loss: 1.5070 - val_mae: 0.7878 - lr: 0.0010
# Epoch 10/500
# 37/37 [==============================] - 2s 43ms/step - loss: 0.9272 - mae: 0.5940 - val_loss: 1.5121 - val_mae: 0.7882 - lr: 0.0010
# Epoch 11/500
# 37/37 [==============================] - 2s 43ms/step - loss: 0.9103 - mae: 0.5860 - val_loss: 1.5182 - val_mae: 0.7875 - lr: 0.0010
# Epoch 12/500
# 37/37 [==============================] - 2s 43ms/step - loss: 0.8946 - mae: 0.5786 - val_loss: 1.5231 - val_mae: 0.7888 - lr: 0.0010
# Epoch 13/500
# 37/37 [==============================] - 2s 43ms/step - loss: 0.8804 - mae: 0.5718 - val_loss: 1.5261 - val_mae: 0.7886 - lr: 0.0010
# Epoch 14/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.8672 - mae: 0.5664 - val_loss: 1.5304 - val_mae: 0.7886 - lr: 0.0010
# Epoch 15/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.8520 - mae: 0.5597 - val_loss: 1.5294 - val_mae: 0.7871 - lr: 0.0010
# Epoch 16/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.8392 - mae: 0.5529 - val_loss: 1.5296 - val_mae: 0.7854 - lr: 0.0010
# Epoch 17/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.8260 - mae: 0.5468 - val_loss: 1.5327 - val_mae: 0.7838 - lr: 0.0010
# Epoch 18/500
# 37/37 [==============================] - 2s 43ms/step - loss: 0.8121 - mae: 0.5391 - val_loss: 1.5422 - val_mae: 0.7864 - lr: 0.0010
# Epoch 19/500
# 37/37 [==============================] - 2s 43ms/step - loss: 0.7999 - mae: 0.5324 - val_loss: 1.5393 - val_mae: 0.7813 - lr: 0.0010
# Epoch 20/500
# 37/37 [==============================] - 2s 43ms/step - loss: 0.7901 - mae: 0.5254 - val_loss: 1.5489 - val_mae: 0.7809 - lr: 0.0010
# Epoch 21/500
# 37/37 [==============================] - 2s 43ms/step - loss: 0.7770 - mae: 0.5159 - val_loss: 1.5531 - val_mae: 0.7760 - lr: 0.0010
# Epoch 22/500
# 37/37 [==============================] - 2s 43ms/step - loss: 0.7642 - mae: 0.5057 - val_loss: 1.5673 - val_mae: 0.7766 - lr: 0.0010
# Epoch 23/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.7530 - mae: 0.4976 - val_loss: 1.5821 - val_mae: 0.7803 - lr: 0.0010
# Epoch 24/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.7393 - mae: 0.4870 - val_loss: 1.5873 - val_mae: 0.7779 - lr: 0.0010
# Epoch 25/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.7257 - mae: 0.4777 - val_loss: 1.5979 - val_mae: 0.7735 - lr: 0.0010
# Epoch 26/500
# 37/37 [==============================] - 2s 43ms/step - loss: 0.7147 - mae: 0.4687 - val_loss: 1.6017 - val_mae: 0.7725 - lr: 0.0010
# Epoch 27/500
# 37/37 [==============================] - 2s 43ms/step - loss: 0.7042 - mae: 0.4606 - val_loss: 1.6110 - val_mae: 0.7711 - lr: 0.0010
# Epoch 28/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.6918 - mae: 0.4518 - val_loss: 1.6164 - val_mae: 0.7714 - lr: 0.0010
# Epoch 29/500
# 37/37 [==============================] - 2s 43ms/step - loss: 0.6825 - mae: 0.4457 - val_loss: 1.6194 - val_mae: 0.7685 - lr: 0.0010
# Epoch 30/500
# 37/37 [==============================] - 2s 43ms/step - loss: 0.6685 - mae: 0.4369 - val_loss: 1.6266 - val_mae: 0.7708 - lr: 0.0010
# Epoch 31/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.6550 - mae: 0.4295 - val_loss: 1.6289 - val_mae: 0.7668 - lr: 0.0010
# Epoch 32/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.6488 - mae: 0.4246 - val_loss: 1.6353 - val_mae: 0.7671 - lr: 0.0010
# Epoch 33/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.6368 - mae: 0.4173 - val_loss: 1.6375 - val_mae: 0.7673 - lr: 0.0010
# Epoch 34/500
# 37/37 [==============================] - 2s 43ms/step - loss: 0.6251 - mae: 0.4106 - val_loss: 1.6408 - val_mae: 0.7633 - lr: 0.0010
# Epoch 35/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.6173 - mae: 0.4038 - val_loss: 1.6418 - val_mae: 0.7618 - lr: 0.0010
# Epoch 36/500
# 37/37 [==============================] - 2s 43ms/step - loss: 0.6059 - mae: 0.3974 - val_loss: 1.6405 - val_mae: 0.7618 - lr: 0.0010
# Epoch 37/500
# 37/37 [==============================] - 2s 43ms/step - loss: 0.5976 - mae: 0.3923 - val_loss: 1.6387 - val_mae: 0.7587 - lr: 0.0010
# Epoch 38/500
# 37/37 [==============================] - 2s 43ms/step - loss: 0.5873 - mae: 0.3861 - val_loss: 1.6418 - val_mae: 0.7581 - lr: 0.0010
# Epoch 39/500
# 37/37 [==============================] - 2s 43ms/step - loss: 0.5764 - mae: 0.3794 - val_loss: 1.6418 - val_mae: 0.7605 - lr: 0.0010
# Epoch 40/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.5687 - mae: 0.3759 - val_loss: 1.6421 - val_mae: 0.7559 - lr: 0.0010
# Epoch 41/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.5587 - mae: 0.3699 - val_loss: 1.6503 - val_mae: 0.7619 - lr: 0.0010
# Epoch 42/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.5505 - mae: 0.3655 - val_loss: 1.6492 - val_mae: 0.7611 - lr: 0.0010
# Epoch 43/500
# 37/37 [==============================] - 2s 43ms/step - loss: 0.5432 - mae: 0.3616 - val_loss: 1.6482 - val_mae: 0.7597 - lr: 0.0010
# Epoch 44/500
# 37/37 [==============================] - 2s 43ms/step - loss: 0.5350 - mae: 0.3568 - val_loss: 1.6452 - val_mae: 0.7576 - lr: 0.0010
# Epoch 45/500
# 37/37 [==============================] - 2s 43ms/step - loss: 0.5275 - mae: 0.3535 - val_loss: 1.6460 - val_mae: 0.7581 - lr: 0.0010
# Epoch 46/500
# 37/37 [==============================] - 2s 43ms/step - loss: 0.5199 - mae: 0.3493 - val_loss: 1.6444 - val_mae: 0.7582 - lr: 0.0010
# Epoch 47/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.5094 - mae: 0.3437 - val_loss: 1.6439 - val_mae: 0.7583 - lr: 0.0010
# Epoch 48/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.5031 - mae: 0.3412 - val_loss: 1.6479 - val_mae: 0.7588 - lr: 0.0010
# Epoch 49/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.4978 - mae: 0.3381 - val_loss: 1.6325 - val_mae: 0.7551 - lr: 0.0010
# Epoch 50/500
# 37/37 [==============================] - 2s 43ms/step - loss: 0.4893 - mae: 0.3338 - val_loss: 1.6435 - val_mae: 0.7575 - lr: 0.0010
# Epoch 51/500
# 37/37 [==============================] - 2s 43ms/step - loss: 0.4800 - mae: 0.3290 - val_loss: 1.6361 - val_mae: 0.7525 - lr: 0.0010
# Epoch 52/500
# 37/37 [==============================] - 2s 54ms/step - loss: 0.4741 - mae: 0.3268 - val_loss: 1.6409 - val_mae: 0.7596 - lr: 0.0010
# CPU times: user 1min 30s, sys: 3.83 s, total: 1min 34s
# Wall time: 1min 26s

# %%
# Predicciones
y_true = ratings_test
predictions = model.predict([user_ids_test, item_ids_test])
# Out:
# 30004/30004 [==============================] - 45s 2ms/step

# %%
# MSE y RMSE
mse = mean_squared_error(y_true, predictions)
rmse = np.sqrt(mse)

# MAE
mae = mean_absolute_error(y_true, predictions)

# MAPE
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    non_zero_idx = y_true != 0  # Para evitar divisiones por cero
    return np.mean(np.abs((y_true[non_zero_idx] - y_pred[non_zero_idx]) / y_true[non_zero_idx])) * 100

def compute_mape_by_batch(y_true, predictions, batch_size=50000):
    mape_sum = 0
    num_batches = int(np.ceil(len(y_true) / batch_size))

    for i in range(num_batches):
        start_idx = i * batch_size
        end_idx = start_idx + batch_size

        batch_y_true = y_true[start_idx:end_idx]
        batch_predictions = predictions[start_idx:end_idx]

        mape_sum += mean_absolute_percentage_error(batch_y_true, batch_predictions)

    return mape_sum / num_batches

# Luego llamas a la función
mape = compute_mape_by_batch(y_true, predictions)

print(f'MSE: {mse}')
print(f'RMSE: {rmse}')
print(f'MAE: {mae}')
print(f'MAPE: {mape}%')
# Out:
# MSE: 1.2274721416811742
# RMSE: 1.1079134179533952
# MAE: 0.8753315500893905
# MAPE: 38.799056155574256%

# %% [markdown]
# # Recomendación

# %%
# Seleccionar un usuario al azar del conjunto de prueba
usuario_id_test_encoded = random.choice(user_ids_test)

# Decodificar el ID del usuario para obtener el ID original
usuario_id_test = reviewerID_encoder.inverse_transform([usuario_id_test_encoded])[0]

# Identificar los ítems que el usuario ha calificado en el conjunto de prueba
indices_usuario = np.where(user_ids_test == usuario_id_test_encoded)[0]
items_calificados_test_encoded = item_ids_test[indices_usuario]
calificaciones_reales_test = ratings_test[indices_usuario]

# Predecir las calificaciones para estos ítems
calificaciones_predichas = model.predict([np.array([usuario_id_test_encoded] * len(items_calificados_test_encoded)), items_calificados_test_encoded])

# Decodificar los ítems para obtener los ID originales
items_calificados_test = asin_encoder.inverse_transform(items_calificados_test_encoded)

# Comparar las calificaciones predichas con las reales
comparacion = list(zip(items_calificados_test, calificaciones_reales_test, calificaciones_predichas.flatten()))

# Suponiendo que 'items_calificados_test' contiene los IDs originales de los ítems
recomendaciones_df = pd.DataFrame({
    'asin': items_calificados_test,
    'Calificación Real': calificaciones_reales_test,
    'Calificación Predicha': calificaciones_predichas.flatten()
})

recomendaciones_df = recomendaciones_df.merge(sentimiento[['asin', 'cluster']], on='asin', how='left')
recomendaciones_df.rename(columns={'cluster': 'Sentimiento'}, inplace=True)

# Mostrar las recomendaciones
print(f"Recomendaciones para el usuario {usuario_id_test}:")
for index, row in recomendaciones_df.iterrows():
    print(f"Ítem: {row['asin']}, Calificación Real: {row['Calificación Real']}, Calificación Predicha: {row['Calificación Predicha']}, Sentimiento: {row['Sentimiento']}")
# Out:
# 1/1 [==============================] - 0s 19ms/step
# Recomendaciones para el usuario A3MSML4BHRP3RC:
# Ítem: B0058YYLEY, Calificación Real: 5.0, Calificación Predicha: 4.682139873504639, Sentimiento: Positivo

# %%
# Seleccionar un usuario al azar del conjunto de prueba
usuario_id_test_encoded = random.choice(user_ids_test)

# Decodificar el ID del usuario para obtener el ID original
usuario_id = reviewerID_encoder.inverse_transform([usuario_id_test_encoded])[0]

# Lista de todos los ítems únicos en el dataset
items_unicos = np.unique(data['asin'].values)

# Ítems que el usuario ya ha calificado
items_calificados = data[data['reviewerID_encoded'] == usuario_id_test_encoded]['asin'].tolist()

# Ítems para predecir
items_a_predecir = [item for item in items_unicos if item not in items_calificados]

# Convierte los ítems a su representación codificada
items_a_predecir_encoded = asin_encoder.transform(items_a_predecir)

# Predecir la calificación para cada ítem no calificado
predicciones = model.predict([np.array([usuario_id_test_encoded] * len(items_a_predecir_encoded)), items_a_predecir_encoded])

# Emparejar cada ítem con su predicción
items_predicciones = list(zip(items_a_predecir, predicciones.flatten()))

# Ordenar por la calificación predicha más alta
items_recomendados = sorted(items_predicciones, key=lambda x: x[1], reverse=True)

# Tomar los top N recomendaciones
top_n = 5
top_recomendaciones = items_recomendados[:top_n]

# Crear un DataFrame a partir de las recomendaciones
recomendaciones_df = pd.DataFrame(top_recomendaciones, columns=['asin', 'Calificación Predicha'])

# Unir con el DataFrame 'sentimiento' para obtener el sentimiento asociado a cada ítem
recomendaciones_df = recomendaciones_df.merge(sentimiento[['asin', 'cluster']], on='asin', how='left')

# Renombrar la columna 'cluster' a 'Sentimiento' para claridad
recomendaciones_df.rename(columns={'cluster': 'Sentimiento'}, inplace=True)

# Mostrar las recomendaciones con el sentimiento
print(f"Recomendaciones para el usuario {usuario_id}:")
for index, row in recomendaciones_df.iterrows():
    print(f"Ítem: {row['asin']}, Calificación Predicha: {row['Calificación Predicha']}, Sentimiento: {row['Sentimiento']}")
# Out:
# 4814/4814 [==============================] - 7s 2ms/step
# Recomendaciones para el usuario A88BPHHETU0SD:
# Ítem: B00V5RV0ME, Calificación Predicha: 4.8303680419921875, Sentimiento: Positivo
# Ítem: B00RLSCLJM, Calificación Predicha: 4.817205429077148, Sentimiento: Positivo
# Ítem: B0007M11XQ, Calificación Predicha: 4.8141889572143555, Sentimiento: Positivo
# Ítem: B00KKXCJQU, Calificación Predicha: 4.8032965660095215, Sentimiento: Positivo
# Ítem: B000JFBHGW, Calificación Predicha: 4.796957492828369, Sentimiento: Positivo

# %% [markdown]
# Estas métricas te ayudarán a tener una mejor idea del desempeño de tu modelo. Por ejemplo:
#
# MSE y RMSE son útiles cuando quieres penalizar grandes errores.
#
# MAE te da una idea del error medio sin considerar la dirección del error.
#
# MAPE es útil cuando quieres representar el error en términos porcentuales.
#
# Para una evaluación completa, es recomendable utilizar un conjunto de validación aparte (es decir, no solo depender del validation_split). Esto asegura que estás evaluando el desempeño en datos que el modelo nunca ha visto durante el entrenamiento.

# %% [markdown]
# En resumen, la elección del tipo de sistema de recomendación dependerá de la naturaleza del conjunto de datos, las características disponibles, las capacidades computacionales y el tipo de relaciones o interacciones que se desean capturar. A menudo, un enfoque híbrido (como el sistema que combina embeddings y redes neuronales) ofrece un buen equilibrio entre precisión y eficiencia.
