# %% [markdown]
# # Paso 1: Importar Librerías de Python

# %%
#pip install scikit-surprise
# Out:
# Collecting scikit-surprise
#   Downloading scikit-surprise-1.1.3.tar.gz (771 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 772.0/772.0 kB 9.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: joblib>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.3.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.11.3)
# Building wheels for collected packages: scikit-surprise
#   Building wheel for scikit-surprise (setup.py) ... done
#   Created wheel for scikit-surprise: filename=scikit_surprise-1.1.3-cp310-cp310-linux_x86_64.whl size=3163489 sha256=1aa320b2d14a61de59645068aa7ec8bc5fe6cc2ce8da1f3387671fe4741276d0
#   Stored in directory: /root/.cache/pip/wheels/a5/ca/a8/4e28def53797fdc4363ca4af740db15a9c2f1595ebc51fb445
# Successfully built scikit-surprise
# Installing collected packages: scikit-surprise
# Successfully installed scikit-surprise-1.1.3

# %%
# Análisis de datos y manipulación
import pandas as pd
import numpy as np

# Visualización de datos
import matplotlib.pyplot as plt
import seaborn as sns

# Utilidades de fechas
from datetime import datetime

# Integración con Google Colab
from google.colab import drive

# Machine Learning: Preprocesamiento y división de datos
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# Machine Learning: Métricas
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.metrics.pairwise import cosine_similarity

# Machine Learning: Modelado y validación
from surprise import SVD, Reader, Dataset, accuracy
from surprise.model_selection import train_test_split, GridSearchCV

# Deep Learning: Construcción de modelos y capas
from keras.models import Model
from keras.layers import Input, Embedding, Flatten, Concatenate, Dense, Dropout, Dot

# Deep Learning: Optimización y regularización
from keras.optimizers import Adam
from keras.regularizers import l2

# Deep Learning: Callbacks
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Paso 2: Lectura del Dataset

# %%
# Suponiendo que tu DataFrame se llama df
df = pd.read_csv('/content/drive/MyDrive/EspecializacionA&DS/Monografia/2doSemestre/DataFinal_Amazon.csv')  # Descomenta y proporciona la ruta si estás cargando un archivo CSV
# Out:
# <ipython-input-4-1f8e3361d82a>:2: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/drive/MyDrive/EspecializacionA&DS/Monografia/2doSemestre/DataFinal_Amazon.csv')  # Descomenta y proporciona la ruta si estás cargando un archivo CSV

# %%
df.shape
# Out:
# (4800571, 10)

# %% [markdown]
# # Modelo de Filtrado Colaborativo usando Embedding con Keras:

# %% [markdown]
# Funcionamiento:
#
# Los embeddings son representaciones vectoriales densas y de baja dimensión de ítems y/o usuarios. Estas representaciones capturan relaciones semánticas entre ítems o entre usuarios.
#
# Un método popular para generar embeddings es la factorización de matrices, como la descomposición en valores singulares (SVD). En el contexto de sistemas de recomendación, se busca factorizar la matriz de interacciones usuario-ítem en dos matrices más pequeñas (una para los usuarios y otra para los ítems) cuyo producto aproximado reproduce la matriz original lo mejor posible.
#
# Una vez que se han obtenido los embeddings, la predicción de una calificación o interacción entre un usuario e ítem se realiza tomando el producto escalar entre sus embeddings respectivos.
#
# Ventajas:
#
# Simplicidad y eficiencia en términos computacionales.
#
# Puede manejar grandes conjuntos de datos debido a su naturaleza de baja dimensión.
#
# Es efectivo para capturar patrones subyacentes en los datos.
#
# Desventajas:
#
# No tiene en cuenta características adicionales de usuarios o ítems.
#
# Dificultades para manejar nuevos ítems o usuarios (problema de arranque en frío).

# %% [markdown]
# El código ahora incluye regularización en los embeddings, un callback para detener el entrenamiento si no hay mejoras (early stopping) y otro para reducir la tasa de aprendizaje si el error de validación no mejora (reduce learning rate on plateau).

# %%
data = df

# %%
# Crear un LabelEncoder para cada columna
reviewerID_encoder = LabelEncoder()
asin_encoder = LabelEncoder()

# Ajustar y transformar las columnas
data['reviewerID_encoded'] = reviewerID_encoder.fit_transform(data['reviewerID'])
data['asin_encoded'] = asin_encoder.fit_transform(data['asin'])

# Número de usuarios únicos y número de ítems únicos
n_users = len(np.unique(data['reviewerID_encoded']))
n_items = len(np.unique(data['asin_encoded']))

# Dimensiones del embedding
embedding_dim = 10

# Entradas
user_input = Input(shape=(1,))
item_input = Input(shape=(1,))

# Embeddings con regularización
user_embedding = Embedding(n_users, embedding_dim, embeddings_regularizer=l2(1e-6))(user_input)
item_embedding = Embedding(n_items, embedding_dim, embeddings_regularizer=l2(1e-6))(item_input)

# Producto punto para predecir la valoración/rating
merged = Dot(axes=2)([user_embedding, item_embedding])
merged = Flatten()(merged)

# Modelo
model = Model(inputs=[user_input, item_input], outputs=merged)
model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# %% [markdown]
# verbose=0: No muestra ninguna barra de progreso ni métricas.
#
# verbose=1: Muestra una barra de progreso y actualiza las métricas después de cada lote.
#
# verbose=2: Muestra las métricas después de cada época, pero no muestra la barra de progreso.

# %%
from sklearn.model_selection import train_test_split

# Crear los arrays con los datos
user_ids = data['reviewerID_encoded'].values
item_ids = data['asin_encoded'].values
ratings = data['overall'].values

# Dividir en train y test
(user_ids_train, user_ids_test, item_ids_train, item_ids_test, ratings_train, ratings_test) = train_test_split(
    user_ids, item_ids, ratings,test_size=0.3,random_state=42)

# %%
# Callbacks
early_stop = EarlyStopping(monitor='val_loss', patience=50)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=50, min_lr=1e-5)

# %%
# %%time
# Entrenar el modelo con el conjunto de entrenamiento
model.fit([user_ids_train, item_ids_train], ratings_train, validation_data=([user_ids_test, item_ids_test], ratings_test), epochs=500, batch_size=800000, verbose=1, callbacks=[early_stop, reduce_lr])
# Out:
# Epoch 1/500
# 5/5 [==============================] - 5s 95ms/step - loss: 19.5284 - mae: 4.2610 - val_loss: 19.5190 - val_mae: 4.2594 - lr: 0.0010
# Epoch 2/500
# 5/5 [==============================] - 0s 46ms/step - loss: 19.5274 - mae: 4.2609 - val_loss: 19.5188 - val_mae: 4.2594 - lr: 0.0010
# Epoch 3/500
# 5/5 [==============================] - 0s 44ms/step - loss: 19.5261 - mae: 4.2608 - val_loss: 19.5185 - val_mae: 4.2594 - lr: 0.0010
# Epoch 4/500
# 5/5 [==============================] - 0s 41ms/step - loss: 19.5247 - mae: 4.2607 - val_loss: 19.5182 - val_mae: 4.2594 - lr: 0.0010
# Epoch 5/500
# 5/5 [==============================] - 0s 43ms/step - loss: 19.5232 - mae: 4.2605 - val_loss: 19.5178 - val_mae: 4.2593 - lr: 0.0010
# Epoch 6/500
# 5/5 [==============================] - 0s 41ms/step - loss: 19.5215 - mae: 4.2604 - val_loss: 19.5174 - val_mae: 4.2593 - lr: 0.0010
# Epoch 7/500
# 5/5 [==============================] - 0s 38ms/step - loss: 19.5197 - mae: 4.2602 - val_loss: 19.5170 - val_mae: 4.2593 - lr: 0.0010
# Epoch 8/500
# 5/5 [==============================] - 0s 41ms/step - loss: 19.5177 - mae: 4.2600 - val_loss: 19.5165 - val_mae: 4.2592 - lr: 0.0010
# Epoch 9/500
# 5/5 [==============================] - 0s 38ms/step - loss: 19.5154 - mae: 4.2598 - val_loss: 19.5159 - val_mae: 4.2592 - lr: 0.0010
# Epoch 10/500
# 5/5 [==============================] - 0s 45ms/step - loss: 19.5129 - mae: 4.2595 - val_loss: 19.5151 - val_mae: 4.2591 - lr: 0.0010
# Epoch 11/500
# 5/5 [==============================] - 0s 39ms/step - loss: 19.5101 - mae: 4.2592 - val_loss: 19.5143 - val_mae: 4.2591 - lr: 0.0010
# Epoch 12/500
# 5/5 [==============================] - 0s 39ms/step - loss: 19.5068 - mae: 4.2588 - val_loss: 19.5133 - val_mae: 4.2589 - lr: 0.0010
# Epoch 13/500
# 5/5 [==============================] - 0s 40ms/step - loss: 19.5032 - mae: 4.2584 - val_loss: 19.5122 - val_mae: 4.2588 - lr: 0.0010
# Epoch 14/500
# 5/5 [==============================] - 0s 39ms/step - loss: 19.4990 - mae: 4.2580 - val_loss: 19.5108 - val_mae: 4.2587 - lr: 0.0010
# Epoch 15/500
# 5/5 [==============================] - 0s 36ms/step - loss: 19.4942 - mae: 4.2574 - val_loss: 19.5093 - val_mae: 4.2585 - lr: 0.0010
# Epoch 16/500
# 5/5 [==============================] - 0s 36ms/step - loss: 19.4887 - mae: 4.2568 - val_loss: 19.5075 - val_mae: 4.2583 - lr: 0.0010
# Epoch 17/500
# 5/5 [==============================] - 0s 37ms/step - loss: 19.4825 - mae: 4.2561 - val_loss: 19.5054 - val_mae: 4.2580 - lr: 0.0010
# Epoch 18/500
# 5/5 [==============================] - 0s 37ms/step - loss: 19.4755 - mae: 4.2553 - val_loss: 19.5031 - val_mae: 4.2577 - lr: 0.0010
# Epoch 19/500
# 5/5 [==============================] - 0s 35ms/step - loss: 19.4677 - mae: 4.2544 - val_loss: 19.5004 - val_mae: 4.2574 - lr: 0.0010
# Epoch 20/500
# 5/5 [==============================] - 0s 38ms/step - loss: 19.4588 - mae: 4.2534 - val_loss: 19.4975 - val_mae: 4.2570 - lr: 0.0010
# Epoch 21/500
# 5/5 [==============================] - 0s 37ms/step - loss: 19.4489 - mae: 4.2522 - val_loss: 19.4942 - val_mae: 4.2565 - lr: 0.0010
# Epoch 22/500
# 5/5 [==============================] - 0s 37ms/step - loss: 19.4380 - mae: 4.2509 - val_loss: 19.4906 - val_mae: 4.2561 - lr: 0.0010
# Epoch 23/500
# 5/5 [==============================] - 0s 37ms/step - loss: 19.4258 - mae: 4.2495 - val_loss: 19.4867 - val_mae: 4.2555 - lr: 0.0010
# Epoch 24/500
# 5/5 [==============================] - 0s 37ms/step - loss: 19.4124 - mae: 4.2479 - val_loss: 19.4824 - val_mae: 4.2549 - lr: 0.0010
# Epoch 25/500
# 5/5 [==============================] - 0s 37ms/step - loss: 19.3978 - mae: 4.2462 - val_loss: 19.4777 - val_mae: 4.2543 - lr: 0.0010
# Epoch 26/500
# 5/5 [==============================] - 0s 36ms/step - loss: 19.3817 - mae: 4.2442 - val_loss: 19.4727 - val_mae: 4.2536 - lr: 0.0010
# Epoch 27/500
# 5/5 [==============================] - 0s 38ms/step - loss: 19.3643 - mae: 4.2422 - val_loss: 19.4674 - val_mae: 4.2528 - lr: 0.0010
# Epoch 28/500
# 5/5 [==============================] - 0s 38ms/step - loss: 19.3454 - mae: 4.2399 - val_loss: 19.4616 - val_mae: 4.2520 - lr: 0.0010
# Epoch 29/500
# 5/5 [==============================] - 0s 35ms/step - loss: 19.3250 - mae: 4.2374 - val_loss: 19.4555 - val_mae: 4.2511 - lr: 0.0010
# Epoch 30/500
# 5/5 [==============================] - 0s 37ms/step - loss: 19.3030 - mae: 4.2348 - val_loss: 19.4491 - val_mae: 4.2502 - lr: 0.0010
# Epoch 31/500
# 5/5 [==============================] - 0s 35ms/step - loss: 19.2794 - mae: 4.2319 - val_loss: 19.4423 - val_mae: 4.2492 - lr: 0.0010
# Epoch 32/500
# 5/5 [==============================] - 0s 40ms/step - loss: 19.2542 - mae: 4.2288 - val_loss: 19.4351 - val_mae: 4.2481 - lr: 0.0010
# Epoch 33/500
# 5/5 [==============================] - 0s 37ms/step - loss: 19.2274 - mae: 4.2255 - val_loss: 19.4277 - val_mae: 4.2470 - lr: 0.0010
# Epoch 34/500
# 5/5 [==============================] - 0s 36ms/step - loss: 19.1988 - mae: 4.2220 - val_loss: 19.4198 - val_mae: 4.2458 - lr: 0.0010
# Epoch 35/500
# 5/5 [==============================] - 0s 37ms/step - loss: 19.1686 - mae: 4.2183 - val_loss: 19.4117 - val_mae: 4.2445 - lr: 0.0010
# Epoch 36/500
# 5/5 [==============================] - 0s 36ms/step - loss: 19.1366 - mae: 4.2144 - val_loss: 19.4032 - val_mae: 4.2432 - lr: 0.0010
# Epoch 37/500
# 5/5 [==============================] - 0s 39ms/step - loss: 19.1028 - mae: 4.2102 - val_loss: 19.3944 - val_mae: 4.2418 - lr: 0.0010
# Epoch 38/500
# 5/5 [==============================] - 0s 37ms/step - loss: 19.0673 - mae: 4.2058 - val_loss: 19.3853 - val_mae: 4.2404 - lr: 0.0010
# Epoch 39/500
# 5/5 [==============================] - 0s 36ms/step - loss: 19.0300 - mae: 4.2011 - val_loss: 19.3760 - val_mae: 4.2389 - lr: 0.0010
# Epoch 40/500
# 5/5 [==============================] - 0s 36ms/step - loss: 18.9910 - mae: 4.1962 - val_loss: 19.3663 - val_mae: 4.2373 - lr: 0.0010
# Epoch 41/500
# 5/5 [==============================] - 0s 36ms/step - loss: 18.9501 - mae: 4.1911 - val_loss: 19.3564 - val_mae: 4.2357 - lr: 0.0010
# Epoch 42/500
# 5/5 [==============================] - 0s 37ms/step - loss: 18.9075 - mae: 4.1857 - val_loss: 19.3463 - val_mae: 4.2340 - lr: 0.0010
# Epoch 43/500
# 5/5 [==============================] - 0s 37ms/step - loss: 18.8631 - mae: 4.1801 - val_loss: 19.3359 - val_mae: 4.2322 - lr: 0.0010
# Epoch 44/500
# 5/5 [==============================] - 0s 36ms/step - loss: 18.8170 - mae: 4.1742 - val_loss: 19.3253 - val_mae: 4.2304 - lr: 0.0010
# Epoch 45/500
# 5/5 [==============================] - 0s 37ms/step - loss: 18.7691 - mae: 4.1681 - val_loss: 19.3145 - val_mae: 4.2285 - lr: 0.0010
# Epoch 46/500
# 5/5 [==============================] - 0s 37ms/step - loss: 18.7195 - mae: 4.1618 - val_loss: 19.3034 - val_mae: 4.2266 - lr: 0.0010
# Epoch 47/500
# 5/5 [==============================] - 0s 36ms/step - loss: 18.6682 - mae: 4.1552 - val_loss: 19.2922 - val_mae: 4.2246 - lr: 0.0010
# Epoch 48/500
# 5/5 [==============================] - 0s 35ms/step - loss: 18.6152 - mae: 4.1484 - val_loss: 19.2808 - val_mae: 4.2225 - lr: 0.0010
# Epoch 49/500
# 5/5 [==============================] - 0s 37ms/step - loss: 18.5604 - mae: 4.1413 - val_loss: 19.2693 - val_mae: 4.2204 - lr: 0.0010
# Epoch 50/500
# 5/5 [==============================] - 0s 36ms/step - loss: 18.5041 - mae: 4.1340 - val_loss: 19.2576 - val_mae: 4.2182 - lr: 0.0010
# Epoch 51/500
# 5/5 [==============================] - 0s 36ms/step - loss: 18.4461 - mae: 4.1264 - val_loss: 19.2458 - val_mae: 4.2160 - lr: 0.0010
# Epoch 52/500
# 5/5 [==============================] - 0s 36ms/step - loss: 18.3865 - mae: 4.1186 - val_loss: 19.2339 - val_mae: 4.2137 - lr: 0.0010
# Epoch 53/500
# 5/5 [==============================] - 0s 37ms/step - loss: 18.3254 - mae: 4.1106 - val_loss: 19.2219 - val_mae: 4.2114 - lr: 0.0010
# Epoch 54/500
# 5/5 [==============================] - 0s 37ms/step - loss: 18.2627 - mae: 4.1023 - val_loss: 19.2098 - val_mae: 4.2090 - lr: 0.0010
# Epoch 55/500
# 5/5 [==============================] - 0s 37ms/step - loss: 18.1985 - mae: 4.0938 - val_loss: 19.1976 - val_mae: 4.2066 - lr: 0.0010
# Epoch 56/500
# 5/5 [==============================] - 0s 39ms/step - loss: 18.1328 - mae: 4.0850 - val_loss: 19.1854 - val_mae: 4.2041 - lr: 0.0010
# Epoch 57/500
# 5/5 [==============================] - 0s 35ms/step - loss: 18.0657 - mae: 4.0761 - val_loss: 19.1731 - val_mae: 4.2015 - lr: 0.0010
# Epoch 58/500
# 5/5 [==============================] - 0s 37ms/step - loss: 17.9972 - mae: 4.0669 - val_loss: 19.1608 - val_mae: 4.1990 - lr: 0.0010
# Epoch 59/500
# 5/5 [==============================] - 0s 37ms/step - loss: 17.9272 - mae: 4.0574 - val_loss: 19.1485 - val_mae: 4.1963 - lr: 0.0010
# Epoch 60/500
# 5/5 [==============================] - 0s 35ms/step - loss: 17.8560 - mae: 4.0478 - val_loss: 19.1362 - val_mae: 4.1936 - lr: 0.0010
# Epoch 61/500
# 5/5 [==============================] - 0s 38ms/step - loss: 17.7834 - mae: 4.0379 - val_loss: 19.1239 - val_mae: 4.1909 - lr: 0.0010
# Epoch 62/500
# 5/5 [==============================] - 0s 37ms/step - loss: 17.7096 - mae: 4.0278 - val_loss: 19.1116 - val_mae: 4.1881 - lr: 0.0010
# Epoch 63/500
# 5/5 [==============================] - 0s 37ms/step - loss: 17.6345 - mae: 4.0175 - val_loss: 19.0994 - val_mae: 4.1853 - lr: 0.0010
# Epoch 64/500
# 5/5 [==============================] - 0s 35ms/step - loss: 17.5583 - mae: 4.0069 - val_loss: 19.0872 - val_mae: 4.1825 - lr: 0.0010
# Epoch 65/500
# 5/5 [==============================] - 0s 37ms/step - loss: 17.4809 - mae: 3.9962 - val_loss: 19.0750 - val_mae: 4.1796 - lr: 0.0010
# Epoch 66/500
# 5/5 [==============================] - 0s 35ms/step - loss: 17.4024 - mae: 3.9852 - val_loss: 19.0630 - val_mae: 4.1766 - lr: 0.0010
# Epoch 67/500
# 5/5 [==============================] - 0s 36ms/step - loss: 17.3228 - mae: 3.9741 - val_loss: 19.0510 - val_mae: 4.1737 - lr: 0.0010
# Epoch 68/500
# 5/5 [==============================] - 0s 35ms/step - loss: 17.2422 - mae: 3.9627 - val_loss: 19.0391 - val_mae: 4.1707 - lr: 0.0010
# Epoch 69/500
# 5/5 [==============================] - 0s 35ms/step - loss: 17.1606 - mae: 3.9512 - val_loss: 19.0274 - val_mae: 4.1676 - lr: 0.0010
# Epoch 70/500
# 5/5 [==============================] - 0s 34ms/step - loss: 17.0781 - mae: 3.9394 - val_loss: 19.0158 - val_mae: 4.1645 - lr: 0.0010
# Epoch 71/500
# 5/5 [==============================] - 0s 36ms/step - loss: 16.9947 - mae: 3.9275 - val_loss: 19.0043 - val_mae: 4.1614 - lr: 0.0010
# Epoch 72/500
# 5/5 [==============================] - 0s 36ms/step - loss: 16.9105 - mae: 3.9153 - val_loss: 18.9930 - val_mae: 4.1583 - lr: 0.0010
# Epoch 73/500
# 5/5 [==============================] - 0s 42ms/step - loss: 16.8254 - mae: 3.9030 - val_loss: 18.9818 - val_mae: 4.1551 - lr: 0.0010
# Epoch 74/500
# 5/5 [==============================] - 0s 36ms/step - loss: 16.7395 - mae: 3.8905 - val_loss: 18.9709 - val_mae: 4.1519 - lr: 0.0010
# Epoch 75/500
# 5/5 [==============================] - 0s 36ms/step - loss: 16.6529 - mae: 3.8779 - val_loss: 18.9600 - val_mae: 4.1487 - lr: 0.0010
# Epoch 76/500
# 5/5 [==============================] - 0s 35ms/step - loss: 16.5655 - mae: 3.8650 - val_loss: 18.9494 - val_mae: 4.1454 - lr: 0.0010
# Epoch 77/500
# 5/5 [==============================] - 0s 38ms/step - loss: 16.4775 - mae: 3.8520 - val_loss: 18.9390 - val_mae: 4.1421 - lr: 0.0010
# Epoch 78/500
# 5/5 [==============================] - 0s 40ms/step - loss: 16.3889 - mae: 3.8388 - val_loss: 18.9288 - val_mae: 4.1388 - lr: 0.0010
# Epoch 79/500
# 5/5 [==============================] - 0s 38ms/step - loss: 16.2997 - mae: 3.8255 - val_loss: 18.9188 - val_mae: 4.1355 - lr: 0.0010
# Epoch 80/500
# 5/5 [==============================] - 0s 39ms/step - loss: 16.2099 - mae: 3.8120 - val_loss: 18.9090 - val_mae: 4.1321 - lr: 0.0010
# Epoch 81/500
# 5/5 [==============================] - 0s 39ms/step - loss: 16.1196 - mae: 3.7984 - val_loss: 18.8995 - val_mae: 4.1287 - lr: 0.0010
# Epoch 82/500
# 5/5 [==============================] - 0s 38ms/step - loss: 16.0289 - mae: 3.7846 - val_loss: 18.8902 - val_mae: 4.1253 - lr: 0.0010
# Epoch 83/500
# 5/5 [==============================] - 0s 37ms/step - loss: 15.9378 - mae: 3.7706 - val_loss: 18.8812 - val_mae: 4.1219 - lr: 0.0010
# Epoch 84/500
# 5/5 [==============================] - 0s 38ms/step - loss: 15.8462 - mae: 3.7565 - val_loss: 18.8724 - val_mae: 4.1185 - lr: 0.0010
# Epoch 85/500
# 5/5 [==============================] - 0s 37ms/step - loss: 15.7543 - mae: 3.7423 - val_loss: 18.8638 - val_mae: 4.1151 - lr: 0.0010
# Epoch 86/500
# 5/5 [==============================] - 0s 39ms/step - loss: 15.6620 - mae: 3.7279 - val_loss: 18.8556 - val_mae: 4.1116 - lr: 0.0010
# Epoch 87/500
# 5/5 [==============================] - 0s 38ms/step - loss: 15.5695 - mae: 3.7134 - val_loss: 18.8476 - val_mae: 4.1081 - lr: 0.0010
# Epoch 88/500
# 5/5 [==============================] - 0s 36ms/step - loss: 15.4767 - mae: 3.6988 - val_loss: 18.8399 - val_mae: 4.1046 - lr: 0.0010
# Epoch 89/500
# 5/5 [==============================] - 0s 36ms/step - loss: 15.3836 - mae: 3.6840 - val_loss: 18.8325 - val_mae: 4.1011 - lr: 0.0010
# Epoch 90/500
# 5/5 [==============================] - 0s 38ms/step - loss: 15.2904 - mae: 3.6691 - val_loss: 18.8254 - val_mae: 4.0976 - lr: 0.0010
# Epoch 91/500
# 5/5 [==============================] - 0s 40ms/step - loss: 15.1970 - mae: 3.6541 - val_loss: 18.8186 - val_mae: 4.0941 - lr: 0.0010
# Epoch 92/500
# 5/5 [==============================] - 0s 38ms/step - loss: 15.1036 - mae: 3.6390 - val_loss: 18.8121 - val_mae: 4.0906 - lr: 0.0010
# Epoch 93/500
# 5/5 [==============================] - 0s 37ms/step - loss: 15.0100 - mae: 3.6238 - val_loss: 18.8059 - val_mae: 4.0871 - lr: 0.0010
# Epoch 94/500
# 5/5 [==============================] - 0s 39ms/step - loss: 14.9164 - mae: 3.6085 - val_loss: 18.7999 - val_mae: 4.0835 - lr: 0.0010
# Epoch 95/500
# 5/5 [==============================] - 0s 39ms/step - loss: 14.8227 - mae: 3.5931 - val_loss: 18.7943 - val_mae: 4.0800 - lr: 0.0010
# Epoch 96/500
# 5/5 [==============================] - 0s 38ms/step - loss: 14.7290 - mae: 3.5776 - val_loss: 18.7890 - val_mae: 4.0764 - lr: 0.0010
# Epoch 97/500
# 5/5 [==============================] - 0s 36ms/step - loss: 14.6354 - mae: 3.5620 - val_loss: 18.7840 - val_mae: 4.0729 - lr: 0.0010
# Epoch 98/500
# 5/5 [==============================] - 0s 37ms/step - loss: 14.5418 - mae: 3.5463 - val_loss: 18.7794 - val_mae: 4.0694 - lr: 0.0010
# Epoch 99/500
# 5/5 [==============================] - 0s 35ms/step - loss: 14.4483 - mae: 3.5305 - val_loss: 18.7750 - val_mae: 4.0658 - lr: 0.0010
# Epoch 100/500
# 5/5 [==============================] - 0s 39ms/step - loss: 14.3549 - mae: 3.5147 - val_loss: 18.7710 - val_mae: 4.0623 - lr: 0.0010
# Epoch 101/500
# 5/5 [==============================] - 0s 36ms/step - loss: 14.2616 - mae: 3.4987 - val_loss: 18.7673 - val_mae: 4.0587 - lr: 0.0010
# Epoch 102/500
# 5/5 [==============================] - 0s 36ms/step - loss: 14.1685 - mae: 3.4827 - val_loss: 18.7639 - val_mae: 4.0552 - lr: 0.0010
# Epoch 103/500
# 5/5 [==============================] - 0s 36ms/step - loss: 14.0755 - mae: 3.4666 - val_loss: 18.7609 - val_mae: 4.0517 - lr: 0.0010
# Epoch 104/500
# 5/5 [==============================] - 0s 34ms/step - loss: 13.9828 - mae: 3.4505 - val_loss: 18.7582 - val_mae: 4.0481 - lr: 0.0010
# Epoch 105/500
# 5/5 [==============================] - 0s 37ms/step - loss: 13.8903 - mae: 3.4342 - val_loss: 18.7558 - val_mae: 4.0446 - lr: 0.0010
# Epoch 106/500
# 5/5 [==============================] - 0s 36ms/step - loss: 13.7981 - mae: 3.4180 - val_loss: 18.7538 - val_mae: 4.0411 - lr: 0.0010
# Epoch 107/500
# 5/5 [==============================] - 0s 35ms/step - loss: 13.7061 - mae: 3.4016 - val_loss: 18.7520 - val_mae: 4.0376 - lr: 0.0010
# Epoch 108/500
# 5/5 [==============================] - 0s 36ms/step - loss: 13.6145 - mae: 3.3852 - val_loss: 18.7506 - val_mae: 4.0341 - lr: 0.0010
# Epoch 109/500
# 5/5 [==============================] - 0s 36ms/step - loss: 13.5231 - mae: 3.3688 - val_loss: 18.7495 - val_mae: 4.0306 - lr: 0.0010
# Epoch 110/500
# 5/5 [==============================] - 0s 36ms/step - loss: 13.4321 - mae: 3.3523 - val_loss: 18.7488 - val_mae: 4.0271 - lr: 0.0010
# Epoch 111/500
# 5/5 [==============================] - 0s 36ms/step - loss: 13.3415 - mae: 3.3358 - val_loss: 18.7484 - val_mae: 4.0236 - lr: 0.0010
# Epoch 112/500
# 5/5 [==============================] - 0s 38ms/step - loss: 13.2512 - mae: 3.3192 - val_loss: 18.7483 - val_mae: 4.0202 - lr: 0.0010
# Epoch 113/500
# 5/5 [==============================] - 0s 38ms/step - loss: 13.1614 - mae: 3.3026 - val_loss: 18.7485 - val_mae: 4.0168 - lr: 0.0010
# Epoch 114/500
# 5/5 [==============================] - 0s 40ms/step - loss: 13.0719 - mae: 3.2860 - val_loss: 18.7490 - val_mae: 4.0133 - lr: 0.0010
# Epoch 115/500
# 5/5 [==============================] - 0s 36ms/step - loss: 12.9829 - mae: 3.2693 - val_loss: 18.7498 - val_mae: 4.0099 - lr: 0.0010
# Epoch 116/500
# 5/5 [==============================] - 0s 37ms/step - loss: 12.8943 - mae: 3.2527 - val_loss: 18.7509 - val_mae: 4.0065 - lr: 0.0010
# Epoch 117/500
# 5/5 [==============================] - 0s 36ms/step - loss: 12.8062 - mae: 3.2360 - val_loss: 18.7524 - val_mae: 4.0031 - lr: 0.0010
# Epoch 118/500
# 5/5 [==============================] - 0s 37ms/step - loss: 12.7186 - mae: 3.2192 - val_loss: 18.7541 - val_mae: 3.9998 - lr: 0.0010
# Epoch 119/500
# 5/5 [==============================] - 0s 39ms/step - loss: 12.6314 - mae: 3.2025 - val_loss: 18.7562 - val_mae: 3.9964 - lr: 0.0010
# Epoch 120/500
# 5/5 [==============================] - 0s 37ms/step - loss: 12.5448 - mae: 3.1857 - val_loss: 18.7586 - val_mae: 3.9931 - lr: 0.0010
# Epoch 121/500
# 5/5 [==============================] - 0s 37ms/step - loss: 12.4586 - mae: 3.1690 - val_loss: 18.7612 - val_mae: 3.9898 - lr: 0.0010
# Epoch 122/500
# 5/5 [==============================] - 0s 36ms/step - loss: 12.3730 - mae: 3.1522 - val_loss: 18.7641 - val_mae: 3.9865 - lr: 0.0010
# Epoch 123/500
# 5/5 [==============================] - 0s 36ms/step - loss: 12.2879 - mae: 3.1354 - val_loss: 18.7674 - val_mae: 3.9832 - lr: 0.0010
# Epoch 124/500
# 5/5 [==============================] - 0s 38ms/step - loss: 12.2034 - mae: 3.1187 - val_loss: 18.7709 - val_mae: 3.9799 - lr: 0.0010
# Epoch 125/500
# 5/5 [==============================] - 0s 37ms/step - loss: 12.1195 - mae: 3.1019 - val_loss: 18.7747 - val_mae: 3.9767 - lr: 0.0010
# Epoch 126/500
# 5/5 [==============================] - 0s 36ms/step - loss: 12.0361 - mae: 3.0851 - val_loss: 18.7788 - val_mae: 3.9735 - lr: 0.0010
# Epoch 127/500
# 5/5 [==============================] - 0s 37ms/step - loss: 11.9533 - mae: 3.0684 - val_loss: 18.7832 - val_mae: 3.9703 - lr: 0.0010
# Epoch 128/500
# 5/5 [==============================] - 0s 35ms/step - loss: 11.8712 - mae: 3.0516 - val_loss: 18.7878 - val_mae: 3.9671 - lr: 0.0010
# Epoch 129/500
# 5/5 [==============================] - 0s 35ms/step - loss: 11.7896 - mae: 3.0349 - val_loss: 18.7927 - val_mae: 3.9639 - lr: 0.0010
# Epoch 130/500
# 5/5 [==============================] - 0s 36ms/step - loss: 11.7086 - mae: 3.0182 - val_loss: 18.7978 - val_mae: 3.9608 - lr: 0.0010
# Epoch 131/500
# 5/5 [==============================] - 0s 36ms/step - loss: 11.6283 - mae: 3.0015 - val_loss: 18.8032 - val_mae: 3.9577 - lr: 0.0010
# Epoch 132/500
# 5/5 [==============================] - 0s 34ms/step - loss: 11.5485 - mae: 2.9848 - val_loss: 18.8089 - val_mae: 3.9546 - lr: 0.0010
# Epoch 133/500
# 5/5 [==============================] - 0s 37ms/step - loss: 11.4694 - mae: 2.9682 - val_loss: 18.8148 - val_mae: 3.9515 - lr: 0.0010
# Epoch 134/500
# 5/5 [==============================] - 0s 35ms/step - loss: 11.3910 - mae: 2.9515 - val_loss: 18.8209 - val_mae: 3.9485 - lr: 0.0010
# Epoch 135/500
# 5/5 [==============================] - 0s 36ms/step - loss: 11.3131 - mae: 2.9349 - val_loss: 18.8273 - val_mae: 3.9455 - lr: 0.0010
# Epoch 136/500
# 5/5 [==============================] - 0s 35ms/step - loss: 11.2360 - mae: 2.9184 - val_loss: 18.8340 - val_mae: 3.9425 - lr: 0.0010
# Epoch 137/500
# 5/5 [==============================] - 0s 37ms/step - loss: 11.1595 - mae: 2.9018 - val_loss: 18.8408 - val_mae: 3.9395 - lr: 0.0010
# Epoch 138/500
# 5/5 [==============================] - 0s 37ms/step - loss: 11.0836 - mae: 2.8853 - val_loss: 18.8479 - val_mae: 3.9365 - lr: 0.0010
# Epoch 139/500
# 5/5 [==============================] - 0s 36ms/step - loss: 11.0084 - mae: 2.8689 - val_loss: 18.8552 - val_mae: 3.9336 - lr: 0.0010
# Epoch 140/500
# 5/5 [==============================] - 0s 36ms/step - loss: 10.9339 - mae: 2.8525 - val_loss: 18.8627 - val_mae: 3.9307 - lr: 0.0010
# Epoch 141/500
# 5/5 [==============================] - 0s 35ms/step - loss: 10.8600 - mae: 2.8361 - val_loss: 18.8704 - val_mae: 3.9278 - lr: 0.0010
# Epoch 142/500
# 5/5 [==============================] - 0s 36ms/step - loss: 10.7868 - mae: 2.8197 - val_loss: 18.8784 - val_mae: 3.9250 - lr: 0.0010
# Epoch 143/500
# 5/5 [==============================] - 0s 35ms/step - loss: 10.7143 - mae: 2.8034 - val_loss: 18.8865 - val_mae: 3.9221 - lr: 0.0010
# Epoch 144/500
# 5/5 [==============================] - 0s 38ms/step - loss: 10.6425 - mae: 2.7872 - val_loss: 18.8948 - val_mae: 3.9193 - lr: 0.0010
# Epoch 145/500
# 5/5 [==============================] - 0s 36ms/step - loss: 10.5713 - mae: 2.7710 - val_loss: 18.9033 - val_mae: 3.9165 - lr: 0.0010
# Epoch 146/500
# 5/5 [==============================] - 0s 38ms/step - loss: 10.5008 - mae: 2.7549 - val_loss: 18.9120 - val_mae: 3.9137 - lr: 0.0010
# Epoch 147/500
# 5/5 [==============================] - 0s 36ms/step - loss: 10.4310 - mae: 2.7388 - val_loss: 18.9209 - val_mae: 3.9110 - lr: 0.0010
# Epoch 148/500
# 5/5 [==============================] - 0s 36ms/step - loss: 10.3619 - mae: 2.7227 - val_loss: 18.9299 - val_mae: 3.9083 - lr: 0.0010
# Epoch 149/500
# 5/5 [==============================] - 0s 36ms/step - loss: 10.2935 - mae: 2.7068 - val_loss: 18.9392 - val_mae: 3.9056 - lr: 0.0010
# Epoch 150/500
# 5/5 [==============================] - 0s 35ms/step - loss: 10.2257 - mae: 2.6908 - val_loss: 18.9486 - val_mae: 3.9029 - lr: 0.0010
# Epoch 151/500
# 5/5 [==============================] - 0s 35ms/step - loss: 10.1587 - mae: 2.6750 - val_loss: 18.9581 - val_mae: 3.9003 - lr: 0.0010
# Epoch 152/500
# 5/5 [==============================] - 0s 36ms/step - loss: 10.0923 - mae: 2.6592 - val_loss: 18.9678 - val_mae: 3.8977 - lr: 0.0010
# Epoch 153/500
# 5/5 [==============================] - 0s 36ms/step - loss: 10.0266 - mae: 2.6435 - val_loss: 18.9777 - val_mae: 3.8951 - lr: 0.0010
# Epoch 154/500
# 5/5 [==============================] - 0s 38ms/step - loss: 9.9616 - mae: 2.6278 - val_loss: 18.9877 - val_mae: 3.8925 - lr: 0.0010
# Epoch 155/500
# 5/5 [==============================] - 0s 37ms/step - loss: 9.8972 - mae: 2.6122 - val_loss: 18.9978 - val_mae: 3.8899 - lr: 0.0010
# Epoch 156/500
# 5/5 [==============================] - 0s 35ms/step - loss: 9.8335 - mae: 2.5967 - val_loss: 19.0081 - val_mae: 3.8874 - lr: 0.0010
# Epoch 157/500
# 5/5 [==============================] - 0s 39ms/step - loss: 9.7705 - mae: 2.5812 - val_loss: 19.0186 - val_mae: 3.8849 - lr: 0.0010
# Epoch 158/500
# 5/5 [==============================] - 0s 40ms/step - loss: 9.7082 - mae: 2.5658 - val_loss: 19.0291 - val_mae: 3.8824 - lr: 0.0010
# Epoch 159/500
# 5/5 [==============================] - 0s 41ms/step - loss: 9.6466 - mae: 2.5505 - val_loss: 19.0398 - val_mae: 3.8800 - lr: 0.0010
# Epoch 160/500
# 5/5 [==============================] - 0s 40ms/step - loss: 9.5856 - mae: 2.5353 - val_loss: 19.0506 - val_mae: 3.8775 - lr: 0.0010
# Epoch 161/500
# 5/5 [==============================] - 0s 39ms/step - loss: 9.5253 - mae: 2.5201 - val_loss: 19.0614 - val_mae: 3.8751 - lr: 0.0010
# Epoch 162/500
# 5/5 [==============================] - 0s 41ms/step - loss: 9.4656 - mae: 2.5050 - val_loss: 19.0724 - val_mae: 3.8727 - lr: 0.0010
# CPU times: user 2min, sys: 5.68 s, total: 2min 6s
# Wall time: 34.1 s

# %%
predictions = model.predict([user_ids_test, item_ids_test])
# Out:
# 45006/45006 [==============================] - 60s 1ms/step

# %%
# Evaluar el modelo con el conjunto de prueba
loss, mae = model.evaluate([user_ids_test, item_ids_test], ratings_test, batch_size=40000)
print(f'Test Loss: {loss:.4f}')
print(f'Test MAE: {mae:.4f}')
# Out:
# 37/37 [==============================] - 0s 3ms/step - loss: 19.0724 - mae: 3.8727
# Test Loss: 19.0724
# Test MAE: 3.8727

# %%
# MSE
mse = mean_squared_error(ratings_test, predictions)
print(f"MSE: {mse:.4f}")

# RMSE
rmse = np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

# MAE
mae = mean_absolute_error(ratings_test, predictions)
print(f"MAE: {mae:.4f}")

# MAPE (Mean Absolute Percentage Error)
mape = np.mean(np.abs((ratings_test - predictions.flatten()) / ratings_test)) * 100
print(f"MAPE: {mape:.2f}%")
# Out:
# MSE: 17.5469
# RMSE: 4.1889
# MAE: 3.8727
# MAPE: 91.04%

# %% [markdown]
# # Modelo de Filtrado Colaborativo usando Red Neuronal Multicapa con Keras:

# %% [markdown]
# Funcionamiento:
#
# Estos sistemas toman características de los ítems y/o usuarios y las pasan a través de una o varias capas de neuronas para obtener una predicción.
# Las redes neuronales son capaces de capturar interacciones no lineales entre características, lo que las hace poderosas para tareas de modelado complejas.
#
# Ventajas:
#
# Capacidad de modelar relaciones no lineales.
#
# Flexibilidad para incorporar múltiples fuentes de datos o características.
#
# Puede manejar arranques en frío al incorporar características de nuevos ítems o usuarios.
#
# Desventajas:
#
# Mayor costo computacional en comparación con los sistemas basados únicamente en embeddings.
#
# Riesgo de sobreajuste si no se tiene un conjunto de datos lo suficientemente grande.

# %% [markdown]
# Ahora el código incluye regularización en los embeddings, early stopping para detener el entrenamiento si el modelo deja de mejorar en el conjunto de validación, y reducción de la tasa de aprendizaje si el error en el conjunto de validación no mejora después de algunas épocas. Estas adiciones deberían ayudar a mejorar la capacidad de generalización del modelo.

# %%
df['user_id'] = df['reviewerID'].astype('category').cat.codes.values
df['item_id'] = df['asin'].astype('category').cat.codes.values

# Número de usuarios e ítems
n_users = df['user_id'].nunique()
n_items = df['item_id'].nunique()

# Hiperparámetros
hidden_units = [128, 64, 32]
dropout_rate = 0.2
l2_reg = 1e-6

# Arquitectura del modelo
user_input = Input(shape=[1], name='user_input')
item_input = Input(shape=[1], name='item_input')
concat = Concatenate()([user_input, item_input])
dense = concat
for units in hidden_units:
    dense = Dense(units, activation='relu', kernel_regularizer=l2(l2_reg))(dense)
    dense = Dropout(dropout_rate)(dense)
output = Dense(1, kernel_regularizer=l2(l2_reg))(dense)  # También puedes aplicar regularización L2 aquí
model = Model(inputs=[user_input, item_input], outputs=output)
model.compile(optimizer=Adam(0.001), loss='mean_squared_error')

# %%
# Callbacks
early_stop = EarlyStopping(monitor='val_loss', patience=50)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=50, min_lr=1e-5)

# %%
# Datos para entrenamiento
user_data = df['user_id'].values
item_data = df['item_id'].values
rating_data = df['overall'].values

# Dividir los datos
user_data_train, user_data_val, item_data_train, item_data_val, ratings_train, ratings_val = train_test_split(
    user_data, item_data, rating_data, test_size=0.3, random_state=42)

# %%
# %%time
# Entrenamiento del modelo
history = model.fit([user_data_train, item_data_train], ratings_train,
    epochs=500,validation_data=([user_data_val, item_data_val], ratings_val),
    batch_size=800000,verbose=1,callbacks=[early_stop, reduce_lr])
# Out:
# Epoch 1/500
# 5/5 [==============================] - 3s 143ms/step - loss: 1227102464.0000 - val_loss: 79843496.0000 - lr: 0.0010
# Epoch 2/500
# 5/5 [==============================] - 0s 93ms/step - loss: 416342592.0000 - val_loss: 1400365.6250 - lr: 0.0010
# Epoch 3/500
# 5/5 [==============================] - 0s 93ms/step - loss: 183772192.0000 - val_loss: 1498450.7500 - lr: 0.0010
# Epoch 4/500
# 5/5 [==============================] - 0s 92ms/step - loss: 107676856.0000 - val_loss: 9927205.0000 - lr: 0.0010
# Epoch 5/500
# 5/5 [==============================] - 0s 93ms/step - loss: 67047860.0000 - val_loss: 8325238.0000 - lr: 0.0010
# Epoch 6/500
# 5/5 [==============================] - 0s 93ms/step - loss: 43375548.0000 - val_loss: 3095880.2500 - lr: 0.0010
# Epoch 7/500
# 5/5 [==============================] - 0s 94ms/step - loss: 29530138.0000 - val_loss: 1500741.7500 - lr: 0.0010
# Epoch 8/500
# 5/5 [==============================] - 0s 93ms/step - loss: 21406516.0000 - val_loss: 1002628.7500 - lr: 0.0010
# Epoch 9/500
# 5/5 [==============================] - 0s 92ms/step - loss: 16199513.0000 - val_loss: 506491.3125 - lr: 0.0010
# Epoch 10/500
# 5/5 [==============================] - 0s 94ms/step - loss: 12644706.0000 - val_loss: 197903.9531 - lr: 0.0010
# Epoch 11/500
# 5/5 [==============================] - 0s 92ms/step - loss: 10050979.0000 - val_loss: 59468.5977 - lr: 0.0010
# Epoch 12/500
# 5/5 [==============================] - 0s 93ms/step - loss: 8170161.5000 - val_loss: 9578.2041 - lr: 0.0010
# Epoch 13/500
# 5/5 [==============================] - 0s 92ms/step - loss: 6792898.5000 - val_loss: 1834.8425 - lr: 0.0010
# Epoch 14/500
# 5/5 [==============================] - 0s 93ms/step - loss: 5747905.0000 - val_loss: 12526.3672 - lr: 0.0010
# Epoch 15/500
# 5/5 [==============================] - 0s 92ms/step - loss: 4926937.0000 - val_loss: 22025.4590 - lr: 0.0010
# Epoch 16/500
# 5/5 [==============================] - 0s 93ms/step - loss: 4257885.5000 - val_loss: 22756.6973 - lr: 0.0010
# Epoch 17/500
# 5/5 [==============================] - 0s 92ms/step - loss: 3754723.7500 - val_loss: 21159.6406 - lr: 0.0010
# Epoch 18/500
# 5/5 [==============================] - 0s 92ms/step - loss: 3308504.7500 - val_loss: 19372.3203 - lr: 0.0010
# Epoch 19/500
# 5/5 [==============================] - 0s 93ms/step - loss: 2935169.0000 - val_loss: 17785.4180 - lr: 0.0010
# Epoch 20/500
# 5/5 [==============================] - 0s 94ms/step - loss: 2637468.7500 - val_loss: 16512.3008 - lr: 0.0010
# Epoch 21/500
# 5/5 [==============================] - 0s 92ms/step - loss: 2369273.2500 - val_loss: 15530.3311 - lr: 0.0010
# Epoch 22/500
# 5/5 [==============================] - 0s 92ms/step - loss: 2184274.0000 - val_loss: 14456.7910 - lr: 0.0010
# Epoch 23/500
# 5/5 [==============================] - 0s 92ms/step - loss: 1969948.7500 - val_loss: 13287.2930 - lr: 0.0010
# Epoch 24/500
# 5/5 [==============================] - 0s 94ms/step - loss: 1813592.5000 - val_loss: 12026.1494 - lr: 0.0010
# Epoch 25/500
# 5/5 [==============================] - 0s 93ms/step - loss: 1647471.0000 - val_loss: 10587.9180 - lr: 0.0010
# Epoch 26/500
# 5/5 [==============================] - 0s 92ms/step - loss: 1537031.8750 - val_loss: 9078.3369 - lr: 0.0010
# Epoch 27/500
# 5/5 [==============================] - 0s 94ms/step - loss: 1410129.2500 - val_loss: 7809.3994 - lr: 0.0010
# Epoch 28/500
# 5/5 [==============================] - 0s 94ms/step - loss: 1301358.5000 - val_loss: 6854.9019 - lr: 0.0010
# Epoch 29/500
# 5/5 [==============================] - 0s 92ms/step - loss: 1199557.2500 - val_loss: 5942.6787 - lr: 0.0010
# Epoch 30/500
# 5/5 [==============================] - 0s 93ms/step - loss: 1105104.0000 - val_loss: 5057.4204 - lr: 0.0010
# Epoch 31/500
# 5/5 [==============================] - 0s 93ms/step - loss: 1042539.1250 - val_loss: 4320.8828 - lr: 0.0010
# Epoch 32/500
# 5/5 [==============================] - 0s 95ms/step - loss: 970124.4375 - val_loss: 3671.7473 - lr: 0.0010
# Epoch 33/500
# 5/5 [==============================] - 0s 93ms/step - loss: 895939.6250 - val_loss: 3112.6128 - lr: 0.0010
# Epoch 34/500
# 5/5 [==============================] - 0s 93ms/step - loss: 825598.5000 - val_loss: 2610.4124 - lr: 0.0010
# Epoch 35/500
# 5/5 [==============================] - 0s 94ms/step - loss: 778216.0000 - val_loss: 2149.1809 - lr: 0.0010
# Epoch 36/500
# 5/5 [==============================] - 0s 93ms/step - loss: 738954.7500 - val_loss: 1726.4480 - lr: 0.0010
# Epoch 37/500
# 5/5 [==============================] - 0s 92ms/step - loss: 689621.2500 - val_loss: 1359.1471 - lr: 0.0010
# Epoch 38/500
# 5/5 [==============================] - 0s 92ms/step - loss: 651793.1875 - val_loss: 1102.9720 - lr: 0.0010
# Epoch 39/500
# 5/5 [==============================] - 0s 92ms/step - loss: 614491.6875 - val_loss: 911.1957 - lr: 0.0010
# Epoch 40/500
# 5/5 [==============================] - 0s 92ms/step - loss: 579303.0000 - val_loss: 774.0030 - lr: 0.0010
# Epoch 41/500
# 5/5 [==============================] - 0s 92ms/step - loss: 553831.1250 - val_loss: 672.6736 - lr: 0.0010
# Epoch 42/500
# 5/5 [==============================] - 0s 92ms/step - loss: 517161.0625 - val_loss: 577.1714 - lr: 0.0010
# Epoch 43/500
# 5/5 [==============================] - 0s 93ms/step - loss: 503605.8438 - val_loss: 487.6576 - lr: 0.0010
# Epoch 44/500
# 5/5 [==============================] - 0s 92ms/step - loss: 477049.3750 - val_loss: 399.8900 - lr: 0.0010
# Epoch 45/500
# 5/5 [==============================] - 0s 94ms/step - loss: 455527.0312 - val_loss: 326.7744 - lr: 0.0010
# Epoch 46/500
# 5/5 [==============================] - 0s 93ms/step - loss: 443605.6875 - val_loss: 291.9912 - lr: 0.0010
# Epoch 47/500
# 5/5 [==============================] - 0s 93ms/step - loss: 422189.7188 - val_loss: 272.5542 - lr: 0.0010
# Epoch 48/500
# 5/5 [==============================] - 0s 93ms/step - loss: 394313.6250 - val_loss: 243.0994 - lr: 0.0010
# Epoch 49/500
# 5/5 [==============================] - 0s 93ms/step - loss: 377745.5312 - val_loss: 214.4818 - lr: 0.0010
# Epoch 50/500
# 5/5 [==============================] - 0s 92ms/step - loss: 360394.6250 - val_loss: 212.5826 - lr: 0.0010
# Epoch 51/500
# 5/5 [==============================] - 0s 93ms/step - loss: 331358.7812 - val_loss: 197.0417 - lr: 0.0010
# Epoch 52/500
# 5/5 [==============================] - 0s 93ms/step - loss: 300146.8750 - val_loss: 210.0044 - lr: 0.0010
# Epoch 53/500
# 5/5 [==============================] - 0s 93ms/step - loss: 258487.2656 - val_loss: 209.0055 - lr: 0.0010
# Epoch 54/500
# 5/5 [==============================] - 0s 93ms/step - loss: 214828.6250 - val_loss: 180.2602 - lr: 0.0010
# Epoch 55/500
# 5/5 [==============================] - 0s 93ms/step - loss: 180590.4062 - val_loss: 151.8419 - lr: 0.0010
# Epoch 56/500
# 5/5 [==============================] - 0s 93ms/step - loss: 158658.1250 - val_loss: 108.3055 - lr: 0.0010
# Epoch 57/500
# 5/5 [==============================] - 0s 93ms/step - loss: 130433.7422 - val_loss: 68.0010 - lr: 0.0010
# Epoch 58/500
# 5/5 [==============================] - 0s 92ms/step - loss: 108481.3438 - val_loss: 42.1438 - lr: 0.0010
# Epoch 59/500
# 5/5 [==============================] - 0s 93ms/step - loss: 95758.8047 - val_loss: 24.9608 - lr: 0.0010
# Epoch 60/500
# 5/5 [==============================] - 0s 93ms/step - loss: 87347.6328 - val_loss: 15.3584 - lr: 0.0010
# Epoch 61/500
# 5/5 [==============================] - 0s 94ms/step - loss: 76184.3672 - val_loss: 9.6340 - lr: 0.0010
# Epoch 62/500
# 5/5 [==============================] - 0s 93ms/step - loss: 70818.1562 - val_loss: 8.0145 - lr: 0.0010
# Epoch 63/500
# 5/5 [==============================] - 0s 93ms/step - loss: 72069.1484 - val_loss: 7.8071 - lr: 0.0010
# Epoch 64/500
# 5/5 [==============================] - 0s 94ms/step - loss: 70670.9297 - val_loss: 7.5264 - lr: 0.0010
# Epoch 65/500
# 5/5 [==============================] - 0s 93ms/step - loss: 64189.4922 - val_loss: 7.0457 - lr: 0.0010
# Epoch 66/500
# 5/5 [==============================] - 0s 94ms/step - loss: 63400.1445 - val_loss: 6.6101 - lr: 0.0010
# Epoch 67/500
# 5/5 [==============================] - 0s 93ms/step - loss: 61799.2578 - val_loss: 6.4861 - lr: 0.0010
# Epoch 68/500
# 5/5 [==============================] - 0s 92ms/step - loss: 64543.9297 - val_loss: 6.5318 - lr: 0.0010
# Epoch 69/500
# 5/5 [==============================] - 0s 93ms/step - loss: 61057.6484 - val_loss: 6.6199 - lr: 0.0010
# Epoch 70/500
# 5/5 [==============================] - 0s 93ms/step - loss: 60718.7266 - val_loss: 6.4233 - lr: 0.0010
# Epoch 71/500
# 5/5 [==============================] - 0s 92ms/step - loss: 58476.5664 - val_loss: 7.2162 - lr: 0.0010
# Epoch 72/500
# 5/5 [==============================] - 0s 93ms/step - loss: 59165.7344 - val_loss: 7.5062 - lr: 0.0010
# Epoch 73/500
# 5/5 [==============================] - 0s 92ms/step - loss: 59120.4453 - val_loss: 6.4361 - lr: 0.0010
# Epoch 74/500
# 5/5 [==============================] - 0s 93ms/step - loss: 55268.5586 - val_loss: 6.3580 - lr: 0.0010
# Epoch 75/500
# 5/5 [==============================] - 0s 93ms/step - loss: 57782.9297 - val_loss: 6.9139 - lr: 0.0010
# Epoch 76/500
# 5/5 [==============================] - 0s 93ms/step - loss: 56462.0664 - val_loss: 7.1843 - lr: 0.0010
# Epoch 77/500
# 5/5 [==============================] - 0s 92ms/step - loss: 57858.0586 - val_loss: 6.6711 - lr: 0.0010
# Epoch 78/500
# 5/5 [==============================] - 0s 93ms/step - loss: 56219.9219 - val_loss: 6.2874 - lr: 0.0010
# Epoch 79/500
# 5/5 [==============================] - 0s 93ms/step - loss: 54304.8477 - val_loss: 6.3389 - lr: 0.0010
# Epoch 80/500
# 5/5 [==============================] - 0s 93ms/step - loss: 55845.6641 - val_loss: 7.3442 - lr: 0.0010
# Epoch 81/500
# 5/5 [==============================] - 0s 92ms/step - loss: 53891.2070 - val_loss: 7.3981 - lr: 0.0010
# Epoch 82/500
# 5/5 [==============================] - 0s 93ms/step - loss: 53810.0508 - val_loss: 6.4122 - lr: 0.0010
# Epoch 83/500
# 5/5 [==============================] - 0s 92ms/step - loss: 51967.8867 - val_loss: 6.4690 - lr: 0.0010
# Epoch 84/500
# 5/5 [==============================] - 0s 92ms/step - loss: 54968.4531 - val_loss: 7.1980 - lr: 0.0010
# Epoch 85/500
# 5/5 [==============================] - 0s 94ms/step - loss: 53534.9219 - val_loss: 7.2784 - lr: 0.0010
# Epoch 86/500
# 5/5 [==============================] - 0s 92ms/step - loss: 50090.7070 - val_loss: 6.7735 - lr: 0.0010
# Epoch 87/500
# 5/5 [==============================] - 0s 93ms/step - loss: 49146.3281 - val_loss: 6.6097 - lr: 0.0010
# Epoch 88/500
# 5/5 [==============================] - 0s 93ms/step - loss: 50880.3086 - val_loss: 6.9186 - lr: 0.0010
# Epoch 89/500
# 5/5 [==============================] - 0s 93ms/step - loss: 50730.8828 - val_loss: 7.5281 - lr: 0.0010
# Epoch 90/500
# 5/5 [==============================] - 0s 94ms/step - loss: 49891.0312 - val_loss: 7.1982 - lr: 0.0010
# Epoch 91/500
# 5/5 [==============================] - 0s 93ms/step - loss: 49000.5586 - val_loss: 6.4628 - lr: 0.0010
# Epoch 92/500
# 5/5 [==============================] - 0s 94ms/step - loss: 49583.6094 - val_loss: 6.6890 - lr: 0.0010
# Epoch 93/500
# 5/5 [==============================] - 0s 93ms/step - loss: 48720.1055 - val_loss: 7.1432 - lr: 0.0010
# Epoch 94/500
# 5/5 [==============================] - 0s 94ms/step - loss: 47861.8633 - val_loss: 6.8152 - lr: 0.0010
# Epoch 95/500
# 5/5 [==============================] - 0s 94ms/step - loss: 48817.0977 - val_loss: 6.3149 - lr: 0.0010
# Epoch 96/500
# 5/5 [==============================] - 0s 94ms/step - loss: 47708.0234 - val_loss: 7.1060 - lr: 0.0010
# Epoch 97/500
# 5/5 [==============================] - 0s 93ms/step - loss: 47316.0508 - val_loss: 8.1801 - lr: 0.0010
# Epoch 98/500
# 5/5 [==============================] - 0s 93ms/step - loss: 47253.9492 - val_loss: 7.1928 - lr: 0.0010
# Epoch 99/500
# 5/5 [==============================] - 0s 93ms/step - loss: 48702.1602 - val_loss: 6.3830 - lr: 0.0010
# Epoch 100/500
# 5/5 [==============================] - 0s 93ms/step - loss: 48722.1797 - val_loss: 6.7669 - lr: 0.0010
# Epoch 101/500
# 5/5 [==============================] - 0s 94ms/step - loss: 47160.1797 - val_loss: 7.4958 - lr: 0.0010
# Epoch 102/500
# 5/5 [==============================] - 0s 93ms/step - loss: 44736.4805 - val_loss: 6.5963 - lr: 0.0010
# Epoch 103/500
# 5/5 [==============================] - 0s 93ms/step - loss: 45418.6875 - val_loss: 6.3880 - lr: 0.0010
# Epoch 104/500
# 5/5 [==============================] - 0s 93ms/step - loss: 45407.0391 - val_loss: 7.5259 - lr: 0.0010
# Epoch 105/500
# 5/5 [==============================] - 0s 94ms/step - loss: 44230.3516 - val_loss: 6.7824 - lr: 0.0010
# Epoch 106/500
# 5/5 [==============================] - 0s 93ms/step - loss: 43758.3398 - val_loss: 6.2728 - lr: 0.0010
# Epoch 107/500
# 5/5 [==============================] - 0s 94ms/step - loss: 44545.7578 - val_loss: 6.7998 - lr: 0.0010
# Epoch 108/500
# 5/5 [==============================] - 0s 92ms/step - loss: 44326.8516 - val_loss: 7.0588 - lr: 0.0010
# Epoch 109/500
# 5/5 [==============================] - 0s 93ms/step - loss: 43062.9258 - val_loss: 7.6361 - lr: 0.0010
# Epoch 110/500
# 5/5 [==============================] - 0s 92ms/step - loss: 41472.2578 - val_loss: 6.9484 - lr: 0.0010
# Epoch 111/500
# 5/5 [==============================] - 0s 95ms/step - loss: 40807.8281 - val_loss: 6.7386 - lr: 0.0010
# Epoch 112/500
# 5/5 [==============================] - 0s 93ms/step - loss: 39675.0703 - val_loss: 6.5929 - lr: 0.0010
# Epoch 113/500
# 5/5 [==============================] - 0s 93ms/step - loss: 40430.2461 - val_loss: 6.7625 - lr: 0.0010
# Epoch 114/500
# 5/5 [==============================] - 0s 93ms/step - loss: 41312.1172 - val_loss: 7.2772 - lr: 0.0010
# Epoch 115/500
# 5/5 [==============================] - 0s 94ms/step - loss: 38651.2539 - val_loss: 7.1267 - lr: 0.0010
# Epoch 116/500
# 5/5 [==============================] - 0s 93ms/step - loss: 39104.2812 - val_loss: 6.1508 - lr: 0.0010
# Epoch 117/500
# 5/5 [==============================] - 0s 92ms/step - loss: 42461.4258 - val_loss: 5.9741 - lr: 0.0010
# Epoch 118/500
# 5/5 [==============================] - 0s 94ms/step - loss: 39493.2539 - val_loss: 6.6981 - lr: 0.0010
# Epoch 119/500
# 5/5 [==============================] - 0s 95ms/step - loss: 39469.2031 - val_loss: 6.8012 - lr: 0.0010
# Epoch 120/500
# 5/5 [==============================] - 0s 93ms/step - loss: 37044.3086 - val_loss: 6.7123 - lr: 0.0010
# Epoch 121/500
# 5/5 [==============================] - 0s 94ms/step - loss: 38781.2891 - val_loss: 6.5904 - lr: 0.0010
# Epoch 122/500
# 5/5 [==============================] - 0s 94ms/step - loss: 38167.0156 - val_loss: 6.8281 - lr: 0.0010
# Epoch 123/500
# 5/5 [==============================] - 0s 94ms/step - loss: 36128.8555 - val_loss: 7.2428 - lr: 0.0010
# Epoch 124/500
# 5/5 [==============================] - 0s 94ms/step - loss: 37098.4141 - val_loss: 6.3001 - lr: 0.0010
# Epoch 125/500
# 5/5 [==============================] - 0s 93ms/step - loss: 35508.0859 - val_loss: 6.0770 - lr: 0.0010
# Epoch 126/500
# 5/5 [==============================] - 0s 94ms/step - loss: 34695.2617 - val_loss: 6.4768 - lr: 0.0010
# Epoch 127/500
# 5/5 [==============================] - 0s 95ms/step - loss: 37001.2500 - val_loss: 6.9727 - lr: 0.0010
# Epoch 128/500
# 5/5 [==============================] - 0s 94ms/step - loss: 34788.0547 - val_loss: 6.4198 - lr: 0.0010
# Epoch 129/500
# 5/5 [==============================] - 0s 93ms/step - loss: 34187.4219 - val_loss: 6.6523 - lr: 0.0010
# Epoch 130/500
# 5/5 [==============================] - 0s 93ms/step - loss: 35713.2344 - val_loss: 7.1467 - lr: 0.0010
# Epoch 131/500
# 5/5 [==============================] - 0s 93ms/step - loss: 37102.1445 - val_loss: 6.2087 - lr: 0.0010
# Epoch 132/500
# 5/5 [==============================] - 0s 93ms/step - loss: 35216.4922 - val_loss: 6.9785 - lr: 0.0010
# Epoch 133/500
# 5/5 [==============================] - 0s 93ms/step - loss: 33209.2773 - val_loss: 6.8680 - lr: 0.0010
# Epoch 134/500
# 5/5 [==============================] - 0s 92ms/step - loss: 32231.3828 - val_loss: 6.4328 - lr: 0.0010
# Epoch 135/500
# 5/5 [==============================] - 0s 92ms/step - loss: 33768.6641 - val_loss: 6.8788 - lr: 0.0010
# Epoch 136/500
# 5/5 [==============================] - 0s 93ms/step - loss: 33762.1719 - val_loss: 6.6443 - lr: 0.0010
# Epoch 137/500
# 5/5 [==============================] - 0s 93ms/step - loss: 34461.7695 - val_loss: 6.3573 - lr: 0.0010
# Epoch 138/500
# 5/5 [==============================] - 0s 93ms/step - loss: 33390.6680 - val_loss: 6.5030 - lr: 0.0010
# Epoch 139/500
# 5/5 [==============================] - 0s 93ms/step - loss: 34069.6484 - val_loss: 6.1901 - lr: 0.0010
# Epoch 140/500
# 5/5 [==============================] - 0s 93ms/step - loss: 32729.2129 - val_loss: 6.6700 - lr: 0.0010
# Epoch 141/500
# 5/5 [==============================] - 0s 93ms/step - loss: 31415.8184 - val_loss: 6.6204 - lr: 0.0010
# Epoch 142/500
# 5/5 [==============================] - 0s 93ms/step - loss: 31876.9121 - val_loss: 6.4414 - lr: 0.0010
# Epoch 143/500
# 5/5 [==============================] - 0s 92ms/step - loss: 32033.6035 - val_loss: 6.4346 - lr: 0.0010
# Epoch 144/500
# 5/5 [==============================] - 0s 93ms/step - loss: 32629.8516 - val_loss: 6.4197 - lr: 0.0010
# Epoch 145/500
# 5/5 [==============================] - 0s 92ms/step - loss: 30056.4180 - val_loss: 6.2336 - lr: 0.0010
# Epoch 146/500
# 5/5 [==============================] - 0s 92ms/step - loss: 32932.5430 - val_loss: 6.3635 - lr: 0.0010
# Epoch 147/500
# 5/5 [==============================] - 0s 93ms/step - loss: 29762.0117 - val_loss: 6.4775 - lr: 0.0010
# Epoch 148/500
# 5/5 [==============================] - 0s 93ms/step - loss: 28892.4688 - val_loss: 6.4466 - lr: 0.0010
# Epoch 149/500
# 5/5 [==============================] - 0s 94ms/step - loss: 28572.2031 - val_loss: 6.7105 - lr: 0.0010
# Epoch 150/500
# 5/5 [==============================] - 0s 93ms/step - loss: 30077.2734 - val_loss: 6.5424 - lr: 0.0010
# Epoch 151/500
# 5/5 [==============================] - 0s 93ms/step - loss: 28708.7871 - val_loss: 6.8777 - lr: 0.0010
# Epoch 152/500
# 5/5 [==============================] - 0s 93ms/step - loss: 28772.4883 - val_loss: 6.4767 - lr: 0.0010
# Epoch 153/500
# 5/5 [==============================] - 0s 94ms/step - loss: 30535.7227 - val_loss: 6.7952 - lr: 0.0010
# Epoch 154/500
# 5/5 [==============================] - 0s 93ms/step - loss: 29265.2969 - val_loss: 6.6908 - lr: 0.0010
# Epoch 155/500
# 5/5 [==============================] - 0s 93ms/step - loss: 29235.0254 - val_loss: 6.6092 - lr: 0.0010
# Epoch 156/500
# 5/5 [==============================] - 0s 92ms/step - loss: 29871.7285 - val_loss: 6.7152 - lr: 0.0010
# Epoch 157/500
# 5/5 [==============================] - 0s 93ms/step - loss: 29179.0352 - val_loss: 6.3249 - lr: 0.0010
# Epoch 158/500
# 5/5 [==============================] - 0s 93ms/step - loss: 27850.5605 - val_loss: 6.4494 - lr: 0.0010
# Epoch 159/500
# 5/5 [==============================] - 0s 92ms/step - loss: 27961.8652 - val_loss: 7.0158 - lr: 0.0010
# Epoch 160/500
# 5/5 [==============================] - 0s 93ms/step - loss: 27326.4688 - val_loss: 6.5438 - lr: 0.0010
# Epoch 161/500
# 5/5 [==============================] - 0s 93ms/step - loss: 27833.5977 - val_loss: 6.1825 - lr: 0.0010
# Epoch 162/500
# 5/5 [==============================] - 0s 92ms/step - loss: 27417.3652 - val_loss: 6.6625 - lr: 0.0010
# Epoch 163/500
# 5/5 [==============================] - 0s 93ms/step - loss: 28012.4707 - val_loss: 6.4669 - lr: 0.0010
# Epoch 164/500
# 5/5 [==============================] - 0s 93ms/step - loss: 27883.2949 - val_loss: 6.5159 - lr: 0.0010
# Epoch 165/500
# 5/5 [==============================] - 0s 93ms/step - loss: 25966.9199 - val_loss: 6.8777 - lr: 0.0010
# Epoch 166/500
# 5/5 [==============================] - 0s 94ms/step - loss: 26482.5781 - val_loss: 6.2770 - lr: 0.0010
# Epoch 167/500
# 5/5 [==============================] - 0s 93ms/step - loss: 25859.9355 - val_loss: 6.4738 - lr: 0.0010
# CPU times: user 2min 7s, sys: 4.31 s, total: 2min 11s
# Wall time: 1min 20s

# %%
# Evaluar el modelo
y_true = ratings_val
predictions = model.predict([user_data_val, item_data_val])
# Out:
# 45006/45006 [==============================] - 68s 2ms/step

# %%
# MSE y RMSE
mse = mean_squared_error(y_true, predictions)
rmse = np.sqrt(mse)

# MAE
mae = mean_absolute_error(y_true, predictions)

# Funciones MAPE
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    non_zero_idx = y_true != 0  # Para evitar divisiones por cero
    return np.mean(np.abs((y_true[non_zero_idx] - y_pred[non_zero_idx]) / y_true[non_zero_idx])) * 100

def compute_mape_by_batch(y_true, predictions, batch_size=50000):
    mape_sum = 0
    num_batches = int(np.ceil(len(y_true) / batch_size))

    for i in range(num_batches):
        start_idx = i * batch_size
        end_idx = start_idx + batch_size

        batch_y_true = y_true[start_idx:end_idx]
        batch_predictions = predictions[start_idx:end_idx]

        mape_sum += mean_absolute_percentage_error(batch_y_true, batch_predictions)

    return mape_sum / num_batches

# Luego llamas a la función
mape = compute_mape_by_batch(y_true, predictions)

print(f'MSE: {mse}')
print(f'RMSE: {rmse}')
print(f'MAE: {mae}')
print(f'MAPE: {mape}%')
# Out:
# MSE: 6.4736417819129874
# RMSE: 2.5443352337915277
# MAE: 2.116064585388091
# MAPE: 55.39934816637558%

# %% [markdown]
# # Modelo de Filtrado Colaborativo usando Red Neuronal Multicapa y Embedding con Keras:
#
# Otra enfoque popular para filtrado colaborativo es utilizar redes neuronales multicapa, que esencialmente aprenden características no lineales de los datos. Vamos a construir un modelo que fusiona los embeddings de usuarios y artículos (por ejemplo, películas) en una red neuronal densa.
#
# Este enfoque, que combina embeddings y redes neuronales multicapa, puede capturar interacciones más complejas y no lineales entre usuarios y artículos. Sin embargo, es crucial prestar atención al sobreajuste y asegurarse de que el modelo no esté simplemente memorizando los datos. Por lo tanto, es recomendable emplear técnicas de regularización, ajustar hiperparámetros y validar el rendimiento con un conjunto de datos de validación.

# %% [markdown]
# Funcionamiento:
#
# Combina lo mejor de ambos mundos. Primero, se utilizan embeddings para convertir ítems y usuarios en representaciones vectoriales densas. Luego, estas representaciones se pasan a través de una red neuronal para hacer la predicción.
#
# El proceso generalmente comienza con capas de embedding que convierten identificadores de usuarios e ítems en vectores. Estos vectores luego se pasan a través de capas densas para obtener la predicción final.
#
# Ventajas:
#
# Capacidad de capturar patrones subyacentes en los datos mediante embeddings y modelar interacciones no lineales mediante la red neuronal.
#
# Flexibilidad para incorporar características adicionales.
#
# Potencialmente más preciso que cualquiera de los otros dos métodos por separado.
#
# Desventajas:
#
# Mayor complejidad en el modelado y entrenamiento.
#
# Mayor costo computacional.
#
# Requiere un ajuste más cuidadoso y riesgo de sobreajuste si no se gestiona adecuadamente.

# %% [markdown]
# Regularización L2: Agregar una regularización L2 a las capas de embedding y densas para prevenir el sobreajuste.
#
# Early Stopping: Añadir una callback de early stopping para detener el entrenamiento cuando no haya mejora en el conjunto de validación durante un cierto número de épocas.
#
# Ajuste de la tasa de aprendizaje: Utilizar la callback ReduceLROnPlateau para reducir la tasa de aprendizaje cuando no haya mejora en el conjunto de validación.
#
# Métricas adicionales: Puedes monitorizar otras métricas como el error absoluto medio (MAE) durante el entrenamiento.

# %%
# Suponiendo que el DataFrame se llama df
df = df

# Convertir reviewerID y asin a índices numéricos secuenciales
df['user_id'] = df['reviewerID'].astype('category').cat.codes.values
df['item_id'] = df['asin'].astype('category').cat.codes.values

# Número de usuarios e ítems
n_users = df['user_id'].nunique()
n_items = df['item_id'].nunique()

# Hiperparámetros
n_latent_factors = 50
hidden_units = [128, 64]
dropout_rate = 0.2
l2_reg = 1e-4

# Arquitectura del modelo con regularización L2
user_embedding = Embedding(n_users, n_latent_factors, embeddings_regularizer=l2(l2_reg), name='user_embedding')(user_input)
item_embedding = Embedding(n_items, n_latent_factors, embeddings_regularizer=l2(l2_reg), name='item_embedding')(item_input)

user_vec = Flatten(name='flatten_users')(user_embedding)
item_vec = Flatten(name='flatten_items')(item_embedding)
concat = Concatenate()([user_vec, item_vec])
dense = concat
for units in hidden_units:
    dense = Dense(units, activation='relu', kernel_regularizer=l2(l2_reg))(dense)
    dense = Dropout(dropout_rate)(dense)
output = Dense(1, kernel_regularizer=l2(l2_reg))(dense)
model = Model(inputs=[user_input, item_input], outputs=output)

model.compile(optimizer=Adam(0.001), loss='mean_squared_error', metrics=['mae'])

# %%
# Callbacks
early_stop = EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=50, min_lr=1e-5)

# %%
# Entrenamiento
user_data = df['user_id'].values
item_data = df['item_id'].values
rating_data = df['overall'].values

# Usando validation_split, divide los datos
train_size = int(0.7 * len(user_data))
user_data_train, user_data_val = user_data[:train_size], user_data[train_size:]
item_data_train, item_data_val = item_data[:train_size], item_data[train_size:]
y_true = rating_data[train_size:]

# %%
# %%time
history = model.fit([user_data_train, item_data_train], rating_data[:train_size],
                    epochs=500,validation_data=([user_data_val, item_data_val], y_true),
                    batch_size=800000,verbose=1,callbacks=[early_stop, reduce_lr])
# Out:
# Epoch 1/500
# 5/5 [==============================] - 3s 356ms/step - loss: 25.6150 - mae: 4.2373 - val_loss: 23.9393 - val_mae: 4.1471 - lr: 0.0010
# Epoch 2/500
# 5/5 [==============================] - 1s 217ms/step - loss: 23.4006 - mae: 4.1360 - val_loss: 21.8787 - val_mae: 4.0512 - lr: 0.0010
# Epoch 3/500
# 5/5 [==============================] - 1s 218ms/step - loss: 21.1153 - mae: 4.0030 - val_loss: 19.9037 - val_mae: 3.9346 - lr: 0.0010
# Epoch 4/500
# 5/5 [==============================] - 1s 218ms/step - loss: 18.6152 - mae: 3.8057 - val_loss: 17.9048 - val_mae: 3.7789 - lr: 0.0010
# Epoch 5/500
# 5/5 [==============================] - 1s 217ms/step - loss: 15.6078 - mae: 3.4918 - val_loss: 15.7131 - val_mae: 3.5575 - lr: 0.0010
# Epoch 6/500
# 5/5 [==============================] - 1s 216ms/step - loss: 11.8423 - mae: 3.0105 - val_loss: 13.2236 - val_mae: 3.2477 - lr: 0.0010
# Epoch 7/500
# 5/5 [==============================] - 1s 217ms/step - loss: 7.4973 - mae: 2.3094 - val_loss: 10.4911 - val_mae: 2.8638 - lr: 0.0010
# Epoch 8/500
# 5/5 [==============================] - 1s 217ms/step - loss: 3.8344 - mae: 1.4499 - val_loss: 7.9120 - val_mae: 2.4294 - lr: 0.0010
# Epoch 9/500
# 5/5 [==============================] - 1s 217ms/step - loss: 2.9648 - mae: 1.0524 - val_loss: 6.4954 - val_mae: 2.1674 - lr: 0.0010
# Epoch 10/500
# 5/5 [==============================] - 1s 137ms/step - loss: 3.1356 - mae: 1.1125 - val_loss: 6.6135 - val_mae: 2.2254 - lr: 0.0010
# Epoch 11/500
# 5/5 [==============================] - 1s 137ms/step - loss: 2.2392 - mae: 0.8996 - val_loss: 7.2811 - val_mae: 2.3848 - lr: 0.0010
# Epoch 12/500
# 5/5 [==============================] - 1s 138ms/step - loss: 1.9510 - mae: 0.9140 - val_loss: 7.6355 - val_mae: 2.4657 - lr: 0.0010
# Epoch 13/500
# 5/5 [==============================] - 1s 137ms/step - loss: 1.9566 - mae: 0.9694 - val_loss: 7.4513 - val_mae: 2.4365 - lr: 0.0010
# Epoch 14/500
# 5/5 [==============================] - 1s 137ms/step - loss: 1.7969 - mae: 0.8942 - val_loss: 6.9465 - val_mae: 2.3414 - lr: 0.0010
# Epoch 15/500
# 5/5 [==============================] - 1s 217ms/step - loss: 1.6483 - mae: 0.7992 - val_loss: 6.4870 - val_mae: 2.2518 - lr: 0.0010
# Epoch 16/500
# 5/5 [==============================] - 1s 217ms/step - loss: 1.6040 - mae: 0.7695 - val_loss: 6.3136 - val_mae: 2.2210 - lr: 0.0010
# Epoch 17/500
# 5/5 [==============================] - 1s 137ms/step - loss: 1.5409 - mae: 0.7596 - val_loss: 6.3676 - val_mae: 2.2385 - lr: 0.0010
# Epoch 18/500
# 5/5 [==============================] - 1s 137ms/step - loss: 1.4775 - mae: 0.7610 - val_loss: 6.4151 - val_mae: 2.2535 - lr: 0.0010
# Epoch 19/500
# 5/5 [==============================] - 1s 218ms/step - loss: 1.4424 - mae: 0.7665 - val_loss: 6.3000 - val_mae: 2.2333 - lr: 0.0010
# Epoch 20/500
# 5/5 [==============================] - 1s 218ms/step - loss: 1.4019 - mae: 0.7538 - val_loss: 6.0675 - val_mae: 2.1875 - lr: 0.0010
# Epoch 21/500
# 5/5 [==============================] - 1s 221ms/step - loss: 1.3652 - mae: 0.7370 - val_loss: 5.8612 - val_mae: 2.1461 - lr: 0.0010
# Epoch 22/500
# 5/5 [==============================] - 1s 222ms/step - loss: 1.3357 - mae: 0.7280 - val_loss: 5.7507 - val_mae: 2.1252 - lr: 0.0010
# Epoch 23/500
# 5/5 [==============================] - 1s 217ms/step - loss: 1.3058 - mae: 0.7243 - val_loss: 5.6825 - val_mae: 2.1134 - lr: 0.0010
# Epoch 24/500
# 5/5 [==============================] - 1s 218ms/step - loss: 1.2815 - mae: 0.7233 - val_loss: 5.5728 - val_mae: 2.0921 - lr: 0.0010
# Epoch 25/500
# 5/5 [==============================] - 1s 218ms/step - loss: 1.2578 - mae: 0.7193 - val_loss: 5.4141 - val_mae: 2.0593 - lr: 0.0010
# Epoch 26/500
# 5/5 [==============================] - 1s 216ms/step - loss: 1.2360 - mae: 0.7140 - val_loss: 5.2564 - val_mae: 2.0263 - lr: 0.0010
# Epoch 27/500
# 5/5 [==============================] - 1s 217ms/step - loss: 1.2163 - mae: 0.7103 - val_loss: 5.1330 - val_mae: 2.0008 - lr: 0.0010
# Epoch 28/500
# 5/5 [==============================] - 1s 218ms/step - loss: 1.1990 - mae: 0.7090 - val_loss: 5.0237 - val_mae: 1.9784 - lr: 0.0010
# Epoch 29/500
# 5/5 [==============================] - 1s 220ms/step - loss: 1.1825 - mae: 0.7080 - val_loss: 4.8988 - val_mae: 1.9519 - lr: 0.0010
# Epoch 30/500
# 5/5 [==============================] - 1s 220ms/step - loss: 1.1672 - mae: 0.7059 - val_loss: 4.7639 - val_mae: 1.9225 - lr: 0.0010
# Epoch 31/500
# 5/5 [==============================] - 1s 217ms/step - loss: 1.1529 - mae: 0.7041 - val_loss: 4.6395 - val_mae: 1.8950 - lr: 0.0010
# Epoch 32/500
# 5/5 [==============================] - 1s 220ms/step - loss: 1.1394 - mae: 0.7027 - val_loss: 4.5243 - val_mae: 1.8694 - lr: 0.0010
# Epoch 33/500
# 5/5 [==============================] - 1s 220ms/step - loss: 1.1278 - mae: 0.7021 - val_loss: 4.4118 - val_mae: 1.8441 - lr: 0.0010
# Epoch 34/500
# 5/5 [==============================] - 1s 218ms/step - loss: 1.1170 - mae: 0.7016 - val_loss: 4.2968 - val_mae: 1.8177 - lr: 0.0010
# Epoch 35/500
# 5/5 [==============================] - 1s 219ms/step - loss: 1.1054 - mae: 0.7001 - val_loss: 4.1824 - val_mae: 1.7909 - lr: 0.0010
# Epoch 36/500
# 5/5 [==============================] - 1s 219ms/step - loss: 1.0966 - mae: 0.6997 - val_loss: 4.0740 - val_mae: 1.7653 - lr: 0.0010
# Epoch 37/500
# 5/5 [==============================] - 1s 218ms/step - loss: 1.0871 - mae: 0.6988 - val_loss: 3.9741 - val_mae: 1.7413 - lr: 0.0010
# Epoch 38/500
# 5/5 [==============================] - 1s 219ms/step - loss: 1.0786 - mae: 0.6982 - val_loss: 3.8736 - val_mae: 1.7165 - lr: 0.0010
# Epoch 39/500
# 5/5 [==============================] - 1s 219ms/step - loss: 1.0702 - mae: 0.6974 - val_loss: 3.7762 - val_mae: 1.6922 - lr: 0.0010
# Epoch 40/500
# 5/5 [==============================] - 1s 220ms/step - loss: 1.0624 - mae: 0.6969 - val_loss: 3.6837 - val_mae: 1.6687 - lr: 0.0010
# Epoch 41/500
# 5/5 [==============================] - 1s 218ms/step - loss: 1.0556 - mae: 0.6965 - val_loss: 3.5930 - val_mae: 1.6453 - lr: 0.0010
# Epoch 42/500
# 5/5 [==============================] - 1s 221ms/step - loss: 1.0492 - mae: 0.6960 - val_loss: 3.5046 - val_mae: 1.6220 - lr: 0.0010
# Epoch 43/500
# 5/5 [==============================] - 1s 220ms/step - loss: 1.0424 - mae: 0.6955 - val_loss: 3.4202 - val_mae: 1.5995 - lr: 0.0010
# Epoch 44/500
# 5/5 [==============================] - 1s 218ms/step - loss: 1.0366 - mae: 0.6947 - val_loss: 3.3372 - val_mae: 1.5767 - lr: 0.0010
# Epoch 45/500
# 5/5 [==============================] - 1s 217ms/step - loss: 1.0309 - mae: 0.6946 - val_loss: 3.2621 - val_mae: 1.5560 - lr: 0.0010
# Epoch 46/500
# 5/5 [==============================] - 1s 217ms/step - loss: 1.0249 - mae: 0.6936 - val_loss: 3.1870 - val_mae: 1.5347 - lr: 0.0010
# Epoch 47/500
# 5/5 [==============================] - 1s 217ms/step - loss: 1.0202 - mae: 0.6934 - val_loss: 3.1121 - val_mae: 1.5134 - lr: 0.0010
# Epoch 48/500
# 5/5 [==============================] - 1s 218ms/step - loss: 1.0148 - mae: 0.6927 - val_loss: 3.0438 - val_mae: 1.4936 - lr: 0.0010
# Epoch 49/500
# 5/5 [==============================] - 1s 219ms/step - loss: 1.0104 - mae: 0.6922 - val_loss: 2.9789 - val_mae: 1.4745 - lr: 0.0010
# Epoch 50/500
# 5/5 [==============================] - 1s 221ms/step - loss: 1.0062 - mae: 0.6919 - val_loss: 2.9149 - val_mae: 1.4554 - lr: 0.0010
# Epoch 51/500
# 5/5 [==============================] - 1s 218ms/step - loss: 1.0011 - mae: 0.6910 - val_loss: 2.8522 - val_mae: 1.4371 - lr: 0.0010
# Epoch 52/500
# 5/5 [==============================] - 1s 223ms/step - loss: 0.9970 - mae: 0.6904 - val_loss: 2.7939 - val_mae: 1.4198 - lr: 0.0010
# Epoch 53/500
# 5/5 [==============================] - 1s 217ms/step - loss: 0.9930 - mae: 0.6900 - val_loss: 2.7387 - val_mae: 1.4028 - lr: 0.0010
# Epoch 54/500
# 5/5 [==============================] - 1s 222ms/step - loss: 0.9901 - mae: 0.6899 - val_loss: 2.6857 - val_mae: 1.3861 - lr: 0.0010
# Epoch 55/500
# 5/5 [==============================] - 1s 220ms/step - loss: 0.9863 - mae: 0.6893 - val_loss: 2.6347 - val_mae: 1.3703 - lr: 0.0010
# Epoch 56/500
# 5/5 [==============================] - 1s 217ms/step - loss: 0.9822 - mae: 0.6885 - val_loss: 2.5845 - val_mae: 1.3546 - lr: 0.0010
# Epoch 57/500
# 5/5 [==============================] - 1s 222ms/step - loss: 0.9785 - mae: 0.6880 - val_loss: 2.5341 - val_mae: 1.3382 - lr: 0.0010
# Epoch 58/500
# 5/5 [==============================] - 1s 223ms/step - loss: 0.9758 - mae: 0.6876 - val_loss: 2.4879 - val_mae: 1.3230 - lr: 0.0010
# Epoch 59/500
# 5/5 [==============================] - 1s 218ms/step - loss: 0.9719 - mae: 0.6867 - val_loss: 2.4454 - val_mae: 1.3087 - lr: 0.0010
# Epoch 60/500
# 5/5 [==============================] - 1s 220ms/step - loss: 0.9691 - mae: 0.6862 - val_loss: 2.4041 - val_mae: 1.2944 - lr: 0.0010
# Epoch 61/500
# 5/5 [==============================] - 1s 218ms/step - loss: 0.9660 - mae: 0.6856 - val_loss: 2.3653 - val_mae: 1.2808 - lr: 0.0010
# Epoch 62/500
# 5/5 [==============================] - 1s 220ms/step - loss: 0.9638 - mae: 0.6855 - val_loss: 2.3278 - val_mae: 1.2677 - lr: 0.0010
# Epoch 63/500
# 5/5 [==============================] - 1s 220ms/step - loss: 0.9605 - mae: 0.6846 - val_loss: 2.2900 - val_mae: 1.2541 - lr: 0.0010
# Epoch 64/500
# 5/5 [==============================] - 1s 217ms/step - loss: 0.9574 - mae: 0.6838 - val_loss: 2.2565 - val_mae: 1.2419 - lr: 0.0010
# Epoch 65/500
# 5/5 [==============================] - 1s 218ms/step - loss: 0.9551 - mae: 0.6835 - val_loss: 2.2245 - val_mae: 1.2298 - lr: 0.0010
# Epoch 66/500
# 5/5 [==============================] - 1s 219ms/step - loss: 0.9529 - mae: 0.6831 - val_loss: 2.1930 - val_mae: 1.2176 - lr: 0.0010
# Epoch 67/500
# 5/5 [==============================] - 1s 219ms/step - loss: 0.9501 - mae: 0.6824 - val_loss: 2.1628 - val_mae: 1.2056 - lr: 0.0010
# Epoch 68/500
# 5/5 [==============================] - 1s 218ms/step - loss: 0.9479 - mae: 0.6816 - val_loss: 2.1322 - val_mae: 1.1933 - lr: 0.0010
# Epoch 69/500
# 5/5 [==============================] - 1s 219ms/step - loss: 0.9455 - mae: 0.6811 - val_loss: 2.1027 - val_mae: 1.1812 - lr: 0.0010
# Epoch 70/500
# 5/5 [==============================] - 1s 218ms/step - loss: 0.9429 - mae: 0.6806 - val_loss: 2.0728 - val_mae: 1.1688 - lr: 0.0010
# Epoch 71/500
# 5/5 [==============================] - 1s 218ms/step - loss: 0.9396 - mae: 0.6794 - val_loss: 2.0431 - val_mae: 1.1561 - lr: 0.0010
# Epoch 72/500
# 5/5 [==============================] - 1s 218ms/step - loss: 0.9362 - mae: 0.6784 - val_loss: 2.0145 - val_mae: 1.1436 - lr: 0.0010
# Epoch 73/500
# 5/5 [==============================] - 1s 221ms/step - loss: 0.9337 - mae: 0.6778 - val_loss: 1.9894 - val_mae: 1.1327 - lr: 0.0010
# Epoch 74/500
# 5/5 [==============================] - 1s 218ms/step - loss: 0.9306 - mae: 0.6772 - val_loss: 1.9644 - val_mae: 1.1214 - lr: 0.0010
# Epoch 75/500
# 5/5 [==============================] - 1s 220ms/step - loss: 0.9280 - mae: 0.6766 - val_loss: 1.9429 - val_mae: 1.1115 - lr: 0.0010
# Epoch 76/500
# 5/5 [==============================] - 1s 222ms/step - loss: 0.9271 - mae: 0.6767 - val_loss: 1.9230 - val_mae: 1.1020 - lr: 0.0010
# Epoch 77/500
# 5/5 [==============================] - 1s 220ms/step - loss: 0.9257 - mae: 0.6765 - val_loss: 1.9058 - val_mae: 1.0938 - lr: 0.0010
# Epoch 78/500
# 5/5 [==============================] - 1s 220ms/step - loss: 0.9230 - mae: 0.6758 - val_loss: 1.8913 - val_mae: 1.0868 - lr: 0.0010
# Epoch 79/500
# 5/5 [==============================] - 1s 218ms/step - loss: 0.9212 - mae: 0.6755 - val_loss: 1.8766 - val_mae: 1.0793 - lr: 0.0010
# Epoch 80/500
# 5/5 [==============================] - 1s 216ms/step - loss: 0.9195 - mae: 0.6745 - val_loss: 1.8620 - val_mae: 1.0717 - lr: 0.0010
# Epoch 81/500
# 5/5 [==============================] - 1s 218ms/step - loss: 0.9178 - mae: 0.6737 - val_loss: 1.8503 - val_mae: 1.0659 - lr: 0.0010
# Epoch 82/500
# 5/5 [==============================] - 1s 221ms/step - loss: 0.9167 - mae: 0.6738 - val_loss: 1.8385 - val_mae: 1.0596 - lr: 0.0010
# Epoch 83/500
# 5/5 [==============================] - 1s 220ms/step - loss: 0.9141 - mae: 0.6723 - val_loss: 1.8248 - val_mae: 1.0520 - lr: 0.0010
# Epoch 84/500
# 5/5 [==============================] - 1s 221ms/step - loss: 0.9127 - mae: 0.6718 - val_loss: 1.8165 - val_mae: 1.0475 - lr: 0.0010
# Epoch 85/500
# 5/5 [==============================] - 1s 217ms/step - loss: 0.9105 - mae: 0.6713 - val_loss: 1.8061 - val_mae: 1.0416 - lr: 0.0010
# Epoch 86/500
# 5/5 [==============================] - 1s 217ms/step - loss: 0.9090 - mae: 0.6708 - val_loss: 1.7949 - val_mae: 1.0350 - lr: 0.0010
# Epoch 87/500
# 5/5 [==============================] - 1s 217ms/step - loss: 0.9077 - mae: 0.6703 - val_loss: 1.7875 - val_mae: 1.0309 - lr: 0.0010
# Epoch 88/500
# 5/5 [==============================] - 1s 217ms/step - loss: 0.9060 - mae: 0.6699 - val_loss: 1.7776 - val_mae: 1.0251 - lr: 0.0010
# Epoch 89/500
# 5/5 [==============================] - 1s 219ms/step - loss: 0.9043 - mae: 0.6691 - val_loss: 1.7679 - val_mae: 1.0189 - lr: 0.0010
# Epoch 90/500
# 5/5 [==============================] - 1s 219ms/step - loss: 0.9030 - mae: 0.6689 - val_loss: 1.7610 - val_mae: 1.0148 - lr: 0.0010
# Epoch 91/500
# 5/5 [==============================] - 1s 220ms/step - loss: 0.9007 - mae: 0.6683 - val_loss: 1.7537 - val_mae: 1.0098 - lr: 0.0010
# Epoch 92/500
# 5/5 [==============================] - 1s 217ms/step - loss: 0.8994 - mae: 0.6677 - val_loss: 1.7465 - val_mae: 1.0049 - lr: 0.0010
# Epoch 93/500
# 5/5 [==============================] - 1s 218ms/step - loss: 0.8982 - mae: 0.6674 - val_loss: 1.7410 - val_mae: 1.0014 - lr: 0.0010
# Epoch 94/500
# 5/5 [==============================] - 1s 221ms/step - loss: 0.8960 - mae: 0.6665 - val_loss: 1.7339 - val_mae: 0.9968 - lr: 0.0010
# Epoch 95/500
# 5/5 [==============================] - 1s 217ms/step - loss: 0.8946 - mae: 0.6663 - val_loss: 1.7286 - val_mae: 0.9932 - lr: 0.0010
# Epoch 96/500
# 5/5 [==============================] - 1s 223ms/step - loss: 0.8928 - mae: 0.6656 - val_loss: 1.7240 - val_mae: 0.9897 - lr: 0.0010
# Epoch 97/500
# 5/5 [==============================] - 1s 219ms/step - loss: 0.8921 - mae: 0.6657 - val_loss: 1.7183 - val_mae: 0.9851 - lr: 0.0010
# Epoch 98/500
# 5/5 [==============================] - 1s 217ms/step - loss: 0.8898 - mae: 0.6646 - val_loss: 1.7133 - val_mae: 0.9816 - lr: 0.0010
# Epoch 99/500
# 5/5 [==============================] - 1s 217ms/step - loss: 0.8881 - mae: 0.6643 - val_loss: 1.7084 - val_mae: 0.9781 - lr: 0.0010
# Epoch 100/500
# 5/5 [==============================] - 1s 218ms/step - loss: 0.8865 - mae: 0.6637 - val_loss: 1.7031 - val_mae: 0.9743 - lr: 0.0010
# Epoch 101/500
# 5/5 [==============================] - 1s 219ms/step - loss: 0.8852 - mae: 0.6630 - val_loss: 1.7000 - val_mae: 0.9720 - lr: 0.0010
# Epoch 102/500
# 5/5 [==============================] - 1s 219ms/step - loss: 0.8837 - mae: 0.6626 - val_loss: 1.6960 - val_mae: 0.9688 - lr: 0.0010
# Epoch 103/500
# 5/5 [==============================] - 1s 216ms/step - loss: 0.8812 - mae: 0.6618 - val_loss: 1.6917 - val_mae: 0.9656 - lr: 0.0010
# Epoch 104/500
# 5/5 [==============================] - 1s 219ms/step - loss: 0.8791 - mae: 0.6609 - val_loss: 1.6875 - val_mae: 0.9619 - lr: 0.0010
# Epoch 105/500
# 5/5 [==============================] - 1s 219ms/step - loss: 0.8775 - mae: 0.6603 - val_loss: 1.6840 - val_mae: 0.9592 - lr: 0.0010
# Epoch 106/500
# 5/5 [==============================] - 1s 218ms/step - loss: 0.8761 - mae: 0.6601 - val_loss: 1.6810 - val_mae: 0.9568 - lr: 0.0010
# Epoch 107/500
# 5/5 [==============================] - 1s 216ms/step - loss: 0.8745 - mae: 0.6595 - val_loss: 1.6783 - val_mae: 0.9540 - lr: 0.0010
# Epoch 108/500
# 5/5 [==============================] - 1s 219ms/step - loss: 0.8732 - mae: 0.6590 - val_loss: 1.6759 - val_mae: 0.9515 - lr: 0.0010
# Epoch 109/500
# 5/5 [==============================] - 1s 220ms/step - loss: 0.8712 - mae: 0.6583 - val_loss: 1.6749 - val_mae: 0.9502 - lr: 0.0010
# Epoch 110/500
# 5/5 [==============================] - 1s 217ms/step - loss: 0.8687 - mae: 0.6576 - val_loss: 1.6720 - val_mae: 0.9479 - lr: 0.0010
# Epoch 111/500
# 5/5 [==============================] - 1s 217ms/step - loss: 0.8669 - mae: 0.6568 - val_loss: 1.6688 - val_mae: 0.9459 - lr: 0.0010
# Epoch 112/500
# 5/5 [==============================] - 1s 217ms/step - loss: 0.8649 - mae: 0.6560 - val_loss: 1.6656 - val_mae: 0.9439 - lr: 0.0010
# Epoch 113/500
# 5/5 [==============================] - 1s 218ms/step - loss: 0.8632 - mae: 0.6554 - val_loss: 1.6635 - val_mae: 0.9418 - lr: 0.0010
# Epoch 114/500
# 5/5 [==============================] - 1s 216ms/step - loss: 0.8619 - mae: 0.6549 - val_loss: 1.6617 - val_mae: 0.9404 - lr: 0.0010
# Epoch 115/500
# 5/5 [==============================] - 1s 217ms/step - loss: 0.8603 - mae: 0.6542 - val_loss: 1.6596 - val_mae: 0.9384 - lr: 0.0010
# Epoch 116/500
# 5/5 [==============================] - 1s 220ms/step - loss: 0.8577 - mae: 0.6533 - val_loss: 1.6577 - val_mae: 0.9365 - lr: 0.0010
# Epoch 117/500
# 5/5 [==============================] - 1s 219ms/step - loss: 0.8561 - mae: 0.6527 - val_loss: 1.6564 - val_mae: 0.9356 - lr: 0.0010
# Epoch 118/500
# 5/5 [==============================] - 1s 218ms/step - loss: 0.8545 - mae: 0.6521 - val_loss: 1.6548 - val_mae: 0.9338 - lr: 0.0010
# Epoch 119/500
# 5/5 [==============================] - 1s 219ms/step - loss: 0.8517 - mae: 0.6509 - val_loss: 1.6526 - val_mae: 0.9320 - lr: 0.0010
# Epoch 120/500
# 5/5 [==============================] - 1s 220ms/step - loss: 0.8502 - mae: 0.6504 - val_loss: 1.6506 - val_mae: 0.9302 - lr: 0.0010
# Epoch 121/500
# 5/5 [==============================] - 1s 220ms/step - loss: 0.8478 - mae: 0.6493 - val_loss: 1.6492 - val_mae: 0.9292 - lr: 0.0010
# Epoch 122/500
# 5/5 [==============================] - 1s 225ms/step - loss: 0.8458 - mae: 0.6485 - val_loss: 1.6477 - val_mae: 0.9280 - lr: 0.0010
# Epoch 123/500
# 5/5 [==============================] - 1s 222ms/step - loss: 0.8436 - mae: 0.6477 - val_loss: 1.6461 - val_mae: 0.9264 - lr: 0.0010
# Epoch 124/500
# 5/5 [==============================] - 1s 220ms/step - loss: 0.8420 - mae: 0.6471 - val_loss: 1.6451 - val_mae: 0.9252 - lr: 0.0010
# Epoch 125/500
# 5/5 [==============================] - 1s 219ms/step - loss: 0.8403 - mae: 0.6463 - val_loss: 1.6445 - val_mae: 0.9245 - lr: 0.0010
# Epoch 126/500
# 5/5 [==============================] - 1s 223ms/step - loss: 0.8384 - mae: 0.6456 - val_loss: 1.6438 - val_mae: 0.9226 - lr: 0.0010
# Epoch 127/500
# 5/5 [==============================] - 1s 219ms/step - loss: 0.8363 - mae: 0.6446 - val_loss: 1.6422 - val_mae: 0.9215 - lr: 0.0010
# Epoch 128/500
# 5/5 [==============================] - 1s 218ms/step - loss: 0.8338 - mae: 0.6437 - val_loss: 1.6410 - val_mae: 0.9200 - lr: 0.0010
# Epoch 129/500
# 5/5 [==============================] - 1s 218ms/step - loss: 0.8324 - mae: 0.6433 - val_loss: 1.6392 - val_mae: 0.9187 - lr: 0.0010
# Epoch 130/500
# 5/5 [==============================] - 1s 220ms/step - loss: 0.8301 - mae: 0.6422 - val_loss: 1.6382 - val_mae: 0.9175 - lr: 0.0010
# Epoch 131/500
# 5/5 [==============================] - 1s 221ms/step - loss: 0.8283 - mae: 0.6415 - val_loss: 1.6375 - val_mae: 0.9166 - lr: 0.0010
# Epoch 132/500
# 5/5 [==============================] - 1s 221ms/step - loss: 0.8263 - mae: 0.6408 - val_loss: 1.6360 - val_mae: 0.9153 - lr: 0.0010
# Epoch 133/500
# 5/5 [==============================] - 1s 139ms/step - loss: 0.8241 - mae: 0.6397 - val_loss: 1.6361 - val_mae: 0.9144 - lr: 0.0010
# Epoch 134/500
# 5/5 [==============================] - 1s 219ms/step - loss: 0.8231 - mae: 0.6394 - val_loss: 1.6359 - val_mae: 0.9139 - lr: 0.0010
# Epoch 135/500
# 5/5 [==============================] - 1s 224ms/step - loss: 0.8211 - mae: 0.6386 - val_loss: 1.6347 - val_mae: 0.9129 - lr: 0.0010
# Epoch 136/500
# 5/5 [==============================] - 1s 220ms/step - loss: 0.8185 - mae: 0.6375 - val_loss: 1.6334 - val_mae: 0.9119 - lr: 0.0010
# Epoch 137/500
# 5/5 [==============================] - 1s 221ms/step - loss: 0.8169 - mae: 0.6368 - val_loss: 1.6324 - val_mae: 0.9107 - lr: 0.0010
# Epoch 138/500
# 5/5 [==============================] - 1s 220ms/step - loss: 0.8150 - mae: 0.6361 - val_loss: 1.6318 - val_mae: 0.9095 - lr: 0.0010
# Epoch 139/500
# 5/5 [==============================] - 1s 221ms/step - loss: 0.8131 - mae: 0.6351 - val_loss: 1.6303 - val_mae: 0.9089 - lr: 0.0010
# Epoch 140/500
# 5/5 [==============================] - 1s 139ms/step - loss: 0.8115 - mae: 0.6346 - val_loss: 1.6303 - val_mae: 0.9082 - lr: 0.0010
# Epoch 141/500
# 5/5 [==============================] - 1s 218ms/step - loss: 0.8098 - mae: 0.6339 - val_loss: 1.6301 - val_mae: 0.9073 - lr: 0.0010
# Epoch 142/500
# 5/5 [==============================] - 1s 223ms/step - loss: 0.8078 - mae: 0.6329 - val_loss: 1.6289 - val_mae: 0.9061 - lr: 0.0010
# Epoch 143/500
# 5/5 [==============================] - 1s 222ms/step - loss: 0.8059 - mae: 0.6319 - val_loss: 1.6284 - val_mae: 0.9052 - lr: 0.0010
# Epoch 144/500
# 5/5 [==============================] - 1s 223ms/step - loss: 0.8040 - mae: 0.6314 - val_loss: 1.6278 - val_mae: 0.9049 - lr: 0.0010
# Epoch 145/500
# 5/5 [==============================] - 1s 140ms/step - loss: 0.8028 - mae: 0.6306 - val_loss: 1.6279 - val_mae: 0.9039 - lr: 0.0010
# Epoch 146/500
# 5/5 [==============================] - 1s 219ms/step - loss: 0.8009 - mae: 0.6300 - val_loss: 1.6271 - val_mae: 0.9030 - lr: 0.0010
# Epoch 147/500
# 5/5 [==============================] - 1s 220ms/step - loss: 0.8000 - mae: 0.6296 - val_loss: 1.6269 - val_mae: 0.9024 - lr: 0.0010
# Epoch 148/500
# 5/5 [==============================] - 1s 219ms/step - loss: 0.7972 - mae: 0.6282 - val_loss: 1.6263 - val_mae: 0.9012 - lr: 0.0010
# Epoch 149/500
# 5/5 [==============================] - 1s 219ms/step - loss: 0.7961 - mae: 0.6276 - val_loss: 1.6258 - val_mae: 0.9008 - lr: 0.0010
# Epoch 150/500
# 5/5 [==============================] - 1s 139ms/step - loss: 0.7949 - mae: 0.6274 - val_loss: 1.6258 - val_mae: 0.8998 - lr: 0.0010
# Epoch 151/500
# 5/5 [==============================] - 1s 219ms/step - loss: 0.7931 - mae: 0.6265 - val_loss: 1.6246 - val_mae: 0.8992 - lr: 0.0010
# Epoch 152/500
# 5/5 [==============================] - 1s 139ms/step - loss: 0.7910 - mae: 0.6255 - val_loss: 1.6247 - val_mae: 0.8985 - lr: 0.0010
# Epoch 153/500
# 5/5 [==============================] - 1s 218ms/step - loss: 0.7897 - mae: 0.6250 - val_loss: 1.6246 - val_mae: 0.8975 - lr: 0.0010
# Epoch 154/500
# 5/5 [==============================] - 1s 221ms/step - loss: 0.7888 - mae: 0.6246 - val_loss: 1.6235 - val_mae: 0.8968 - lr: 0.0010
# Epoch 155/500
# 5/5 [==============================] - 1s 219ms/step - loss: 0.7875 - mae: 0.6240 - val_loss: 1.6227 - val_mae: 0.8964 - lr: 0.0010
# Epoch 156/500
# 5/5 [==============================] - 1s 139ms/step - loss: 0.7853 - mae: 0.6231 - val_loss: 1.6230 - val_mae: 0.8952 - lr: 0.0010
# Epoch 157/500
# 5/5 [==============================] - 1s 223ms/step - loss: 0.7848 - mae: 0.6227 - val_loss: 1.6226 - val_mae: 0.8947 - lr: 0.0010
# Epoch 158/500
# 5/5 [==============================] - 1s 219ms/step - loss: 0.7828 - mae: 0.6218 - val_loss: 1.6222 - val_mae: 0.8943 - lr: 0.0010
# Epoch 159/500
# 5/5 [==============================] - 1s 219ms/step - loss: 0.7821 - mae: 0.6215 - val_loss: 1.6217 - val_mae: 0.8934 - lr: 0.0010
# Epoch 160/500
# 5/5 [==============================] - 1s 220ms/step - loss: 0.7804 - mae: 0.6208 - val_loss: 1.6208 - val_mae: 0.8927 - lr: 0.0010
# Epoch 161/500
# 5/5 [==============================] - 1s 219ms/step - loss: 0.7793 - mae: 0.6202 - val_loss: 1.6197 - val_mae: 0.8924 - lr: 0.0010
# Epoch 162/500
# 5/5 [==============================] - 1s 139ms/step - loss: 0.7784 - mae: 0.6199 - val_loss: 1.6207 - val_mae: 0.8914 - lr: 0.0010
# Epoch 163/500
# 5/5 [==============================] - 1s 138ms/step - loss: 0.7766 - mae: 0.6190 - val_loss: 1.6206 - val_mae: 0.8906 - lr: 0.0010
# Epoch 164/500
# 5/5 [==============================] - 1s 217ms/step - loss: 0.7759 - mae: 0.6187 - val_loss: 1.6192 - val_mae: 0.8904 - lr: 0.0010
# Epoch 165/500
# 5/5 [==============================] - 1s 139ms/step - loss: 0.7747 - mae: 0.6183 - val_loss: 1.6199 - val_mae: 0.8894 - lr: 0.0010
# Epoch 166/500
# 5/5 [==============================] - 1s 218ms/step - loss: 0.7733 - mae: 0.6173 - val_loss: 1.6186 - val_mae: 0.8890 - lr: 0.0010
# Epoch 167/500
# 5/5 [==============================] - 1s 219ms/step - loss: 0.7719 - mae: 0.6167 - val_loss: 1.6184 - val_mae: 0.8888 - lr: 0.0010
# Epoch 168/500
# 5/5 [==============================] - 1s 139ms/step - loss: 0.7706 - mae: 0.6162 - val_loss: 1.6199 - val_mae: 0.8874 - lr: 0.0010
# Epoch 169/500
# 5/5 [==============================] - 1s 218ms/step - loss: 0.7699 - mae: 0.6160 - val_loss: 1.6180 - val_mae: 0.8874 - lr: 0.0010
# Epoch 170/500
# 5/5 [==============================] - 1s 223ms/step - loss: 0.7686 - mae: 0.6152 - val_loss: 1.6176 - val_mae: 0.8869 - lr: 0.0010
# Epoch 171/500
# 5/5 [==============================] - 1s 219ms/step - loss: 0.7678 - mae: 0.6149 - val_loss: 1.6171 - val_mae: 0.8860 - lr: 0.0010
# Epoch 172/500
# 5/5 [==============================] - 1s 225ms/step - loss: 0.7671 - mae: 0.6147 - val_loss: 1.6167 - val_mae: 0.8854 - lr: 0.0010
# Epoch 173/500
# 5/5 [==============================] - 1s 139ms/step - loss: 0.7658 - mae: 0.6141 - val_loss: 1.6171 - val_mae: 0.8849 - lr: 0.0010
# Epoch 174/500
# 5/5 [==============================] - 1s 219ms/step - loss: 0.7653 - mae: 0.6138 - val_loss: 1.6159 - val_mae: 0.8845 - lr: 0.0010
# Epoch 175/500
# 5/5 [==============================] - 1s 138ms/step - loss: 0.7635 - mae: 0.6128 - val_loss: 1.6177 - val_mae: 0.8842 - lr: 0.0010
# Epoch 176/500
# 5/5 [==============================] - 1s 139ms/step - loss: 0.7633 - mae: 0.6127 - val_loss: 1.6164 - val_mae: 0.8837 - lr: 0.0010
# Epoch 177/500
# 5/5 [==============================] - 1s 140ms/step - loss: 0.7622 - mae: 0.6123 - val_loss: 1.6171 - val_mae: 0.8833 - lr: 0.0010
# Epoch 178/500
# 5/5 [==============================] - 1s 139ms/step - loss: 0.7614 - mae: 0.6121 - val_loss: 1.6182 - val_mae: 0.8825 - lr: 0.0010
# Epoch 179/500
# 5/5 [==============================] - 1s 139ms/step - loss: 0.7602 - mae: 0.6113 - val_loss: 1.6173 - val_mae: 0.8819 - lr: 0.0010
# Epoch 180/500
# 5/5 [==============================] - 1s 140ms/step - loss: 0.7598 - mae: 0.6112 - val_loss: 1.6167 - val_mae: 0.8821 - lr: 0.0010
# Epoch 181/500
# 5/5 [==============================] - 1s 139ms/step - loss: 0.7592 - mae: 0.6110 - val_loss: 1.6183 - val_mae: 0.8808 - lr: 0.0010
# Epoch 182/500
# 5/5 [==============================] - 1s 138ms/step - loss: 0.7581 - mae: 0.6101 - val_loss: 1.6173 - val_mae: 0.8805 - lr: 0.0010
# Epoch 183/500
# 5/5 [==============================] - 1s 139ms/step - loss: 0.7578 - mae: 0.6101 - val_loss: 1.6167 - val_mae: 0.8806 - lr: 0.0010
# Epoch 184/500
# 5/5 [==============================] - 1s 139ms/step - loss: 0.7564 - mae: 0.6094 - val_loss: 1.6176 - val_mae: 0.8795 - lr: 0.0010
# Epoch 185/500
# 5/5 [==============================] - 1s 139ms/step - loss: 0.7557 - mae: 0.6089 - val_loss: 1.6168 - val_mae: 0.8797 - lr: 0.0010
# Epoch 186/500
# 5/5 [==============================] - 1s 221ms/step - loss: 0.7552 - mae: 0.6089 - val_loss: 1.6155 - val_mae: 0.8795 - lr: 0.0010
# Epoch 187/500
# 5/5 [==============================] - 1s 139ms/step - loss: 0.7538 - mae: 0.6082 - val_loss: 1.6173 - val_mae: 0.8783 - lr: 0.0010
# Epoch 188/500
# 5/5 [==============================] - 1s 139ms/step - loss: 0.7535 - mae: 0.6080 - val_loss: 1.6170 - val_mae: 0.8783 - lr: 0.0010
# Epoch 189/500
# 5/5 [==============================] - 1s 139ms/step - loss: 0.7533 - mae: 0.6079 - val_loss: 1.6165 - val_mae: 0.8782 - lr: 0.0010
# Epoch 190/500
# 5/5 [==============================] - 1s 139ms/step - loss: 0.7523 - mae: 0.6075 - val_loss: 1.6173 - val_mae: 0.8772 - lr: 0.0010
# Epoch 191/500
# 5/5 [==============================] - 1s 139ms/step - loss: 0.7515 - mae: 0.6071 - val_loss: 1.6178 - val_mae: 0.8770 - lr: 0.0010
# Epoch 192/500
# 5/5 [==============================] - 1s 140ms/step - loss: 0.7510 - mae: 0.6066 - val_loss: 1.6172 - val_mae: 0.8766 - lr: 0.0010
# Epoch 193/500
# 5/5 [==============================] - 1s 139ms/step - loss: 0.7503 - mae: 0.6061 - val_loss: 1.6163 - val_mae: 0.8763 - lr: 0.0010
# Epoch 194/500
# 5/5 [==============================] - 1s 140ms/step - loss: 0.7503 - mae: 0.6062 - val_loss: 1.6181 - val_mae: 0.8756 - lr: 0.0010
# Epoch 195/500
# 5/5 [==============================] - 1s 140ms/step - loss: 0.7496 - mae: 0.6060 - val_loss: 1.6187 - val_mae: 0.8756 - lr: 0.0010
# Epoch 196/500
# 5/5 [==============================] - 1s 140ms/step - loss: 0.7480 - mae: 0.6050 - val_loss: 1.6186 - val_mae: 0.8751 - lr: 0.0010
# Epoch 197/500
# 5/5 [==============================] - 1s 139ms/step - loss: 0.7482 - mae: 0.6050 - val_loss: 1.6177 - val_mae: 0.8748 - lr: 0.0010
# Epoch 198/500
# 5/5 [==============================] - 1s 139ms/step - loss: 0.7476 - mae: 0.6047 - val_loss: 1.6186 - val_mae: 0.8741 - lr: 0.0010
# Epoch 199/500
# 5/5 [==============================] - 1s 138ms/step - loss: 0.7469 - mae: 0.6044 - val_loss: 1.6189 - val_mae: 0.8737 - lr: 0.0010
# Epoch 200/500
# 5/5 [==============================] - 1s 138ms/step - loss: 0.7464 - mae: 0.6041 - val_loss: 1.6178 - val_mae: 0.8737 - lr: 0.0010
# Epoch 201/500
# 5/5 [==============================] - 1s 139ms/step - loss: 0.7463 - mae: 0.6040 - val_loss: 1.6188 - val_mae: 0.8731 - lr: 0.0010
# Epoch 202/500
# 5/5 [==============================] - 1s 139ms/step - loss: 0.7452 - mae: 0.6035 - val_loss: 1.6192 - val_mae: 0.8724 - lr: 0.0010
# Epoch 203/500
# 5/5 [==============================] - 1s 139ms/step - loss: 0.7444 - mae: 0.6033 - val_loss: 1.6185 - val_mae: 0.8724 - lr: 0.0010
# Epoch 204/500
# 5/5 [==============================] - 1s 140ms/step - loss: 0.7439 - mae: 0.6028 - val_loss: 1.6181 - val_mae: 0.8722 - lr: 0.0010
# Epoch 205/500
# 5/5 [==============================] - 1s 140ms/step - loss: 0.7431 - mae: 0.6025 - val_loss: 1.6187 - val_mae: 0.8716 - lr: 0.0010
# Epoch 206/500
# 5/5 [==============================] - 1s 140ms/step - loss: 0.7428 - mae: 0.6021 - val_loss: 1.6188 - val_mae: 0.8717 - lr: 0.0010
# Epoch 207/500
# 5/5 [==============================] - 1s 139ms/step - loss: 0.7428 - mae: 0.6022 - val_loss: 1.6192 - val_mae: 0.8707 - lr: 0.0010
# Epoch 208/500
# 5/5 [==============================] - 1s 140ms/step - loss: 0.7423 - mae: 0.6020 - val_loss: 1.6201 - val_mae: 0.8707 - lr: 0.0010
# Epoch 209/500
# 5/5 [==============================] - 1s 139ms/step - loss: 0.7417 - mae: 0.6015 - val_loss: 1.6212 - val_mae: 0.8706 - lr: 0.0010
# Epoch 210/500
# 5/5 [==============================] - 1s 138ms/step - loss: 0.7414 - mae: 0.6014 - val_loss: 1.6214 - val_mae: 0.8703 - lr: 0.0010
# Epoch 211/500
# 5/5 [==============================] - 1s 140ms/step - loss: 0.7416 - mae: 0.6014 - val_loss: 1.6208 - val_mae: 0.8704 - lr: 0.0010
# Epoch 212/500
# 5/5 [==============================] - 1s 139ms/step - loss: 0.7411 - mae: 0.6010 - val_loss: 1.6217 - val_mae: 0.8697 - lr: 0.0010
# Epoch 213/500
# 5/5 [==============================] - 1s 139ms/step - loss: 0.7401 - mae: 0.6006 - val_loss: 1.6223 - val_mae: 0.8696 - lr: 0.0010
# Epoch 214/500
# 5/5 [==============================] - 1s 140ms/step - loss: 0.7404 - mae: 0.6007 - val_loss: 1.6212 - val_mae: 0.8695 - lr: 0.0010
# Epoch 215/500
# 5/5 [==============================] - 1s 140ms/step - loss: 0.7399 - mae: 0.6002 - val_loss: 1.6211 - val_mae: 0.8693 - lr: 0.0010
# Epoch 216/500
# 5/5 [==============================] - 1s 140ms/step - loss: 0.7385 - mae: 0.5998 - val_loss: 1.6208 - val_mae: 0.8686 - lr: 0.0010
# Epoch 217/500
# 5/5 [==============================] - 1s 140ms/step - loss: 0.7388 - mae: 0.5998 - val_loss: 1.6225 - val_mae: 0.8681 - lr: 0.0010
# Epoch 218/500
# 5/5 [==============================] - 1s 139ms/step - loss: 0.7381 - mae: 0.5994 - val_loss: 1.6205 - val_mae: 0.8680 - lr: 0.0010
# Epoch 219/500
# 5/5 [==============================] - 1s 139ms/step - loss: 0.7374 - mae: 0.5990 - val_loss: 1.6213 - val_mae: 0.8676 - lr: 0.0010
# Epoch 220/500
# 5/5 [==============================] - 1s 139ms/step - loss: 0.7376 - mae: 0.5988 - val_loss: 1.6229 - val_mae: 0.8674 - lr: 0.0010
# Epoch 221/500
# 5/5 [==============================] - 1s 139ms/step - loss: 0.7376 - mae: 0.5989 - val_loss: 1.6220 - val_mae: 0.8677 - lr: 0.0010
# Epoch 222/500
# 5/5 [==============================] - 1s 139ms/step - loss: 0.7367 - mae: 0.5985 - val_loss: 1.6219 - val_mae: 0.8671 - lr: 0.0010
# Epoch 223/500
# 5/5 [==============================] - 1s 139ms/step - loss: 0.7364 - mae: 0.5982 - val_loss: 1.6242 - val_mae: 0.8672 - lr: 0.0010
# Epoch 224/500
# 5/5 [==============================] - 1s 140ms/step - loss: 0.7362 - mae: 0.5983 - val_loss: 1.6235 - val_mae: 0.8665 - lr: 0.0010
# Epoch 225/500
# 5/5 [==============================] - 1s 140ms/step - loss: 0.7363 - mae: 0.5982 - val_loss: 1.6223 - val_mae: 0.8665 - lr: 0.0010
# Epoch 226/500
# 5/5 [==============================] - 1s 139ms/step - loss: 0.7359 - mae: 0.5980 - val_loss: 1.6238 - val_mae: 0.8666 - lr: 0.0010
# Epoch 227/500
# 5/5 [==============================] - 1s 140ms/step - loss: 0.7354 - mae: 0.5975 - val_loss: 1.6229 - val_mae: 0.8664 - lr: 0.0010
# Epoch 228/500
# 5/5 [==============================] - 1s 139ms/step - loss: 0.7353 - mae: 0.5976 - val_loss: 1.6247 - val_mae: 0.8661 - lr: 0.0010
# Epoch 229/500
# 5/5 [==============================] - 1s 138ms/step - loss: 0.7350 - mae: 0.5975 - val_loss: 1.6244 - val_mae: 0.8658 - lr: 0.0010
# Epoch 230/500
# 5/5 [==============================] - 1s 139ms/step - loss: 0.7347 - mae: 0.5971 - val_loss: 1.6236 - val_mae: 0.8661 - lr: 0.0010
# Epoch 231/500
# 5/5 [==============================] - 1s 139ms/step - loss: 0.7342 - mae: 0.5968 - val_loss: 1.6242 - val_mae: 0.8658 - lr: 0.0010
# Epoch 232/500
# 5/5 [==============================] - 1s 140ms/step - loss: 0.7342 - mae: 0.5967 - val_loss: 1.6235 - val_mae: 0.8663 - lr: 0.0010
# Epoch 233/500
# 5/5 [==============================] - 1s 140ms/step - loss: 0.7341 - mae: 0.5969 - val_loss: 1.6264 - val_mae: 0.8659 - lr: 0.0010
# Epoch 234/500
# 5/5 [==============================] - 1s 139ms/step - loss: 0.7337 - mae: 0.5968 - val_loss: 1.6281 - val_mae: 0.8653 - lr: 0.0010
# Epoch 235/500
# 5/5 [==============================] - 1s 141ms/step - loss: 0.7339 - mae: 0.5966 - val_loss: 1.6257 - val_mae: 0.8660 - lr: 0.0010
# Epoch 236/500
# 5/5 [==============================] - 1s 235ms/step - loss: 0.7330 - mae: 0.5962 - val_loss: 1.6260 - val_mae: 0.8660 - lr: 0.0010
# CPU times: user 3min 55s, sys: 36.3 s, total: 4min 32s
# Wall time: 3min 35s

# %%
# Predicciones
predictions = model.predict([user_data_val, item_data_val])
# Out:
# 45006/45006 [==============================] - 69s 2ms/step

# %%
# MSE y RMSE
mse = mean_squared_error(y_true, predictions)
rmse = np.sqrt(mse)

# MAE
mae = mean_absolute_error(y_true, predictions)

# MAPE
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    non_zero_idx = y_true != 0  # Para evitar divisiones por cero
    return np.mean(np.abs((y_true[non_zero_idx] - y_pred[non_zero_idx]) / y_true[non_zero_idx])) * 100

def compute_mape_by_batch(y_true, predictions, batch_size=50000):
    mape_sum = 0
    num_batches = int(np.ceil(len(y_true) / batch_size))

    for i in range(num_batches):
        start_idx = i * batch_size
        end_idx = start_idx + batch_size

        batch_y_true = y_true[start_idx:end_idx]
        batch_predictions = predictions[start_idx:end_idx]

        mape_sum += mean_absolute_percentage_error(batch_y_true, batch_predictions)

    return mape_sum / num_batches

# Luego llamas a la función
mape = compute_mape_by_batch(y_true, predictions)

print(f'MSE: {mse}')
print(f'RMSE: {rmse}')
print(f'MAE: {mae}')
print(f'MAPE: {mape}%')
# Out:
# MSE: 1.5301933993368448
# RMSE: 1.2370098622633714
# MAE: 0.8794854575873077
# MAPE: 41.15648169178964%

# %% [markdown]
# Estas métricas te ayudarán a tener una mejor idea del desempeño de tu modelo. Por ejemplo:
#
# MSE y RMSE son útiles cuando quieres penalizar grandes errores.
#
# MAE te da una idea del error medio sin considerar la dirección del error.
#
# MAPE es útil cuando quieres representar el error en términos porcentuales.
#
# Para una evaluación completa, es recomendable utilizar un conjunto de validación aparte (es decir, no solo depender del validation_split). Esto asegura que estás evaluando el desempeño en datos que el modelo nunca ha visto durante el entrenamiento.

# %% [markdown]
# En resumen, la elección del tipo de sistema de recomendación dependerá de la naturaleza del conjunto de datos, las características disponibles, las capacidades computacionales y el tipo de relaciones o interacciones que se desean capturar. A menudo, un enfoque híbrido (como el sistema que combina embeddings y redes neuronales) ofrece un buen equilibrio entre precisión y eficiencia.
