# %% [markdown]
# # Paso 1: Importar Librerías de Python

# %%
#pip install scikit-surprise
# Out:
# Requirement already satisfied: scikit-surprise in /usr/local/lib/python3.10/dist-packages (1.1.3)
# Requirement already satisfied: joblib>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.3.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.11.3)

# %%
# Análisis de datos y manipulación
import pandas as pd
import numpy as np
import random


# Visualización de datos
import matplotlib.pyplot as plt
import seaborn as sns

# Utilidades de fechas
from datetime import datetime

# Integración con Google Colab
from google.colab import drive

# Machine Learning: Preprocesamiento y división de datos
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# Machine Learning: Métricas
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.metrics.pairwise import cosine_similarity

# Machine Learning: Modelado y validación
from surprise import SVD, Reader, Dataset, accuracy
from surprise.model_selection import train_test_split, GridSearchCV

# Deep Learning: Construcción de modelos y capas
from keras.models import Model
from keras.layers import Input, Embedding, Flatten, Concatenate, Dense, Dropout, Dot,Lambda

# Deep Learning: Optimización y regularización
from keras.optimizers import Adam
from keras.regularizers import l2

# Deep Learning: Callbacks
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Paso 2: Lectura del Dataset

# %%
df = pd.read_csv('/content/drive/MyDrive/EspecializacionA&DS/Monografia/2doSemestre/DataFinal_Amazon.csv')
# Out:
# <ipython-input-4-9e77e6115feb>:1: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/drive/MyDrive/EspecializacionA&DS/Monografia/2doSemestre/DataFinal_Amazon.csv')

# %%
df.shape
# Out:
# (4800571, 10)

# %%
sentimiento = pd.read_csv('/content/drive/MyDrive/EspecializacionA&DS/Monografia/2doSemestre/sentimientos_productos.csv')

# %%
sentimiento.shape
# Out:
# (154026, 4)

# %%
sentimiento.head()
# Out:
#          asin  reviewText_sentiment   cluster  cluster_hdbscan
# 0  0871167042              0.632713  Positivo                0
# 1  1519588135              0.568186    Neutro                2
# 2  1579652956              0.713937  Positivo                0
# 3  1936023857              0.765550  Positivo               -1
# 4  5120053017              0.485311    Neutro               -1

# %% [markdown]
# # Modelo de Filtrado Colaborativo usando Embedding con Keras:

# %% [markdown]
# Funcionamiento:
#
# Los embeddings son representaciones vectoriales densas y de baja dimensión de ítems y/o usuarios. Estas representaciones capturan relaciones semánticas entre ítems o entre usuarios.
#
# Un método popular para generar embeddings es la factorización de matrices, como la descomposición en valores singulares (SVD). En el contexto de sistemas de recomendación, se busca factorizar la matriz de interacciones usuario-ítem en dos matrices más pequeñas (una para los usuarios y otra para los ítems) cuyo producto aproximado reproduce la matriz original lo mejor posible.
#
# Una vez que se han obtenido los embeddings, la predicción de una calificación o interacción entre un usuario e ítem se realiza tomando el producto escalar entre sus embeddings respectivos.
#
# Ventajas:
#
# Simplicidad y eficiencia en términos computacionales.
#
# Puede manejar grandes conjuntos de datos debido a su naturaleza de baja dimensión.
#
# Es efectivo para capturar patrones subyacentes en los datos.
#
# Desventajas:
#
# No tiene en cuenta características adicionales de usuarios o ítems.
#
# Dificultades para manejar nuevos ítems o usuarios (problema de arranque en frío).

# %% [markdown]
# El código ahora incluye regularización en los embeddings, un callback para detener el entrenamiento si no hay mejoras (early stopping) y otro para reducir la tasa de aprendizaje si el error de validación no mejora (reduce learning rate on plateau).

# %%
data = df

# %%
# Crear un LabelEncoder para cada columna
reviewerID_encoder = LabelEncoder()
asin_encoder = LabelEncoder()

# Ajustar y transformar las columnas
data['reviewerID_encoded'] = reviewerID_encoder.fit_transform(data['reviewerID'])
data['asin_encoded'] = asin_encoder.fit_transform(data['asin'])

# Número de usuarios únicos y número de ítems únicos
n_users = len(np.unique(data['reviewerID_encoded']))
n_items = len(np.unique(data['asin_encoded']))

# Dimensiones del embedding
embedding_dim = 10

# Entradas
user_input = Input(shape=(1,))
item_input = Input(shape=(1,))

# Embeddings con regularización
user_embedding = Embedding(n_users, embedding_dim, embeddings_regularizer=l2(1e-6))(user_input)
item_embedding = Embedding(n_items, embedding_dim, embeddings_regularizer=l2(1e-6))(item_input)

# Producto punto para predecir la valoración/rating
merged = Dot(axes=2)([user_embedding, item_embedding])
merged = Flatten()(merged)

# Agregar una capa de activación sigmoid y escalar a [0, 5]
output = Dense(1, activation='sigmoid')(merged)  # Función de activación sigmoid
output = Lambda(lambda x: x * 5)(output)  # Escalar las predicciones al rango [0, 5]

# Modelo
model = Model(inputs=[user_input, item_input], outputs=output)
model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# %% [markdown]
# verbose=0: No muestra ninguna barra de progreso ni métricas.
#
# verbose=1: Muestra una barra de progreso y actualiza las métricas después de cada lote.
#
# verbose=2: Muestra las métricas después de cada época, pero no muestra la barra de progreso.

# %%
from sklearn.model_selection import train_test_split

# Crear los arrays con los datos
user_ids = data['reviewerID_encoded'].values
item_ids = data['asin_encoded'].values
ratings = data['overall'].values

# División en entrenamiento y prueba
(user_ids_temp, user_ids_test, item_ids_temp, item_ids_test, ratings_temp, ratings_test) = train_test_split(
    user_ids, item_ids, ratings, test_size=0.2, random_state=42)

# División del conjunto de entrenamiento en entrenamiento y validación
(user_ids_train, user_ids_val, item_ids_train, item_ids_val, ratings_train, ratings_val) = train_test_split(
    user_ids_temp, item_ids_temp, ratings_temp, test_size=0.25, random_state=42)  # 0.25 x 0.8 = 0.2

# %%
# Callbacks
early_stop = EarlyStopping(monitor='val_loss', patience=50)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=50, min_lr=1e-5)

# %%
# %%time
# Entrenar el modelo con el conjunto de entrenamiento
model.fit([user_ids_train, item_ids_train], ratings_train, validation_data=([user_ids_val, item_ids_val], ratings_val), epochs=500,
          batch_size=800000, verbose=1, callbacks=[early_stop, reduce_lr])
# Out:
# Epoch 1/500
# 4/4 [==============================] - 3s 114ms/step - loss: 4.4654 - mae: 1.9779 - val_loss: 4.4606 - val_mae: 1.9773 - lr: 0.0010
# Epoch 2/500
# 4/4 [==============================] - 0s 52ms/step - loss: 4.4477 - mae: 1.9739 - val_loss: 4.4429 - val_mae: 1.9734 - lr: 0.0010
# Epoch 3/500
# 4/4 [==============================] - 0s 50ms/step - loss: 4.4300 - mae: 1.9700 - val_loss: 4.4252 - val_mae: 1.9695 - lr: 0.0010
# Epoch 4/500
# 4/4 [==============================] - 0s 44ms/step - loss: 4.4124 - mae: 1.9661 - val_loss: 4.4075 - val_mae: 1.9656 - lr: 0.0010
# Epoch 5/500
# 4/4 [==============================] - 0s 46ms/step - loss: 4.3947 - mae: 1.9621 - val_loss: 4.3899 - val_mae: 1.9616 - lr: 0.0010
# Epoch 6/500
# 4/4 [==============================] - 0s 46ms/step - loss: 4.3771 - mae: 1.9582 - val_loss: 4.3723 - val_mae: 1.9577 - lr: 0.0010
# Epoch 7/500
# 4/4 [==============================] - 0s 45ms/step - loss: 4.3595 - mae: 1.9543 - val_loss: 4.3548 - val_mae: 1.9538 - lr: 0.0010
# Epoch 8/500
# 4/4 [==============================] - 0s 47ms/step - loss: 4.3420 - mae: 1.9504 - val_loss: 4.3373 - val_mae: 1.9499 - lr: 0.0010
# Epoch 9/500
# 4/4 [==============================] - 0s 44ms/step - loss: 4.3245 - mae: 1.9464 - val_loss: 4.3199 - val_mae: 1.9460 - lr: 0.0010
# Epoch 10/500
# 4/4 [==============================] - 0s 45ms/step - loss: 4.3071 - mae: 1.9425 - val_loss: 4.3026 - val_mae: 1.9421 - lr: 0.0010
# Epoch 11/500
# 4/4 [==============================] - 0s 45ms/step - loss: 4.2898 - mae: 1.9386 - val_loss: 4.2853 - val_mae: 1.9382 - lr: 0.0010
# Epoch 12/500
# 4/4 [==============================] - 0s 46ms/step - loss: 4.2725 - mae: 1.9347 - val_loss: 4.2682 - val_mae: 1.9343 - lr: 0.0010
# Epoch 13/500
# 4/4 [==============================] - 0s 45ms/step - loss: 4.2553 - mae: 1.9308 - val_loss: 4.2510 - val_mae: 1.9304 - lr: 0.0010
# Epoch 14/500
# 4/4 [==============================] - 0s 44ms/step - loss: 4.2381 - mae: 1.9269 - val_loss: 4.2340 - val_mae: 1.9265 - lr: 0.0010
# Epoch 15/500
# 4/4 [==============================] - 0s 45ms/step - loss: 4.2211 - mae: 1.9230 - val_loss: 4.2170 - val_mae: 1.9227 - lr: 0.0010
# Epoch 16/500
# 4/4 [==============================] - 0s 45ms/step - loss: 4.2040 - mae: 1.9191 - val_loss: 4.2001 - val_mae: 1.9188 - lr: 0.0010
# Epoch 17/500
# 4/4 [==============================] - 0s 47ms/step - loss: 4.1871 - mae: 1.9152 - val_loss: 4.1833 - val_mae: 1.9149 - lr: 0.0010
# Epoch 18/500
# 4/4 [==============================] - 0s 47ms/step - loss: 4.1702 - mae: 1.9113 - val_loss: 4.1665 - val_mae: 1.9111 - lr: 0.0010
# Epoch 19/500
# 4/4 [==============================] - 0s 47ms/step - loss: 4.1534 - mae: 1.9075 - val_loss: 4.1498 - val_mae: 1.9072 - lr: 0.0010
# Epoch 20/500
# 4/4 [==============================] - 0s 44ms/step - loss: 4.1366 - mae: 1.9036 - val_loss: 4.1332 - val_mae: 1.9033 - lr: 0.0010
# Epoch 21/500
# 4/4 [==============================] - 0s 51ms/step - loss: 4.1199 - mae: 1.8997 - val_loss: 4.1166 - val_mae: 1.8995 - lr: 0.0010
# Epoch 22/500
# 4/4 [==============================] - 0s 47ms/step - loss: 4.1032 - mae: 1.8958 - val_loss: 4.1002 - val_mae: 1.8956 - lr: 0.0010
# Epoch 23/500
# 4/4 [==============================] - 0s 46ms/step - loss: 4.0866 - mae: 1.8919 - val_loss: 4.0837 - val_mae: 1.8918 - lr: 0.0010
# Epoch 24/500
# 4/4 [==============================] - 0s 48ms/step - loss: 4.0701 - mae: 1.8880 - val_loss: 4.0674 - val_mae: 1.8879 - lr: 0.0010
# Epoch 25/500
# 4/4 [==============================] - 0s 48ms/step - loss: 4.0536 - mae: 1.8841 - val_loss: 4.0511 - val_mae: 1.8841 - lr: 0.0010
# Epoch 26/500
# 4/4 [==============================] - 0s 48ms/step - loss: 4.0371 - mae: 1.8802 - val_loss: 4.0349 - val_mae: 1.8802 - lr: 0.0010
# Epoch 27/500
# 4/4 [==============================] - 0s 50ms/step - loss: 4.0206 - mae: 1.8763 - val_loss: 4.0187 - val_mae: 1.8764 - lr: 0.0010
# Epoch 28/500
# 4/4 [==============================] - 0s 50ms/step - loss: 4.0042 - mae: 1.8724 - val_loss: 4.0025 - val_mae: 1.8725 - lr: 0.0010
# Epoch 29/500
# 4/4 [==============================] - 0s 44ms/step - loss: 3.9877 - mae: 1.8684 - val_loss: 3.9865 - val_mae: 1.8687 - lr: 0.0010
# Epoch 30/500
# 4/4 [==============================] - 0s 46ms/step - loss: 3.9713 - mae: 1.8645 - val_loss: 3.9704 - val_mae: 1.8648 - lr: 0.0010
# Epoch 31/500
# 4/4 [==============================] - 0s 45ms/step - loss: 3.9549 - mae: 1.8605 - val_loss: 3.9544 - val_mae: 1.8609 - lr: 0.0010
# Epoch 32/500
# 4/4 [==============================] - 0s 46ms/step - loss: 3.9385 - mae: 1.8565 - val_loss: 3.9385 - val_mae: 1.8571 - lr: 0.0010
# Epoch 33/500
# 4/4 [==============================] - 0s 45ms/step - loss: 3.9220 - mae: 1.8525 - val_loss: 3.9226 - val_mae: 1.8532 - lr: 0.0010
# Epoch 34/500
# 4/4 [==============================] - 0s 46ms/step - loss: 3.9055 - mae: 1.8485 - val_loss: 3.9067 - val_mae: 1.8493 - lr: 0.0010
# Epoch 35/500
# 4/4 [==============================] - 0s 47ms/step - loss: 3.8889 - mae: 1.8444 - val_loss: 3.8908 - val_mae: 1.8454 - lr: 0.0010
# Epoch 36/500
# 4/4 [==============================] - 0s 47ms/step - loss: 3.8723 - mae: 1.8403 - val_loss: 3.8749 - val_mae: 1.8415 - lr: 0.0010
# Epoch 37/500
# 4/4 [==============================] - 0s 48ms/step - loss: 3.8556 - mae: 1.8362 - val_loss: 3.8591 - val_mae: 1.8375 - lr: 0.0010
# Epoch 38/500
# 4/4 [==============================] - 0s 46ms/step - loss: 3.8388 - mae: 1.8320 - val_loss: 3.8433 - val_mae: 1.8336 - lr: 0.0010
# Epoch 39/500
# 4/4 [==============================] - 0s 45ms/step - loss: 3.8219 - mae: 1.8278 - val_loss: 3.8275 - val_mae: 1.8296 - lr: 0.0010
# Epoch 40/500
# 4/4 [==============================] - 0s 48ms/step - loss: 3.8049 - mae: 1.8235 - val_loss: 3.8117 - val_mae: 1.8256 - lr: 0.0010
# Epoch 41/500
# 4/4 [==============================] - 0s 47ms/step - loss: 3.7877 - mae: 1.8191 - val_loss: 3.7959 - val_mae: 1.8216 - lr: 0.0010
# Epoch 42/500
# 4/4 [==============================] - 0s 45ms/step - loss: 3.7704 - mae: 1.8147 - val_loss: 3.7801 - val_mae: 1.8175 - lr: 0.0010
# Epoch 43/500
# 4/4 [==============================] - 0s 45ms/step - loss: 3.7529 - mae: 1.8103 - val_loss: 3.7643 - val_mae: 1.8135 - lr: 0.0010
# Epoch 44/500
# 4/4 [==============================] - 0s 47ms/step - loss: 3.7353 - mae: 1.8057 - val_loss: 3.7484 - val_mae: 1.8094 - lr: 0.0010
# Epoch 45/500
# 4/4 [==============================] - 0s 45ms/step - loss: 3.7174 - mae: 1.8011 - val_loss: 3.7326 - val_mae: 1.8052 - lr: 0.0010
# Epoch 46/500
# 4/4 [==============================] - 0s 48ms/step - loss: 3.6993 - mae: 1.7964 - val_loss: 3.7168 - val_mae: 1.8011 - lr: 0.0010
# Epoch 47/500
# 4/4 [==============================] - 0s 45ms/step - loss: 3.6809 - mae: 1.7915 - val_loss: 3.7010 - val_mae: 1.7969 - lr: 0.0010
# Epoch 48/500
# 4/4 [==============================] - 0s 44ms/step - loss: 3.6623 - mae: 1.7866 - val_loss: 3.6851 - val_mae: 1.7927 - lr: 0.0010
# Epoch 49/500
# 4/4 [==============================] - 0s 44ms/step - loss: 3.6434 - mae: 1.7816 - val_loss: 3.6693 - val_mae: 1.7884 - lr: 0.0010
# Epoch 50/500
# 4/4 [==============================] - 0s 44ms/step - loss: 3.6243 - mae: 1.7765 - val_loss: 3.6534 - val_mae: 1.7841 - lr: 0.0010
# Epoch 51/500
# 4/4 [==============================] - 0s 43ms/step - loss: 3.6048 - mae: 1.7712 - val_loss: 3.6375 - val_mae: 1.7798 - lr: 0.0010
# Epoch 52/500
# 4/4 [==============================] - 0s 44ms/step - loss: 3.5850 - mae: 1.7659 - val_loss: 3.6217 - val_mae: 1.7754 - lr: 0.0010
# Epoch 53/500
# 4/4 [==============================] - 0s 45ms/step - loss: 3.5648 - mae: 1.7604 - val_loss: 3.6058 - val_mae: 1.7710 - lr: 0.0010
# Epoch 54/500
# 4/4 [==============================] - 0s 46ms/step - loss: 3.5443 - mae: 1.7547 - val_loss: 3.5900 - val_mae: 1.7666 - lr: 0.0010
# Epoch 55/500
# 4/4 [==============================] - 0s 42ms/step - loss: 3.5235 - mae: 1.7489 - val_loss: 3.5742 - val_mae: 1.7621 - lr: 0.0010
# Epoch 56/500
# 4/4 [==============================] - 0s 44ms/step - loss: 3.5022 - mae: 1.7430 - val_loss: 3.5584 - val_mae: 1.7576 - lr: 0.0010
# Epoch 57/500
# 4/4 [==============================] - 0s 44ms/step - loss: 3.4805 - mae: 1.7368 - val_loss: 3.5426 - val_mae: 1.7530 - lr: 0.0010
# Epoch 58/500
# 4/4 [==============================] - 0s 43ms/step - loss: 3.4585 - mae: 1.7306 - val_loss: 3.5269 - val_mae: 1.7484 - lr: 0.0010
# Epoch 59/500
# 4/4 [==============================] - 0s 43ms/step - loss: 3.4360 - mae: 1.7241 - val_loss: 3.5112 - val_mae: 1.7437 - lr: 0.0010
# Epoch 60/500
# 4/4 [==============================] - 0s 44ms/step - loss: 3.4131 - mae: 1.7175 - val_loss: 3.4956 - val_mae: 1.7390 - lr: 0.0010
# Epoch 61/500
# 4/4 [==============================] - 0s 47ms/step - loss: 3.3898 - mae: 1.7107 - val_loss: 3.4800 - val_mae: 1.7343 - lr: 0.0010
# Epoch 62/500
# 4/4 [==============================] - 0s 48ms/step - loss: 3.3661 - mae: 1.7037 - val_loss: 3.4646 - val_mae: 1.7295 - lr: 0.0010
# Epoch 63/500
# 4/4 [==============================] - 0s 47ms/step - loss: 3.3419 - mae: 1.6965 - val_loss: 3.4492 - val_mae: 1.7247 - lr: 0.0010
# Epoch 64/500
# 4/4 [==============================] - 0s 43ms/step - loss: 3.3173 - mae: 1.6891 - val_loss: 3.4339 - val_mae: 1.7199 - lr: 0.0010
# Epoch 65/500
# 4/4 [==============================] - 0s 49ms/step - loss: 3.2923 - mae: 1.6815 - val_loss: 3.4188 - val_mae: 1.7151 - lr: 0.0010
# Epoch 66/500
# 4/4 [==============================] - 0s 43ms/step - loss: 3.2668 - mae: 1.6737 - val_loss: 3.4037 - val_mae: 1.7102 - lr: 0.0010
# Epoch 67/500
# 4/4 [==============================] - 0s 47ms/step - loss: 3.2409 - mae: 1.6658 - val_loss: 3.3889 - val_mae: 1.7053 - lr: 0.0010
# Epoch 68/500
# 4/4 [==============================] - 0s 43ms/step - loss: 3.2146 - mae: 1.6576 - val_loss: 3.3741 - val_mae: 1.7003 - lr: 0.0010
# Epoch 69/500
# 4/4 [==============================] - 0s 44ms/step - loss: 3.1879 - mae: 1.6492 - val_loss: 3.3596 - val_mae: 1.6954 - lr: 0.0010
# Epoch 70/500
# 4/4 [==============================] - 0s 46ms/step - loss: 3.1607 - mae: 1.6405 - val_loss: 3.3452 - val_mae: 1.6904 - lr: 0.0010
# Epoch 71/500
# 4/4 [==============================] - 0s 44ms/step - loss: 3.1332 - mae: 1.6317 - val_loss: 3.3310 - val_mae: 1.6854 - lr: 0.0010
# Epoch 72/500
# 4/4 [==============================] - 0s 46ms/step - loss: 3.1053 - mae: 1.6227 - val_loss: 3.3171 - val_mae: 1.6804 - lr: 0.0010
# Epoch 73/500
# 4/4 [==============================] - 0s 48ms/step - loss: 3.0771 - mae: 1.6135 - val_loss: 3.3033 - val_mae: 1.6754 - lr: 0.0010
# Epoch 74/500
# 4/4 [==============================] - 0s 45ms/step - loss: 3.0485 - mae: 1.6040 - val_loss: 3.2898 - val_mae: 1.6704 - lr: 0.0010
# Epoch 75/500
# 4/4 [==============================] - 0s 44ms/step - loss: 3.0195 - mae: 1.5944 - val_loss: 3.2765 - val_mae: 1.6654 - lr: 0.0010
# Epoch 76/500
# 4/4 [==============================] - 0s 43ms/step - loss: 2.9903 - mae: 1.5845 - val_loss: 3.2635 - val_mae: 1.6604 - lr: 0.0010
# Epoch 77/500
# 4/4 [==============================] - 0s 45ms/step - loss: 2.9607 - mae: 1.5745 - val_loss: 3.2507 - val_mae: 1.6554 - lr: 0.0010
# Epoch 78/500
# 4/4 [==============================] - 0s 46ms/step - loss: 2.9309 - mae: 1.5643 - val_loss: 3.2382 - val_mae: 1.6504 - lr: 0.0010
# Epoch 79/500
# 4/4 [==============================] - 0s 46ms/step - loss: 2.9008 - mae: 1.5539 - val_loss: 3.2260 - val_mae: 1.6454 - lr: 0.0010
# Epoch 80/500
# 4/4 [==============================] - 0s 49ms/step - loss: 2.8705 - mae: 1.5433 - val_loss: 3.2141 - val_mae: 1.6405 - lr: 0.0010
# Epoch 81/500
# 4/4 [==============================] - 0s 44ms/step - loss: 2.8400 - mae: 1.5325 - val_loss: 3.2025 - val_mae: 1.6356 - lr: 0.0010
# Epoch 82/500
# 4/4 [==============================] - 0s 44ms/step - loss: 2.8094 - mae: 1.5216 - val_loss: 3.1912 - val_mae: 1.6307 - lr: 0.0010
# Epoch 83/500
# 4/4 [==============================] - 0s 44ms/step - loss: 2.7785 - mae: 1.5105 - val_loss: 3.1802 - val_mae: 1.6258 - lr: 0.0010
# Epoch 84/500
# 4/4 [==============================] - 0s 45ms/step - loss: 2.7476 - mae: 1.4993 - val_loss: 3.1696 - val_mae: 1.6210 - lr: 0.0010
# Epoch 85/500
# 4/4 [==============================] - 0s 44ms/step - loss: 2.7165 - mae: 1.4879 - val_loss: 3.1592 - val_mae: 1.6162 - lr: 0.0010
# Epoch 86/500
# 4/4 [==============================] - 0s 45ms/step - loss: 2.6854 - mae: 1.4764 - val_loss: 3.1492 - val_mae: 1.6115 - lr: 0.0010
# Epoch 87/500
# 4/4 [==============================] - 0s 44ms/step - loss: 2.6542 - mae: 1.4647 - val_loss: 3.1395 - val_mae: 1.6068 - lr: 0.0010
# Epoch 88/500
# 4/4 [==============================] - 0s 56ms/step - loss: 2.6230 - mae: 1.4530 - val_loss: 3.1302 - val_mae: 1.6022 - lr: 0.0010
# Epoch 89/500
# 4/4 [==============================] - 0s 45ms/step - loss: 2.5918 - mae: 1.4411 - val_loss: 3.1212 - val_mae: 1.5976 - lr: 0.0010
# Epoch 90/500
# 4/4 [==============================] - 0s 45ms/step - loss: 2.5606 - mae: 1.4291 - val_loss: 3.1125 - val_mae: 1.5931 - lr: 0.0010
# Epoch 91/500
# 4/4 [==============================] - 0s 44ms/step - loss: 2.5296 - mae: 1.4170 - val_loss: 3.1042 - val_mae: 1.5887 - lr: 0.0010
# Epoch 92/500
# 4/4 [==============================] - 0s 43ms/step - loss: 2.4986 - mae: 1.4049 - val_loss: 3.0963 - val_mae: 1.5843 - lr: 0.0010
# Epoch 93/500
# 4/4 [==============================] - 0s 49ms/step - loss: 2.4677 - mae: 1.3926 - val_loss: 3.0886 - val_mae: 1.5799 - lr: 0.0010
# Epoch 94/500
# 4/4 [==============================] - 0s 45ms/step - loss: 2.4369 - mae: 1.3803 - val_loss: 3.0813 - val_mae: 1.5757 - lr: 0.0010
# Epoch 95/500
# 4/4 [==============================] - 0s 46ms/step - loss: 2.4064 - mae: 1.3679 - val_loss: 3.0744 - val_mae: 1.5715 - lr: 0.0010
# Epoch 96/500
# 4/4 [==============================] - 0s 47ms/step - loss: 2.3760 - mae: 1.3555 - val_loss: 3.0678 - val_mae: 1.5674 - lr: 0.0010
# Epoch 97/500
# 4/4 [==============================] - 0s 63ms/step - loss: 2.3458 - mae: 1.3431 - val_loss: 3.0615 - val_mae: 1.5633 - lr: 0.0010
# Epoch 98/500
# 4/4 [==============================] - 0s 43ms/step - loss: 2.3159 - mae: 1.3306 - val_loss: 3.0556 - val_mae: 1.5593 - lr: 0.0010
# Epoch 99/500
# 4/4 [==============================] - 0s 43ms/step - loss: 2.2862 - mae: 1.3181 - val_loss: 3.0499 - val_mae: 1.5554 - lr: 0.0010
# Epoch 100/500
# 4/4 [==============================] - 0s 46ms/step - loss: 2.2568 - mae: 1.3056 - val_loss: 3.0447 - val_mae: 1.5516 - lr: 0.0010
# Epoch 101/500
# 4/4 [==============================] - 0s 46ms/step - loss: 2.2277 - mae: 1.2931 - val_loss: 3.0397 - val_mae: 1.5478 - lr: 0.0010
# Epoch 102/500
# 4/4 [==============================] - 0s 42ms/step - loss: 2.1989 - mae: 1.2806 - val_loss: 3.0350 - val_mae: 1.5441 - lr: 0.0010
# Epoch 103/500
# 4/4 [==============================] - 0s 46ms/step - loss: 2.1704 - mae: 1.2681 - val_loss: 3.0307 - val_mae: 1.5405 - lr: 0.0010
# Epoch 104/500
# 4/4 [==============================] - 0s 47ms/step - loss: 2.1423 - mae: 1.2556 - val_loss: 3.0266 - val_mae: 1.5369 - lr: 0.0010
# Epoch 105/500
# 4/4 [==============================] - 0s 48ms/step - loss: 2.1145 - mae: 1.2431 - val_loss: 3.0229 - val_mae: 1.5335 - lr: 0.0010
# Epoch 106/500
# 4/4 [==============================] - 0s 46ms/step - loss: 2.0872 - mae: 1.2307 - val_loss: 3.0194 - val_mae: 1.5301 - lr: 0.0010
# Epoch 107/500
# 4/4 [==============================] - 0s 50ms/step - loss: 2.0601 - mae: 1.2183 - val_loss: 3.0163 - val_mae: 1.5267 - lr: 0.0010
# Epoch 108/500
# 4/4 [==============================] - 0s 46ms/step - loss: 2.0335 - mae: 1.2060 - val_loss: 3.0134 - val_mae: 1.5235 - lr: 0.0010
# Epoch 109/500
# 4/4 [==============================] - 0s 46ms/step - loss: 2.0073 - mae: 1.1937 - val_loss: 3.0108 - val_mae: 1.5203 - lr: 0.0010
# Epoch 110/500
# 4/4 [==============================] - 0s 45ms/step - loss: 1.9815 - mae: 1.1815 - val_loss: 3.0084 - val_mae: 1.5171 - lr: 0.0010
# Epoch 111/500
# 4/4 [==============================] - 0s 45ms/step - loss: 1.9561 - mae: 1.1694 - val_loss: 3.0063 - val_mae: 1.5141 - lr: 0.0010
# Epoch 112/500
# 4/4 [==============================] - 0s 45ms/step - loss: 1.9312 - mae: 1.1573 - val_loss: 3.0045 - val_mae: 1.5111 - lr: 0.0010
# Epoch 113/500
# 4/4 [==============================] - 0s 46ms/step - loss: 1.9066 - mae: 1.1454 - val_loss: 3.0028 - val_mae: 1.5082 - lr: 0.0010
# Epoch 114/500
# 4/4 [==============================] - 0s 45ms/step - loss: 1.8825 - mae: 1.1335 - val_loss: 3.0015 - val_mae: 1.5053 - lr: 0.0010
# Epoch 115/500
# 4/4 [==============================] - 0s 46ms/step - loss: 1.8588 - mae: 1.1217 - val_loss: 3.0003 - val_mae: 1.5025 - lr: 0.0010
# Epoch 116/500
# 4/4 [==============================] - 0s 47ms/step - loss: 1.8356 - mae: 1.1100 - val_loss: 2.9994 - val_mae: 1.4998 - lr: 0.0010
# Epoch 117/500
# 4/4 [==============================] - 0s 48ms/step - loss: 1.8128 - mae: 1.0984 - val_loss: 2.9986 - val_mae: 1.4971 - lr: 0.0010
# Epoch 118/500
# 4/4 [==============================] - 0s 48ms/step - loss: 1.7904 - mae: 1.0869 - val_loss: 2.9981 - val_mae: 1.4945 - lr: 0.0010
# Epoch 119/500
# 4/4 [==============================] - 0s 48ms/step - loss: 1.7685 - mae: 1.0755 - val_loss: 2.9978 - val_mae: 1.4919 - lr: 0.0010
# Epoch 120/500
# 4/4 [==============================] - 0s 44ms/step - loss: 1.7470 - mae: 1.0643 - val_loss: 2.9976 - val_mae: 1.4895 - lr: 0.0010
# Epoch 121/500
# 4/4 [==============================] - 0s 48ms/step - loss: 1.7259 - mae: 1.0532 - val_loss: 2.9976 - val_mae: 1.4871 - lr: 0.0010
# Epoch 122/500
# 4/4 [==============================] - 0s 46ms/step - loss: 1.7053 - mae: 1.0422 - val_loss: 2.9978 - val_mae: 1.4848 - lr: 0.0010
# Epoch 123/500
# 4/4 [==============================] - 0s 46ms/step - loss: 1.6850 - mae: 1.0313 - val_loss: 2.9981 - val_mae: 1.4826 - lr: 0.0010
# Epoch 124/500
# 4/4 [==============================] - 0s 49ms/step - loss: 1.6652 - mae: 1.0205 - val_loss: 2.9986 - val_mae: 1.4804 - lr: 0.0010
# Epoch 125/500
# 4/4 [==============================] - 0s 46ms/step - loss: 1.6459 - mae: 1.0099 - val_loss: 2.9993 - val_mae: 1.4783 - lr: 0.0010
# Epoch 126/500
# 4/4 [==============================] - 0s 44ms/step - loss: 1.6269 - mae: 0.9994 - val_loss: 3.0001 - val_mae: 1.4762 - lr: 0.0010
# Epoch 127/500
# 4/4 [==============================] - 0s 46ms/step - loss: 1.6083 - mae: 0.9890 - val_loss: 3.0010 - val_mae: 1.4742 - lr: 0.0010
# Epoch 128/500
# 4/4 [==============================] - 0s 46ms/step - loss: 1.5902 - mae: 0.9788 - val_loss: 3.0020 - val_mae: 1.4722 - lr: 0.0010
# Epoch 129/500
# 4/4 [==============================] - 0s 45ms/step - loss: 1.5724 - mae: 0.9686 - val_loss: 3.0032 - val_mae: 1.4703 - lr: 0.0010
# Epoch 130/500
# 4/4 [==============================] - 0s 43ms/step - loss: 1.5550 - mae: 0.9587 - val_loss: 3.0044 - val_mae: 1.4684 - lr: 0.0010
# Epoch 131/500
# 4/4 [==============================] - 0s 47ms/step - loss: 1.5380 - mae: 0.9488 - val_loss: 3.0058 - val_mae: 1.4665 - lr: 0.0010
# Epoch 132/500
# 4/4 [==============================] - 0s 43ms/step - loss: 1.5214 - mae: 0.9391 - val_loss: 3.0072 - val_mae: 1.4647 - lr: 0.0010
# Epoch 133/500
# 4/4 [==============================] - 0s 45ms/step - loss: 1.5052 - mae: 0.9295 - val_loss: 3.0088 - val_mae: 1.4630 - lr: 0.0010
# Epoch 134/500
# 4/4 [==============================] - 0s 43ms/step - loss: 1.4894 - mae: 0.9201 - val_loss: 3.0104 - val_mae: 1.4613 - lr: 0.0010
# Epoch 135/500
# 4/4 [==============================] - 0s 44ms/step - loss: 1.4739 - mae: 0.9108 - val_loss: 3.0121 - val_mae: 1.4596 - lr: 0.0010
# Epoch 136/500
# 4/4 [==============================] - 0s 44ms/step - loss: 1.4587 - mae: 0.9016 - val_loss: 3.0139 - val_mae: 1.4579 - lr: 0.0010
# Epoch 137/500
# 4/4 [==============================] - 0s 44ms/step - loss: 1.4439 - mae: 0.8926 - val_loss: 3.0158 - val_mae: 1.4563 - lr: 0.0010
# Epoch 138/500
# 4/4 [==============================] - 0s 46ms/step - loss: 1.4295 - mae: 0.8837 - val_loss: 3.0177 - val_mae: 1.4548 - lr: 0.0010
# Epoch 139/500
# 4/4 [==============================] - 0s 43ms/step - loss: 1.4153 - mae: 0.8750 - val_loss: 3.0197 - val_mae: 1.4532 - lr: 0.0010
# Epoch 140/500
# 4/4 [==============================] - 0s 44ms/step - loss: 1.4015 - mae: 0.8664 - val_loss: 3.0217 - val_mae: 1.4517 - lr: 0.0010
# Epoch 141/500
# 4/4 [==============================] - 0s 44ms/step - loss: 1.3881 - mae: 0.8579 - val_loss: 3.0238 - val_mae: 1.4503 - lr: 0.0010
# Epoch 142/500
# 4/4 [==============================] - 0s 45ms/step - loss: 1.3749 - mae: 0.8495 - val_loss: 3.0259 - val_mae: 1.4489 - lr: 0.0010
# Epoch 143/500
# 4/4 [==============================] - 0s 44ms/step - loss: 1.3621 - mae: 0.8413 - val_loss: 3.0280 - val_mae: 1.4475 - lr: 0.0010
# Epoch 144/500
# 4/4 [==============================] - 0s 46ms/step - loss: 1.3495 - mae: 0.8332 - val_loss: 3.0302 - val_mae: 1.4461 - lr: 0.0010
# Epoch 145/500
# 4/4 [==============================] - 0s 44ms/step - loss: 1.3373 - mae: 0.8253 - val_loss: 3.0324 - val_mae: 1.4448 - lr: 0.0010
# Epoch 146/500
# 4/4 [==============================] - 0s 45ms/step - loss: 1.3253 - mae: 0.8174 - val_loss: 3.0347 - val_mae: 1.4435 - lr: 0.0010
# Epoch 147/500
# 4/4 [==============================] - 0s 44ms/step - loss: 1.3136 - mae: 0.8097 - val_loss: 3.0369 - val_mae: 1.4422 - lr: 0.0010
# Epoch 148/500
# 4/4 [==============================] - 0s 45ms/step - loss: 1.3022 - mae: 0.8022 - val_loss: 3.0392 - val_mae: 1.4409 - lr: 0.0010
# Epoch 149/500
# 4/4 [==============================] - 0s 45ms/step - loss: 1.2911 - mae: 0.7947 - val_loss: 3.0415 - val_mae: 1.4397 - lr: 0.0010
# Epoch 150/500
# 4/4 [==============================] - 0s 44ms/step - loss: 1.2802 - mae: 0.7874 - val_loss: 3.0438 - val_mae: 1.4385 - lr: 0.0010
# Epoch 151/500
# 4/4 [==============================] - 0s 43ms/step - loss: 1.2696 - mae: 0.7802 - val_loss: 3.0461 - val_mae: 1.4373 - lr: 0.0010
# Epoch 152/500
# 4/4 [==============================] - 0s 42ms/step - loss: 1.2592 - mae: 0.7731 - val_loss: 3.0484 - val_mae: 1.4362 - lr: 0.0010
# Epoch 153/500
# 4/4 [==============================] - 0s 44ms/step - loss: 1.2491 - mae: 0.7662 - val_loss: 3.0507 - val_mae: 1.4351 - lr: 0.0010
# Epoch 154/500
# 4/4 [==============================] - 0s 43ms/step - loss: 1.2392 - mae: 0.7593 - val_loss: 3.0530 - val_mae: 1.4340 - lr: 0.0010
# Epoch 155/500
# 4/4 [==============================] - 0s 44ms/step - loss: 1.2296 - mae: 0.7526 - val_loss: 3.0553 - val_mae: 1.4329 - lr: 0.0010
# Epoch 156/500
# 4/4 [==============================] - 0s 44ms/step - loss: 1.2201 - mae: 0.7460 - val_loss: 3.0576 - val_mae: 1.4318 - lr: 0.0010
# Epoch 157/500
# 4/4 [==============================] - 0s 43ms/step - loss: 1.2109 - mae: 0.7395 - val_loss: 3.0599 - val_mae: 1.4308 - lr: 0.0010
# Epoch 158/500
# 4/4 [==============================] - 0s 46ms/step - loss: 1.2019 - mae: 0.7331 - val_loss: 3.0621 - val_mae: 1.4298 - lr: 0.0010
# Epoch 159/500
# 4/4 [==============================] - 0s 43ms/step - loss: 1.1932 - mae: 0.7269 - val_loss: 3.0644 - val_mae: 1.4288 - lr: 0.0010
# Epoch 160/500
# 4/4 [==============================] - 0s 45ms/step - loss: 1.1846 - mae: 0.7207 - val_loss: 3.0666 - val_mae: 1.4278 - lr: 0.0010
# Epoch 161/500
# 4/4 [==============================] - 0s 45ms/step - loss: 1.1762 - mae: 0.7147 - val_loss: 3.0688 - val_mae: 1.4269 - lr: 0.0010
# Epoch 162/500
# 4/4 [==============================] - 0s 45ms/step - loss: 1.1681 - mae: 0.7087 - val_loss: 3.0710 - val_mae: 1.4259 - lr: 0.0010
# Epoch 163/500
# 4/4 [==============================] - 0s 46ms/step - loss: 1.1601 - mae: 0.7029 - val_loss: 3.0732 - val_mae: 1.4250 - lr: 0.0010
# Epoch 164/500
# 4/4 [==============================] - 0s 43ms/step - loss: 1.1523 - mae: 0.6971 - val_loss: 3.0754 - val_mae: 1.4241 - lr: 0.0010
# Epoch 165/500
# 4/4 [==============================] - 0s 46ms/step - loss: 1.1446 - mae: 0.6915 - val_loss: 3.0775 - val_mae: 1.4232 - lr: 0.0010
# Epoch 166/500
# 4/4 [==============================] - 0s 45ms/step - loss: 1.1372 - mae: 0.6860 - val_loss: 3.0796 - val_mae: 1.4223 - lr: 0.0010
# Epoch 167/500
# 4/4 [==============================] - 0s 44ms/step - loss: 1.1299 - mae: 0.6805 - val_loss: 3.0817 - val_mae: 1.4215 - lr: 0.0010
# Epoch 168/500
# 4/4 [==============================] - 0s 46ms/step - loss: 1.1228 - mae: 0.6752 - val_loss: 3.0837 - val_mae: 1.4206 - lr: 0.0010
# Epoch 169/500
# 4/4 [==============================] - 0s 43ms/step - loss: 1.1159 - mae: 0.6699 - val_loss: 3.0857 - val_mae: 1.4198 - lr: 0.0010
# Epoch 170/500
# 4/4 [==============================] - 0s 45ms/step - loss: 1.1091 - mae: 0.6648 - val_loss: 3.0877 - val_mae: 1.4190 - lr: 0.0010
# CPU times: user 1min 40s, sys: 4.39 s, total: 1min 45s
# Wall time: 31.3 s

# %%
y_true = ratings_test
predictions = model.predict([user_ids_test, item_ids_test])
# Out:
# 30004/30004 [==============================] - 41s 1ms/step

# %%
# Evaluar el modelo con el conjunto de prueba
loss, mae = model.evaluate([user_ids_test, item_ids_test], ratings_test)
print(f'Test Loss: {loss:.4f}')
print(f'Test MAE: {mae:.4f}')
# Out:
# 30004/30004 [==============================] - 79s 3ms/step - loss: 3.0845 - mae: 1.4174
# Test Loss: 3.0845
# Test MAE: 1.4174

# %%
# MSE
mse = mean_squared_error(y_true, predictions)
print(f"MSE: {mse:.4f}")

# RMSE
rmse = np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

# MAE
mae = mean_absolute_error(y_true, predictions)
print(f"MAE: {mae:.4f}")

# MAPE (Mean Absolute Percentage Error)
mape = np.mean(np.abs((y_true - predictions.flatten()) / y_true)) * 100
print(f"MAPE: {mape:.2f}%")
# Out:
# MSE: 2.6137
# RMSE: 1.6167
# MAE: 1.4174
# MAPE: 39.43%

# %% [markdown]
# # Recomedanción

# %%
# Seleccionar un usuario al azar del conjunto de prueba
usuario_id_test_encoded = random.choice(user_ids_test)

# Decodificar el ID del usuario para obtener el ID original
usuario_id_test = reviewerID_encoder.inverse_transform([usuario_id_test_encoded])[0]

# Identificar los ítems que el usuario ha calificado en el conjunto de prueba
indices_usuario = np.where(user_ids_test == usuario_id_test_encoded)[0]
items_calificados_test_encoded = item_ids_test[indices_usuario]
calificaciones_reales_test = ratings_test[indices_usuario]

# Predecir las calificaciones para estos ítems
calificaciones_predichas = model.predict([np.array([usuario_id_test_encoded] * len(items_calificados_test_encoded)), items_calificados_test_encoded])

# Decodificar los ítems para obtener los ID originales
items_calificados_test = asin_encoder.inverse_transform(items_calificados_test_encoded)

# Comparar las calificaciones predichas con las reales
comparacion = list(zip(items_calificados_test, calificaciones_reales_test, calificaciones_predichas.flatten()))

# Suponiendo que 'items_calificados_test' contiene los IDs originales de los ítems
recomendaciones_df = pd.DataFrame({
    'asin': items_calificados_test,
    'Calificación Real': calificaciones_reales_test,
    'Calificación Predicha': calificaciones_predichas.flatten()
})

recomendaciones_df = recomendaciones_df.merge(sentimiento[['asin', 'cluster']], on='asin', how='left')
recomendaciones_df.rename(columns={'cluster': 'Sentimiento'}, inplace=True)

# Mostrar las recomendaciones
print(f"Recomendaciones para el usuario {usuario_id_test}:")
for index, row in recomendaciones_df.iterrows():
    print(f"Ítem: {row['asin']}, Calificación Real: {row['Calificación Real']}, Calificación Predicha: {row['Calificación Predicha']}, Sentimiento: {row['Sentimiento']}")
# Out:
# 1/1 [==============================] - 0s 22ms/step
# Recomendaciones para el usuario A2CB9CIUCE84IK:
# Ítem: B00OGSB3KI, Calificación Real: 5.0, Calificación Predicha: 3.5127627849578857, Sentimiento: Positivo
# Ítem: B007JX1PFK, Calificación Real: 5.0, Calificación Predicha: 4.478430271148682, Sentimiento: Positivo

# %%
# Seleccionar un usuario al azar del conjunto de prueba
usuario_id_test_encoded = random.choice(user_ids_test)

# Decodificar el ID del usuario para obtener el ID original
usuario_id = reviewerID_encoder.inverse_transform([usuario_id_test_encoded])[0]

# Lista de todos los ítems únicos en el dataset
items_unicos = np.unique(data['asin'].values)

# Ítems que el usuario ya ha calificado
items_calificados = data[data['reviewerID_encoded'] == usuario_id_test_encoded]['asin'].tolist()

# Ítems para predecir
items_a_predecir = [item for item in items_unicos if item not in items_calificados]

# Convierte los ítems a su representación codificada
items_a_predecir_encoded = asin_encoder.transform(items_a_predecir)

# Predecir la calificación para cada ítem no calificado
predicciones = model.predict([np.array([usuario_id_test_encoded] * len(items_a_predecir_encoded)), items_a_predecir_encoded])

# Emparejar cada ítem con su predicción
items_predicciones = list(zip(items_a_predecir, predicciones.flatten()))

# Ordenar por la calificación predicha más alta
items_recomendados = sorted(items_predicciones, key=lambda x: x[1], reverse=True)

# Tomar los top N recomendaciones
top_n = 5
top_recomendaciones = items_recomendados[:top_n]

# Crear un DataFrame a partir de las recomendaciones
recomendaciones_df = pd.DataFrame(top_recomendaciones, columns=['asin', 'Calificación Predicha'])

# Unir con el DataFrame 'sentimiento' para obtener el sentimiento asociado a cada ítem
recomendaciones_df = recomendaciones_df.merge(sentimiento[['asin', 'cluster']], on='asin', how='left')

# Renombrar la columna 'cluster' a 'Sentimiento' para claridad
recomendaciones_df.rename(columns={'cluster': 'Sentimiento'}, inplace=True)

# Mostrar las recomendaciones con el sentimiento
print(f"Recomendaciones para el usuario {usuario_id}:")
for index, row in recomendaciones_df.iterrows():
    print(f"Ítem: {row['asin']}, Calificación Predicha: {row['Calificación Predicha']}, Sentimiento: {row['Sentimiento']}")
# Out:
# 4814/4814 [==============================] - 7s 1ms/step
# Recomendaciones para el usuario A259GS5QFKI9KR:
# Ítem: B00SD288QU, Calificación Predicha: 4.553009033203125, Sentimiento: Positivo
# Ítem: B00ZPWR0N8, Calificación Predicha: 4.547565460205078, Sentimiento: Neutro
# Ítem: B00VIQW74M, Calificación Predicha: 4.546778678894043, Sentimiento: Neutro
# Ítem: B0058YKI46, Calificación Predicha: 4.543819904327393, Sentimiento: Negativo
# Ítem: B00FWX631K, Calificación Predicha: 4.532367706298828, Sentimiento: Neutro

# %% [markdown]
# # Modelo de Filtrado Colaborativo usando Red Neuronal Multicapa con Keras:

# %% [markdown]
# Funcionamiento:
#
# Estos sistemas toman características de los ítems y/o usuarios y las pasan a través de una o varias capas de neuronas para obtener una predicción.
# Las redes neuronales son capaces de capturar interacciones no lineales entre características, lo que las hace poderosas para tareas de modelado complejas.
#
# Ventajas:
#
# Capacidad de modelar relaciones no lineales.
#
# Flexibilidad para incorporar múltiples fuentes de datos o características.
#
# Puede manejar arranques en frío al incorporar características de nuevos ítems o usuarios.
#
# Desventajas:
#
# Mayor costo computacional en comparación con los sistemas basados únicamente en embeddings.
#
# Riesgo de sobreajuste si no se tiene un conjunto de datos lo suficientemente grande.

# %% [markdown]
# Ahora el código incluye regularización en los embeddings, early stopping para detener el entrenamiento si el modelo deja de mejorar en el conjunto de validación, y reducción de la tasa de aprendizaje si el error en el conjunto de validación no mejora después de algunas épocas. Estas adiciones deberían ayudar a mejorar la capacidad de generalización del modelo.

# %%
df['user_id'] = df['reviewerID'].astype('category').cat.codes.values
df['item_id'] = df['asin'].astype('category').cat.codes.values

# Número de usuarios e ítems
n_users = df['user_id'].nunique()
n_items = df['item_id'].nunique()

# Hiperparámetros
hidden_units = [128, 64, 32]
dropout_rate = 0.2
l2_reg = 1e-6

# Arquitectura del modelo
user_input = Input(shape=[1], name='user_input')
item_input = Input(shape=[1], name='item_input')
concat = Concatenate()([user_input, item_input])
dense = concat
for units in hidden_units:
    dense = Dense(units, activation='relu', kernel_regularizer=l2(l2_reg))(dense)
    dense = Dropout(dropout_rate)(dense)

# Agregar una capa de activación sigmoid y escalar a [0, 5]
output = Dense(1, activation='sigmoid', kernel_regularizer=l2(l2_reg))(dense)  # Función de activación sigmoid
output = Lambda(lambda x: x * 5)(output)  # Escalar las predicciones al rango [0, 5]

model = Model(inputs=[user_input, item_input], outputs=output)
model.compile(optimizer=Adam(0.001), loss='mean_squared_error')

# %%
# Callbacks
early_stop = EarlyStopping(monitor='val_loss', patience=50)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=50, min_lr=1e-5)

# %%
# Datos para entrenamiento
user_data = df['user_id'].values
item_data = df['item_id'].values
rating_data = df['overall'].values

# División en entrenamiento y prueba
(user_ids_temp, user_ids_test, item_ids_temp, item_ids_test, ratings_temp, ratings_test) = train_test_split(
    user_ids, item_ids, ratings, test_size=0.2, random_state=42)

# División del conjunto de entrenamiento en entrenamiento y validación
(user_ids_train, user_ids_val, item_ids_train, item_ids_val, ratings_train, ratings_val) = train_test_split(
    user_ids_temp, item_ids_temp, ratings_temp, test_size=0.25, random_state=42)  # 0.25 x 0.8 = 0.2

# %%
# %%time
# Entrenamiento del modelo
history = model.fit([user_ids_train, item_ids_train], ratings_train,
    epochs=500,validation_data=([user_ids_val, item_ids_val], ratings_val),
    batch_size=800000,verbose=1,callbacks=[early_stop, reduce_lr])
# Out:
# Epoch 1/500
# 4/4 [==============================] - 3s 163ms/step - loss: 2.8132 - val_loss: 1.8981 - lr: 0.0010
# Epoch 2/500
# 4/4 [==============================] - 0s 101ms/step - loss: 1.9442 - val_loss: 1.8981 - lr: 0.0010
# Epoch 3/500
# 4/4 [==============================] - 0s 104ms/step - loss: 1.9136 - val_loss: 1.8981 - lr: 0.0010
# Epoch 4/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9104 - val_loss: 1.8981 - lr: 0.0010
# Epoch 5/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9097 - val_loss: 1.8981 - lr: 0.0010
# Epoch 6/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9093 - val_loss: 1.8981 - lr: 0.0010
# Epoch 7/500
# 4/4 [==============================] - 0s 106ms/step - loss: 1.9092 - val_loss: 1.8981 - lr: 0.0010
# Epoch 8/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9093 - val_loss: 1.8981 - lr: 0.0010
# Epoch 9/500
# 4/4 [==============================] - 0s 105ms/step - loss: 1.9092 - val_loss: 1.8981 - lr: 0.0010
# Epoch 10/500
# 4/4 [==============================] - 0s 104ms/step - loss: 1.9092 - val_loss: 1.8981 - lr: 0.0010
# Epoch 11/500
# 4/4 [==============================] - 0s 102ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 12/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 13/500
# 4/4 [==============================] - 0s 104ms/step - loss: 1.9092 - val_loss: 1.8981 - lr: 0.0010
# Epoch 14/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 15/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9092 - val_loss: 1.8981 - lr: 0.0010
# Epoch 16/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9092 - val_loss: 1.8981 - lr: 0.0010
# Epoch 17/500
# 4/4 [==============================] - 0s 104ms/step - loss: 1.9092 - val_loss: 1.8981 - lr: 0.0010
# Epoch 18/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9092 - val_loss: 1.8981 - lr: 0.0010
# Epoch 19/500
# 4/4 [==============================] - 0s 102ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 20/500
# 4/4 [==============================] - 0s 102ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 21/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 22/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9092 - val_loss: 1.8981 - lr: 0.0010
# Epoch 23/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9092 - val_loss: 1.8981 - lr: 0.0010
# Epoch 24/500
# 4/4 [==============================] - 0s 102ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 25/500
# 4/4 [==============================] - 0s 104ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 26/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 27/500
# 4/4 [==============================] - 0s 104ms/step - loss: 1.9092 - val_loss: 1.8981 - lr: 0.0010
# Epoch 28/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 29/500
# 4/4 [==============================] - 0s 101ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 30/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 31/500
# 4/4 [==============================] - 0s 104ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 32/500
# 4/4 [==============================] - 0s 102ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 33/500
# 4/4 [==============================] - 0s 104ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 34/500
# 4/4 [==============================] - 0s 102ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 35/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 36/500
# 4/4 [==============================] - 0s 104ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 37/500
# 4/4 [==============================] - 0s 102ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 38/500
# 4/4 [==============================] - 0s 104ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 39/500
# 4/4 [==============================] - 0s 104ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 40/500
# 4/4 [==============================] - 0s 104ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 41/500
# 4/4 [==============================] - 0s 104ms/step - loss: 1.9092 - val_loss: 1.8981 - lr: 0.0010
# Epoch 42/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 43/500
# 4/4 [==============================] - 0s 104ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 44/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 45/500
# 4/4 [==============================] - 0s 105ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 46/500
# 4/4 [==============================] - 0s 104ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 47/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 48/500
# 4/4 [==============================] - 0s 104ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 49/500
# 4/4 [==============================] - 0s 104ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 50/500
# 4/4 [==============================] - 0s 101ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 51/500
# 4/4 [==============================] - 0s 102ms/step - loss: 1.9092 - val_loss: 1.8981 - lr: 0.0010
# Epoch 52/500
# 4/4 [==============================] - 0s 102ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 53/500
# 4/4 [==============================] - 0s 105ms/step - loss: 1.9092 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 54/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 55/500
# 4/4 [==============================] - 0s 101ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 56/500
# 4/4 [==============================] - 0s 101ms/step - loss: 1.9092 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 57/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 58/500
# 4/4 [==============================] - 0s 102ms/step - loss: 1.9092 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 59/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 60/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 61/500
# 4/4 [==============================] - 0s 101ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 62/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 63/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 64/500
# 4/4 [==============================] - 0s 102ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 65/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9092 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 66/500
# 4/4 [==============================] - 0s 104ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 67/500
# 4/4 [==============================] - 0s 104ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 68/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 69/500
# 4/4 [==============================] - 0s 102ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 70/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 71/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 72/500
# 4/4 [==============================] - 0s 104ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 73/500
# 4/4 [==============================] - 0s 105ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 74/500
# 4/4 [==============================] - 0s 104ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 75/500
# 4/4 [==============================] - 0s 104ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 76/500
# 4/4 [==============================] - 0s 105ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 77/500
# 4/4 [==============================] - 0s 104ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 78/500
# 4/4 [==============================] - 0s 104ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 79/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 80/500
# 4/4 [==============================] - 0s 102ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 81/500
# 4/4 [==============================] - 0s 105ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 82/500
# 4/4 [==============================] - 0s 102ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 83/500
# 4/4 [==============================] - 0s 104ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 84/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 85/500
# 4/4 [==============================] - 0s 102ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 86/500
# 4/4 [==============================] - 0s 104ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 87/500
# 4/4 [==============================] - 0s 105ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 88/500
# 4/4 [==============================] - 0s 104ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 89/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 90/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 91/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 92/500
# 4/4 [==============================] - 0s 102ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 93/500
# 4/4 [==============================] - 0s 102ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 94/500
# 4/4 [==============================] - 0s 104ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 95/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 96/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 97/500
# 4/4 [==============================] - 0s 106ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 98/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9092 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 99/500
# 4/4 [==============================] - 0s 102ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 100/500
# 4/4 [==============================] - 0s 104ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 101/500
# 4/4 [==============================] - 0s 102ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 102/500
# 4/4 [==============================] - 0s 104ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 103/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 104/500
# 4/4 [==============================] - 0s 101ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 105/500
# 4/4 [==============================] - 0s 102ms/step - loss: 1.9092 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 106/500
# 4/4 [==============================] - 0s 105ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 107/500
# 4/4 [==============================] - 0s 102ms/step - loss: 1.9092 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 108/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 109/500
# 4/4 [==============================] - 0s 104ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 110/500
# 4/4 [==============================] - 0s 104ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 111/500
# 4/4 [==============================] - 0s 104ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 112/500
# 4/4 [==============================] - 0s 104ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 113/500
# 4/4 [==============================] - 0s 104ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 114/500
# 4/4 [==============================] - 0s 104ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 115/500
# 4/4 [==============================] - 0s 104ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 116/500
# 4/4 [==============================] - 0s 102ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 117/500
# 4/4 [==============================] - 0s 102ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 118/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 119/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 120/500
# 4/4 [==============================] - 0s 102ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 121/500
# 4/4 [==============================] - 0s 102ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 122/500
# 4/4 [==============================] - 0s 104ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 123/500
# 4/4 [==============================] - 0s 102ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 124/500
# 4/4 [==============================] - 0s 102ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 125/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 126/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 127/500
# 4/4 [==============================] - 0s 104ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 128/500
# 4/4 [==============================] - 0s 102ms/step - loss: 1.9092 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 129/500
# 4/4 [==============================] - 0s 101ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 130/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 131/500
# 4/4 [==============================] - 0s 105ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 132/500
# 4/4 [==============================] - 0s 102ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 133/500
# 4/4 [==============================] - 0s 105ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 134/500
# 4/4 [==============================] - 0s 102ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 135/500
# 4/4 [==============================] - 0s 101ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 136/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 137/500
# 4/4 [==============================] - 0s 105ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 138/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 139/500
# 4/4 [==============================] - 0s 101ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 140/500
# 4/4 [==============================] - 0s 102ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 141/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 142/500
# 4/4 [==============================] - 0s 104ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 143/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 144/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 145/500
# 4/4 [==============================] - 0s 104ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 146/500
# 4/4 [==============================] - 0s 105ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 147/500
# 4/4 [==============================] - 0s 107ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 148/500
# 4/4 [==============================] - 0s 106ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 149/500
# 4/4 [==============================] - 0s 104ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 150/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 151/500
# 4/4 [==============================] - 0s 104ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 152/500
# 4/4 [==============================] - 0s 105ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 153/500
# 4/4 [==============================] - 0s 104ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 154/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 155/500
# 4/4 [==============================] - 0s 104ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 156/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 157/500
# 4/4 [==============================] - 0s 101ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 158/500
# 4/4 [==============================] - 0s 102ms/step - loss: 1.9092 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 159/500
# 4/4 [==============================] - 0s 102ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 160/500
# 4/4 [==============================] - 0s 102ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 161/500
# 4/4 [==============================] - 0s 104ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 162/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 163/500
# 4/4 [==============================] - 0s 102ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 164/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 165/500
# 4/4 [==============================] - 0s 101ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 166/500
# 4/4 [==============================] - 0s 102ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 167/500
# 4/4 [==============================] - 0s 104ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 168/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 169/500
# 4/4 [==============================] - 0s 101ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 170/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 171/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 172/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 173/500
# 4/4 [==============================] - 0s 102ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 174/500
# 4/4 [==============================] - 0s 102ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 175/500
# 4/4 [==============================] - 0s 102ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 176/500
# 4/4 [==============================] - 0s 104ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 177/500
# 4/4 [==============================] - 0s 105ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 178/500
# 4/4 [==============================] - 0s 102ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 179/500
# 4/4 [==============================] - 0s 104ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 180/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 181/500
# 4/4 [==============================] - 0s 102ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 182/500
# 4/4 [==============================] - 0s 105ms/step - loss: 1.9092 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 183/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 184/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 185/500
# 4/4 [==============================] - 0s 104ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 186/500
# 4/4 [==============================] - 0s 102ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 187/500
# 4/4 [==============================] - 0s 104ms/step - loss: 1.9092 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 188/500
# 4/4 [==============================] - 0s 104ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 189/500
# 4/4 [==============================] - 0s 101ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 190/500
# 4/4 [==============================] - 0s 102ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 191/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 192/500
# 4/4 [==============================] - 0s 101ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 193/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 194/500
# 4/4 [==============================] - 0s 102ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 195/500
# 4/4 [==============================] - 0s 104ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 196/500
# 4/4 [==============================] - 0s 104ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 197/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 198/500
# 4/4 [==============================] - 0s 101ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 199/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 200/500
# 4/4 [==============================] - 0s 101ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 201/500
# 4/4 [==============================] - 0s 102ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 202/500
# 4/4 [==============================] - 0s 101ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 203/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 204/500
# 4/4 [==============================] - 0s 104ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 205/500
# 4/4 [==============================] - 0s 102ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 206/500
# 4/4 [==============================] - 0s 104ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 207/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 208/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 209/500
# 4/4 [==============================] - 0s 102ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 210/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 211/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 212/500
# 4/4 [==============================] - 0s 101ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 213/500
# 4/4 [==============================] - 0s 102ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 214/500
# 4/4 [==============================] - 0s 106ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# CPU times: user 2min 20s, sys: 4.73 s, total: 2min 25s
# Wall time: 1min 28s

# %%
# Evaluar el modelo
y_true = ratings_test
predictions = model.predict([user_ids_test, item_ids_test])
# Out:
# 30004/30004 [==============================] - 45s 2ms/step

# %%
# MSE y RMSE
mse = mean_squared_error(y_true, predictions)
rmse = np.sqrt(mse)

# MAE
mae = mean_absolute_error(y_true, predictions)

# Funciones MAPE
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    non_zero_idx = y_true != 0  # Para evitar divisiones por cero
    return np.mean(np.abs((y_true[non_zero_idx] - y_pred[non_zero_idx]) / y_true[non_zero_idx])) * 100

def compute_mape_by_batch(y_true, predictions, batch_size=50000):
    mape_sum = 0
    num_batches = int(np.ceil(len(y_true) / batch_size))

    for i in range(num_batches):
        start_idx = i * batch_size
        end_idx = start_idx + batch_size

        batch_y_true = y_true[start_idx:end_idx]
        batch_predictions = predictions[start_idx:end_idx]

        mape_sum += mean_absolute_percentage_error(batch_y_true, batch_predictions)

    return mape_sum / num_batches

# Luego llamas a la función
mape = compute_mape_by_batch(y_true, predictions)

print(f'MSE: {mse}')
print(f'RMSE: {rmse}')
print(f'MAE: {mae}')
print(f'MAPE: {mape}%')
# Out:
# MSE: 1.91015555428256
# RMSE: 1.3820837725270345
# MAE: 0.7401227977898481
# MAPE: 40.77108911682409%

# %% [markdown]
# # Recomendación

# %%
# Seleccionar un usuario al azar del conjunto de prueba
usuario_id_test_encoded = random.choice(user_ids_test)

# Decodificar el ID del usuario para obtener el ID original
usuario_id_test = reviewerID_encoder.inverse_transform([usuario_id_test_encoded])[0]

# Identificar los ítems que el usuario ha calificado en el conjunto de prueba
indices_usuario = np.where(user_ids_test == usuario_id_test_encoded)[0]
items_calificados_test_encoded = item_ids_test[indices_usuario]
calificaciones_reales_test = ratings_test[indices_usuario]

# Predecir las calificaciones para estos ítems
calificaciones_predichas = model.predict([np.array([usuario_id_test_encoded] * len(items_calificados_test_encoded)), items_calificados_test_encoded])

# Decodificar los ítems para obtener los ID originales
items_calificados_test = asin_encoder.inverse_transform(items_calificados_test_encoded)

# Comparar las calificaciones predichas con las reales
comparacion = list(zip(items_calificados_test, calificaciones_reales_test, calificaciones_predichas.flatten()))

# Suponiendo que 'items_calificados_test' contiene los IDs originales de los ítems
recomendaciones_df = pd.DataFrame({
    'asin': items_calificados_test,
    'Calificación Real': calificaciones_reales_test,
    'Calificación Predicha': calificaciones_predichas.flatten()
})

recomendaciones_df = recomendaciones_df.merge(sentimiento[['asin', 'cluster']], on='asin', how='left')
recomendaciones_df.rename(columns={'cluster': 'Sentimiento'}, inplace=True)

# Mostrar las recomendaciones
print(f"Recomendaciones para el usuario {usuario_id_test}:")
for index, row in recomendaciones_df.iterrows():
    print(f"Ítem: {row['asin']}, Calificación Real: {row['Calificación Real']}, Calificación Predicha: {row['Calificación Predicha']}, Sentimiento: {row['Sentimiento']}")
# Out:
# 1/1 [==============================] - 0s 18ms/step
# Recomendaciones para el usuario A3HIB8EDYX56LE:
# Ítem: B00JZ1RLLG, Calificación Real: 5.0, Calificación Predicha: 5.0, Sentimiento: Positivo
# Ítem: B00JZ1RLKW, Calificación Real: 5.0, Calificación Predicha: 5.0, Sentimiento: Positivo

# %%
# Seleccionar un usuario al azar del conjunto de prueba
usuario_id_test_encoded = random.choice(user_ids_test)

# Decodificar el ID del usuario para obtener el ID original
usuario_id = reviewerID_encoder.inverse_transform([usuario_id_test_encoded])[0]

# Lista de todos los ítems únicos en el dataset
items_unicos = np.unique(data['asin'].values)

# Ítems que el usuario ya ha calificado
items_calificados = data[data['reviewerID_encoded'] == usuario_id_test_encoded]['asin'].tolist()

# Ítems para predecir
items_a_predecir = [item for item in items_unicos if item not in items_calificados]

# Convierte los ítems a su representación codificada
items_a_predecir_encoded = asin_encoder.transform(items_a_predecir)

# Predecir la calificación para cada ítem no calificado
predicciones = model.predict([np.array([usuario_id_test_encoded] * len(items_a_predecir_encoded)), items_a_predecir_encoded])

# Emparejar cada ítem con su predicción
items_predicciones = list(zip(items_a_predecir, predicciones.flatten()))

# Ordenar por la calificación predicha más alta
items_recomendados = sorted(items_predicciones, key=lambda x: x[1], reverse=True)

# Tomar los top N recomendaciones
top_n = 5
top_recomendaciones = items_recomendados[:top_n]

# Crear un DataFrame a partir de las recomendaciones
recomendaciones_df = pd.DataFrame(top_recomendaciones, columns=['asin', 'Calificación Predicha'])

# Unir con el DataFrame 'sentimiento' para obtener el sentimiento asociado a cada ítem
recomendaciones_df = recomendaciones_df.merge(sentimiento[['asin', 'cluster']], on='asin', how='left')

# Renombrar la columna 'cluster' a 'Sentimiento' para claridad
recomendaciones_df.rename(columns={'cluster': 'Sentimiento'}, inplace=True)

# Mostrar las recomendaciones con el sentimiento
print(f"Recomendaciones para el usuario {usuario_id}:")
for index, row in recomendaciones_df.iterrows():
    print(f"Ítem: {row['asin']}, Calificación Predicha: {row['Calificación Predicha']}, Sentimiento: {row['Sentimiento']}")
# Out:
# 4814/4814 [==============================] - 7s 1ms/step
# Recomendaciones para el usuario A1TRNPEHX4YFMK:
# Ítem: 0871167042, Calificación Predicha: 5.0, Sentimiento: Positivo
# Ítem: 1519588135, Calificación Predicha: 5.0, Sentimiento: Neutro
# Ítem: 1579652956, Calificación Predicha: 5.0, Sentimiento: Positivo
# Ítem: 1936023857, Calificación Predicha: 5.0, Sentimiento: Positivo
# Ítem: 5120053017, Calificación Predicha: 5.0, Sentimiento: Neutro

# %% [markdown]
# # Modelo de Filtrado Colaborativo usando Red Neuronal Multicapa y Embedding con Keras:
#
# Otra enfoque popular para filtrado colaborativo es utilizar redes neuronales multicapa, que esencialmente aprenden características no lineales de los datos. Vamos a construir un modelo que fusiona los embeddings de usuarios y artículos (por ejemplo, películas) en una red neuronal densa.
#
# Este enfoque, que combina embeddings y redes neuronales multicapa, puede capturar interacciones más complejas y no lineales entre usuarios y artículos. Sin embargo, es crucial prestar atención al sobreajuste y asegurarse de que el modelo no esté simplemente memorizando los datos. Por lo tanto, es recomendable emplear técnicas de regularización, ajustar hiperparámetros y validar el rendimiento con un conjunto de datos de validación.

# %% [markdown]
# Funcionamiento:
#
# Combina lo mejor de ambos mundos. Primero, se utilizan embeddings para convertir ítems y usuarios en representaciones vectoriales densas. Luego, estas representaciones se pasan a través de una red neuronal para hacer la predicción.
#
# El proceso generalmente comienza con capas de embedding que convierten identificadores de usuarios e ítems en vectores. Estos vectores luego se pasan a través de capas densas para obtener la predicción final.
#
# Ventajas:
#
# Capacidad de capturar patrones subyacentes en los datos mediante embeddings y modelar interacciones no lineales mediante la red neuronal.
#
# Flexibilidad para incorporar características adicionales.
#
# Potencialmente más preciso que cualquiera de los otros dos métodos por separado.
#
# Desventajas:
#
# Mayor complejidad en el modelado y entrenamiento.
#
# Mayor costo computacional.
#
# Requiere un ajuste más cuidadoso y riesgo de sobreajuste si no se gestiona adecuadamente.

# %% [markdown]
# Regularización L2: Agregar una regularización L2 a las capas de embedding y densas para prevenir el sobreajuste.
#
# Early Stopping: Añadir una callback de early stopping para detener el entrenamiento cuando no haya mejora en el conjunto de validación durante un cierto número de épocas.
#
# Ajuste de la tasa de aprendizaje: Utilizar la callback ReduceLROnPlateau para reducir la tasa de aprendizaje cuando no haya mejora en el conjunto de validación.
#
# Métricas adicionales: Puedes monitorizar otras métricas como el error absoluto medio (MAE) durante el entrenamiento.

# %%
# Convertir reviewerID y asin a índices numéricos secuenciales
df['user_id'] = df['reviewerID'].astype('category').cat.codes.values
df['item_id'] = df['asin'].astype('category').cat.codes.values

# Número de usuarios e ítems
n_users = df['user_id'].nunique()
n_items = df['item_id'].nunique()

# Hiperparámetros
n_latent_factors = 50
hidden_units = [128, 64]
dropout_rate = 0.2
l2_reg = 1e-4

# Entradas
user_input = Input(shape=[1], name='user_input')
item_input = Input(shape=[1], name='item_input')

# Embeddings con regularización L2
user_embedding = Embedding(n_users, n_latent_factors, embeddings_regularizer=l2(l2_reg), name='user_embedding')(user_input)
item_embedding = Embedding(n_items, n_latent_factors, embeddings_regularizer=l2(l2_reg), name='item_embedding')(item_input)

user_vec = Flatten(name='flatten_users')(user_embedding)
item_vec = Flatten(name='flatten_items')(item_embedding)
concat = Concatenate()([user_vec, item_vec])

# Capas densas
dense = concat
for units in hidden_units:
    dense = Dense(units, activation='relu', kernel_regularizer=l2(l2_reg))(dense)
    dense = Dropout(dropout_rate)(dense)

# Agregar una capa de activación sigmoid y escalar a [0, 5]
output = Dense(1, activation='sigmoid', kernel_regularizer=l2(l2_reg))(dense)  # Función de activación sigmoid
output = Lambda(lambda x: x * 5)(output)  # Escalar las predicciones al rango [0, 5]

# Modelo
model = Model(inputs=[user_input, item_input], outputs=output)
model.compile(optimizer=Adam(0.001), loss='mean_squared_error', metrics=['mae'])

# %%
# Callbacks
early_stop = EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=50, min_lr=1e-5)

# %%
# Entrenamiento
user_data = df['user_id'].values
item_data = df['item_id'].values
rating_data = df['overall'].values

# División en entrenamiento y prueba
(user_ids_temp, user_ids_test, item_ids_temp, item_ids_test, ratings_temp, ratings_test) = train_test_split(
    user_ids, item_ids, ratings, test_size=0.2, random_state=42)

# División del conjunto de entrenamiento en entrenamiento y validación
(user_ids_train, user_ids_val, item_ids_train, item_ids_val, ratings_train, ratings_val) = train_test_split(
    user_ids_temp, item_ids_temp, ratings_temp, test_size=0.25, random_state=42)  # 0.25 x 0.8 = 0.2

# %%
# %%time
history = model.fit([user_ids_train, item_ids_train], ratings_train,
                    epochs=500,validation_data=([user_ids_val, item_ids_val], ratings_val),
                    batch_size=800000,verbose=1,callbacks=[early_stop, reduce_lr])
# Out:
# Epoch 1/500
# 4/4 [==============================] - 3s 439ms/step - loss: 10.7952 - mae: 1.9690 - val_loss: 9.8582 - val_mae: 1.9269 - lr: 0.0010
# Epoch 2/500
# 4/4 [==============================] - 1s 254ms/step - loss: 9.3942 - mae: 1.9043 - val_loss: 8.5026 - val_mae: 1.8632 - lr: 0.0010
# Epoch 3/500
# 4/4 [==============================] - 1s 258ms/step - loss: 8.0705 - mae: 1.8373 - val_loss: 7.2475 - val_mae: 1.7885 - lr: 0.0010
# Epoch 4/500
# 4/4 [==============================] - 1s 255ms/step - loss: 6.8463 - mae: 1.7557 - val_loss: 6.0844 - val_mae: 1.6920 - lr: 0.0010
# Epoch 5/500
# 4/4 [==============================] - 1s 256ms/step - loss: 5.7085 - mae: 1.6501 - val_loss: 4.9959 - val_mae: 1.5705 - lr: 0.0010
# Epoch 6/500
# 4/4 [==============================] - 1s 255ms/step - loss: 4.6419 - mae: 1.5219 - val_loss: 3.9820 - val_mae: 1.4297 - lr: 0.0010
# Epoch 7/500
# 4/4 [==============================] - 1s 254ms/step - loss: 3.6635 - mae: 1.3675 - val_loss: 3.0997 - val_mae: 1.2549 - lr: 0.0010
# Epoch 8/500
# 4/4 [==============================] - 1s 262ms/step - loss: 2.8489 - mae: 1.1834 - val_loss: 2.4536 - val_mae: 1.0727 - lr: 0.0010
# Epoch 9/500
# 4/4 [==============================] - 1s 254ms/step - loss: 2.2905 - mae: 1.0194 - val_loss: 2.0814 - val_mae: 0.9540 - lr: 0.0010
# Epoch 10/500
# 4/4 [==============================] - 1s 255ms/step - loss: 1.9756 - mae: 0.9138 - val_loss: 1.8886 - val_mae: 0.8862 - lr: 0.0010
# Epoch 11/500
# 4/4 [==============================] - 1s 255ms/step - loss: 1.7960 - mae: 0.8540 - val_loss: 1.7638 - val_mae: 0.8527 - lr: 0.0010
# Epoch 12/500
# 4/4 [==============================] - 1s 261ms/step - loss: 1.6604 - mae: 0.8223 - val_loss: 1.6587 - val_mae: 0.8401 - lr: 0.0010
# Epoch 13/500
# 4/4 [==============================] - 1s 256ms/step - loss: 1.5370 - mae: 0.8072 - val_loss: 1.5673 - val_mae: 0.8407 - lr: 0.0010
# Epoch 14/500
# 4/4 [==============================] - 1s 255ms/step - loss: 1.4251 - mae: 0.8021 - val_loss: 1.4969 - val_mae: 0.8500 - lr: 0.0010
# Epoch 15/500
# 4/4 [==============================] - 1s 253ms/step - loss: 1.3321 - mae: 0.8029 - val_loss: 1.4520 - val_mae: 0.8635 - lr: 0.0010
# Epoch 16/500
# 4/4 [==============================] - 1s 255ms/step - loss: 1.2594 - mae: 0.8039 - val_loss: 1.4269 - val_mae: 0.8741 - lr: 0.0010
# Epoch 17/500
# 4/4 [==============================] - 1s 257ms/step - loss: 1.1997 - mae: 0.7983 - val_loss: 1.4112 - val_mae: 0.8757 - lr: 0.0010
# Epoch 18/500
# 4/4 [==============================] - 1s 253ms/step - loss: 1.1435 - mae: 0.7811 - val_loss: 1.3998 - val_mae: 0.8675 - lr: 0.0010
# Epoch 19/500
# 4/4 [==============================] - 1s 256ms/step - loss: 1.0901 - mae: 0.7542 - val_loss: 1.3933 - val_mae: 0.8541 - lr: 0.0010
# Epoch 20/500
# 4/4 [==============================] - 1s 253ms/step - loss: 1.0424 - mae: 0.7242 - val_loss: 1.3920 - val_mae: 0.8414 - lr: 0.0010
# Epoch 21/500
# 4/4 [==============================] - 1s 150ms/step - loss: 1.0008 - mae: 0.6966 - val_loss: 1.3928 - val_mae: 0.8320 - lr: 0.0010
# Epoch 22/500
# 4/4 [==============================] - 1s 149ms/step - loss: 0.9640 - mae: 0.6737 - val_loss: 1.3927 - val_mae: 0.8264 - lr: 0.0010
# Epoch 23/500
# 4/4 [==============================] - 1s 254ms/step - loss: 0.9304 - mae: 0.6557 - val_loss: 1.3901 - val_mae: 0.8231 - lr: 0.0010
# Epoch 24/500
# 4/4 [==============================] - 1s 252ms/step - loss: 0.9006 - mae: 0.6416 - val_loss: 1.3850 - val_mae: 0.8200 - lr: 0.0010
# Epoch 25/500
# 4/4 [==============================] - 1s 254ms/step - loss: 0.8737 - mae: 0.6297 - val_loss: 1.3781 - val_mae: 0.8160 - lr: 0.0010
# Epoch 26/500
# 4/4 [==============================] - 1s 257ms/step - loss: 0.8506 - mae: 0.6195 - val_loss: 1.3719 - val_mae: 0.8118 - lr: 0.0010
# Epoch 27/500
# 4/4 [==============================] - 1s 258ms/step - loss: 0.8301 - mae: 0.6100 - val_loss: 1.3679 - val_mae: 0.8082 - lr: 0.0010
# Epoch 28/500
# 4/4 [==============================] - 1s 256ms/step - loss: 0.8123 - mae: 0.6010 - val_loss: 1.3661 - val_mae: 0.8051 - lr: 0.0010
# Epoch 29/500
# 4/4 [==============================] - 1s 256ms/step - loss: 0.7965 - mae: 0.5923 - val_loss: 1.3653 - val_mae: 0.8019 - lr: 0.0010
# Epoch 30/500
# 4/4 [==============================] - 1s 253ms/step - loss: 0.7824 - mae: 0.5836 - val_loss: 1.3650 - val_mae: 0.7987 - lr: 0.0010
# Epoch 31/500
# 4/4 [==============================] - 1s 152ms/step - loss: 0.7701 - mae: 0.5757 - val_loss: 1.3653 - val_mae: 0.7959 - lr: 0.0010
# Epoch 32/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.7589 - mae: 0.5684 - val_loss: 1.3662 - val_mae: 0.7938 - lr: 0.0010
# Epoch 33/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.7492 - mae: 0.5621 - val_loss: 1.3672 - val_mae: 0.7919 - lr: 0.0010
# Epoch 34/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.7402 - mae: 0.5562 - val_loss: 1.3684 - val_mae: 0.7900 - lr: 0.0010
# Epoch 35/500
# 4/4 [==============================] - 1s 149ms/step - loss: 0.7321 - mae: 0.5509 - val_loss: 1.3709 - val_mae: 0.7888 - lr: 0.0010
# Epoch 36/500
# 4/4 [==============================] - 1s 151ms/step - loss: 0.7247 - mae: 0.5459 - val_loss: 1.3734 - val_mae: 0.7877 - lr: 0.0010
# Epoch 37/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.7178 - mae: 0.5413 - val_loss: 1.3762 - val_mae: 0.7866 - lr: 0.0010
# Epoch 38/500
# 4/4 [==============================] - 1s 152ms/step - loss: 0.7116 - mae: 0.5369 - val_loss: 1.3793 - val_mae: 0.7856 - lr: 0.0010
# Epoch 39/500
# 4/4 [==============================] - 1s 152ms/step - loss: 0.7058 - mae: 0.5325 - val_loss: 1.3827 - val_mae: 0.7847 - lr: 0.0010
# Epoch 40/500
# 4/4 [==============================] - 1s 153ms/step - loss: 0.7001 - mae: 0.5283 - val_loss: 1.3864 - val_mae: 0.7840 - lr: 0.0010
# Epoch 41/500
# 4/4 [==============================] - 1s 149ms/step - loss: 0.6949 - mae: 0.5245 - val_loss: 1.3910 - val_mae: 0.7836 - lr: 0.0010
# Epoch 42/500
# 4/4 [==============================] - 1s 151ms/step - loss: 0.6898 - mae: 0.5208 - val_loss: 1.3959 - val_mae: 0.7836 - lr: 0.0010
# Epoch 43/500
# 4/4 [==============================] - 1s 151ms/step - loss: 0.6847 - mae: 0.5171 - val_loss: 1.4005 - val_mae: 0.7833 - lr: 0.0010
# Epoch 44/500
# 4/4 [==============================] - 1s 149ms/step - loss: 0.6799 - mae: 0.5136 - val_loss: 1.4058 - val_mae: 0.7832 - lr: 0.0010
# Epoch 45/500
# 4/4 [==============================] - 1s 151ms/step - loss: 0.6751 - mae: 0.5101 - val_loss: 1.4116 - val_mae: 0.7835 - lr: 0.0010
# Epoch 46/500
# 4/4 [==============================] - 1s 153ms/step - loss: 0.6707 - mae: 0.5070 - val_loss: 1.4174 - val_mae: 0.7837 - lr: 0.0010
# Epoch 47/500
# 4/4 [==============================] - 1s 152ms/step - loss: 0.6667 - mae: 0.5038 - val_loss: 1.4228 - val_mae: 0.7837 - lr: 0.0010
# Epoch 48/500
# 4/4 [==============================] - 1s 153ms/step - loss: 0.6628 - mae: 0.5009 - val_loss: 1.4283 - val_mae: 0.7838 - lr: 0.0010
# Epoch 49/500
# 4/4 [==============================] - 1s 151ms/step - loss: 0.6593 - mae: 0.4981 - val_loss: 1.4340 - val_mae: 0.7841 - lr: 0.0010
# Epoch 50/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.6563 - mae: 0.4956 - val_loss: 1.4396 - val_mae: 0.7843 - lr: 0.0010
# Epoch 51/500
# 4/4 [==============================] - 1s 152ms/step - loss: 0.6536 - mae: 0.4933 - val_loss: 1.4451 - val_mae: 0.7844 - lr: 0.0010
# Epoch 52/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.6512 - mae: 0.4911 - val_loss: 1.4517 - val_mae: 0.7850 - lr: 0.0010
# Epoch 53/500
# 4/4 [==============================] - 1s 169ms/step - loss: 0.6489 - mae: 0.4889 - val_loss: 1.4578 - val_mae: 0.7853 - lr: 0.0010
# Epoch 54/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.6469 - mae: 0.4870 - val_loss: 1.4628 - val_mae: 0.7854 - lr: 0.0010
# Epoch 55/500
# 4/4 [==============================] - 1s 151ms/step - loss: 0.6448 - mae: 0.4851 - val_loss: 1.4682 - val_mae: 0.7858 - lr: 0.0010
# Epoch 56/500
# 4/4 [==============================] - 1s 151ms/step - loss: 0.6432 - mae: 0.4836 - val_loss: 1.4735 - val_mae: 0.7861 - lr: 0.0010
# Epoch 57/500
# 4/4 [==============================] - 1s 149ms/step - loss: 0.6414 - mae: 0.4817 - val_loss: 1.4789 - val_mae: 0.7865 - lr: 0.0010
# Epoch 58/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.6401 - mae: 0.4803 - val_loss: 1.4834 - val_mae: 0.7868 - lr: 0.0010
# Epoch 59/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.6385 - mae: 0.4788 - val_loss: 1.4890 - val_mae: 0.7871 - lr: 0.0010
# Epoch 60/500
# 4/4 [==============================] - 1s 152ms/step - loss: 0.6371 - mae: 0.4773 - val_loss: 1.4946 - val_mae: 0.7877 - lr: 0.0010
# Epoch 61/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.6358 - mae: 0.4761 - val_loss: 1.4989 - val_mae: 0.7878 - lr: 0.0010
# Epoch 62/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.6349 - mae: 0.4749 - val_loss: 1.5036 - val_mae: 0.7882 - lr: 0.0010
# Epoch 63/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.6338 - mae: 0.4738 - val_loss: 1.5093 - val_mae: 0.7892 - lr: 0.0010
# Epoch 64/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.6326 - mae: 0.4724 - val_loss: 1.5147 - val_mae: 0.7896 - lr: 0.0010
# Epoch 65/500
# 4/4 [==============================] - 1s 151ms/step - loss: 0.6318 - mae: 0.4715 - val_loss: 1.5200 - val_mae: 0.7902 - lr: 0.0010
# Epoch 66/500
# 4/4 [==============================] - 1s 149ms/step - loss: 0.6306 - mae: 0.4703 - val_loss: 1.5251 - val_mae: 0.7907 - lr: 0.0010
# Epoch 67/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.6300 - mae: 0.4693 - val_loss: 1.5307 - val_mae: 0.7915 - lr: 0.0010
# Epoch 68/500
# 4/4 [==============================] - 1s 151ms/step - loss: 0.6290 - mae: 0.4683 - val_loss: 1.5356 - val_mae: 0.7920 - lr: 0.0010
# Epoch 69/500
# 4/4 [==============================] - 1s 152ms/step - loss: 0.6283 - mae: 0.4675 - val_loss: 1.5402 - val_mae: 0.7923 - lr: 0.0010
# Epoch 70/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.6273 - mae: 0.4662 - val_loss: 1.5459 - val_mae: 0.7931 - lr: 0.0010
# Epoch 71/500
# 4/4 [==============================] - 1s 151ms/step - loss: 0.6268 - mae: 0.4656 - val_loss: 1.5518 - val_mae: 0.7940 - lr: 0.0010
# Epoch 72/500
# 4/4 [==============================] - 1s 152ms/step - loss: 0.6260 - mae: 0.4646 - val_loss: 1.5564 - val_mae: 0.7944 - lr: 0.0010
# Epoch 73/500
# 4/4 [==============================] - 1s 155ms/step - loss: 0.6253 - mae: 0.4637 - val_loss: 1.5604 - val_mae: 0.7947 - lr: 0.0010
# Epoch 74/500
# 4/4 [==============================] - 1s 152ms/step - loss: 0.6249 - mae: 0.4630 - val_loss: 1.5644 - val_mae: 0.7950 - lr: 0.0010
# Epoch 75/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.6246 - mae: 0.4625 - val_loss: 1.5696 - val_mae: 0.7959 - lr: 0.0010
# Epoch 76/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.6238 - mae: 0.4617 - val_loss: 1.5735 - val_mae: 0.7962 - lr: 0.0010
# Epoch 77/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.6230 - mae: 0.4609 - val_loss: 1.5779 - val_mae: 0.7969 - lr: 0.0010
# Epoch 78/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.6224 - mae: 0.4601 - val_loss: 1.5824 - val_mae: 0.7972 - lr: 0.0010
# Epoch 79/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.6218 - mae: 0.4594 - val_loss: 1.5852 - val_mae: 0.7975 - lr: 0.0010
# Epoch 80/500
# 4/4 [==============================] - 1s 276ms/step - loss: 0.6214 - mae: 0.4590 - val_loss: 1.5881 - val_mae: 0.7980 - lr: 0.0010
# CPU times: user 1min 8s, sys: 7.45 s, total: 1min 15s
# Wall time: 58.4 s

# %%
# Predicciones
y_true = ratings_test
predictions = model.predict([user_ids_test, item_ids_test])
# Out:
# 30004/30004 [==============================] - 46s 2ms/step

# %%
# MSE y RMSE
mse = mean_squared_error(y_true, predictions)
rmse = np.sqrt(mse)

# MAE
mae = mean_absolute_error(y_true, predictions)

# MAPE
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    non_zero_idx = y_true != 0  # Para evitar divisiones por cero
    return np.mean(np.abs((y_true[non_zero_idx] - y_pred[non_zero_idx]) / y_true[non_zero_idx])) * 100

def compute_mape_by_batch(y_true, predictions, batch_size=50000):
    mape_sum = 0
    num_batches = int(np.ceil(len(y_true) / batch_size))

    for i in range(num_batches):
        start_idx = i * batch_size
        end_idx = start_idx + batch_size

        batch_y_true = y_true[start_idx:end_idx]
        batch_predictions = predictions[start_idx:end_idx]

        mape_sum += mean_absolute_percentage_error(batch_y_true, batch_predictions)

    return mape_sum / num_batches

# Luego llamas a la función
mape = compute_mape_by_batch(y_true, predictions)

print(f'MSE: {mse}')
print(f'RMSE: {rmse}')
print(f'MAE: {mae}')
print(f'MAPE: {mape}%')
# Out:
# MSE: 1.213246151737755
# RMSE: 1.1014745352198365
# MAE: 0.7994800724480138
# MAPE: 39.77720849709324%

# %% [markdown]
# # Recomendación

# %%
# Seleccionar un usuario al azar del conjunto de prueba
usuario_id_test_encoded = random.choice(user_ids_test)

# Decodificar el ID del usuario para obtener el ID original
usuario_id_test = reviewerID_encoder.inverse_transform([usuario_id_test_encoded])[0]

# Identificar los ítems que el usuario ha calificado en el conjunto de prueba
indices_usuario = np.where(user_ids_test == usuario_id_test_encoded)[0]
items_calificados_test_encoded = item_ids_test[indices_usuario]
calificaciones_reales_test = ratings_test[indices_usuario]

# Predecir las calificaciones para estos ítems
calificaciones_predichas = model.predict([np.array([usuario_id_test_encoded] * len(items_calificados_test_encoded)), items_calificados_test_encoded])

# Decodificar los ítems para obtener los ID originales
items_calificados_test = asin_encoder.inverse_transform(items_calificados_test_encoded)

# Comparar las calificaciones predichas con las reales
comparacion = list(zip(items_calificados_test, calificaciones_reales_test, calificaciones_predichas.flatten()))

# Suponiendo que 'items_calificados_test' contiene los IDs originales de los ítems
recomendaciones_df = pd.DataFrame({
    'asin': items_calificados_test,
    'Calificación Real': calificaciones_reales_test,
    'Calificación Predicha': calificaciones_predichas.flatten()
})

recomendaciones_df = recomendaciones_df.merge(sentimiento[['asin', 'cluster']], on='asin', how='left')
recomendaciones_df.rename(columns={'cluster': 'Sentimiento'}, inplace=True)

# Mostrar las recomendaciones
print(f"Recomendaciones para el usuario {usuario_id_test}:")
for index, row in recomendaciones_df.iterrows():
    print(f"Ítem: {row['asin']}, Calificación Real: {row['Calificación Real']}, Calificación Predicha: {row['Calificación Predicha']}, Sentimiento: {row['Sentimiento']}")
# Out:
# 1/1 [==============================] - 0s 18ms/step
# Recomendaciones para el usuario AOED81JH8OMWD:
# Ítem: B002M0MIJ2, Calificación Real: 5.0, Calificación Predicha: 4.631375789642334, Sentimiento: Neutro
# Ítem: B000MAPS7S, Calificación Real: 5.0, Calificación Predicha: 4.788207530975342, Sentimiento: Neutro
# Ítem: B00VY215KC, Calificación Real: 5.0, Calificación Predicha: 4.25316858291626, Sentimiento: Neutro
# Ítem: B00KNJP2EW, Calificación Real: 5.0, Calificación Predicha: 4.611866474151611, Sentimiento: Positivo
# Ítem: B00062BIC6, Calificación Real: 4.0, Calificación Predicha: 4.612146854400635, Sentimiento: Neutro
# Ítem: B00I5QWK1I, Calificación Real: 5.0, Calificación Predicha: 4.478981018066406, Sentimiento: Positivo

# %%
# Seleccionar un usuario al azar del conjunto de prueba
usuario_id_test_encoded = random.choice(user_ids_test)

# Decodificar el ID del usuario para obtener el ID original
usuario_id = reviewerID_encoder.inverse_transform([usuario_id_test_encoded])[0]

# Lista de todos los ítems únicos en el dataset
items_unicos = np.unique(data['asin'].values)

# Ítems que el usuario ya ha calificado
items_calificados = data[data['reviewerID_encoded'] == usuario_id_test_encoded]['asin'].tolist()

# Ítems para predecir
items_a_predecir = [item for item in items_unicos if item not in items_calificados]

# Convierte los ítems a su representación codificada
items_a_predecir_encoded = asin_encoder.transform(items_a_predecir)

# Predecir la calificación para cada ítem no calificado
predicciones = model.predict([np.array([usuario_id_test_encoded] * len(items_a_predecir_encoded)), items_a_predecir_encoded])

# Emparejar cada ítem con su predicción
items_predicciones = list(zip(items_a_predecir, predicciones.flatten()))

# Ordenar por la calificación predicha más alta
items_recomendados = sorted(items_predicciones, key=lambda x: x[1], reverse=True)

# Tomar los top N recomendaciones
top_n = 5
top_recomendaciones = items_recomendados[:top_n]

# Crear un DataFrame a partir de las recomendaciones
recomendaciones_df = pd.DataFrame(top_recomendaciones, columns=['asin', 'Calificación Predicha'])

# Unir con el DataFrame 'sentimiento' para obtener el sentimiento asociado a cada ítem
recomendaciones_df = recomendaciones_df.merge(sentimiento[['asin', 'cluster']], on='asin', how='left')

# Renombrar la columna 'cluster' a 'Sentimiento' para claridad
recomendaciones_df.rename(columns={'cluster': 'Sentimiento'}, inplace=True)

# Mostrar las recomendaciones con el sentimiento
print(f"Recomendaciones para el usuario {usuario_id}:")
for index, row in recomendaciones_df.iterrows():
    print(f"Ítem: {row['asin']}, Calificación Predicha: {row['Calificación Predicha']}, Sentimiento: {row['Sentimiento']}")
# Out:
# 4813/4813 [==============================] - 7s 2ms/step
# Recomendaciones para el usuario A3PP1KBWQKN4O6:
# Ítem: B00KKXCJQU, Calificación Predicha: 4.659495830535889, Sentimiento: Positivo
# Ítem: B00H9RZDRM, Calificación Predicha: 4.654723167419434, Sentimiento: Neutro
# Ítem: B0013KGG7M, Calificación Predicha: 4.594662189483643, Sentimiento: Positivo
# Ítem: B01E4SQNLS, Calificación Predicha: 4.542489051818848, Sentimiento: Positivo
# Ítem: B000JFBHGW, Calificación Predicha: 4.520904064178467, Sentimiento: Positivo

# %% [markdown]
# Estas métricas te ayudarán a tener una mejor idea del desempeño de tu modelo. Por ejemplo:
#
# MSE y RMSE son útiles cuando quieres penalizar grandes errores.
#
# MAE te da una idea del error medio sin considerar la dirección del error.
#
# MAPE es útil cuando quieres representar el error en términos porcentuales.
#
# Para una evaluación completa, es recomendable utilizar un conjunto de validación aparte (es decir, no solo depender del validation_split). Esto asegura que estás evaluando el desempeño en datos que el modelo nunca ha visto durante el entrenamiento.

# %% [markdown]
# En resumen, la elección del tipo de sistema de recomendación dependerá de la naturaleza del conjunto de datos, las características disponibles, las capacidades computacionales y el tipo de relaciones o interacciones que se desean capturar. A menudo, un enfoque híbrido (como el sistema que combina embeddings y redes neuronales) ofrece un buen equilibrio entre precisión y eficiencia.
