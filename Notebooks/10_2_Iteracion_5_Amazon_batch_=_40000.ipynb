# %% [markdown]
# # Paso 1: Importar Librerías de Python

# %%
#pip install scikit-surprise
# Out:
# Collecting scikit-surprise
#   Downloading scikit-surprise-1.1.3.tar.gz (771 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 772.0/772.0 kB 13.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: joblib>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.3.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.11.3)
# Building wheels for collected packages: scikit-surprise
#   Building wheel for scikit-surprise (setup.py) ... done
#   Created wheel for scikit-surprise: filename=scikit_surprise-1.1.3-cp310-cp310-linux_x86_64.whl size=3163484 sha256=1d00935dfbe67579c99d960f3614f249465bd4afdb7fffb238a3569169f8ed18
#   Stored in directory: /root/.cache/pip/wheels/a5/ca/a8/4e28def53797fdc4363ca4af740db15a9c2f1595ebc51fb445
# Successfully built scikit-surprise
# Installing collected packages: scikit-surprise
# Successfully installed scikit-surprise-1.1.3

# %%
# Análisis de datos y manipulación
import pandas as pd
import numpy as np
import random


# Visualización de datos
import matplotlib.pyplot as plt
import seaborn as sns

# Utilidades de fechas
from datetime import datetime

# Integración con Google Colab
from google.colab import drive

# Machine Learning: Preprocesamiento y división de datos
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# Machine Learning: Métricas
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.metrics.pairwise import cosine_similarity

# Machine Learning: Modelado y validación
from surprise import SVD, Reader, Dataset, accuracy
from surprise.model_selection import train_test_split, GridSearchCV

# Deep Learning: Construcción de modelos y capas
from keras.models import Model
from keras.layers import Input, Embedding, Flatten, Concatenate, Dense, Dropout, Dot,Lambda

# Deep Learning: Optimización y regularización
from keras.optimizers import Adam
from keras.regularizers import l2

# Deep Learning: Callbacks
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Paso 2: Lectura del Dataset

# %%
df = pd.read_csv('/content/drive/MyDrive/EspecializacionA&DS/Monografia/2doSemestre/DataFinal_Amazon.csv')
# Out:
# <ipython-input-4-9e77e6115feb>:1: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/drive/MyDrive/EspecializacionA&DS/Monografia/2doSemestre/DataFinal_Amazon.csv')

# %%
df.shape
# Out:
# (4800571, 10)

# %%
sentimiento = pd.read_csv('/content/drive/MyDrive/EspecializacionA&DS/Monografia/2doSemestre/sentimientos_productos.csv')

# %%
sentimiento.shape
# Out:
# (154026, 4)

# %% [markdown]
# # Modelo de Filtrado Colaborativo usando Embedding con Keras:

# %% [markdown]
# Funcionamiento:
#
# Los embeddings son representaciones vectoriales densas y de baja dimensión de ítems y/o usuarios. Estas representaciones capturan relaciones semánticas entre ítems o entre usuarios.
#
# Un método popular para generar embeddings es la factorización de matrices, como la descomposición en valores singulares (SVD). En el contexto de sistemas de recomendación, se busca factorizar la matriz de interacciones usuario-ítem en dos matrices más pequeñas (una para los usuarios y otra para los ítems) cuyo producto aproximado reproduce la matriz original lo mejor posible.
#
# Una vez que se han obtenido los embeddings, la predicción de una calificación o interacción entre un usuario e ítem se realiza tomando el producto escalar entre sus embeddings respectivos.
#
# Ventajas:
#
# Simplicidad y eficiencia en términos computacionales.
#
# Puede manejar grandes conjuntos de datos debido a su naturaleza de baja dimensión.
#
# Es efectivo para capturar patrones subyacentes en los datos.
#
# Desventajas:
#
# No tiene en cuenta características adicionales de usuarios o ítems.
#
# Dificultades para manejar nuevos ítems o usuarios (problema de arranque en frío).

# %% [markdown]
# El código ahora incluye regularización en los embeddings, un callback para detener el entrenamiento si no hay mejoras (early stopping) y otro para reducir la tasa de aprendizaje si el error de validación no mejora (reduce learning rate on plateau).

# %%
data = df

# %%
# Crear un LabelEncoder para cada columna
reviewerID_encoder = LabelEncoder()
asin_encoder = LabelEncoder()

# Ajustar y transformar las columnas
data['reviewerID_encoded'] = reviewerID_encoder.fit_transform(data['reviewerID'])
data['asin_encoded'] = asin_encoder.fit_transform(data['asin'])

# Número de usuarios únicos y número de ítems únicos
n_users = len(np.unique(data['reviewerID_encoded']))
n_items = len(np.unique(data['asin_encoded']))

# Dimensiones del embedding
embedding_dim = 10

# Entradas
user_input = Input(shape=(1,))
item_input = Input(shape=(1,))

# Embeddings con regularización
user_embedding = Embedding(n_users, embedding_dim, embeddings_regularizer=l2(1e-6))(user_input)
item_embedding = Embedding(n_items, embedding_dim, embeddings_regularizer=l2(1e-6))(item_input)

# Producto punto para predecir la valoración/rating
merged = Dot(axes=2)([user_embedding, item_embedding])
merged = Flatten()(merged)

# Agregar una capa de activación sigmoid y escalar a [0, 5]
output = Dense(1, activation='sigmoid')(merged)  # Función de activación sigmoid
output = Lambda(lambda x: x * 5)(output)  # Escalar las predicciones al rango [0, 5]

# Modelo
model = Model(inputs=[user_input, item_input], outputs=output)
model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# %% [markdown]
# verbose=0: No muestra ninguna barra de progreso ni métricas.
#
# verbose=1: Muestra una barra de progreso y actualiza las métricas después de cada lote.
#
# verbose=2: Muestra las métricas después de cada época, pero no muestra la barra de progreso.

# %%
from sklearn.model_selection import train_test_split

# Crear los arrays con los datos
user_ids = data['reviewerID_encoded'].values
item_ids = data['asin_encoded'].values
ratings = data['overall'].values

# División en entrenamiento y prueba
(user_ids_temp, user_ids_test, item_ids_temp, item_ids_test, ratings_temp, ratings_test) = train_test_split(
    user_ids, item_ids, ratings, test_size=0.2, random_state=42)

# División del conjunto de entrenamiento en entrenamiento y validación
(user_ids_train, user_ids_val, item_ids_train, item_ids_val, ratings_train, ratings_val) = train_test_split(
    user_ids_temp, item_ids_temp, ratings_temp, test_size=0.25, random_state=42)  # 0.25 x 0.8 = 0.2

# %%
# Callbacks
early_stop = EarlyStopping(monitor='val_loss', patience=50)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=50, min_lr=1e-5)

# %%
# %%time
# Entrenar el modelo con el conjunto de entrenamiento
model.fit([user_ids_train, item_ids_train], ratings_train, validation_data=([user_ids_val, item_ids_val], ratings_val), epochs=500,
          batch_size=40000, verbose=1, callbacks=[early_stop, reduce_lr])
# Out:
# Epoch 1/500
# 73/73 [==============================] - 6s 13ms/step - loss: 4.3166 - mae: 1.9444 - val_loss: 4.1632 - val_mae: 1.9100 - lr: 0.0010
# Epoch 2/500
# 73/73 [==============================] - 1s 10ms/step - loss: 4.0072 - mae: 1.8724 - val_loss: 3.8697 - val_mae: 1.8396 - lr: 0.0010
# Epoch 3/500
# 73/73 [==============================] - 1s 10ms/step - loss: 3.7099 - mae: 1.7985 - val_loss: 3.5914 - val_mae: 1.7679 - lr: 0.0010
# Epoch 4/500
# 73/73 [==============================] - 1s 10ms/step - loss: 3.4081 - mae: 1.7175 - val_loss: 3.3263 - val_mae: 1.6938 - lr: 0.0010
# Epoch 5/500
# 73/73 [==============================] - 1s 10ms/step - loss: 3.0900 - mae: 1.6245 - val_loss: 3.0829 - val_mae: 1.6187 - lr: 0.0010
# Epoch 6/500
# 73/73 [==============================] - 1s 10ms/step - loss: 2.7565 - mae: 1.5186 - val_loss: 2.8724 - val_mae: 1.5483 - lr: 0.0010
# Epoch 7/500
# 73/73 [==============================] - 1s 10ms/step - loss: 2.4208 - mae: 1.4074 - val_loss: 2.7016 - val_mae: 1.4914 - lr: 0.0010
# Epoch 8/500
# 73/73 [==============================] - 1s 10ms/step - loss: 2.1025 - mae: 1.2936 - val_loss: 2.5709 - val_mae: 1.4432 - lr: 0.0010
# Epoch 9/500
# 73/73 [==============================] - 1s 10ms/step - loss: 1.8184 - mae: 1.1795 - val_loss: 2.4760 - val_mae: 1.4025 - lr: 0.0010
# Epoch 10/500
# 73/73 [==============================] - 1s 10ms/step - loss: 1.5772 - mae: 1.0713 - val_loss: 2.4104 - val_mae: 1.3687 - lr: 0.0010
# Epoch 11/500
# 73/73 [==============================] - 1s 10ms/step - loss: 1.3785 - mae: 0.9729 - val_loss: 2.3672 - val_mae: 1.3410 - lr: 0.0010
# Epoch 12/500
# 73/73 [==============================] - 1s 10ms/step - loss: 1.2171 - mae: 0.8857 - val_loss: 2.3407 - val_mae: 1.3183 - lr: 0.0010
# Epoch 13/500
# 73/73 [==============================] - 1s 10ms/step - loss: 1.0864 - mae: 0.8092 - val_loss: 2.3261 - val_mae: 1.2997 - lr: 0.0010
# Epoch 14/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.9801 - mae: 0.7424 - val_loss: 2.3195 - val_mae: 1.2843 - lr: 0.0010
# Epoch 15/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.8932 - mae: 0.6841 - val_loss: 2.3185 - val_mae: 1.2715 - lr: 0.0010
# Epoch 16/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.8217 - mae: 0.6334 - val_loss: 2.3211 - val_mae: 1.2607 - lr: 0.0010
# Epoch 17/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.7625 - mae: 0.5891 - val_loss: 2.3260 - val_mae: 1.2516 - lr: 0.0010
# Epoch 18/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.7130 - mae: 0.5503 - val_loss: 2.3318 - val_mae: 1.2437 - lr: 0.0010
# Epoch 19/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.6715 - mae: 0.5163 - val_loss: 2.3380 - val_mae: 1.2367 - lr: 0.0010
# Epoch 20/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.6363 - mae: 0.4863 - val_loss: 2.3439 - val_mae: 1.2306 - lr: 0.0010
# Epoch 21/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.6063 - mae: 0.4598 - val_loss: 2.3489 - val_mae: 1.2249 - lr: 0.0010
# Epoch 22/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.5806 - mae: 0.4364 - val_loss: 2.3533 - val_mae: 1.2197 - lr: 0.0010
# Epoch 23/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.5583 - mae: 0.4157 - val_loss: 2.3565 - val_mae: 1.2149 - lr: 0.0010
# Epoch 24/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.5390 - mae: 0.3973 - val_loss: 2.3586 - val_mae: 1.2102 - lr: 0.0010
# Epoch 25/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.5220 - mae: 0.3809 - val_loss: 2.3594 - val_mae: 1.2058 - lr: 0.0010
# Epoch 26/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.5070 - mae: 0.3664 - val_loss: 2.3593 - val_mae: 1.2016 - lr: 0.0010
# Epoch 27/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.4937 - mae: 0.3534 - val_loss: 2.3580 - val_mae: 1.1974 - lr: 0.0010
# Epoch 28/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.4817 - mae: 0.3419 - val_loss: 2.3556 - val_mae: 1.1933 - lr: 0.0010
# Epoch 29/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.4709 - mae: 0.3315 - val_loss: 2.3521 - val_mae: 1.1892 - lr: 0.0010
# Epoch 30/500
# 73/73 [==============================] - 1s 11ms/step - loss: 0.4611 - mae: 0.3222 - val_loss: 2.3477 - val_mae: 1.1852 - lr: 0.0010
# Epoch 31/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.4521 - mae: 0.3137 - val_loss: 2.3423 - val_mae: 1.1811 - lr: 0.0010
# Epoch 32/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.4438 - mae: 0.3061 - val_loss: 2.3361 - val_mae: 1.1770 - lr: 0.0010
# Epoch 33/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.4361 - mae: 0.2992 - val_loss: 2.3292 - val_mae: 1.1729 - lr: 0.0010
# Epoch 34/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.4289 - mae: 0.2929 - val_loss: 2.3217 - val_mae: 1.1688 - lr: 0.0010
# Epoch 35/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.4221 - mae: 0.2872 - val_loss: 2.3134 - val_mae: 1.1646 - lr: 0.0010
# Epoch 36/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.4157 - mae: 0.2820 - val_loss: 2.3046 - val_mae: 1.1605 - lr: 0.0010
# Epoch 37/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.4097 - mae: 0.2772 - val_loss: 2.2953 - val_mae: 1.1562 - lr: 0.0010
# Epoch 38/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.4039 - mae: 0.2728 - val_loss: 2.2857 - val_mae: 1.1521 - lr: 0.0010
# Epoch 39/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3984 - mae: 0.2688 - val_loss: 2.2755 - val_mae: 1.1478 - lr: 0.0010
# Epoch 40/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3931 - mae: 0.2650 - val_loss: 2.2649 - val_mae: 1.1435 - lr: 0.0010
# Epoch 41/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3880 - mae: 0.2615 - val_loss: 2.2539 - val_mae: 1.1391 - lr: 0.0010
# Epoch 42/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3831 - mae: 0.2583 - val_loss: 2.2428 - val_mae: 1.1347 - lr: 0.0010
# Epoch 43/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3783 - mae: 0.2552 - val_loss: 2.2313 - val_mae: 1.1303 - lr: 0.0010
# Epoch 44/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3737 - mae: 0.2524 - val_loss: 2.2196 - val_mae: 1.1258 - lr: 0.0010
# Epoch 45/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3692 - mae: 0.2497 - val_loss: 2.2076 - val_mae: 1.1213 - lr: 0.0010
# Epoch 46/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3648 - mae: 0.2472 - val_loss: 2.1955 - val_mae: 1.1168 - lr: 0.0010
# Epoch 47/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3605 - mae: 0.2447 - val_loss: 2.1832 - val_mae: 1.1122 - lr: 0.0010
# Epoch 48/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3564 - mae: 0.2425 - val_loss: 2.1708 - val_mae: 1.1076 - lr: 0.0010
# Epoch 49/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3523 - mae: 0.2403 - val_loss: 2.1583 - val_mae: 1.1030 - lr: 0.0010
# Epoch 50/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3483 - mae: 0.2382 - val_loss: 2.1457 - val_mae: 1.0983 - lr: 0.0010
# Epoch 51/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3444 - mae: 0.2362 - val_loss: 2.1329 - val_mae: 1.0936 - lr: 0.0010
# Epoch 52/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3406 - mae: 0.2343 - val_loss: 2.1200 - val_mae: 1.0889 - lr: 0.0010
# Epoch 53/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3368 - mae: 0.2325 - val_loss: 2.1071 - val_mae: 1.0842 - lr: 0.0010
# Epoch 54/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3331 - mae: 0.2308 - val_loss: 2.0943 - val_mae: 1.0794 - lr: 0.0010
# Epoch 55/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3295 - mae: 0.2290 - val_loss: 2.0814 - val_mae: 1.0747 - lr: 0.0010
# Epoch 56/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3259 - mae: 0.2274 - val_loss: 2.0684 - val_mae: 1.0698 - lr: 0.0010
# Epoch 57/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3225 - mae: 0.2258 - val_loss: 2.0553 - val_mae: 1.0649 - lr: 0.0010
# Epoch 58/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3190 - mae: 0.2243 - val_loss: 2.0424 - val_mae: 1.0601 - lr: 0.0010
# Epoch 59/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3156 - mae: 0.2227 - val_loss: 2.0293 - val_mae: 1.0552 - lr: 0.0010
# Epoch 60/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3123 - mae: 0.2213 - val_loss: 2.0166 - val_mae: 1.0503 - lr: 0.0010
# Epoch 61/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3090 - mae: 0.2198 - val_loss: 2.0037 - val_mae: 1.0454 - lr: 0.0010
# Epoch 62/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3058 - mae: 0.2185 - val_loss: 1.9910 - val_mae: 1.0405 - lr: 0.0010
# Epoch 63/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3026 - mae: 0.2171 - val_loss: 1.9783 - val_mae: 1.0356 - lr: 0.0010
# Epoch 64/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.2995 - mae: 0.2158 - val_loss: 1.9659 - val_mae: 1.0308 - lr: 0.0010
# Epoch 65/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.2964 - mae: 0.2144 - val_loss: 1.9533 - val_mae: 1.0259 - lr: 0.0010
# Epoch 66/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.2934 - mae: 0.2132 - val_loss: 1.9411 - val_mae: 1.0210 - lr: 0.0010
# Epoch 67/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.2904 - mae: 0.2119 - val_loss: 1.9288 - val_mae: 1.0162 - lr: 0.0010
# Epoch 68/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.2875 - mae: 0.2107 - val_loss: 1.9167 - val_mae: 1.0113 - lr: 0.0010
# Epoch 69/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.2846 - mae: 0.2095 - val_loss: 1.9048 - val_mae: 1.0065 - lr: 0.0010
# Epoch 70/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.2818 - mae: 0.2084 - val_loss: 1.8930 - val_mae: 1.0017 - lr: 0.0010
# Epoch 71/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.2790 - mae: 0.2072 - val_loss: 1.8814 - val_mae: 0.9969 - lr: 0.0010
# Epoch 72/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.2762 - mae: 0.2061 - val_loss: 1.8700 - val_mae: 0.9921 - lr: 0.0010
# Epoch 73/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.2735 - mae: 0.2050 - val_loss: 1.8587 - val_mae: 0.9874 - lr: 0.0010
# Epoch 74/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.2708 - mae: 0.2040 - val_loss: 1.8477 - val_mae: 0.9834 - lr: 0.0010
# Epoch 75/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.2682 - mae: 0.2030 - val_loss: 1.8370 - val_mae: 0.9795 - lr: 0.0010
# Epoch 76/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.2657 - mae: 0.2020 - val_loss: 1.8263 - val_mae: 0.9757 - lr: 0.0010
# Epoch 77/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.2631 - mae: 0.2010 - val_loss: 1.8158 - val_mae: 0.9719 - lr: 0.0010
# Epoch 78/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.2606 - mae: 0.2000 - val_loss: 1.8056 - val_mae: 0.9682 - lr: 0.0010
# Epoch 79/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.2582 - mae: 0.1990 - val_loss: 1.7956 - val_mae: 0.9645 - lr: 0.0010
# Epoch 80/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.2558 - mae: 0.1981 - val_loss: 1.7858 - val_mae: 0.9608 - lr: 0.0010
# Epoch 81/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.2534 - mae: 0.1971 - val_loss: 1.7763 - val_mae: 0.9572 - lr: 0.0010
# Epoch 82/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.2510 - mae: 0.1962 - val_loss: 1.7669 - val_mae: 0.9536 - lr: 0.0010
# Epoch 83/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.2488 - mae: 0.1952 - val_loss: 1.7578 - val_mae: 0.9501 - lr: 0.0010
# Epoch 84/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.2465 - mae: 0.1943 - val_loss: 1.7489 - val_mae: 0.9467 - lr: 0.0010
# Epoch 85/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.2443 - mae: 0.1934 - val_loss: 1.7404 - val_mae: 0.9433 - lr: 0.0010
# Epoch 86/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.2421 - mae: 0.1925 - val_loss: 1.7319 - val_mae: 0.9399 - lr: 0.0010
# Epoch 87/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.2400 - mae: 0.1916 - val_loss: 1.7238 - val_mae: 0.9366 - lr: 0.0010
# Epoch 88/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.2379 - mae: 0.1907 - val_loss: 1.7158 - val_mae: 0.9333 - lr: 0.0010
# Epoch 89/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.2358 - mae: 0.1898 - val_loss: 1.7081 - val_mae: 0.9301 - lr: 0.0010
# Epoch 90/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.2337 - mae: 0.1889 - val_loss: 1.7007 - val_mae: 0.9269 - lr: 0.0010
# Epoch 91/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.2317 - mae: 0.1880 - val_loss: 1.6935 - val_mae: 0.9238 - lr: 0.0010
# Epoch 92/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.2298 - mae: 0.1872 - val_loss: 1.6864 - val_mae: 0.9208 - lr: 0.0010
# Epoch 93/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.2278 - mae: 0.1864 - val_loss: 1.6796 - val_mae: 0.9177 - lr: 0.0010
# Epoch 94/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.2260 - mae: 0.1855 - val_loss: 1.6731 - val_mae: 0.9148 - lr: 0.0010
# Epoch 95/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.2241 - mae: 0.1847 - val_loss: 1.6666 - val_mae: 0.9119 - lr: 0.0010
# Epoch 96/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.2223 - mae: 0.1839 - val_loss: 1.6606 - val_mae: 0.9091 - lr: 0.0010
# Epoch 97/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.2205 - mae: 0.1831 - val_loss: 1.6545 - val_mae: 0.9062 - lr: 0.0010
# Epoch 98/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.2187 - mae: 0.1822 - val_loss: 1.6489 - val_mae: 0.9035 - lr: 0.0010
# Epoch 99/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.2170 - mae: 0.1815 - val_loss: 1.6434 - val_mae: 0.9009 - lr: 0.0010
# Epoch 100/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.2153 - mae: 0.1807 - val_loss: 1.6381 - val_mae: 0.8982 - lr: 0.0010
# Epoch 101/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.2136 - mae: 0.1799 - val_loss: 1.6330 - val_mae: 0.8957 - lr: 0.0010
# Epoch 102/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.2120 - mae: 0.1791 - val_loss: 1.6279 - val_mae: 0.8931 - lr: 0.0010
# Epoch 103/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.2104 - mae: 0.1784 - val_loss: 1.6233 - val_mae: 0.8907 - lr: 0.0010
# Epoch 104/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.2088 - mae: 0.1775 - val_loss: 1.6186 - val_mae: 0.8882 - lr: 0.0010
# Epoch 105/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.2072 - mae: 0.1768 - val_loss: 1.6143 - val_mae: 0.8858 - lr: 0.0010
# Epoch 106/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.2056 - mae: 0.1760 - val_loss: 1.6097 - val_mae: 0.8835 - lr: 0.0010
# Epoch 107/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.2042 - mae: 0.1754 - val_loss: 1.6060 - val_mae: 0.8813 - lr: 0.0010
# Epoch 108/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.2027 - mae: 0.1746 - val_loss: 1.6017 - val_mae: 0.8790 - lr: 0.0010
# Epoch 109/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.2012 - mae: 0.1739 - val_loss: 1.5982 - val_mae: 0.8769 - lr: 0.0010
# Epoch 110/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1998 - mae: 0.1731 - val_loss: 1.5945 - val_mae: 0.8747 - lr: 0.0010
# Epoch 111/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1984 - mae: 0.1724 - val_loss: 1.5911 - val_mae: 0.8727 - lr: 0.0010
# Epoch 112/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1970 - mae: 0.1716 - val_loss: 1.5876 - val_mae: 0.8706 - lr: 0.0010
# Epoch 113/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1956 - mae: 0.1711 - val_loss: 1.5846 - val_mae: 0.8687 - lr: 0.0010
# Epoch 114/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1943 - mae: 0.1704 - val_loss: 1.5814 - val_mae: 0.8668 - lr: 0.0010
# Epoch 115/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1930 - mae: 0.1697 - val_loss: 1.5786 - val_mae: 0.8649 - lr: 0.0010
# Epoch 116/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1917 - mae: 0.1690 - val_loss: 1.5756 - val_mae: 0.8631 - lr: 0.0010
# Epoch 117/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1904 - mae: 0.1683 - val_loss: 1.5729 - val_mae: 0.8613 - lr: 0.0010
# Epoch 118/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1892 - mae: 0.1677 - val_loss: 1.5703 - val_mae: 0.8596 - lr: 0.0010
# Epoch 119/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1879 - mae: 0.1671 - val_loss: 1.5677 - val_mae: 0.8579 - lr: 0.0010
# Epoch 120/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1867 - mae: 0.1665 - val_loss: 1.5654 - val_mae: 0.8563 - lr: 0.0010
# Epoch 121/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1856 - mae: 0.1658 - val_loss: 1.5631 - val_mae: 0.8547 - lr: 0.0010
# Epoch 122/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1844 - mae: 0.1652 - val_loss: 1.5610 - val_mae: 0.8531 - lr: 0.0010
# Epoch 123/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1832 - mae: 0.1647 - val_loss: 1.5589 - val_mae: 0.8516 - lr: 0.0010
# Epoch 124/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1821 - mae: 0.1641 - val_loss: 1.5568 - val_mae: 0.8502 - lr: 0.0010
# Epoch 125/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1810 - mae: 0.1635 - val_loss: 1.5549 - val_mae: 0.8487 - lr: 0.0010
# Epoch 126/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1799 - mae: 0.1629 - val_loss: 1.5531 - val_mae: 0.8474 - lr: 0.0010
# Epoch 127/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1788 - mae: 0.1623 - val_loss: 1.5511 - val_mae: 0.8459 - lr: 0.0010
# Epoch 128/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1778 - mae: 0.1618 - val_loss: 1.5496 - val_mae: 0.8447 - lr: 0.0010
# Epoch 129/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1767 - mae: 0.1612 - val_loss: 1.5478 - val_mae: 0.8434 - lr: 0.0010
# Epoch 130/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1757 - mae: 0.1607 - val_loss: 1.5463 - val_mae: 0.8422 - lr: 0.0010
# Epoch 131/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1746 - mae: 0.1601 - val_loss: 1.5446 - val_mae: 0.8410 - lr: 0.0010
# Epoch 132/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1736 - mae: 0.1597 - val_loss: 1.5433 - val_mae: 0.8399 - lr: 0.0010
# Epoch 133/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1726 - mae: 0.1591 - val_loss: 1.5418 - val_mae: 0.8387 - lr: 0.0010
# Epoch 134/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1717 - mae: 0.1586 - val_loss: 1.5405 - val_mae: 0.8376 - lr: 0.0010
# Epoch 135/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1707 - mae: 0.1580 - val_loss: 1.5392 - val_mae: 0.8365 - lr: 0.0010
# Epoch 136/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1697 - mae: 0.1576 - val_loss: 1.5379 - val_mae: 0.8354 - lr: 0.0010
# Epoch 137/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1688 - mae: 0.1570 - val_loss: 1.5367 - val_mae: 0.8344 - lr: 0.0010
# Epoch 138/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1679 - mae: 0.1565 - val_loss: 1.5354 - val_mae: 0.8334 - lr: 0.0010
# Epoch 139/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1669 - mae: 0.1560 - val_loss: 1.5341 - val_mae: 0.8325 - lr: 0.0010
# Epoch 140/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1660 - mae: 0.1557 - val_loss: 1.5331 - val_mae: 0.8317 - lr: 0.0010
# Epoch 141/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1652 - mae: 0.1552 - val_loss: 1.5321 - val_mae: 0.8307 - lr: 0.0010
# Epoch 142/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1643 - mae: 0.1548 - val_loss: 1.5310 - val_mae: 0.8298 - lr: 0.0010
# Epoch 143/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1634 - mae: 0.1543 - val_loss: 1.5301 - val_mae: 0.8290 - lr: 0.0010
# Epoch 144/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1626 - mae: 0.1539 - val_loss: 1.5291 - val_mae: 0.8282 - lr: 0.0010
# Epoch 145/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1617 - mae: 0.1534 - val_loss: 1.5281 - val_mae: 0.8274 - lr: 0.0010
# Epoch 146/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1609 - mae: 0.1530 - val_loss: 1.5272 - val_mae: 0.8266 - lr: 0.0010
# Epoch 147/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1601 - mae: 0.1526 - val_loss: 1.5262 - val_mae: 0.8259 - lr: 0.0010
# Epoch 148/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1592 - mae: 0.1522 - val_loss: 1.5255 - val_mae: 0.8252 - lr: 0.0010
# Epoch 149/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1584 - mae: 0.1518 - val_loss: 1.5246 - val_mae: 0.8245 - lr: 0.0010
# Epoch 150/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1576 - mae: 0.1514 - val_loss: 1.5238 - val_mae: 0.8238 - lr: 0.0010
# Epoch 151/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1569 - mae: 0.1510 - val_loss: 1.5230 - val_mae: 0.8231 - lr: 0.0010
# Epoch 152/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1561 - mae: 0.1506 - val_loss: 1.5223 - val_mae: 0.8224 - lr: 0.0010
# Epoch 153/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1553 - mae: 0.1502 - val_loss: 1.5215 - val_mae: 0.8218 - lr: 0.0010
# Epoch 154/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1546 - mae: 0.1498 - val_loss: 1.5208 - val_mae: 0.8212 - lr: 0.0010
# Epoch 155/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1538 - mae: 0.1494 - val_loss: 1.5200 - val_mae: 0.8205 - lr: 0.0010
# Epoch 156/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1530 - mae: 0.1490 - val_loss: 1.5195 - val_mae: 0.8199 - lr: 0.0010
# Epoch 157/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1523 - mae: 0.1486 - val_loss: 1.5186 - val_mae: 0.8192 - lr: 0.0010
# Epoch 158/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1516 - mae: 0.1483 - val_loss: 1.5181 - val_mae: 0.8187 - lr: 0.0010
# Epoch 159/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1509 - mae: 0.1479 - val_loss: 1.5173 - val_mae: 0.8181 - lr: 0.0010
# Epoch 160/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1502 - mae: 0.1476 - val_loss: 1.5167 - val_mae: 0.8176 - lr: 0.0010
# Epoch 161/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1495 - mae: 0.1472 - val_loss: 1.5160 - val_mae: 0.8171 - lr: 0.0010
# Epoch 162/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1488 - mae: 0.1470 - val_loss: 1.5153 - val_mae: 0.8166 - lr: 0.0010
# Epoch 163/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1481 - mae: 0.1466 - val_loss: 1.5148 - val_mae: 0.8161 - lr: 0.0010
# Epoch 164/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1474 - mae: 0.1462 - val_loss: 1.5141 - val_mae: 0.8157 - lr: 0.0010
# Epoch 165/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1467 - mae: 0.1459 - val_loss: 1.5136 - val_mae: 0.8152 - lr: 0.0010
# Epoch 166/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1461 - mae: 0.1456 - val_loss: 1.5129 - val_mae: 0.8147 - lr: 0.0010
# Epoch 167/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1454 - mae: 0.1453 - val_loss: 1.5124 - val_mae: 0.8143 - lr: 0.0010
# Epoch 168/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1448 - mae: 0.1450 - val_loss: 1.5116 - val_mae: 0.8138 - lr: 0.0010
# Epoch 169/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1441 - mae: 0.1447 - val_loss: 1.5112 - val_mae: 0.8135 - lr: 0.0010
# Epoch 170/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1435 - mae: 0.1443 - val_loss: 1.5106 - val_mae: 0.8130 - lr: 0.0010
# Epoch 171/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1428 - mae: 0.1440 - val_loss: 1.5100 - val_mae: 0.8125 - lr: 0.0010
# Epoch 172/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1422 - mae: 0.1437 - val_loss: 1.5095 - val_mae: 0.8121 - lr: 0.0010
# Epoch 173/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1416 - mae: 0.1434 - val_loss: 1.5089 - val_mae: 0.8116 - lr: 0.0010
# Epoch 174/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1410 - mae: 0.1431 - val_loss: 1.5085 - val_mae: 0.8113 - lr: 0.0010
# Epoch 175/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1404 - mae: 0.1428 - val_loss: 1.5079 - val_mae: 0.8108 - lr: 0.0010
# Epoch 176/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1398 - mae: 0.1426 - val_loss: 1.5075 - val_mae: 0.8106 - lr: 0.0010
# Epoch 177/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1392 - mae: 0.1423 - val_loss: 1.5069 - val_mae: 0.8102 - lr: 0.0010
# Epoch 178/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1386 - mae: 0.1420 - val_loss: 1.5065 - val_mae: 0.8099 - lr: 0.0010
# Epoch 179/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1380 - mae: 0.1417 - val_loss: 1.5060 - val_mae: 0.8094 - lr: 0.0010
# Epoch 180/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1374 - mae: 0.1415 - val_loss: 1.5056 - val_mae: 0.8091 - lr: 0.0010
# Epoch 181/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1368 - mae: 0.1411 - val_loss: 1.5052 - val_mae: 0.8087 - lr: 0.0010
# Epoch 182/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1363 - mae: 0.1408 - val_loss: 1.5046 - val_mae: 0.8083 - lr: 0.0010
# Epoch 183/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1357 - mae: 0.1405 - val_loss: 1.5041 - val_mae: 0.8080 - lr: 0.0010
# Epoch 184/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1351 - mae: 0.1403 - val_loss: 1.5036 - val_mae: 0.8076 - lr: 0.0010
# Epoch 185/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1346 - mae: 0.1401 - val_loss: 1.5033 - val_mae: 0.8074 - lr: 0.0010
# Epoch 186/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1341 - mae: 0.1399 - val_loss: 1.5027 - val_mae: 0.8071 - lr: 0.0010
# Epoch 187/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1335 - mae: 0.1396 - val_loss: 1.5024 - val_mae: 0.8068 - lr: 0.0010
# Epoch 188/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1330 - mae: 0.1393 - val_loss: 1.5018 - val_mae: 0.8064 - lr: 0.0010
# Epoch 189/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1324 - mae: 0.1390 - val_loss: 1.5014 - val_mae: 0.8061 - lr: 0.0010
# Epoch 190/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1319 - mae: 0.1388 - val_loss: 1.5010 - val_mae: 0.8058 - lr: 0.0010
# Epoch 191/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1314 - mae: 0.1385 - val_loss: 1.5006 - val_mae: 0.8055 - lr: 0.0010
# Epoch 192/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1308 - mae: 0.1383 - val_loss: 1.5003 - val_mae: 0.8052 - lr: 0.0010
# Epoch 193/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1303 - mae: 0.1380 - val_loss: 1.4997 - val_mae: 0.8048 - lr: 0.0010
# Epoch 194/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1298 - mae: 0.1378 - val_loss: 1.4994 - val_mae: 0.8046 - lr: 0.0010
# Epoch 195/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1293 - mae: 0.1375 - val_loss: 1.4990 - val_mae: 0.8043 - lr: 0.0010
# Epoch 196/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1288 - mae: 0.1373 - val_loss: 1.4987 - val_mae: 0.8041 - lr: 0.0010
# Epoch 197/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1283 - mae: 0.1370 - val_loss: 1.4983 - val_mae: 0.8038 - lr: 0.0010
# Epoch 198/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1278 - mae: 0.1369 - val_loss: 1.4978 - val_mae: 0.8035 - lr: 0.0010
# Epoch 199/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1274 - mae: 0.1367 - val_loss: 1.4975 - val_mae: 0.8033 - lr: 0.0010
# Epoch 200/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1268 - mae: 0.1364 - val_loss: 1.4970 - val_mae: 0.8029 - lr: 0.0010
# Epoch 201/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1264 - mae: 0.1363 - val_loss: 1.4966 - val_mae: 0.8028 - lr: 0.0010
# Epoch 202/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1259 - mae: 0.1361 - val_loss: 1.4962 - val_mae: 0.8025 - lr: 0.0010
# Epoch 203/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1255 - mae: 0.1358 - val_loss: 1.4959 - val_mae: 0.8023 - lr: 0.0010
# Epoch 204/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1250 - mae: 0.1355 - val_loss: 1.4956 - val_mae: 0.8021 - lr: 0.0010
# Epoch 205/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1245 - mae: 0.1354 - val_loss: 1.4951 - val_mae: 0.8019 - lr: 0.0010
# Epoch 206/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1241 - mae: 0.1353 - val_loss: 1.4948 - val_mae: 0.8016 - lr: 0.0010
# Epoch 207/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1236 - mae: 0.1350 - val_loss: 1.4944 - val_mae: 0.8014 - lr: 0.0010
# Epoch 208/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1232 - mae: 0.1348 - val_loss: 1.4941 - val_mae: 0.8012 - lr: 0.0010
# Epoch 209/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1227 - mae: 0.1346 - val_loss: 1.4937 - val_mae: 0.8009 - lr: 0.0010
# Epoch 210/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1222 - mae: 0.1344 - val_loss: 1.4934 - val_mae: 0.8008 - lr: 0.0010
# Epoch 211/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1218 - mae: 0.1342 - val_loss: 1.4929 - val_mae: 0.8005 - lr: 0.0010
# Epoch 212/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1214 - mae: 0.1340 - val_loss: 1.4927 - val_mae: 0.8004 - lr: 0.0010
# Epoch 213/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1209 - mae: 0.1338 - val_loss: 1.4922 - val_mae: 0.8001 - lr: 0.0010
# Epoch 214/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1205 - mae: 0.1336 - val_loss: 1.4920 - val_mae: 0.7999 - lr: 0.0010
# Epoch 215/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1201 - mae: 0.1334 - val_loss: 1.4916 - val_mae: 0.7997 - lr: 0.0010
# Epoch 216/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1197 - mae: 0.1332 - val_loss: 1.4915 - val_mae: 0.7995 - lr: 0.0010
# Epoch 217/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1193 - mae: 0.1331 - val_loss: 1.4911 - val_mae: 0.7993 - lr: 0.0010
# Epoch 218/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1188 - mae: 0.1328 - val_loss: 1.4908 - val_mae: 0.7990 - lr: 0.0010
# Epoch 219/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1184 - mae: 0.1326 - val_loss: 1.4906 - val_mae: 0.7987 - lr: 0.0010
# Epoch 220/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1180 - mae: 0.1323 - val_loss: 1.4902 - val_mae: 0.7984 - lr: 0.0010
# Epoch 221/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1176 - mae: 0.1322 - val_loss: 1.4898 - val_mae: 0.7982 - lr: 0.0010
# Epoch 222/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1172 - mae: 0.1320 - val_loss: 1.4896 - val_mae: 0.7981 - lr: 0.0010
# Epoch 223/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1168 - mae: 0.1318 - val_loss: 1.4893 - val_mae: 0.7979 - lr: 0.0010
# Epoch 224/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1164 - mae: 0.1316 - val_loss: 1.4888 - val_mae: 0.7976 - lr: 0.0010
# Epoch 225/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1160 - mae: 0.1315 - val_loss: 1.4887 - val_mae: 0.7976 - lr: 0.0010
# Epoch 226/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1156 - mae: 0.1312 - val_loss: 1.4883 - val_mae: 0.7973 - lr: 0.0010
# Epoch 227/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1153 - mae: 0.1312 - val_loss: 1.4880 - val_mae: 0.7972 - lr: 0.0010
# Epoch 228/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1149 - mae: 0.1310 - val_loss: 1.4877 - val_mae: 0.7970 - lr: 0.0010
# Epoch 229/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1145 - mae: 0.1308 - val_loss: 1.4875 - val_mae: 0.7968 - lr: 0.0010
# Epoch 230/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1141 - mae: 0.1306 - val_loss: 1.4873 - val_mae: 0.7965 - lr: 0.0010
# Epoch 231/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1137 - mae: 0.1305 - val_loss: 1.4868 - val_mae: 0.7963 - lr: 0.0010
# Epoch 232/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1134 - mae: 0.1303 - val_loss: 1.4868 - val_mae: 0.7962 - lr: 0.0010
# Epoch 233/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1130 - mae: 0.1301 - val_loss: 1.4865 - val_mae: 0.7960 - lr: 0.0010
# Epoch 234/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1126 - mae: 0.1300 - val_loss: 1.4862 - val_mae: 0.7959 - lr: 0.0010
# Epoch 235/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1123 - mae: 0.1298 - val_loss: 1.4860 - val_mae: 0.7957 - lr: 0.0010
# Epoch 236/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1119 - mae: 0.1296 - val_loss: 1.4857 - val_mae: 0.7955 - lr: 0.0010
# Epoch 237/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1116 - mae: 0.1295 - val_loss: 1.4855 - val_mae: 0.7953 - lr: 0.0010
# Epoch 238/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1112 - mae: 0.1293 - val_loss: 1.4851 - val_mae: 0.7951 - lr: 0.0010
# Epoch 239/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1108 - mae: 0.1291 - val_loss: 1.4848 - val_mae: 0.7950 - lr: 0.0010
# Epoch 240/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1105 - mae: 0.1290 - val_loss: 1.4845 - val_mae: 0.7948 - lr: 0.0010
# Epoch 241/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1101 - mae: 0.1288 - val_loss: 1.4843 - val_mae: 0.7947 - lr: 0.0010
# Epoch 242/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1098 - mae: 0.1287 - val_loss: 1.4840 - val_mae: 0.7946 - lr: 0.0010
# Epoch 243/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1094 - mae: 0.1284 - val_loss: 1.4841 - val_mae: 0.7945 - lr: 0.0010
# Epoch 244/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1091 - mae: 0.1284 - val_loss: 1.4835 - val_mae: 0.7941 - lr: 0.0010
# Epoch 245/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1088 - mae: 0.1283 - val_loss: 1.4835 - val_mae: 0.7941 - lr: 0.0010
# Epoch 246/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1085 - mae: 0.1282 - val_loss: 1.4830 - val_mae: 0.7939 - lr: 0.0010
# Epoch 247/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1081 - mae: 0.1279 - val_loss: 1.4829 - val_mae: 0.7937 - lr: 0.0010
# Epoch 248/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1078 - mae: 0.1278 - val_loss: 1.4826 - val_mae: 0.7936 - lr: 0.0010
# Epoch 249/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1075 - mae: 0.1277 - val_loss: 1.4824 - val_mae: 0.7934 - lr: 0.0010
# Epoch 250/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1071 - mae: 0.1276 - val_loss: 1.4822 - val_mae: 0.7932 - lr: 0.0010
# Epoch 251/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1068 - mae: 0.1274 - val_loss: 1.4820 - val_mae: 0.7932 - lr: 0.0010
# Epoch 252/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1065 - mae: 0.1273 - val_loss: 1.4815 - val_mae: 0.7930 - lr: 0.0010
# Epoch 253/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1063 - mae: 0.1273 - val_loss: 1.4814 - val_mae: 0.7929 - lr: 0.0010
# Epoch 254/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1059 - mae: 0.1270 - val_loss: 1.4812 - val_mae: 0.7927 - lr: 0.0010
# Epoch 255/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1056 - mae: 0.1269 - val_loss: 1.4808 - val_mae: 0.7925 - lr: 0.0010
# Epoch 256/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1052 - mae: 0.1267 - val_loss: 1.4807 - val_mae: 0.7925 - lr: 0.0010
# Epoch 257/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1049 - mae: 0.1266 - val_loss: 1.4804 - val_mae: 0.7923 - lr: 0.0010
# Epoch 258/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1046 - mae: 0.1265 - val_loss: 1.4801 - val_mae: 0.7921 - lr: 0.0010
# Epoch 259/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1043 - mae: 0.1262 - val_loss: 1.4802 - val_mae: 0.7920 - lr: 0.0010
# Epoch 260/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1040 - mae: 0.1260 - val_loss: 1.4798 - val_mae: 0.7917 - lr: 0.0010
# Epoch 261/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1037 - mae: 0.1260 - val_loss: 1.4796 - val_mae: 0.7916 - lr: 0.0010
# Epoch 262/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1034 - mae: 0.1259 - val_loss: 1.4793 - val_mae: 0.7915 - lr: 0.0010
# Epoch 263/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1031 - mae: 0.1258 - val_loss: 1.4791 - val_mae: 0.7914 - lr: 0.0010
# Epoch 264/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1029 - mae: 0.1258 - val_loss: 1.4788 - val_mae: 0.7912 - lr: 0.0010
# Epoch 265/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1026 - mae: 0.1256 - val_loss: 1.4787 - val_mae: 0.7912 - lr: 0.0010
# Epoch 266/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1023 - mae: 0.1255 - val_loss: 1.4783 - val_mae: 0.7910 - lr: 0.0010
# Epoch 267/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1020 - mae: 0.1253 - val_loss: 1.4783 - val_mae: 0.7909 - lr: 0.0010
# Epoch 268/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1017 - mae: 0.1252 - val_loss: 1.4780 - val_mae: 0.7907 - lr: 0.0010
# Epoch 269/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1014 - mae: 0.1250 - val_loss: 1.4779 - val_mae: 0.7907 - lr: 0.0010
# Epoch 270/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1011 - mae: 0.1249 - val_loss: 1.4776 - val_mae: 0.7903 - lr: 0.0010
# Epoch 271/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1009 - mae: 0.1248 - val_loss: 1.4776 - val_mae: 0.7903 - lr: 0.0010
# Epoch 272/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1005 - mae: 0.1246 - val_loss: 1.4772 - val_mae: 0.7901 - lr: 0.0010
# Epoch 273/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1003 - mae: 0.1245 - val_loss: 1.4770 - val_mae: 0.7900 - lr: 0.0010
# Epoch 274/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.1000 - mae: 0.1244 - val_loss: 1.4769 - val_mae: 0.7899 - lr: 0.0010
# Epoch 275/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0998 - mae: 0.1243 - val_loss: 1.4766 - val_mae: 0.7898 - lr: 0.0010
# Epoch 276/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0995 - mae: 0.1242 - val_loss: 1.4765 - val_mae: 0.7896 - lr: 0.0010
# Epoch 277/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0992 - mae: 0.1241 - val_loss: 1.4762 - val_mae: 0.7895 - lr: 0.0010
# Epoch 278/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0989 - mae: 0.1239 - val_loss: 1.4762 - val_mae: 0.7893 - lr: 0.0010
# Epoch 279/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0987 - mae: 0.1238 - val_loss: 1.4759 - val_mae: 0.7892 - lr: 0.0010
# Epoch 280/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0984 - mae: 0.1236 - val_loss: 1.4758 - val_mae: 0.7891 - lr: 0.0010
# Epoch 281/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0981 - mae: 0.1235 - val_loss: 1.4754 - val_mae: 0.7889 - lr: 0.0010
# Epoch 282/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0979 - mae: 0.1234 - val_loss: 1.4753 - val_mae: 0.7888 - lr: 0.0010
# Epoch 283/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0976 - mae: 0.1233 - val_loss: 1.4751 - val_mae: 0.7887 - lr: 0.0010
# Epoch 284/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0973 - mae: 0.1232 - val_loss: 1.4752 - val_mae: 0.7886 - lr: 0.0010
# Epoch 285/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0971 - mae: 0.1231 - val_loss: 1.4748 - val_mae: 0.7884 - lr: 0.0010
# Epoch 286/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0968 - mae: 0.1230 - val_loss: 1.4748 - val_mae: 0.7883 - lr: 0.0010
# Epoch 287/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0966 - mae: 0.1229 - val_loss: 1.4744 - val_mae: 0.7881 - lr: 0.0010
# Epoch 288/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0963 - mae: 0.1228 - val_loss: 1.4745 - val_mae: 0.7881 - lr: 0.0010
# Epoch 289/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0961 - mae: 0.1227 - val_loss: 1.4742 - val_mae: 0.7880 - lr: 0.0010
# Epoch 290/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0958 - mae: 0.1225 - val_loss: 1.4741 - val_mae: 0.7879 - lr: 0.0010
# Epoch 291/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0956 - mae: 0.1224 - val_loss: 1.4737 - val_mae: 0.7877 - lr: 0.0010
# Epoch 292/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0953 - mae: 0.1223 - val_loss: 1.4738 - val_mae: 0.7876 - lr: 0.0010
# Epoch 293/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0951 - mae: 0.1222 - val_loss: 1.4735 - val_mae: 0.7874 - lr: 0.0010
# Epoch 294/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0949 - mae: 0.1221 - val_loss: 1.4734 - val_mae: 0.7873 - lr: 0.0010
# Epoch 295/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0946 - mae: 0.1218 - val_loss: 1.4733 - val_mae: 0.7872 - lr: 0.0010
# Epoch 296/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0944 - mae: 0.1218 - val_loss: 1.4731 - val_mae: 0.7871 - lr: 0.0010
# Epoch 297/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0942 - mae: 0.1218 - val_loss: 1.4729 - val_mae: 0.7870 - lr: 0.0010
# Epoch 298/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0939 - mae: 0.1218 - val_loss: 1.4726 - val_mae: 0.7868 - lr: 0.0010
# Epoch 299/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0937 - mae: 0.1216 - val_loss: 1.4726 - val_mae: 0.7867 - lr: 0.0010
# Epoch 300/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0935 - mae: 0.1215 - val_loss: 1.4723 - val_mae: 0.7866 - lr: 0.0010
# Epoch 301/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0932 - mae: 0.1214 - val_loss: 1.4723 - val_mae: 0.7866 - lr: 0.0010
# Epoch 302/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0930 - mae: 0.1213 - val_loss: 1.4720 - val_mae: 0.7864 - lr: 0.0010
# Epoch 303/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0928 - mae: 0.1213 - val_loss: 1.4720 - val_mae: 0.7864 - lr: 0.0010
# Epoch 304/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0925 - mae: 0.1211 - val_loss: 1.4717 - val_mae: 0.7861 - lr: 0.0010
# Epoch 305/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0923 - mae: 0.1210 - val_loss: 1.4715 - val_mae: 0.7861 - lr: 0.0010
# Epoch 306/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0921 - mae: 0.1209 - val_loss: 1.4715 - val_mae: 0.7860 - lr: 0.0010
# Epoch 307/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0919 - mae: 0.1209 - val_loss: 1.4712 - val_mae: 0.7860 - lr: 0.0010
# Epoch 308/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0916 - mae: 0.1207 - val_loss: 1.4710 - val_mae: 0.7858 - lr: 0.0010
# Epoch 309/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0914 - mae: 0.1206 - val_loss: 1.4711 - val_mae: 0.7858 - lr: 0.0010
# Epoch 310/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0912 - mae: 0.1206 - val_loss: 1.4707 - val_mae: 0.7856 - lr: 0.0010
# Epoch 311/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0910 - mae: 0.1204 - val_loss: 1.4707 - val_mae: 0.7855 - lr: 0.0010
# Epoch 312/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0908 - mae: 0.1204 - val_loss: 1.4705 - val_mae: 0.7854 - lr: 0.0010
# Epoch 313/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0905 - mae: 0.1202 - val_loss: 1.4706 - val_mae: 0.7853 - lr: 0.0010
# Epoch 314/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0903 - mae: 0.1201 - val_loss: 1.4701 - val_mae: 0.7851 - lr: 0.0010
# Epoch 315/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0900 - mae: 0.1200 - val_loss: 1.4702 - val_mae: 0.7850 - lr: 0.0010
# Epoch 316/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0898 - mae: 0.1198 - val_loss: 1.4698 - val_mae: 0.7848 - lr: 0.0010
# Epoch 317/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0895 - mae: 0.1197 - val_loss: 1.4699 - val_mae: 0.7848 - lr: 0.0010
# Epoch 318/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0893 - mae: 0.1196 - val_loss: 1.4696 - val_mae: 0.7847 - lr: 0.0010
# Epoch 319/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0891 - mae: 0.1195 - val_loss: 1.4696 - val_mae: 0.7846 - lr: 0.0010
# Epoch 320/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0889 - mae: 0.1195 - val_loss: 1.4696 - val_mae: 0.7845 - lr: 0.0010
# Epoch 321/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0887 - mae: 0.1194 - val_loss: 1.4694 - val_mae: 0.7843 - lr: 0.0010
# Epoch 322/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0885 - mae: 0.1192 - val_loss: 1.4693 - val_mae: 0.7842 - lr: 0.0010
# Epoch 323/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0883 - mae: 0.1191 - val_loss: 1.4692 - val_mae: 0.7842 - lr: 0.0010
# Epoch 324/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0881 - mae: 0.1190 - val_loss: 1.4691 - val_mae: 0.7839 - lr: 0.0010
# Epoch 325/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0879 - mae: 0.1190 - val_loss: 1.4689 - val_mae: 0.7839 - lr: 0.0010
# Epoch 326/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0877 - mae: 0.1189 - val_loss: 1.4688 - val_mae: 0.7839 - lr: 0.0010
# Epoch 327/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0875 - mae: 0.1188 - val_loss: 1.4688 - val_mae: 0.7838 - lr: 0.0010
# Epoch 328/500
# ...
# Epoch 393/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0765 - mae: 0.1139 - val_loss: 1.4625 - val_mae: 0.7778 - lr: 0.0010
# Epoch 394/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0763 - mae: 0.1139 - val_loss: 1.4623 - val_mae: 0.7777 - lr: 0.0010
# Epoch 395/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0762 - mae: 0.1138 - val_loss: 1.4624 - val_mae: 0.7777 - lr: 0.0010
# Epoch 396/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0760 - mae: 0.1137 - val_loss: 1.4619 - val_mae: 0.7774 - lr: 0.0010
# Epoch 397/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0759 - mae: 0.1138 - val_loss: 1.4621 - val_mae: 0.7774 - lr: 0.0010
# Epoch 398/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0758 - mae: 0.1137 - val_loss: 1.4620 - val_mae: 0.7774 - lr: 0.0010
# Epoch 399/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0756 - mae: 0.1135 - val_loss: 1.4618 - val_mae: 0.7773 - lr: 0.0010
# Epoch 400/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0755 - mae: 0.1135 - val_loss: 1.4620 - val_mae: 0.7772 - lr: 0.0010
# Epoch 401/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0754 - mae: 0.1135 - val_loss: 1.4619 - val_mae: 0.7772 - lr: 0.0010
# Epoch 402/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0753 - mae: 0.1134 - val_loss: 1.4618 - val_mae: 0.7771 - lr: 0.0010
# Epoch 403/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0751 - mae: 0.1134 - val_loss: 1.4617 - val_mae: 0.7771 - lr: 0.0010
# Epoch 404/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0750 - mae: 0.1134 - val_loss: 1.4615 - val_mae: 0.7770 - lr: 0.0010
# Epoch 405/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0749 - mae: 0.1133 - val_loss: 1.4615 - val_mae: 0.7770 - lr: 0.0010
# Epoch 406/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0748 - mae: 0.1133 - val_loss: 1.4614 - val_mae: 0.7770 - lr: 0.0010
# Epoch 407/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0746 - mae: 0.1132 - val_loss: 1.4612 - val_mae: 0.7768 - lr: 0.0010
# Epoch 408/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0745 - mae: 0.1131 - val_loss: 1.4615 - val_mae: 0.7769 - lr: 0.0010
# Epoch 409/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0743 - mae: 0.1130 - val_loss: 1.4612 - val_mae: 0.7767 - lr: 0.0010
# Epoch 410/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0742 - mae: 0.1130 - val_loss: 1.4612 - val_mae: 0.7767 - lr: 0.0010
# Epoch 411/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0741 - mae: 0.1129 - val_loss: 1.4612 - val_mae: 0.7766 - lr: 0.0010
# Epoch 412/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0740 - mae: 0.1129 - val_loss: 1.4611 - val_mae: 0.7765 - lr: 0.0010
# Epoch 413/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0738 - mae: 0.1129 - val_loss: 1.4610 - val_mae: 0.7765 - lr: 0.0010
# Epoch 414/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0737 - mae: 0.1128 - val_loss: 1.4610 - val_mae: 0.7764 - lr: 0.0010
# Epoch 415/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0736 - mae: 0.1128 - val_loss: 1.4610 - val_mae: 0.7763 - lr: 0.0010
# Epoch 416/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0734 - mae: 0.1127 - val_loss: 1.4608 - val_mae: 0.7762 - lr: 0.0010
# Epoch 417/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0734 - mae: 0.1126 - val_loss: 1.4609 - val_mae: 0.7762 - lr: 0.0010
# Epoch 418/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0732 - mae: 0.1125 - val_loss: 1.4607 - val_mae: 0.7761 - lr: 0.0010
# Epoch 419/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0731 - mae: 0.1125 - val_loss: 1.4609 - val_mae: 0.7760 - lr: 0.0010
# Epoch 420/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0730 - mae: 0.1124 - val_loss: 1.4607 - val_mae: 0.7760 - lr: 0.0010
# Epoch 421/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0728 - mae: 0.1123 - val_loss: 1.4608 - val_mae: 0.7759 - lr: 0.0010
# Epoch 422/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0727 - mae: 0.1123 - val_loss: 1.4605 - val_mae: 0.7758 - lr: 0.0010
# Epoch 423/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0726 - mae: 0.1123 - val_loss: 1.4607 - val_mae: 0.7758 - lr: 0.0010
# Epoch 424/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0725 - mae: 0.1123 - val_loss: 1.4605 - val_mae: 0.7757 - lr: 0.0010
# Epoch 425/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0723 - mae: 0.1122 - val_loss: 1.4603 - val_mae: 0.7758 - lr: 0.0010
# Epoch 426/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0722 - mae: 0.1121 - val_loss: 1.4602 - val_mae: 0.7756 - lr: 0.0010
# Epoch 427/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0721 - mae: 0.1121 - val_loss: 1.4601 - val_mae: 0.7755 - lr: 0.0010
# Epoch 428/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0719 - mae: 0.1119 - val_loss: 1.4602 - val_mae: 0.7754 - lr: 0.0010
# Epoch 429/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0718 - mae: 0.1119 - val_loss: 1.4601 - val_mae: 0.7752 - lr: 0.0010
# Epoch 430/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0717 - mae: 0.1119 - val_loss: 1.4601 - val_mae: 0.7753 - lr: 0.0010
# Epoch 431/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0716 - mae: 0.1118 - val_loss: 1.4602 - val_mae: 0.7752 - lr: 0.0010
# Epoch 432/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0715 - mae: 0.1118 - val_loss: 1.4599 - val_mae: 0.7752 - lr: 0.0010
# Epoch 433/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0714 - mae: 0.1118 - val_loss: 1.4600 - val_mae: 0.7752 - lr: 0.0010
# Epoch 434/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0713 - mae: 0.1118 - val_loss: 1.4598 - val_mae: 0.7751 - lr: 0.0010
# Epoch 435/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0712 - mae: 0.1118 - val_loss: 1.4598 - val_mae: 0.7751 - lr: 0.0010
# Epoch 436/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0711 - mae: 0.1116 - val_loss: 1.4594 - val_mae: 0.7750 - lr: 0.0010
# Epoch 437/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0709 - mae: 0.1116 - val_loss: 1.4597 - val_mae: 0.7749 - lr: 0.0010
# Epoch 438/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0708 - mae: 0.1115 - val_loss: 1.4597 - val_mae: 0.7748 - lr: 0.0010
# Epoch 439/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0707 - mae: 0.1114 - val_loss: 1.4597 - val_mae: 0.7747 - lr: 0.0010
# Epoch 440/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0706 - mae: 0.1114 - val_loss: 1.4595 - val_mae: 0.7747 - lr: 0.0010
# Epoch 441/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0705 - mae: 0.1114 - val_loss: 1.4596 - val_mae: 0.7747 - lr: 0.0010
# Epoch 442/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0704 - mae: 0.1114 - val_loss: 1.4594 - val_mae: 0.7746 - lr: 0.0010
# Epoch 443/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0703 - mae: 0.1113 - val_loss: 1.4596 - val_mae: 0.7746 - lr: 0.0010
# Epoch 444/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0702 - mae: 0.1112 - val_loss: 1.4594 - val_mae: 0.7744 - lr: 0.0010
# Epoch 445/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0701 - mae: 0.1111 - val_loss: 1.4594 - val_mae: 0.7744 - lr: 0.0010
# Epoch 446/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0699 - mae: 0.1110 - val_loss: 1.4593 - val_mae: 0.7743 - lr: 0.0010
# Epoch 447/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0698 - mae: 0.1110 - val_loss: 1.4592 - val_mae: 0.7742 - lr: 0.0010
# Epoch 448/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0697 - mae: 0.1110 - val_loss: 1.4593 - val_mae: 0.7741 - lr: 0.0010
# Epoch 449/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0696 - mae: 0.1109 - val_loss: 1.4590 - val_mae: 0.7740 - lr: 0.0010
# Epoch 450/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0695 - mae: 0.1108 - val_loss: 1.4591 - val_mae: 0.7739 - lr: 0.0010
# Epoch 451/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0693 - mae: 0.1107 - val_loss: 1.4591 - val_mae: 0.7739 - lr: 0.0010
# Epoch 452/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0692 - mae: 0.1107 - val_loss: 1.4591 - val_mae: 0.7739 - lr: 0.0010
# Epoch 453/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0692 - mae: 0.1108 - val_loss: 1.4589 - val_mae: 0.7738 - lr: 0.0010
# Epoch 454/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0691 - mae: 0.1107 - val_loss: 1.4590 - val_mae: 0.7739 - lr: 0.0010
# Epoch 455/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0689 - mae: 0.1106 - val_loss: 1.4588 - val_mae: 0.7738 - lr: 0.0010
# Epoch 456/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0689 - mae: 0.1107 - val_loss: 1.4588 - val_mae: 0.7737 - lr: 0.0010
# Epoch 457/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0688 - mae: 0.1107 - val_loss: 1.4588 - val_mae: 0.7738 - lr: 0.0010
# Epoch 458/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0686 - mae: 0.1105 - val_loss: 1.4586 - val_mae: 0.7736 - lr: 0.0010
# Epoch 459/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0685 - mae: 0.1105 - val_loss: 1.4586 - val_mae: 0.7736 - lr: 0.0010
# Epoch 460/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0685 - mae: 0.1105 - val_loss: 1.4586 - val_mae: 0.7736 - lr: 0.0010
# Epoch 461/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0683 - mae: 0.1104 - val_loss: 1.4586 - val_mae: 0.7735 - lr: 0.0010
# Epoch 462/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0682 - mae: 0.1103 - val_loss: 1.4585 - val_mae: 0.7734 - lr: 0.0010
# Epoch 463/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0681 - mae: 0.1102 - val_loss: 1.4585 - val_mae: 0.7734 - lr: 0.0010
# Epoch 464/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0680 - mae: 0.1101 - val_loss: 1.4587 - val_mae: 0.7733 - lr: 0.0010
# Epoch 465/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0679 - mae: 0.1101 - val_loss: 1.4585 - val_mae: 0.7732 - lr: 0.0010
# Epoch 466/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0678 - mae: 0.1101 - val_loss: 1.4585 - val_mae: 0.7731 - lr: 0.0010
# Epoch 467/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0677 - mae: 0.1101 - val_loss: 1.4586 - val_mae: 0.7731 - lr: 0.0010
# Epoch 468/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0676 - mae: 0.1100 - val_loss: 1.4584 - val_mae: 0.7730 - lr: 0.0010
# Epoch 469/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0676 - mae: 0.1101 - val_loss: 1.4584 - val_mae: 0.7730 - lr: 0.0010
# Epoch 470/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0674 - mae: 0.1099 - val_loss: 1.4584 - val_mae: 0.7729 - lr: 0.0010
# Epoch 471/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0673 - mae: 0.1099 - val_loss: 1.4584 - val_mae: 0.7729 - lr: 0.0010
# Epoch 472/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0672 - mae: 0.1099 - val_loss: 1.4584 - val_mae: 0.7729 - lr: 0.0010
# Epoch 473/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0671 - mae: 0.1098 - val_loss: 1.4584 - val_mae: 0.7729 - lr: 0.0010
# Epoch 474/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0670 - mae: 0.1098 - val_loss: 1.4582 - val_mae: 0.7727 - lr: 0.0010
# Epoch 475/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0670 - mae: 0.1098 - val_loss: 1.4583 - val_mae: 0.7728 - lr: 0.0010
# Epoch 476/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0668 - mae: 0.1097 - val_loss: 1.4581 - val_mae: 0.7727 - lr: 0.0010
# Epoch 477/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0667 - mae: 0.1097 - val_loss: 1.4582 - val_mae: 0.7727 - lr: 0.0010
# Epoch 478/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0667 - mae: 0.1096 - val_loss: 1.4581 - val_mae: 0.7726 - lr: 0.0010
# Epoch 479/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0665 - mae: 0.1095 - val_loss: 1.4580 - val_mae: 0.7725 - lr: 0.0010
# Epoch 480/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0664 - mae: 0.1095 - val_loss: 1.4579 - val_mae: 0.7725 - lr: 0.0010
# Epoch 481/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0663 - mae: 0.1095 - val_loss: 1.4579 - val_mae: 0.7724 - lr: 0.0010
# Epoch 482/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0663 - mae: 0.1096 - val_loss: 1.4577 - val_mae: 0.7726 - lr: 0.0010
# Epoch 483/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0662 - mae: 0.1095 - val_loss: 1.4578 - val_mae: 0.7725 - lr: 0.0010
# Epoch 484/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0661 - mae: 0.1095 - val_loss: 1.4579 - val_mae: 0.7725 - lr: 0.0010
# Epoch 485/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0660 - mae: 0.1093 - val_loss: 1.4579 - val_mae: 0.7725 - lr: 0.0010
# Epoch 486/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0659 - mae: 0.1093 - val_loss: 1.4579 - val_mae: 0.7723 - lr: 0.0010
# Epoch 487/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0658 - mae: 0.1093 - val_loss: 1.4580 - val_mae: 0.7723 - lr: 0.0010
# Epoch 488/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0657 - mae: 0.1093 - val_loss: 1.4580 - val_mae: 0.7723 - lr: 0.0010
# Epoch 489/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0656 - mae: 0.1092 - val_loss: 1.4579 - val_mae: 0.7721 - lr: 0.0010
# Epoch 490/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0656 - mae: 0.1092 - val_loss: 1.4579 - val_mae: 0.7722 - lr: 0.0010
# Epoch 491/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0655 - mae: 0.1091 - val_loss: 1.4579 - val_mae: 0.7721 - lr: 0.0010
# Epoch 492/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0654 - mae: 0.1091 - val_loss: 1.4578 - val_mae: 0.7720 - lr: 0.0010
# Epoch 493/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0652 - mae: 0.1090 - val_loss: 1.4579 - val_mae: 0.7719 - lr: 0.0010
# Epoch 494/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0651 - mae: 0.1089 - val_loss: 1.4578 - val_mae: 0.7718 - lr: 0.0010
# Epoch 495/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0650 - mae: 0.1089 - val_loss: 1.4577 - val_mae: 0.7719 - lr: 0.0010
# Epoch 496/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0649 - mae: 0.1088 - val_loss: 1.4576 - val_mae: 0.7718 - lr: 0.0010
# Epoch 497/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0649 - mae: 0.1088 - val_loss: 1.4576 - val_mae: 0.7718 - lr: 0.0010
# Epoch 498/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0648 - mae: 0.1088 - val_loss: 1.4577 - val_mae: 0.7718 - lr: 0.0010
# Epoch 499/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0647 - mae: 0.1087 - val_loss: 1.4577 - val_mae: 0.7717 - lr: 0.0010
# Epoch 500/500
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0646 - mae: 0.1086 - val_loss: 1.4576 - val_mae: 0.7717 - lr: 0.0010
# CPU times: user 10min 18s, sys: 34.9 s, total: 10min 53s
# Wall time: 6min 12s

# %%
y_true = ratings_test
predictions = model.predict([user_ids_test, item_ids_test])
# Out:
# 30004/30004 [==============================] - 41s 1ms/step

# %%
# Evaluar el modelo con el conjunto de prueba
loss, mae = model.evaluate([user_ids_test, item_ids_test], ratings_test)
print(f'Test Loss: {loss:.4f}')
print(f'Test MAE: {mae:.4f}')
# Out:
# 30004/30004 [==============================] - 78s 3ms/step - loss: 1.4651 - mae: 0.7738
# Test Loss: 1.4651
# Test MAE: 0.7738

# %%
# MSE
mse = mean_squared_error(y_true, predictions)
print(f"MSE: {mse:.4f}")

# RMSE
rmse = np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

# MAE
mae = mean_absolute_error(y_true, predictions)
print(f"MAE: {mae:.4f}")

# MAPE (Mean Absolute Percentage Error)
mape = np.mean(np.abs((y_true - predictions.flatten()) / y_true)) * 100
print(f"MAPE: {mape:.2f}%")
# Out:
# MSE: 1.4180
# RMSE: 1.1908
# MAE: 0.7738
# MAPE: 35.23%

# %% [markdown]
# # Recomedanción

# %%
# Seleccionar un usuario al azar del conjunto de prueba
usuario_id_test_encoded = random.choice(user_ids_test)

# Decodificar el ID del usuario para obtener el ID original
usuario_id_test = reviewerID_encoder.inverse_transform([usuario_id_test_encoded])[0]

# Identificar los ítems que el usuario ha calificado en el conjunto de prueba
indices_usuario = np.where(user_ids_test == usuario_id_test_encoded)[0]
items_calificados_test_encoded = item_ids_test[indices_usuario]
calificaciones_reales_test = ratings_test[indices_usuario]

# Predecir las calificaciones para estos ítems
calificaciones_predichas = model.predict([np.array([usuario_id_test_encoded] * len(items_calificados_test_encoded)), items_calificados_test_encoded])

# Decodificar los ítems para obtener los ID originales
items_calificados_test = asin_encoder.inverse_transform(items_calificados_test_encoded)

# Comparar las calificaciones predichas con las reales
comparacion = list(zip(items_calificados_test, calificaciones_reales_test, calificaciones_predichas.flatten()))

# Suponiendo que 'items_calificados_test' contiene los IDs originales de los ítems
recomendaciones_df = pd.DataFrame({
    'asin': items_calificados_test,
    'Calificación Real': calificaciones_reales_test,
    'Calificación Predicha': calificaciones_predichas.flatten()
})

recomendaciones_df = recomendaciones_df.merge(sentimiento[['asin', 'cluster']], on='asin', how='left')
recomendaciones_df.rename(columns={'cluster': 'Sentimiento'}, inplace=True)

# Mostrar las recomendaciones
print(f"Recomendaciones para el usuario {usuario_id_test}:")
for index, row in recomendaciones_df.iterrows():
    print(f"Ítem: {row['asin']}, Calificación Real: {row['Calificación Real']}, Calificación Predicha: {row['Calificación Predicha']}, Sentimiento: {row['Sentimiento']}")
# Out:
# 1/1 [==============================] - 0s 28ms/step
# Recomendaciones para el usuario A2POJBI09ABW6A:
# Ítem: B002EI07E0, Calificación Real: 5.0, Calificación Predicha: 4.670485973358154, Sentimiento: Neutro

# %%
# Seleccionar un usuario al azar del conjunto de prueba
usuario_id_test_encoded = random.choice(user_ids_test)

# Decodificar el ID del usuario para obtener el ID original
usuario_id = reviewerID_encoder.inverse_transform([usuario_id_test_encoded])[0]

# Lista de todos los ítems únicos en el dataset
items_unicos = np.unique(data['asin'].values)

# Ítems que el usuario ya ha calificado
items_calificados = data[data['reviewerID_encoded'] == usuario_id_test_encoded]['asin'].tolist()

# Ítems para predecir
items_a_predecir = [item for item in items_unicos if item not in items_calificados]

# Convierte los ítems a su representación codificada
items_a_predecir_encoded = asin_encoder.transform(items_a_predecir)

# Predecir la calificación para cada ítem no calificado
predicciones = model.predict([np.array([usuario_id_test_encoded] * len(items_a_predecir_encoded)), items_a_predecir_encoded])

# Emparejar cada ítem con su predicción
items_predicciones = list(zip(items_a_predecir, predicciones.flatten()))

# Ordenar por la calificación predicha más alta
items_recomendados = sorted(items_predicciones, key=lambda x: x[1], reverse=True)

# Tomar los top N recomendaciones
top_n = 5
top_recomendaciones = items_recomendados[:top_n]

# Crear un DataFrame a partir de las recomendaciones
recomendaciones_df = pd.DataFrame(top_recomendaciones, columns=['asin', 'Calificación Predicha'])

# Unir con el DataFrame 'sentimiento' para obtener el sentimiento asociado a cada ítem
recomendaciones_df = recomendaciones_df.merge(sentimiento[['asin', 'cluster']], on='asin', how='left')

# Renombrar la columna 'cluster' a 'Sentimiento' para claridad
recomendaciones_df.rename(columns={'cluster': 'Sentimiento'}, inplace=True)

# Mostrar las recomendaciones con el sentimiento
print(f"Recomendaciones para el usuario {usuario_id}:")
for index, row in recomendaciones_df.iterrows():
    print(f"Ítem: {row['asin']}, Calificación Predicha: {row['Calificación Predicha']}, Sentimiento: {row['Sentimiento']}")
# Out:
# 4814/4814 [==============================] - 7s 1ms/step
# Recomendaciones para el usuario AVIYCG75A9WEF:
# Ítem: B00ALHISAQ, Calificación Predicha: 4.992595195770264, Sentimiento: Neutro
# Ítem: B00PQN2M70, Calificación Predicha: 4.992236614227295, Sentimiento: Positivo
# Ítem: B01CF6XQYI, Calificación Predicha: 4.988303184509277, Sentimiento: Negativo
# Ítem: B0055NELXY, Calificación Predicha: 4.985450744628906, Sentimiento: Neutro
# Ítem: B00E7T212K, Calificación Predicha: 4.9853434562683105, Sentimiento: Negativo

# %% [markdown]
# # Modelo de Filtrado Colaborativo usando Red Neuronal Multicapa con Keras:

# %% [markdown]
# Funcionamiento:
#
# Estos sistemas toman características de los ítems y/o usuarios y las pasan a través de una o varias capas de neuronas para obtener una predicción.
# Las redes neuronales son capaces de capturar interacciones no lineales entre características, lo que las hace poderosas para tareas de modelado complejas.
#
# Ventajas:
#
# Capacidad de modelar relaciones no lineales.
#
# Flexibilidad para incorporar múltiples fuentes de datos o características.
#
# Puede manejar arranques en frío al incorporar características de nuevos ítems o usuarios.
#
# Desventajas:
#
# Mayor costo computacional en comparación con los sistemas basados únicamente en embeddings.
#
# Riesgo de sobreajuste si no se tiene un conjunto de datos lo suficientemente grande.

# %% [markdown]
# Ahora el código incluye regularización en los embeddings, early stopping para detener el entrenamiento si el modelo deja de mejorar en el conjunto de validación, y reducción de la tasa de aprendizaje si el error en el conjunto de validación no mejora después de algunas épocas. Estas adiciones deberían ayudar a mejorar la capacidad de generalización del modelo.

# %%
df['user_id'] = df['reviewerID'].astype('category').cat.codes.values
df['item_id'] = df['asin'].astype('category').cat.codes.values

# Número de usuarios e ítems
n_users = df['user_id'].nunique()
n_items = df['item_id'].nunique()

# Hiperparámetros
hidden_units = [128, 64, 32]
dropout_rate = 0.2
l2_reg = 1e-6

# Arquitectura del modelo
user_input = Input(shape=[1], name='user_input')
item_input = Input(shape=[1], name='item_input')
concat = Concatenate()([user_input, item_input])
dense = concat
for units in hidden_units:
    dense = Dense(units, activation='relu', kernel_regularizer=l2(l2_reg))(dense)
    dense = Dropout(dropout_rate)(dense)

# Agregar una capa de activación sigmoid y escalar a [0, 5]
output = Dense(1, activation='sigmoid', kernel_regularizer=l2(l2_reg))(dense)  # Función de activación sigmoid
output = Lambda(lambda x: x * 5)(output)  # Escalar las predicciones al rango [0, 5]

model = Model(inputs=[user_input, item_input], outputs=output)
model.compile(optimizer=Adam(0.001), loss='mean_squared_error')

# %%
# Callbacks
early_stop = EarlyStopping(monitor='val_loss', patience=50)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=50, min_lr=1e-5)

# %%
# Datos para entrenamiento
user_data = df['user_id'].values
item_data = df['item_id'].values
rating_data = df['overall'].values

# División en entrenamiento y prueba
(user_ids_temp, user_ids_test, item_ids_temp, item_ids_test, ratings_temp, ratings_test) = train_test_split(
    user_ids, item_ids, ratings, test_size=0.2, random_state=42)

# División del conjunto de entrenamiento en entrenamiento y validación
(user_ids_train, user_ids_val, item_ids_train, item_ids_val, ratings_train, ratings_val) = train_test_split(
    user_ids_temp, item_ids_temp, ratings_temp, test_size=0.25, random_state=42)  # 0.25 x 0.8 = 0.2

# %%
# %%time
# Entrenamiento del modelo
history = model.fit([user_ids_train, item_ids_train], ratings_train,
    epochs=500,validation_data=([user_ids_val, item_ids_val], ratings_val),
    batch_size=40000,verbose=1,callbacks=[early_stop, reduce_lr])
# Out:
# Epoch 1/500
# 73/73 [==============================] - 3s 10ms/step - loss: 4.8223 - val_loss: 1.8981 - lr: 0.0010
# Epoch 2/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9255 - val_loss: 1.8981 - lr: 0.0010
# Epoch 3/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9204 - val_loss: 1.8981 - lr: 0.0010
# Epoch 4/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9176 - val_loss: 1.8981 - lr: 0.0010
# Epoch 5/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9134 - val_loss: 1.8981 - lr: 0.0010
# Epoch 6/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9115 - val_loss: 1.8981 - lr: 0.0010
# Epoch 7/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9116 - val_loss: 1.8981 - lr: 0.0010
# Epoch 8/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9116 - val_loss: 1.8981 - lr: 0.0010
# Epoch 9/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9101 - val_loss: 1.8981 - lr: 0.0010
# Epoch 10/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9096 - val_loss: 1.8981 - lr: 0.0010
# Epoch 11/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9095 - val_loss: 1.8981 - lr: 0.0010
# Epoch 12/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9096 - val_loss: 1.8981 - lr: 0.0010
# Epoch 13/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9095 - val_loss: 1.8981 - lr: 0.0010
# Epoch 14/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9095 - val_loss: 1.8981 - lr: 0.0010
# Epoch 15/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9095 - val_loss: 1.8981 - lr: 0.0010
# Epoch 16/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9096 - val_loss: 1.8981 - lr: 0.0010
# Epoch 17/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9096 - val_loss: 1.8981 - lr: 0.0010
# Epoch 18/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9095 - val_loss: 1.8981 - lr: 0.0010
# Epoch 19/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9095 - val_loss: 1.8981 - lr: 0.0010
# Epoch 20/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9093 - val_loss: 1.8981 - lr: 0.0010
# Epoch 21/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9092 - val_loss: 1.8981 - lr: 0.0010
# Epoch 22/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9092 - val_loss: 1.8981 - lr: 0.0010
# Epoch 23/500
# 73/73 [==============================] - 1s 7ms/step - loss: 1.9092 - val_loss: 1.8981 - lr: 0.0010
# Epoch 24/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 25/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 26/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 27/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 28/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 29/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 30/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 31/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 32/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 33/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 34/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 0.0010
# Epoch 35/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 36/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 37/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 38/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 0.0010
# Epoch 39/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 40/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 41/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 42/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 0.0010
# Epoch 43/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 0.0010
# Epoch 44/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 45/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 0.0010
# Epoch 46/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 47/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 48/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 0.0010
# Epoch 49/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 50/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 0.0010
# Epoch 51/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 0.0010
# Epoch 52/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 53/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 54/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 55/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 56/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 57/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 58/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 59/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 60/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 61/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 62/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 63/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 64/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 65/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 66/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 67/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 68/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 69/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 70/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 71/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 72/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 73/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 74/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 75/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 76/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 77/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 78/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 79/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 80/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 81/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 82/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 83/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 84/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 85/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 86/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 87/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 88/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 89/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 90/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 91/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 92/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 93/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 94/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 95/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 96/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 97/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 98/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 99/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 100/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 101/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 2.0000e-04
# Epoch 102/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 103/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 104/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 105/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 106/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 107/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 108/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 109/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 110/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 111/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 112/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 113/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 114/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 115/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 116/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 117/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 118/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 119/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 120/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 121/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 122/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 123/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 124/500
# 73/73 [==============================] - 1s 7ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 125/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 126/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 127/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 128/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 129/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 130/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 131/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 132/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 133/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 134/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 135/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 136/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 137/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 138/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 139/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 140/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 141/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 142/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 143/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 144/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 145/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 146/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 147/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 148/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 149/500
# 73/73 [==============================] - 1s 7ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 150/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 151/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 4.0000e-05
# Epoch 152/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 153/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 154/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 155/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 156/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 157/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 158/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 159/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 160/500
# 73/73 [==============================] - 1s 7ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 161/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 162/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 163/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 164/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 165/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 166/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 167/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 168/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 169/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 170/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 171/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 172/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 173/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 174/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 175/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 176/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 177/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 178/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 179/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 180/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 181/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 182/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 183/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 184/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 185/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 186/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 187/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 188/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 189/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 190/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 191/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 192/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 193/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 194/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 195/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 196/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 197/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 198/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 199/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 200/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 201/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 202/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 203/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 204/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 205/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 206/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 207/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 208/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 209/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 210/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 211/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 212/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 213/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 214/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 215/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 216/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 217/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 218/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 219/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 220/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 221/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 222/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 223/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 224/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 225/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 226/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 227/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 228/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 229/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 230/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 231/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 232/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 233/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 234/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 235/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 236/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 237/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 238/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 239/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 240/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 241/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 242/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 243/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 244/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 245/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 246/500
# 73/73 [==============================] - 1s 7ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 247/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 248/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 249/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 250/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 251/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 252/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 253/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 254/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 255/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 256/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 257/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 258/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 259/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 260/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 261/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 262/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 263/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 264/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 265/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 266/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 267/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 268/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 269/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 270/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 271/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 272/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 273/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 274/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 275/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 276/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 277/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 278/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 279/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 280/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 281/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 282/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 283/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 284/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 285/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 286/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 287/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 288/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 289/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 290/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 291/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 292/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 293/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 294/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 295/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 296/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 297/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 298/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 299/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 300/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 301/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 302/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 303/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 304/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 305/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 306/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 307/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 308/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 309/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 310/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 311/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 312/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 313/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 314/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 315/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 316/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 317/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 318/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 319/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 320/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 321/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 322/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 323/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 324/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 325/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 326/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 327/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 328/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 329/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 330/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 331/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 332/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 333/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 334/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 335/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 336/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 337/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 338/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 339/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 340/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 341/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 342/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 343/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 344/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 345/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 346/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 347/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 348/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 349/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 350/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 351/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 352/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 353/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 354/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 355/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 356/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 357/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 358/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 359/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 360/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 361/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 362/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 363/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 364/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 365/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 366/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 367/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 368/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 369/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 370/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 371/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 372/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 373/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 374/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 375/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 376/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 377/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 378/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 379/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 380/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 381/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 382/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 383/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 384/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 385/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 386/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 387/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 388/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 389/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 390/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 391/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 392/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 393/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 394/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 395/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 396/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 397/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 398/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 399/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 400/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 401/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 402/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 403/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 404/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 405/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 406/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 407/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 408/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 409/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 410/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 411/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 412/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 413/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 414/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 415/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 416/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 417/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 418/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 419/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 420/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 421/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 422/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 423/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 424/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 425/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 426/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 427/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 428/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 429/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 430/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 431/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 432/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 433/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 434/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 435/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 436/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 437/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 438/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 439/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 440/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 441/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 442/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 443/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 444/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 445/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 446/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 447/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 448/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 449/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 450/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 451/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 452/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 453/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 454/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 455/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 456/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 457/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 458/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 459/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 460/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 461/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 462/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 463/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 464/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 465/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 466/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 467/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 468/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 469/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 470/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 471/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 472/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 473/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 474/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 475/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 476/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 477/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 478/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 479/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 480/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 481/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 482/500
# 73/73 [==============================] - 1s 7ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 483/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 484/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9091 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 485/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 486/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 487/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 488/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 489/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 490/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 491/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 492/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8981 - lr: 1.0000e-05
# Epoch 493/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8980 - lr: 1.0000e-05
# Epoch 494/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8980 - lr: 1.0000e-05
# Epoch 495/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8980 - lr: 1.0000e-05
# Epoch 496/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8980 - lr: 1.0000e-05
# Epoch 497/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8980 - lr: 1.0000e-05
# Epoch 498/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8980 - lr: 1.0000e-05
# Epoch 499/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8980 - lr: 1.0000e-05
# Epoch 500/500
# 73/73 [==============================] - 1s 8ms/step - loss: 1.9090 - val_loss: 1.8980 - lr: 1.0000e-05
# CPU times: user 8min 3s, sys: 27.6 s, total: 8min 31s
# Wall time: 4min 45s

# %%
# Evaluar el modelo
y_true = ratings_test
predictions = model.predict([user_ids_test, item_ids_test])
# Out:
# 30004/30004 [==============================] - 45s 1ms/step

# %%
# MSE y RMSE
mse = mean_squared_error(y_true, predictions)
rmse = np.sqrt(mse)

# MAE
mae = mean_absolute_error(y_true, predictions)

# Funciones MAPE
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    non_zero_idx = y_true != 0  # Para evitar divisiones por cero
    return np.mean(np.abs((y_true[non_zero_idx] - y_pred[non_zero_idx]) / y_true[non_zero_idx])) * 100

def compute_mape_by_batch(y_true, predictions, batch_size=50000):
    mape_sum = 0
    num_batches = int(np.ceil(len(y_true) / batch_size))

    for i in range(num_batches):
        start_idx = i * batch_size
        end_idx = start_idx + batch_size

        batch_y_true = y_true[start_idx:end_idx]
        batch_predictions = predictions[start_idx:end_idx]

        mape_sum += mean_absolute_percentage_error(batch_y_true, batch_predictions)

    return mape_sum / num_batches

# Luego llamas a la función
mape = compute_mape_by_batch(y_true, predictions)

print(f'MSE: {mse}')
print(f'RMSE: {rmse}')
print(f'MAE: {mae}')
print(f'MAPE: {mape}%')
# Out:
# MSE: 1.91015555428256
# RMSE: 1.3820837725270345
# MAE: 0.7401227977898481
# MAPE: 40.77108911682409%

# %% [markdown]
# # Recomendación

# %%
# Seleccionar un usuario al azar del conjunto de prueba
usuario_id_test_encoded = random.choice(user_ids_test)

# Decodificar el ID del usuario para obtener el ID original
usuario_id_test = reviewerID_encoder.inverse_transform([usuario_id_test_encoded])[0]

# Identificar los ítems que el usuario ha calificado en el conjunto de prueba
indices_usuario = np.where(user_ids_test == usuario_id_test_encoded)[0]
items_calificados_test_encoded = item_ids_test[indices_usuario]
calificaciones_reales_test = ratings_test[indices_usuario]

# Predecir las calificaciones para estos ítems
calificaciones_predichas = model.predict([np.array([usuario_id_test_encoded] * len(items_calificados_test_encoded)), items_calificados_test_encoded])

# Decodificar los ítems para obtener los ID originales
items_calificados_test = asin_encoder.inverse_transform(items_calificados_test_encoded)

# Comparar las calificaciones predichas con las reales
comparacion = list(zip(items_calificados_test, calificaciones_reales_test, calificaciones_predichas.flatten()))

# Suponiendo que 'items_calificados_test' contiene los IDs originales de los ítems
recomendaciones_df = pd.DataFrame({
    'asin': items_calificados_test,
    'Calificación Real': calificaciones_reales_test,
    'Calificación Predicha': calificaciones_predichas.flatten()
})

recomendaciones_df = recomendaciones_df.merge(sentimiento[['asin', 'cluster']], on='asin', how='left')
recomendaciones_df.rename(columns={'cluster': 'Sentimiento'}, inplace=True)

# Mostrar las recomendaciones
print(f"Recomendaciones para el usuario {usuario_id_test}:")
for index, row in recomendaciones_df.iterrows():
    print(f"Ítem: {row['asin']}, Calificación Real: {row['Calificación Real']}, Calificación Predicha: {row['Calificación Predicha']}, Sentimiento: {row['Sentimiento']}")
# Out:
# 1/1 [==============================] - 0s 21ms/step
# Recomendaciones para el usuario A304YD9JUQ1PO1:
# Ítem: B00NB3ZXR8, Calificación Real: 5.0, Calificación Predicha: 5.0, Sentimiento: Neutro

# %%
# Seleccionar un usuario al azar del conjunto de prueba
usuario_id_test_encoded = random.choice(user_ids_test)

# Decodificar el ID del usuario para obtener el ID original
usuario_id = reviewerID_encoder.inverse_transform([usuario_id_test_encoded])[0]

# Lista de todos los ítems únicos en el dataset
items_unicos = np.unique(data['asin'].values)

# Ítems que el usuario ya ha calificado
items_calificados = data[data['reviewerID_encoded'] == usuario_id_test_encoded]['asin'].tolist()

# Ítems para predecir
items_a_predecir = [item for item in items_unicos if item not in items_calificados]

# Convierte los ítems a su representación codificada
items_a_predecir_encoded = asin_encoder.transform(items_a_predecir)

# Predecir la calificación para cada ítem no calificado
predicciones = model.predict([np.array([usuario_id_test_encoded] * len(items_a_predecir_encoded)), items_a_predecir_encoded])

# Emparejar cada ítem con su predicción
items_predicciones = list(zip(items_a_predecir, predicciones.flatten()))

# Ordenar por la calificación predicha más alta
items_recomendados = sorted(items_predicciones, key=lambda x: x[1], reverse=True)

# Tomar los top N recomendaciones
top_n = 5
top_recomendaciones = items_recomendados[:top_n]

# Crear un DataFrame a partir de las recomendaciones
recomendaciones_df = pd.DataFrame(top_recomendaciones, columns=['asin', 'Calificación Predicha'])

# Unir con el DataFrame 'sentimiento' para obtener el sentimiento asociado a cada ítem
recomendaciones_df = recomendaciones_df.merge(sentimiento[['asin', 'cluster']], on='asin', how='left')

# Renombrar la columna 'cluster' a 'Sentimiento' para claridad
recomendaciones_df.rename(columns={'cluster': 'Sentimiento'}, inplace=True)

# Mostrar las recomendaciones con el sentimiento
print(f"Recomendaciones para el usuario {usuario_id}:")
for index, row in recomendaciones_df.iterrows():
    print(f"Ítem: {row['asin']}, Calificación Predicha: {row['Calificación Predicha']}, Sentimiento: {row['Sentimiento']}")
# Out:
# 4813/4813 [==============================] - 7s 1ms/step
# Recomendaciones para el usuario A2LFARJK62B8NZ:
# Ítem: 0871167042, Calificación Predicha: 5.0, Sentimiento: Positivo
# Ítem: 1519588135, Calificación Predicha: 5.0, Sentimiento: Neutro
# Ítem: 1579652956, Calificación Predicha: 5.0, Sentimiento: Positivo
# Ítem: 1936023857, Calificación Predicha: 5.0, Sentimiento: Positivo
# Ítem: 5120053017, Calificación Predicha: 5.0, Sentimiento: Neutro

# %% [markdown]
# # Modelo de Filtrado Colaborativo usando Red Neuronal Multicapa y Embedding con Keras:
#
# Otra enfoque popular para filtrado colaborativo es utilizar redes neuronales multicapa, que esencialmente aprenden características no lineales de los datos. Vamos a construir un modelo que fusiona los embeddings de usuarios y artículos (por ejemplo, películas) en una red neuronal densa.
#
# Este enfoque, que combina embeddings y redes neuronales multicapa, puede capturar interacciones más complejas y no lineales entre usuarios y artículos. Sin embargo, es crucial prestar atención al sobreajuste y asegurarse de que el modelo no esté simplemente memorizando los datos. Por lo tanto, es recomendable emplear técnicas de regularización, ajustar hiperparámetros y validar el rendimiento con un conjunto de datos de validación.

# %% [markdown]
# Funcionamiento:
#
# Combina lo mejor de ambos mundos. Primero, se utilizan embeddings para convertir ítems y usuarios en representaciones vectoriales densas. Luego, estas representaciones se pasan a través de una red neuronal para hacer la predicción.
#
# El proceso generalmente comienza con capas de embedding que convierten identificadores de usuarios e ítems en vectores. Estos vectores luego se pasan a través de capas densas para obtener la predicción final.
#
# Ventajas:
#
# Capacidad de capturar patrones subyacentes en los datos mediante embeddings y modelar interacciones no lineales mediante la red neuronal.
#
# Flexibilidad para incorporar características adicionales.
#
# Potencialmente más preciso que cualquiera de los otros dos métodos por separado.
#
# Desventajas:
#
# Mayor complejidad en el modelado y entrenamiento.
#
# Mayor costo computacional.
#
# Requiere un ajuste más cuidadoso y riesgo de sobreajuste si no se gestiona adecuadamente.

# %% [markdown]
# Regularización L2: Agregar una regularización L2 a las capas de embedding y densas para prevenir el sobreajuste.
#
# Early Stopping: Añadir una callback de early stopping para detener el entrenamiento cuando no haya mejora en el conjunto de validación durante un cierto número de épocas.
#
# Ajuste de la tasa de aprendizaje: Utilizar la callback ReduceLROnPlateau para reducir la tasa de aprendizaje cuando no haya mejora en el conjunto de validación.
#
# Métricas adicionales: Puedes monitorizar otras métricas como el error absoluto medio (MAE) durante el entrenamiento.

# %%
# Convertir reviewerID y asin a índices numéricos secuenciales
df['user_id'] = df['reviewerID'].astype('category').cat.codes.values
df['item_id'] = df['asin'].astype('category').cat.codes.values

# Número de usuarios e ítems
n_users = df['user_id'].nunique()
n_items = df['item_id'].nunique()

# Hiperparámetros
n_latent_factors = 50
hidden_units = [128, 64]
dropout_rate = 0.2
l2_reg = 1e-4

# Entradas
user_input = Input(shape=[1], name='user_input')
item_input = Input(shape=[1], name='item_input')

# Embeddings con regularización L2
user_embedding = Embedding(n_users, n_latent_factors, embeddings_regularizer=l2(l2_reg), name='user_embedding')(user_input)
item_embedding = Embedding(n_items, n_latent_factors, embeddings_regularizer=l2(l2_reg), name='item_embedding')(item_input)

user_vec = Flatten(name='flatten_users')(user_embedding)
item_vec = Flatten(name='flatten_items')(item_embedding)
concat = Concatenate()([user_vec, item_vec])

# Capas densas
dense = concat
for units in hidden_units:
    dense = Dense(units, activation='relu', kernel_regularizer=l2(l2_reg))(dense)
    dense = Dropout(dropout_rate)(dense)

# Agregar una capa de activación sigmoid y escalar a [0, 5]
output = Dense(1, activation='sigmoid', kernel_regularizer=l2(l2_reg))(dense)  # Función de activación sigmoid
output = Lambda(lambda x: x * 5)(output)  # Escalar las predicciones al rango [0, 5]

# Modelo
model = Model(inputs=[user_input, item_input], outputs=output)
model.compile(optimizer=Adam(0.001), loss='mean_squared_error', metrics=['mae'])

# %%
# Callbacks
early_stop = EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=50, min_lr=1e-5)

# %%
# Entrenamiento
user_data = df['user_id'].values
item_data = df['item_id'].values
rating_data = df['overall'].values

# División en entrenamiento y prueba
(user_ids_temp, user_ids_test, item_ids_temp, item_ids_test, ratings_temp, ratings_test) = train_test_split(
    user_ids, item_ids, ratings, test_size=0.2, random_state=42)

# División del conjunto de entrenamiento en entrenamiento y validación
(user_ids_train, user_ids_val, item_ids_train, item_ids_val, ratings_train, ratings_val) = train_test_split(
    user_ids_temp, item_ids_temp, ratings_temp, test_size=0.25, random_state=42)  # 0.25 x 0.8 = 0.2

# %%
# %%time
history = model.fit([user_ids_train, item_ids_train], ratings_train,
                    epochs=500,validation_data=([user_ids_val, item_ids_val], ratings_val),
                    batch_size=40000,verbose=1,callbacks=[early_stop, reduce_lr])
# Out:
# Epoch 1/500
# 73/73 [==============================] - 5s 49ms/step - loss: 3.8212 - mae: 1.2039 - val_loss: 1.4273 - val_mae: 0.8788 - lr: 0.0010
# Epoch 2/500
# 73/73 [==============================] - 3s 42ms/step - loss: 1.3564 - mae: 0.8241 - val_loss: 1.4247 - val_mae: 0.8201 - lr: 0.0010
# Epoch 3/500
# 73/73 [==============================] - 3s 38ms/step - loss: 1.2029 - mae: 0.7272 - val_loss: 1.4727 - val_mae: 0.8019 - lr: 0.0010
# Epoch 4/500
# 73/73 [==============================] - 3s 38ms/step - loss: 1.1117 - mae: 0.6769 - val_loss: 1.4871 - val_mae: 0.7957 - lr: 0.0010
# Epoch 5/500
# 73/73 [==============================] - 3s 38ms/step - loss: 1.0613 - mae: 0.6493 - val_loss: 1.5088 - val_mae: 0.7939 - lr: 0.0010
# Epoch 6/500
# 73/73 [==============================] - 3s 38ms/step - loss: 1.0299 - mae: 0.6301 - val_loss: 1.5252 - val_mae: 0.7903 - lr: 0.0010
# Epoch 7/500
# 73/73 [==============================] - 3s 38ms/step - loss: 1.0001 - mae: 0.6136 - val_loss: 1.5303 - val_mae: 0.7882 - lr: 0.0010
# Epoch 8/500
# 73/73 [==============================] - 3s 38ms/step - loss: 0.9720 - mae: 0.6003 - val_loss: 1.5338 - val_mae: 0.7867 - lr: 0.0010
# Epoch 9/500
# 73/73 [==============================] - 3s 37ms/step - loss: 0.9516 - mae: 0.5882 - val_loss: 1.5557 - val_mae: 0.7850 - lr: 0.0010
# Epoch 10/500
# 73/73 [==============================] - 3s 38ms/step - loss: 0.9395 - mae: 0.5784 - val_loss: 1.5717 - val_mae: 0.7835 - lr: 0.0010
# Epoch 11/500
# 73/73 [==============================] - 3s 38ms/step - loss: 0.9223 - mae: 0.5697 - val_loss: 1.5675 - val_mae: 0.7806 - lr: 0.0010
# Epoch 12/500
# 73/73 [==============================] - 3s 38ms/step - loss: 0.9007 - mae: 0.5604 - val_loss: 1.5703 - val_mae: 0.7810 - lr: 0.0010
# Epoch 13/500
# 73/73 [==============================] - 3s 38ms/step - loss: 0.8834 - mae: 0.5515 - val_loss: 1.5707 - val_mae: 0.7792 - lr: 0.0010
# Epoch 14/500
# 73/73 [==============================] - 3s 38ms/step - loss: 0.8708 - mae: 0.5448 - val_loss: 1.5753 - val_mae: 0.7778 - lr: 0.0010
# Epoch 15/500
# 73/73 [==============================] - 3s 38ms/step - loss: 0.8527 - mae: 0.5355 - val_loss: 1.5656 - val_mae: 0.7730 - lr: 0.0010
# Epoch 16/500
# 73/73 [==============================] - 3s 38ms/step - loss: 0.8320 - mae: 0.5279 - val_loss: 1.5677 - val_mae: 0.7772 - lr: 0.0010
# Epoch 17/500
# 73/73 [==============================] - 3s 38ms/step - loss: 0.8154 - mae: 0.5191 - val_loss: 1.5776 - val_mae: 0.7750 - lr: 0.0010
# Epoch 18/500
# 73/73 [==============================] - 3s 38ms/step - loss: 0.8053 - mae: 0.5113 - val_loss: 1.5932 - val_mae: 0.7777 - lr: 0.0010
# Epoch 19/500
# 73/73 [==============================] - 3s 38ms/step - loss: 0.7932 - mae: 0.5032 - val_loss: 1.5985 - val_mae: 0.7752 - lr: 0.0010
# Epoch 20/500
# 73/73 [==============================] - 3s 38ms/step - loss: 0.7763 - mae: 0.4951 - val_loss: 1.5934 - val_mae: 0.7758 - lr: 0.0010
# Epoch 21/500
# 73/73 [==============================] - 3s 38ms/step - loss: 0.7555 - mae: 0.4866 - val_loss: 1.5938 - val_mae: 0.7739 - lr: 0.0010
# Epoch 22/500
# 73/73 [==============================] - 3s 38ms/step - loss: 0.7359 - mae: 0.4788 - val_loss: 1.5960 - val_mae: 0.7743 - lr: 0.0010
# Epoch 23/500
# 73/73 [==============================] - 3s 38ms/step - loss: 0.7214 - mae: 0.4715 - val_loss: 1.6055 - val_mae: 0.7720 - lr: 0.0010
# Epoch 24/500
# 73/73 [==============================] - 3s 38ms/step - loss: 0.7089 - mae: 0.4650 - val_loss: 1.6032 - val_mae: 0.7712 - lr: 0.0010
# Epoch 25/500
# 73/73 [==============================] - 3s 38ms/step - loss: 0.6944 - mae: 0.4571 - val_loss: 1.6140 - val_mae: 0.7762 - lr: 0.0010
# Epoch 26/500
# 73/73 [==============================] - 3s 38ms/step - loss: 0.6840 - mae: 0.4519 - val_loss: 1.6176 - val_mae: 0.7738 - lr: 0.0010
# Epoch 27/500
# 73/73 [==============================] - 3s 38ms/step - loss: 0.6715 - mae: 0.4449 - val_loss: 1.6177 - val_mae: 0.7694 - lr: 0.0010
# Epoch 28/500
# 73/73 [==============================] - 3s 38ms/step - loss: 0.6602 - mae: 0.4391 - val_loss: 1.6274 - val_mae: 0.7751 - lr: 0.0010
# Epoch 29/500
# 73/73 [==============================] - 3s 38ms/step - loss: 0.6460 - mae: 0.4320 - val_loss: 1.6229 - val_mae: 0.7700 - lr: 0.0010
# Epoch 30/500
# 73/73 [==============================] - 3s 38ms/step - loss: 0.6330 - mae: 0.4245 - val_loss: 1.6256 - val_mae: 0.7699 - lr: 0.0010
# Epoch 31/500
# 73/73 [==============================] - 3s 38ms/step - loss: 0.6258 - mae: 0.4188 - val_loss: 1.6342 - val_mae: 0.7724 - lr: 0.0010
# Epoch 32/500
# 73/73 [==============================] - 3s 38ms/step - loss: 0.6204 - mae: 0.4127 - val_loss: 1.6507 - val_mae: 0.7734 - lr: 0.0010
# Epoch 33/500
# 73/73 [==============================] - 3s 38ms/step - loss: 0.6165 - mae: 0.4073 - val_loss: 1.6474 - val_mae: 0.7680 - lr: 0.0010
# Epoch 34/500
# 73/73 [==============================] - 3s 38ms/step - loss: 0.6060 - mae: 0.4013 - val_loss: 1.6511 - val_mae: 0.7669 - lr: 0.0010
# Epoch 35/500
# 73/73 [==============================] - 3s 38ms/step - loss: 0.5986 - mae: 0.3968 - val_loss: 1.6525 - val_mae: 0.7618 - lr: 0.0010
# Epoch 36/500
# 73/73 [==============================] - 3s 38ms/step - loss: 0.5933 - mae: 0.3924 - val_loss: 1.6620 - val_mae: 0.7712 - lr: 0.0010
# Epoch 37/500
# 73/73 [==============================] - 3s 38ms/step - loss: 0.5869 - mae: 0.3875 - val_loss: 1.6664 - val_mae: 0.7696 - lr: 0.0010
# Epoch 38/500
# 73/73 [==============================] - 3s 37ms/step - loss: 0.5826 - mae: 0.3833 - val_loss: 1.6693 - val_mae: 0.7689 - lr: 0.0010
# Epoch 39/500
# 73/73 [==============================] - 3s 38ms/step - loss: 0.5745 - mae: 0.3806 - val_loss: 1.6668 - val_mae: 0.7654 - lr: 0.0010
# Epoch 40/500
# 73/73 [==============================] - 3s 38ms/step - loss: 0.5662 - mae: 0.3766 - val_loss: 1.6708 - val_mae: 0.7716 - lr: 0.0010
# Epoch 41/500
# 73/73 [==============================] - 3s 38ms/step - loss: 0.5610 - mae: 0.3748 - val_loss: 1.6747 - val_mae: 0.7704 - lr: 0.0010
# Epoch 42/500
# 73/73 [==============================] - 3s 38ms/step - loss: 0.5575 - mae: 0.3711 - val_loss: 1.6834 - val_mae: 0.7725 - lr: 0.0010
# Epoch 43/500
# 73/73 [==============================] - 3s 37ms/step - loss: 0.5539 - mae: 0.3679 - val_loss: 1.6939 - val_mae: 0.7787 - lr: 0.0010
# Epoch 44/500
# 73/73 [==============================] - 3s 38ms/step - loss: 0.5497 - mae: 0.3655 - val_loss: 1.6863 - val_mae: 0.7716 - lr: 0.0010
# Epoch 45/500
# 73/73 [==============================] - 3s 37ms/step - loss: 0.5484 - mae: 0.3644 - val_loss: 1.6913 - val_mae: 0.7673 - lr: 0.0010
# Epoch 46/500
# 73/73 [==============================] - 3s 38ms/step - loss: 0.5445 - mae: 0.3611 - val_loss: 1.7023 - val_mae: 0.7765 - lr: 0.0010
# Epoch 47/500
# 73/73 [==============================] - 3s 38ms/step - loss: 0.5421 - mae: 0.3596 - val_loss: 1.6982 - val_mae: 0.7690 - lr: 0.0010
# Epoch 48/500
# 73/73 [==============================] - 3s 38ms/step - loss: 0.5382 - mae: 0.3567 - val_loss: 1.7051 - val_mae: 0.7758 - lr: 0.0010
# Epoch 49/500
# 73/73 [==============================] - 3s 37ms/step - loss: 0.5340 - mae: 0.3548 - val_loss: 1.7045 - val_mae: 0.7715 - lr: 0.0010
# Epoch 50/500
# 73/73 [==============================] - 3s 37ms/step - loss: 0.5308 - mae: 0.3525 - val_loss: 1.7063 - val_mae: 0.7690 - lr: 0.0010
# Epoch 51/500
# 73/73 [==============================] - 3s 38ms/step - loss: 0.5271 - mae: 0.3503 - val_loss: 1.6972 - val_mae: 0.7662 - lr: 0.0010
# Epoch 52/500
# 73/73 [==============================] - 3s 43ms/step - loss: 0.5253 - mae: 0.3490 - val_loss: 1.7065 - val_mae: 0.7690 - lr: 0.0010
# CPU times: user 2min 21s, sys: 5.61 s, total: 2min 26s
# Wall time: 2min 26s

# %%
# Predicciones
y_true = ratings_test
predictions = model.predict([user_ids_test, item_ids_test])
# Out:
# 30004/30004 [==============================] - 45s 2ms/step

# %%
# MSE y RMSE
mse = mean_squared_error(y_true, predictions)
rmse = np.sqrt(mse)

# MAE
mae = mean_absolute_error(y_true, predictions)

# MAPE
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    non_zero_idx = y_true != 0  # Para evitar divisiones por cero
    return np.mean(np.abs((y_true[non_zero_idx] - y_pred[non_zero_idx]) / y_true[non_zero_idx])) * 100

def compute_mape_by_batch(y_true, predictions, batch_size=50000):
    mape_sum = 0
    num_batches = int(np.ceil(len(y_true) / batch_size))

    for i in range(num_batches):
        start_idx = i * batch_size
        end_idx = start_idx + batch_size

        batch_y_true = y_true[start_idx:end_idx]
        batch_predictions = predictions[start_idx:end_idx]

        mape_sum += mean_absolute_percentage_error(batch_y_true, batch_predictions)

    return mape_sum / num_batches

# Luego llamas a la función
mape = compute_mape_by_batch(y_true, predictions)

print(f'MSE: {mse}')
print(f'RMSE: {rmse}')
print(f'MAE: {mae}')
print(f'MAPE: {mape}%')
# Out:
# MSE: 1.1989827115855063
# RMSE: 1.0949806900514303
# MAE: 0.8209608923100524
# MAPE: 39.305389692791486%

# %% [markdown]
# # Recomendación

# %%
# Seleccionar un usuario al azar del conjunto de prueba
usuario_id_test_encoded = random.choice(user_ids_test)

# Decodificar el ID del usuario para obtener el ID original
usuario_id_test = reviewerID_encoder.inverse_transform([usuario_id_test_encoded])[0]

# Identificar los ítems que el usuario ha calificado en el conjunto de prueba
indices_usuario = np.where(user_ids_test == usuario_id_test_encoded)[0]
items_calificados_test_encoded = item_ids_test[indices_usuario]
calificaciones_reales_test = ratings_test[indices_usuario]

# Predecir las calificaciones para estos ítems
calificaciones_predichas = model.predict([np.array([usuario_id_test_encoded] * len(items_calificados_test_encoded)), items_calificados_test_encoded])

# Decodificar los ítems para obtener los ID originales
items_calificados_test = asin_encoder.inverse_transform(items_calificados_test_encoded)

# Comparar las calificaciones predichas con las reales
comparacion = list(zip(items_calificados_test, calificaciones_reales_test, calificaciones_predichas.flatten()))

# Suponiendo que 'items_calificados_test' contiene los IDs originales de los ítems
recomendaciones_df = pd.DataFrame({
    'asin': items_calificados_test,
    'Calificación Real': calificaciones_reales_test,
    'Calificación Predicha': calificaciones_predichas.flatten()
})

recomendaciones_df = recomendaciones_df.merge(sentimiento[['asin', 'cluster']], on='asin', how='left')
recomendaciones_df.rename(columns={'cluster': 'Sentimiento'}, inplace=True)

# Mostrar las recomendaciones
print(f"Recomendaciones para el usuario {usuario_id_test}:")
for index, row in recomendaciones_df.iterrows():
    print(f"Ítem: {row['asin']}, Calificación Real: {row['Calificación Real']}, Calificación Predicha: {row['Calificación Predicha']}, Sentimiento: {row['Sentimiento']}")
# Out:
# 1/1 [==============================] - 0s 18ms/step
# Recomendaciones para el usuario A1YBGSD8HECOME:
# Ítem: B00KWIKGSQ, Calificación Real: 5.0, Calificación Predicha: 4.815544128417969, Sentimiento: Positivo
# Ítem: B00Y64FHVS, Calificación Real: 5.0, Calificación Predicha: 4.105264186859131, Sentimiento: Neutro

# %%
# Seleccionar un usuario al azar del conjunto de prueba
usuario_id_test_encoded = random.choice(user_ids_test)

# Decodificar el ID del usuario para obtener el ID original
usuario_id = reviewerID_encoder.inverse_transform([usuario_id_test_encoded])[0]

# Lista de todos los ítems únicos en el dataset
items_unicos = np.unique(data['asin'].values)

# Ítems que el usuario ya ha calificado
items_calificados = data[data['reviewerID_encoded'] == usuario_id_test_encoded]['asin'].tolist()

# Ítems para predecir
items_a_predecir = [item for item in items_unicos if item not in items_calificados]

# Convierte los ítems a su representación codificada
items_a_predecir_encoded = asin_encoder.transform(items_a_predecir)

# Predecir la calificación para cada ítem no calificado
predicciones = model.predict([np.array([usuario_id_test_encoded] * len(items_a_predecir_encoded)), items_a_predecir_encoded])

# Emparejar cada ítem con su predicción
items_predicciones = list(zip(items_a_predecir, predicciones.flatten()))

# Ordenar por la calificación predicha más alta
items_recomendados = sorted(items_predicciones, key=lambda x: x[1], reverse=True)

# Tomar los top N recomendaciones
top_n = 5
top_recomendaciones = items_recomendados[:top_n]

# Crear un DataFrame a partir de las recomendaciones
recomendaciones_df = pd.DataFrame(top_recomendaciones, columns=['asin', 'Calificación Predicha'])

# Unir con el DataFrame 'sentimiento' para obtener el sentimiento asociado a cada ítem
recomendaciones_df = recomendaciones_df.merge(sentimiento[['asin', 'cluster']], on='asin', how='left')

# Renombrar la columna 'cluster' a 'Sentimiento' para claridad
recomendaciones_df.rename(columns={'cluster': 'Sentimiento'}, inplace=True)

# Mostrar las recomendaciones con el sentimiento
print(f"Recomendaciones para el usuario {usuario_id}:")
for index, row in recomendaciones_df.iterrows():
    print(f"Ítem: {row['asin']}, Calificación Predicha: {row['Calificación Predicha']}, Sentimiento: {row['Sentimiento']}")
# Out:
# 4814/4814 [==============================] - 7s 1ms/step
# Recomendaciones para el usuario A1KKLSIK2LLH2R:
# Ítem: B00RLSCLJM, Calificación Predicha: 4.943234443664551, Sentimiento: Positivo
# Ítem: B00KKXCJQU, Calificación Predicha: 4.917655944824219, Sentimiento: Positivo
# Ítem: B00H9RZDRM, Calificación Predicha: 4.913823127746582, Sentimiento: Neutro
# Ítem: B01B5BWTNS, Calificación Predicha: 4.90779972076416, Sentimiento: Positivo
# Ítem: B00GKDFOJS, Calificación Predicha: 4.906577110290527, Sentimiento: Positivo

# %% [markdown]
# Estas métricas te ayudarán a tener una mejor idea del desempeño de tu modelo. Por ejemplo:
#
# MSE y RMSE son útiles cuando quieres penalizar grandes errores.
#
# MAE te da una idea del error medio sin considerar la dirección del error.
#
# MAPE es útil cuando quieres representar el error en términos porcentuales.
#
# Para una evaluación completa, es recomendable utilizar un conjunto de validación aparte (es decir, no solo depender del validation_split). Esto asegura que estás evaluando el desempeño en datos que el modelo nunca ha visto durante el entrenamiento.

# %% [markdown]
# En resumen, la elección del tipo de sistema de recomendación dependerá de la naturaleza del conjunto de datos, las características disponibles, las capacidades computacionales y el tipo de relaciones o interacciones que se desean capturar. A menudo, un enfoque híbrido (como el sistema que combina embeddings y redes neuronales) ofrece un buen equilibrio entre precisión y eficiencia.
