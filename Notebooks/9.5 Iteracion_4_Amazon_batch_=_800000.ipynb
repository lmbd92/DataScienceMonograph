# %% [markdown]
# # Paso 1: Importar Librerías de Python

# %%
#pip install scikit-surprise
# Out:
# Collecting scikit-surprise
#   Downloading scikit-surprise-1.1.3.tar.gz (771 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 772.0/772.0 kB 12.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: joblib>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.3.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.11.3)
# Building wheels for collected packages: scikit-surprise
#   Building wheel for scikit-surprise (setup.py) ... done
#   Created wheel for scikit-surprise: filename=scikit_surprise-1.1.3-cp310-cp310-linux_x86_64.whl size=3163484 sha256=f88b81d93fdbb42da745efd36f51cc99b718d784c9329493040e8631035dae02
#   Stored in directory: /root/.cache/pip/wheels/a5/ca/a8/4e28def53797fdc4363ca4af740db15a9c2f1595ebc51fb445
# Successfully built scikit-surprise
# Installing collected packages: scikit-surprise
# Successfully installed scikit-surprise-1.1.3

# %%
# Análisis de datos y manipulación
import pandas as pd
import numpy as np
import random

# Visualización de datos
import matplotlib.pyplot as plt
import seaborn as sns

# Utilidades de fechas
from datetime import datetime

# Integración con Google Colab
from google.colab import drive

# Machine Learning: Preprocesamiento y división de datos
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# Machine Learning: Métricas
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.metrics.pairwise import cosine_similarity

# Machine Learning: Modelado y validación
from surprise import SVD, Reader, Dataset, accuracy
from surprise.model_selection import train_test_split, GridSearchCV

# Deep Learning: Construcción de modelos y capas
from keras.models import Model
from keras.layers import Input, Embedding, Flatten, Concatenate, Dense, Dropout, Dot

# Deep Learning: Optimización y regularización
from keras.optimizers import Adam
from keras.regularizers import l2

# Deep Learning: Callbacks
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Paso 2: Lectura del Dataset

# %%
# Suponiendo que tu DataFrame se llama df
df = pd.read_csv('/content/drive/MyDrive/EspecializacionA&DS/Monografia/2doSemestre/DataFinal_Amazon.csv')  # Descomenta y proporciona la ruta si estás cargando un archivo CSV
# Out:
# <ipython-input-4-1f8e3361d82a>:2: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/drive/MyDrive/EspecializacionA&DS/Monografia/2doSemestre/DataFinal_Amazon.csv')  # Descomenta y proporciona la ruta si estás cargando un archivo CSV

# %%
df.shape
# Out:
# (4800571, 10)

# %% [markdown]
# # Modelo de Filtrado Colaborativo usando Embedding con Keras:

# %% [markdown]
# Funcionamiento:
#
# Los embeddings son representaciones vectoriales densas y de baja dimensión de ítems y/o usuarios. Estas representaciones capturan relaciones semánticas entre ítems o entre usuarios.
#
# Un método popular para generar embeddings es la factorización de matrices, como la descomposición en valores singulares (SVD). En el contexto de sistemas de recomendación, se busca factorizar la matriz de interacciones usuario-ítem en dos matrices más pequeñas (una para los usuarios y otra para los ítems) cuyo producto aproximado reproduce la matriz original lo mejor posible.
#
# Una vez que se han obtenido los embeddings, la predicción de una calificación o interacción entre un usuario e ítem se realiza tomando el producto escalar entre sus embeddings respectivos.
#
# Ventajas:
#
# Simplicidad y eficiencia en términos computacionales.
#
# Puede manejar grandes conjuntos de datos debido a su naturaleza de baja dimensión.
#
# Es efectivo para capturar patrones subyacentes en los datos.
#
# Desventajas:
#
# No tiene en cuenta características adicionales de usuarios o ítems.
#
# Dificultades para manejar nuevos ítems o usuarios (problema de arranque en frío).

# %% [markdown]
# El código ahora incluye regularización en los embeddings, un callback para detener el entrenamiento si no hay mejoras (early stopping) y otro para reducir la tasa de aprendizaje si el error de validación no mejora (reduce learning rate on plateau).

# %%
data = df

# %%
# Crear un LabelEncoder para cada columna
reviewerID_encoder = LabelEncoder()
asin_encoder = LabelEncoder()

# Ajustar y transformar las columnas
data['reviewerID_encoded'] = reviewerID_encoder.fit_transform(data['reviewerID'])
data['asin_encoded'] = asin_encoder.fit_transform(data['asin'])

# Número de usuarios únicos y número de ítems únicos
n_users = len(np.unique(data['reviewerID_encoded']))
n_items = len(np.unique(data['asin_encoded']))

# Dimensiones del embedding
embedding_dim = 10

# Entradas
user_input = Input(shape=(1,))
item_input = Input(shape=(1,))

# Embeddings con regularización
user_embedding = Embedding(n_users, embedding_dim, embeddings_regularizer=l2(1e-6))(user_input)
item_embedding = Embedding(n_items, embedding_dim, embeddings_regularizer=l2(1e-6))(item_input)

# Producto punto para predecir la valoración/rating
merged = Dot(axes=2)([user_embedding, item_embedding])
merged = Flatten()(merged)

# Modelo
model = Model(inputs=[user_input, item_input], outputs=merged)
model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# %% [markdown]
# verbose=0: No muestra ninguna barra de progreso ni métricas.
#
# verbose=1: Muestra una barra de progreso y actualiza las métricas después de cada lote.
#
# verbose=2: Muestra las métricas después de cada época, pero no muestra la barra de progreso.

# %%
from sklearn.model_selection import train_test_split

# Crear los arrays con los datos
user_ids = data['reviewerID_encoded'].values
item_ids = data['asin_encoded'].values
ratings = data['overall'].values

# División en entrenamiento y prueba
(user_ids_temp, user_ids_test, item_ids_temp, item_ids_test, ratings_temp, ratings_test) = train_test_split(
    user_ids, item_ids, ratings, test_size=0.2, random_state=42)

# División del conjunto de entrenamiento en entrenamiento y validación
(user_ids_train, user_ids_val, item_ids_train, item_ids_val, ratings_train, ratings_val) = train_test_split(
    user_ids_temp, item_ids_temp, ratings_temp, test_size=0.25, random_state=42)  # 0.25 x 0.8 = 0.2

# %%
# Callbacks
early_stop = EarlyStopping(monitor='val_loss', patience=50)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=50, min_lr=1e-5)

# %%
# %%time
# Entrenar el modelo con el conjunto de entrenamiento
model.fit([user_ids_train, item_ids_train], ratings_train, validation_data=([user_ids_val, item_ids_val], ratings_val), epochs=500, batch_size=800000, verbose=1, callbacks=[early_stop, reduce_lr])
# Out:
# Epoch 1/500
# 4/4 [==============================] - 5s 117ms/step - loss: 19.5203 - mae: 4.2598 - val_loss: 19.5451 - val_mae: 4.2634 - lr: 0.0010
# Epoch 2/500
# 4/4 [==============================] - 0s 55ms/step - loss: 19.5194 - mae: 4.2597 - val_loss: 19.5449 - val_mae: 4.2634 - lr: 0.0010
# Epoch 3/500
# 4/4 [==============================] - 0s 51ms/step - loss: 19.5183 - mae: 4.2596 - val_loss: 19.5447 - val_mae: 4.2634 - lr: 0.0010
# Epoch 4/500
# 4/4 [==============================] - 0s 47ms/step - loss: 19.5170 - mae: 4.2595 - val_loss: 19.5444 - val_mae: 4.2634 - lr: 0.0010
# Epoch 5/500
# 4/4 [==============================] - 0s 48ms/step - loss: 19.5157 - mae: 4.2594 - val_loss: 19.5442 - val_mae: 4.2633 - lr: 0.0010
# Epoch 6/500
# 4/4 [==============================] - 0s 48ms/step - loss: 19.5142 - mae: 4.2592 - val_loss: 19.5439 - val_mae: 4.2633 - lr: 0.0010
# Epoch 7/500
# 4/4 [==============================] - 0s 46ms/step - loss: 19.5126 - mae: 4.2591 - val_loss: 19.5436 - val_mae: 4.2633 - lr: 0.0010
# Epoch 8/500
# 4/4 [==============================] - 0s 47ms/step - loss: 19.5109 - mae: 4.2589 - val_loss: 19.5432 - val_mae: 4.2633 - lr: 0.0010
# Epoch 9/500
# 4/4 [==============================] - 0s 44ms/step - loss: 19.5090 - mae: 4.2587 - val_loss: 19.5428 - val_mae: 4.2633 - lr: 0.0010
# Epoch 10/500
# 4/4 [==============================] - 0s 53ms/step - loss: 19.5069 - mae: 4.2585 - val_loss: 19.5423 - val_mae: 4.2632 - lr: 0.0010
# Epoch 11/500
# 4/4 [==============================] - 0s 48ms/step - loss: 19.5046 - mae: 4.2582 - val_loss: 19.5418 - val_mae: 4.2632 - lr: 0.0010
# Epoch 12/500
# 4/4 [==============================] - 0s 49ms/step - loss: 19.5020 - mae: 4.2580 - val_loss: 19.5412 - val_mae: 4.2631 - lr: 0.0010
# Epoch 13/500
# 4/4 [==============================] - 0s 45ms/step - loss: 19.4991 - mae: 4.2576 - val_loss: 19.5405 - val_mae: 4.2630 - lr: 0.0010
# Epoch 14/500
# 4/4 [==============================] - 0s 50ms/step - loss: 19.4959 - mae: 4.2573 - val_loss: 19.5397 - val_mae: 4.2629 - lr: 0.0010
# Epoch 15/500
# 4/4 [==============================] - 0s 45ms/step - loss: 19.4923 - mae: 4.2569 - val_loss: 19.5387 - val_mae: 4.2628 - lr: 0.0010
# Epoch 16/500
# 4/4 [==============================] - 0s 45ms/step - loss: 19.4882 - mae: 4.2564 - val_loss: 19.5377 - val_mae: 4.2627 - lr: 0.0010
# Epoch 17/500
# 4/4 [==============================] - 0s 45ms/step - loss: 19.4836 - mae: 4.2559 - val_loss: 19.5365 - val_mae: 4.2626 - lr: 0.0010
# Epoch 18/500
# 4/4 [==============================] - 0s 48ms/step - loss: 19.4785 - mae: 4.2553 - val_loss: 19.5352 - val_mae: 4.2624 - lr: 0.0010
# Epoch 19/500
# 4/4 [==============================] - 0s 45ms/step - loss: 19.4728 - mae: 4.2547 - val_loss: 19.5337 - val_mae: 4.2622 - lr: 0.0010
# Epoch 20/500
# 4/4 [==============================] - 0s 45ms/step - loss: 19.4665 - mae: 4.2540 - val_loss: 19.5320 - val_mae: 4.2620 - lr: 0.0010
# Epoch 21/500
# 4/4 [==============================] - 0s 45ms/step - loss: 19.4594 - mae: 4.2531 - val_loss: 19.5301 - val_mae: 4.2617 - lr: 0.0010
# Epoch 22/500
# 4/4 [==============================] - 0s 46ms/step - loss: 19.4516 - mae: 4.2522 - val_loss: 19.5281 - val_mae: 4.2615 - lr: 0.0010
# Epoch 23/500
# 4/4 [==============================] - 0s 46ms/step - loss: 19.4429 - mae: 4.2512 - val_loss: 19.5259 - val_mae: 4.2612 - lr: 0.0010
# Epoch 24/500
# 4/4 [==============================] - 0s 44ms/step - loss: 19.4334 - mae: 4.2501 - val_loss: 19.5234 - val_mae: 4.2608 - lr: 0.0010
# Epoch 25/500
# 4/4 [==============================] - 0s 43ms/step - loss: 19.4230 - mae: 4.2489 - val_loss: 19.5208 - val_mae: 4.2605 - lr: 0.0010
# Epoch 26/500
# 4/4 [==============================] - 0s 46ms/step - loss: 19.4116 - mae: 4.2475 - val_loss: 19.5179 - val_mae: 4.2600 - lr: 0.0010
# Epoch 27/500
# 4/4 [==============================] - 0s 43ms/step - loss: 19.3991 - mae: 4.2461 - val_loss: 19.5148 - val_mae: 4.2596 - lr: 0.0010
# Epoch 28/500
# 4/4 [==============================] - 0s 43ms/step - loss: 19.3856 - mae: 4.2445 - val_loss: 19.5115 - val_mae: 4.2591 - lr: 0.0010
# Epoch 29/500
# 4/4 [==============================] - 0s 46ms/step - loss: 19.3710 - mae: 4.2427 - val_loss: 19.5080 - val_mae: 4.2586 - lr: 0.0010
# Epoch 30/500
# 4/4 [==============================] - 0s 45ms/step - loss: 19.3552 - mae: 4.2408 - val_loss: 19.5042 - val_mae: 4.2580 - lr: 0.0010
# Epoch 31/500
# 4/4 [==============================] - 0s 45ms/step - loss: 19.3381 - mae: 4.2388 - val_loss: 19.5003 - val_mae: 4.2574 - lr: 0.0010
# Epoch 32/500
# 4/4 [==============================] - 0s 43ms/step - loss: 19.3199 - mae: 4.2366 - val_loss: 19.4961 - val_mae: 4.2568 - lr: 0.0010
# Epoch 33/500
# 4/4 [==============================] - 0s 43ms/step - loss: 19.3003 - mae: 4.2342 - val_loss: 19.4916 - val_mae: 4.2561 - lr: 0.0010
# Epoch 34/500
# 4/4 [==============================] - 0s 44ms/step - loss: 19.2794 - mae: 4.2317 - val_loss: 19.4870 - val_mae: 4.2554 - lr: 0.0010
# Epoch 35/500
# 4/4 [==============================] - 0s 45ms/step - loss: 19.2572 - mae: 4.2290 - val_loss: 19.4821 - val_mae: 4.2546 - lr: 0.0010
# Epoch 36/500
# 4/4 [==============================] - 0s 43ms/step - loss: 19.2335 - mae: 4.2261 - val_loss: 19.4770 - val_mae: 4.2538 - lr: 0.0010
# Epoch 37/500
# 4/4 [==============================] - 0s 47ms/step - loss: 19.2084 - mae: 4.2231 - val_loss: 19.4717 - val_mae: 4.2530 - lr: 0.0010
# Epoch 38/500
# 4/4 [==============================] - 0s 44ms/step - loss: 19.1819 - mae: 4.2198 - val_loss: 19.4662 - val_mae: 4.2521 - lr: 0.0010
# Epoch 39/500
# 4/4 [==============================] - 0s 44ms/step - loss: 19.1539 - mae: 4.2164 - val_loss: 19.4605 - val_mae: 4.2511 - lr: 0.0010
# Epoch 40/500
# 4/4 [==============================] - 0s 41ms/step - loss: 19.1244 - mae: 4.2128 - val_loss: 19.4546 - val_mae: 4.2501 - lr: 0.0010
# Epoch 41/500
# 4/4 [==============================] - 0s 42ms/step - loss: 19.0934 - mae: 4.2089 - val_loss: 19.4485 - val_mae: 4.2491 - lr: 0.0010
# Epoch 42/500
# 4/4 [==============================] - 0s 42ms/step - loss: 19.0609 - mae: 4.2049 - val_loss: 19.4422 - val_mae: 4.2480 - lr: 0.0010
# Epoch 43/500
# 4/4 [==============================] - 0s 45ms/step - loss: 19.0268 - mae: 4.2007 - val_loss: 19.4357 - val_mae: 4.2469 - lr: 0.0010
# Epoch 44/500
# 4/4 [==============================] - 0s 45ms/step - loss: 18.9912 - mae: 4.1962 - val_loss: 19.4291 - val_mae: 4.2457 - lr: 0.0010
# Epoch 45/500
# 4/4 [==============================] - 0s 43ms/step - loss: 18.9540 - mae: 4.1916 - val_loss: 19.4222 - val_mae: 4.2445 - lr: 0.0010
# Epoch 46/500
# 4/4 [==============================] - 0s 42ms/step - loss: 18.9152 - mae: 4.1867 - val_loss: 19.4153 - val_mae: 4.2432 - lr: 0.0010
# Epoch 47/500
# 4/4 [==============================] - 0s 45ms/step - loss: 18.8749 - mae: 4.1817 - val_loss: 19.4081 - val_mae: 4.2419 - lr: 0.0010
# Epoch 48/500
# 4/4 [==============================] - 0s 43ms/step - loss: 18.8330 - mae: 4.1764 - val_loss: 19.4009 - val_mae: 4.2406 - lr: 0.0010
# Epoch 49/500
# 4/4 [==============================] - 0s 46ms/step - loss: 18.7896 - mae: 4.1709 - val_loss: 19.3935 - val_mae: 4.2392 - lr: 0.0010
# Epoch 50/500
# 4/4 [==============================] - 0s 42ms/step - loss: 18.7445 - mae: 4.1652 - val_loss: 19.3859 - val_mae: 4.2377 - lr: 0.0010
# Epoch 51/500
# 4/4 [==============================] - 0s 45ms/step - loss: 18.6980 - mae: 4.1593 - val_loss: 19.3783 - val_mae: 4.2363 - lr: 0.0010
# Epoch 52/500
# 4/4 [==============================] - 0s 44ms/step - loss: 18.6498 - mae: 4.1531 - val_loss: 19.3705 - val_mae: 4.2347 - lr: 0.0010
# Epoch 53/500
# 4/4 [==============================] - 0s 46ms/step - loss: 18.6002 - mae: 4.1468 - val_loss: 19.3626 - val_mae: 4.2332 - lr: 0.0010
# Epoch 54/500
# 4/4 [==============================] - 0s 46ms/step - loss: 18.5490 - mae: 4.1402 - val_loss: 19.3547 - val_mae: 4.2315 - lr: 0.0010
# Epoch 55/500
# 4/4 [==============================] - 0s 43ms/step - loss: 18.4962 - mae: 4.1334 - val_loss: 19.3466 - val_mae: 4.2299 - lr: 0.0010
# Epoch 56/500
# 4/4 [==============================] - 0s 43ms/step - loss: 18.4420 - mae: 4.1264 - val_loss: 19.3385 - val_mae: 4.2282 - lr: 0.0010
# Epoch 57/500
# 4/4 [==============================] - 0s 43ms/step - loss: 18.3863 - mae: 4.1192 - val_loss: 19.3303 - val_mae: 4.2264 - lr: 0.0010
# Epoch 58/500
# 4/4 [==============================] - 0s 45ms/step - loss: 18.3291 - mae: 4.1117 - val_loss: 19.3221 - val_mae: 4.2247 - lr: 0.0010
# Epoch 59/500
# 4/4 [==============================] - 0s 45ms/step - loss: 18.2705 - mae: 4.1041 - val_loss: 19.3138 - val_mae: 4.2228 - lr: 0.0010
# Epoch 60/500
# 4/4 [==============================] - 0s 42ms/step - loss: 18.2104 - mae: 4.0962 - val_loss: 19.3054 - val_mae: 4.2210 - lr: 0.0010
# Epoch 61/500
# 4/4 [==============================] - 0s 49ms/step - loss: 18.1489 - mae: 4.0881 - val_loss: 19.2971 - val_mae: 4.2191 - lr: 0.0010
# Epoch 62/500
# 4/4 [==============================] - 0s 44ms/step - loss: 18.0860 - mae: 4.0798 - val_loss: 19.2887 - val_mae: 4.2171 - lr: 0.0010
# Epoch 63/500
# 4/4 [==============================] - 0s 45ms/step - loss: 18.0218 - mae: 4.0713 - val_loss: 19.2803 - val_mae: 4.2151 - lr: 0.0010
# Epoch 64/500
# 4/4 [==============================] - 0s 42ms/step - loss: 17.9562 - mae: 4.0625 - val_loss: 19.2719 - val_mae: 4.2131 - lr: 0.0010
# Epoch 65/500
# 4/4 [==============================] - 0s 41ms/step - loss: 17.8893 - mae: 4.0536 - val_loss: 19.2636 - val_mae: 4.2111 - lr: 0.0010
# Epoch 66/500
# 4/4 [==============================] - 0s 44ms/step - loss: 17.8212 - mae: 4.0444 - val_loss: 19.2552 - val_mae: 4.2090 - lr: 0.0010
# Epoch 67/500
# 4/4 [==============================] - 0s 57ms/step - loss: 17.7517 - mae: 4.0351 - val_loss: 19.2469 - val_mae: 4.2068 - lr: 0.0010
# Epoch 68/500
# 4/4 [==============================] - 0s 44ms/step - loss: 17.6811 - mae: 4.0255 - val_loss: 19.2386 - val_mae: 4.2047 - lr: 0.0010
# Epoch 69/500
# 4/4 [==============================] - 0s 43ms/step - loss: 17.6092 - mae: 4.0157 - val_loss: 19.2303 - val_mae: 4.2025 - lr: 0.0010
# Epoch 70/500
# 4/4 [==============================] - 0s 48ms/step - loss: 17.5361 - mae: 4.0057 - val_loss: 19.2221 - val_mae: 4.2002 - lr: 0.0010
# Epoch 71/500
# 4/4 [==============================] - 0s 62ms/step - loss: 17.4619 - mae: 3.9956 - val_loss: 19.2140 - val_mae: 4.1980 - lr: 0.0010
# Epoch 72/500
# 4/4 [==============================] - 0s 44ms/step - loss: 17.3866 - mae: 3.9852 - val_loss: 19.2059 - val_mae: 4.1957 - lr: 0.0010
# Epoch 73/500
# 4/4 [==============================] - 0s 45ms/step - loss: 17.3102 - mae: 3.9746 - val_loss: 19.1980 - val_mae: 4.1933 - lr: 0.0010
# Epoch 74/500
# 4/4 [==============================] - 0s 43ms/step - loss: 17.2328 - mae: 3.9639 - val_loss: 19.1901 - val_mae: 4.1910 - lr: 0.0010
# Epoch 75/500
# 4/4 [==============================] - 0s 50ms/step - loss: 17.1543 - mae: 3.9529 - val_loss: 19.1823 - val_mae: 4.1886 - lr: 0.0010
# Epoch 76/500
# 4/4 [==============================] - 0s 55ms/step - loss: 17.0749 - mae: 3.9418 - val_loss: 19.1746 - val_mae: 4.1862 - lr: 0.0010
# Epoch 77/500
# 4/4 [==============================] - 0s 43ms/step - loss: 16.9944 - mae: 3.9304 - val_loss: 19.1671 - val_mae: 4.1837 - lr: 0.0010
# Epoch 78/500
# 4/4 [==============================] - 0s 47ms/step - loss: 16.9131 - mae: 3.9189 - val_loss: 19.1596 - val_mae: 4.1812 - lr: 0.0010
# Epoch 79/500
# 4/4 [==============================] - 0s 44ms/step - loss: 16.8309 - mae: 3.9072 - val_loss: 19.1523 - val_mae: 4.1787 - lr: 0.0010
# Epoch 80/500
# 4/4 [==============================] - 0s 46ms/step - loss: 16.7478 - mae: 3.8954 - val_loss: 19.1451 - val_mae: 4.1762 - lr: 0.0010
# Epoch 81/500
# 4/4 [==============================] - 0s 43ms/step - loss: 16.6639 - mae: 3.8833 - val_loss: 19.1381 - val_mae: 4.1736 - lr: 0.0010
# Epoch 82/500
# 4/4 [==============================] - 0s 42ms/step - loss: 16.5792 - mae: 3.8711 - val_loss: 19.1312 - val_mae: 4.1710 - lr: 0.0010
# Epoch 83/500
# 4/4 [==============================] - 0s 42ms/step - loss: 16.4937 - mae: 3.8587 - val_loss: 19.1245 - val_mae: 4.1684 - lr: 0.0010
# Epoch 84/500
# 4/4 [==============================] - 0s 45ms/step - loss: 16.4075 - mae: 3.8461 - val_loss: 19.1180 - val_mae: 4.1658 - lr: 0.0010
# Epoch 85/500
# 4/4 [==============================] - 0s 47ms/step - loss: 16.3207 - mae: 3.8334 - val_loss: 19.1116 - val_mae: 4.1631 - lr: 0.0010
# Epoch 86/500
# 4/4 [==============================] - 0s 44ms/step - loss: 16.2331 - mae: 3.8205 - val_loss: 19.1054 - val_mae: 4.1605 - lr: 0.0010
# Epoch 87/500
# 4/4 [==============================] - 0s 45ms/step - loss: 16.1450 - mae: 3.8075 - val_loss: 19.0995 - val_mae: 4.1578 - lr: 0.0010
# Epoch 88/500
# 4/4 [==============================] - 0s 45ms/step - loss: 16.0562 - mae: 3.7942 - val_loss: 19.0937 - val_mae: 4.1551 - lr: 0.0010
# Epoch 89/500
# 4/4 [==============================] - 0s 43ms/step - loss: 15.9669 - mae: 3.7809 - val_loss: 19.0881 - val_mae: 4.1523 - lr: 0.0010
# Epoch 90/500
# 4/4 [==============================] - 0s 44ms/step - loss: 15.8771 - mae: 3.7674 - val_loss: 19.0827 - val_mae: 4.1496 - lr: 0.0010
# Epoch 91/500
# 4/4 [==============================] - 0s 45ms/step - loss: 15.7867 - mae: 3.7537 - val_loss: 19.0775 - val_mae: 4.1468 - lr: 0.0010
# Epoch 92/500
# 4/4 [==============================] - 0s 44ms/step - loss: 15.6960 - mae: 3.7399 - val_loss: 19.0726 - val_mae: 4.1440 - lr: 0.0010
# Epoch 93/500
# 4/4 [==============================] - 0s 44ms/step - loss: 15.6047 - mae: 3.7260 - val_loss: 19.0679 - val_mae: 4.1412 - lr: 0.0010
# Epoch 94/500
# 4/4 [==============================] - 0s 53ms/step - loss: 15.5131 - mae: 3.7119 - val_loss: 19.0634 - val_mae: 4.1384 - lr: 0.0010
# Epoch 95/500
# 4/4 [==============================] - 0s 44ms/step - loss: 15.4212 - mae: 3.6977 - val_loss: 19.0592 - val_mae: 4.1355 - lr: 0.0010
# Epoch 96/500
# 4/4 [==============================] - 0s 45ms/step - loss: 15.3288 - mae: 3.6833 - val_loss: 19.0552 - val_mae: 4.1327 - lr: 0.0010
# Epoch 97/500
# 4/4 [==============================] - 0s 43ms/step - loss: 15.2362 - mae: 3.6688 - val_loss: 19.0514 - val_mae: 4.1298 - lr: 0.0010
# Epoch 98/500
# 4/4 [==============================] - 0s 51ms/step - loss: 15.1433 - mae: 3.6542 - val_loss: 19.0479 - val_mae: 4.1270 - lr: 0.0010
# Epoch 99/500
# 4/4 [==============================] - 0s 45ms/step - loss: 15.0502 - mae: 3.6395 - val_loss: 19.0447 - val_mae: 4.1241 - lr: 0.0010
# Epoch 100/500
# 4/4 [==============================] - 0s 47ms/step - loss: 14.9569 - mae: 3.6246 - val_loss: 19.0417 - val_mae: 4.1212 - lr: 0.0010
# Epoch 101/500
# 4/4 [==============================] - 0s 50ms/step - loss: 14.8634 - mae: 3.6097 - val_loss: 19.0390 - val_mae: 4.1183 - lr: 0.0010
# Epoch 102/500
# 4/4 [==============================] - 0s 44ms/step - loss: 14.7697 - mae: 3.5946 - val_loss: 19.0365 - val_mae: 4.1154 - lr: 0.0010
# Epoch 103/500
# 4/4 [==============================] - 0s 43ms/step - loss: 14.6759 - mae: 3.5794 - val_loss: 19.0344 - val_mae: 4.1125 - lr: 0.0010
# Epoch 104/500
# 4/4 [==============================] - 0s 44ms/step - loss: 14.5820 - mae: 3.5641 - val_loss: 19.0324 - val_mae: 4.1096 - lr: 0.0010
# Epoch 105/500
# 4/4 [==============================] - 0s 43ms/step - loss: 14.4881 - mae: 3.5487 - val_loss: 19.0308 - val_mae: 4.1066 - lr: 0.0010
# Epoch 106/500
# 4/4 [==============================] - 0s 45ms/step - loss: 14.3941 - mae: 3.5332 - val_loss: 19.0294 - val_mae: 4.1037 - lr: 0.0010
# Epoch 107/500
# 4/4 [==============================] - 0s 44ms/step - loss: 14.3001 - mae: 3.5176 - val_loss: 19.0284 - val_mae: 4.1008 - lr: 0.0010
# Epoch 108/500
# 4/4 [==============================] - 0s 50ms/step - loss: 14.2061 - mae: 3.5019 - val_loss: 19.0276 - val_mae: 4.0978 - lr: 0.0010
# Epoch 109/500
# 4/4 [==============================] - 0s 46ms/step - loss: 14.1122 - mae: 3.4862 - val_loss: 19.0271 - val_mae: 4.0949 - lr: 0.0010
# Epoch 110/500
# 4/4 [==============================] - 0s 43ms/step - loss: 14.0183 - mae: 3.4703 - val_loss: 19.0269 - val_mae: 4.0919 - lr: 0.0010
# Epoch 111/500
# 4/4 [==============================] - 0s 46ms/step - loss: 13.9245 - mae: 3.4544 - val_loss: 19.0269 - val_mae: 4.0890 - lr: 0.0010
# Epoch 112/500
# 4/4 [==============================] - 0s 45ms/step - loss: 13.8309 - mae: 3.4383 - val_loss: 19.0273 - val_mae: 4.0860 - lr: 0.0010
# Epoch 113/500
# 4/4 [==============================] - 0s 44ms/step - loss: 13.7373 - mae: 3.4222 - val_loss: 19.0279 - val_mae: 4.0831 - lr: 0.0010
# Epoch 114/500
# 4/4 [==============================] - 0s 42ms/step - loss: 13.6440 - mae: 3.4061 - val_loss: 19.0289 - val_mae: 4.0801 - lr: 0.0010
# Epoch 115/500
# 4/4 [==============================] - 0s 43ms/step - loss: 13.5509 - mae: 3.3898 - val_loss: 19.0301 - val_mae: 4.0772 - lr: 0.0010
# Epoch 116/500
# 4/4 [==============================] - 0s 43ms/step - loss: 13.4579 - mae: 3.3735 - val_loss: 19.0316 - val_mae: 4.0743 - lr: 0.0010
# Epoch 117/500
# 4/4 [==============================] - 0s 43ms/step - loss: 13.3652 - mae: 3.3571 - val_loss: 19.0334 - val_mae: 4.0713 - lr: 0.0010
# Epoch 118/500
# 4/4 [==============================] - 0s 44ms/step - loss: 13.2727 - mae: 3.3407 - val_loss: 19.0355 - val_mae: 4.0684 - lr: 0.0010
# Epoch 119/500
# 4/4 [==============================] - 0s 42ms/step - loss: 13.1805 - mae: 3.3242 - val_loss: 19.0379 - val_mae: 4.0655 - lr: 0.0010
# Epoch 120/500
# 4/4 [==============================] - 0s 47ms/step - loss: 13.0887 - mae: 3.3077 - val_loss: 19.0405 - val_mae: 4.0626 - lr: 0.0010
# Epoch 121/500
# 4/4 [==============================] - 0s 42ms/step - loss: 12.9971 - mae: 3.2911 - val_loss: 19.0435 - val_mae: 4.0596 - lr: 0.0010
# Epoch 122/500
# 4/4 [==============================] - 0s 42ms/step - loss: 12.9059 - mae: 3.2744 - val_loss: 19.0468 - val_mae: 4.0567 - lr: 0.0010
# Epoch 123/500
# 4/4 [==============================] - 0s 42ms/step - loss: 12.8150 - mae: 3.2577 - val_loss: 19.0503 - val_mae: 4.0538 - lr: 0.0010
# Epoch 124/500
# 4/4 [==============================] - 0s 41ms/step - loss: 12.7245 - mae: 3.2410 - val_loss: 19.0541 - val_mae: 4.0509 - lr: 0.0010
# Epoch 125/500
# 4/4 [==============================] - 0s 44ms/step - loss: 12.6344 - mae: 3.2242 - val_loss: 19.0583 - val_mae: 4.0481 - lr: 0.0010
# Epoch 126/500
# 4/4 [==============================] - 0s 44ms/step - loss: 12.5447 - mae: 3.2074 - val_loss: 19.0627 - val_mae: 4.0452 - lr: 0.0010
# Epoch 127/500
# 4/4 [==============================] - 0s 43ms/step - loss: 12.4555 - mae: 3.1906 - val_loss: 19.0674 - val_mae: 4.0423 - lr: 0.0010
# Epoch 128/500
# 4/4 [==============================] - 0s 41ms/step - loss: 12.3667 - mae: 3.1737 - val_loss: 19.0724 - val_mae: 4.0395 - lr: 0.0010
# Epoch 129/500
# 4/4 [==============================] - 0s 42ms/step - loss: 12.2783 - mae: 3.1568 - val_loss: 19.0776 - val_mae: 4.0366 - lr: 0.0010
# Epoch 130/500
# 4/4 [==============================] - 0s 47ms/step - loss: 12.1904 - mae: 3.1399 - val_loss: 19.0831 - val_mae: 4.0338 - lr: 0.0010
# Epoch 131/500
# 4/4 [==============================] - 0s 47ms/step - loss: 12.1030 - mae: 3.1230 - val_loss: 19.0890 - val_mae: 4.0310 - lr: 0.0010
# Epoch 132/500
# 4/4 [==============================] - 0s 47ms/step - loss: 12.0161 - mae: 3.1060 - val_loss: 19.0950 - val_mae: 4.0282 - lr: 0.0010
# Epoch 133/500
# 4/4 [==============================] - 0s 43ms/step - loss: 11.9297 - mae: 3.0891 - val_loss: 19.1014 - val_mae: 4.0254 - lr: 0.0010
# Epoch 134/500
# 4/4 [==============================] - 0s 42ms/step - loss: 11.8438 - mae: 3.0721 - val_loss: 19.1080 - val_mae: 4.0226 - lr: 0.0010
# Epoch 135/500
# 4/4 [==============================] - 0s 44ms/step - loss: 11.7585 - mae: 3.0551 - val_loss: 19.1149 - val_mae: 4.0199 - lr: 0.0010
# Epoch 136/500
# 4/4 [==============================] - 0s 43ms/step - loss: 11.6737 - mae: 3.0381 - val_loss: 19.1220 - val_mae: 4.0171 - lr: 0.0010
# Epoch 137/500
# 4/4 [==============================] - 0s 42ms/step - loss: 11.5895 - mae: 3.0211 - val_loss: 19.1294 - val_mae: 4.0144 - lr: 0.0010
# Epoch 138/500
# 4/4 [==============================] - 0s 45ms/step - loss: 11.5059 - mae: 3.0042 - val_loss: 19.1370 - val_mae: 4.0117 - lr: 0.0010
# Epoch 139/500
# 4/4 [==============================] - 0s 44ms/step - loss: 11.4228 - mae: 2.9872 - val_loss: 19.1449 - val_mae: 4.0090 - lr: 0.0010
# Epoch 140/500
# 4/4 [==============================] - 0s 43ms/step - loss: 11.3404 - mae: 2.9702 - val_loss: 19.1530 - val_mae: 4.0063 - lr: 0.0010
# Epoch 141/500
# 4/4 [==============================] - 0s 43ms/step - loss: 11.2585 - mae: 2.9532 - val_loss: 19.1614 - val_mae: 4.0036 - lr: 0.0010
# Epoch 142/500
# 4/4 [==============================] - 0s 45ms/step - loss: 11.1773 - mae: 2.9363 - val_loss: 19.1700 - val_mae: 4.0010 - lr: 0.0010
# Epoch 143/500
# 4/4 [==============================] - 0s 44ms/step - loss: 11.0967 - mae: 2.9193 - val_loss: 19.1789 - val_mae: 3.9984 - lr: 0.0010
# Epoch 144/500
# 4/4 [==============================] - 0s 44ms/step - loss: 11.0167 - mae: 2.9024 - val_loss: 19.1880 - val_mae: 3.9957 - lr: 0.0010
# Epoch 145/500
# 4/4 [==============================] - 0s 46ms/step - loss: 10.9373 - mae: 2.8855 - val_loss: 19.1973 - val_mae: 3.9931 - lr: 0.0010
# Epoch 146/500
# 4/4 [==============================] - 0s 46ms/step - loss: 10.8586 - mae: 2.8686 - val_loss: 19.2068 - val_mae: 3.9906 - lr: 0.0010
# Epoch 147/500
# 4/4 [==============================] - 0s 48ms/step - loss: 10.7806 - mae: 2.8517 - val_loss: 19.2166 - val_mae: 3.9880 - lr: 0.0010
# Epoch 148/500
# 4/4 [==============================] - 0s 45ms/step - loss: 10.7031 - mae: 2.8349 - val_loss: 19.2265 - val_mae: 3.9855 - lr: 0.0010
# Epoch 149/500
# 4/4 [==============================] - 0s 42ms/step - loss: 10.6264 - mae: 2.8180 - val_loss: 19.2367 - val_mae: 3.9830 - lr: 0.0010
# Epoch 150/500
# 4/4 [==============================] - 0s 44ms/step - loss: 10.5503 - mae: 2.8013 - val_loss: 19.2471 - val_mae: 3.9805 - lr: 0.0010
# Epoch 151/500
# 4/4 [==============================] - 0s 44ms/step - loss: 10.4749 - mae: 2.7845 - val_loss: 19.2576 - val_mae: 3.9780 - lr: 0.0010
# Epoch 152/500
# 4/4 [==============================] - 0s 45ms/step - loss: 10.4002 - mae: 2.7678 - val_loss: 19.2684 - val_mae: 3.9755 - lr: 0.0010
# Epoch 153/500
# 4/4 [==============================] - 0s 42ms/step - loss: 10.3262 - mae: 2.7511 - val_loss: 19.2794 - val_mae: 3.9731 - lr: 0.0010
# Epoch 154/500
# 4/4 [==============================] - 0s 44ms/step - loss: 10.2528 - mae: 2.7345 - val_loss: 19.2906 - val_mae: 3.9707 - lr: 0.0010
# Epoch 155/500
# 4/4 [==============================] - 0s 45ms/step - loss: 10.1801 - mae: 2.7179 - val_loss: 19.3019 - val_mae: 3.9683 - lr: 0.0010
# Epoch 156/500
# 4/4 [==============================] - 0s 43ms/step - loss: 10.1081 - mae: 2.7013 - val_loss: 19.3134 - val_mae: 3.9659 - lr: 0.0010
# Epoch 157/500
# 4/4 [==============================] - 0s 45ms/step - loss: 10.0368 - mae: 2.6848 - val_loss: 19.3251 - val_mae: 3.9635 - lr: 0.0010
# Epoch 158/500
# 4/4 [==============================] - 0s 48ms/step - loss: 9.9662 - mae: 2.6684 - val_loss: 19.3370 - val_mae: 3.9612 - lr: 0.0010
# Epoch 159/500
# 4/4 [==============================] - 0s 45ms/step - loss: 9.8963 - mae: 2.6520 - val_loss: 19.3490 - val_mae: 3.9589 - lr: 0.0010
# Epoch 160/500
# 4/4 [==============================] - 0s 44ms/step - loss: 9.8272 - mae: 2.6356 - val_loss: 19.3612 - val_mae: 3.9566 - lr: 0.0010
# CPU times: user 1min 34s, sys: 4.38 s, total: 1min 38s
# Wall time: 31.3 s

# %%
y_true = ratings_test
predictions = model.predict([user_ids_test, item_ids_test])
# Out:
# 30004/30004 [==============================] - 40s 1ms/step

# %%
# Evaluar el modelo con el conjunto de prueba
loss, mae = model.evaluate([user_ids_test, item_ids_test], ratings_test)
print(f'Test Loss: {loss:.4f}')
print(f'Test MAE: {mae:.4f}')
# Out:
# 30004/30004 [==============================] - 78s 3ms/step - loss: 19.3491 - mae: 3.9537
# Test Loss: 19.3491
# Test MAE: 3.9537

# %%
# MSE
mse = mean_squared_error(y_true, predictions)
print(f"MSE: {mse:.4f}")

# RMSE
rmse = np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")

# MAE
mae = mean_absolute_error(y_true, predictions)
print(f"MAE: {mae:.4f}")

# MAPE (Mean Absolute Percentage Error)
mape = np.mean(np.abs((y_true - predictions.flatten()) / y_true)) * 100
print(f"MAPE: {mape:.2f}%")
# Out:
# MSE: 17.9036
# RMSE: 4.2313
# MAE: 3.9537
# MAPE: 92.83%

# %% [markdown]
# # Recomedanción

# %%
# Seleccionar un usuario al azar del conjunto de prueba
usuario_id_test_encoded = random.choice(user_ids_test)

# Decodificar el ID del usuario para obtener el ID original
usuario_id_test = reviewerID_encoder.inverse_transform([usuario_id_test_encoded])[0]

# Identificar los ítems que el usuario ha calificado en el conjunto de prueba
indices_usuario = np.where(user_ids_test == usuario_id_test_encoded)[0]
items_calificados_test_encoded = item_ids_test[indices_usuario]
calificaciones_reales_test = ratings_test[indices_usuario]

# Predecir las calificaciones para estos ítems
calificaciones_predichas = model.predict([np.array([usuario_id_test_encoded] * len(items_calificados_test_encoded)), items_calificados_test_encoded])

# Decodificar los ítems para obtener los ID originales
items_calificados_test = asin_encoder.inverse_transform(items_calificados_test_encoded)

# Comparar las calificaciones predichas con las reales
comparacion = list(zip(items_calificados_test, calificaciones_reales_test, calificaciones_predichas.flatten()))

# Mostrar las comparaciones
print(f"Recomendaciones para el usuario {usuario_id_test}:")
for item, real, predicha in comparacion:
    print(f"Ítem: {item}, Calificación Real: {real}, Calificación Predicha: {predicha}")
# Out:
# 1/1 [==============================] - 0s 18ms/step
# Recomendaciones para el usuario A2G9AVNR3TJW7F:
# Ítem: B01G6XDS3K, Calificación Real: 5.0, Calificación Predicha: -75.36486053466797
# Ítem: B00HN1UJQY, Calificación Real: 5.0, Calificación Predicha: -76.27241516113281
# Ítem: B015CONUEQ, Calificación Real: 5.0, Calificación Predicha: -74.96355438232422
# Ítem: B017LZ4KMU, Calificación Real: 5.0, Calificación Predicha: -74.83280944824219
# Ítem: B00YFOO7PG, Calificación Real: 5.0, Calificación Predicha: -75.20083618164062

# %%
# Seleccionar un usuario al azar del conjunto de prueba
usuario_id_test_encoded = random.choice(user_ids_test)

# Decodificar el ID del usuario para obtener el ID original
usuario_id = reviewerID_encoder.inverse_transform([usuario_id_test_encoded])[0]

# Lista de todos los ítems únicos en el dataset
items_unicos = np.unique(data['asin'].values)

# Ítems que el usuario ya ha calificado
items_calificados = data[data['reviewerID_encoded'] == usuario_id_test_encoded]['asin'].tolist()

# Ítems para predecir
items_a_predecir = [item for item in items_unicos if item not in items_calificados]

# Convierte los ítems a su representación codificada
items_a_predecir_encoded = asin_encoder.transform(items_a_predecir)

# Predecir la calificación para cada ítem no calificado
predicciones = model.predict([np.array([usuario_id_test_encoded] * len(items_a_predecir_encoded)), items_a_predecir_encoded])

# Emparejar cada ítem con su predicción
items_predicciones = list(zip(items_a_predecir, predicciones.flatten()))

# Ordenar por la calificación predicha más alta
items_recomendados = sorted(items_predicciones, key=lambda x: x[1], reverse=True)

# Tomar los top N recomendaciones
top_n = 5
top_recomendaciones = items_recomendados[:top_n]

# Imprimir las recomendaciones
print(f"Recomendaciones para el usuario {usuario_id}:")
for item, calificacion in top_recomendaciones:
    print(f"Ítem: {item}, Calificación Predicha: {calificacion}")
# Out:
# 4814/4814 [==============================] - 7s 1ms/step
# Recomendaciones para el usuario A1AS9DWV9MXZXF:
# Ítem: B000ZI9Q8O, Calificación Predicha: 0.0008771164575591683
# Ítem: B005BD9NPY, Calificación Predicha: 0.0008653445402160287
# Ítem: B00AETVUC4, Calificación Predicha: 0.0008630891097709537
# Ítem: B0150DSI7S, Calificación Predicha: 0.0008602667367085814
# Ítem: B00YS136TY, Calificación Predicha: 0.0008479505777359009

# %% [markdown]
# # Modelo de Filtrado Colaborativo usando Red Neuronal Multicapa con Keras:

# %% [markdown]
# Funcionamiento:
#
# Estos sistemas toman características de los ítems y/o usuarios y las pasan a través de una o varias capas de neuronas para obtener una predicción.
# Las redes neuronales son capaces de capturar interacciones no lineales entre características, lo que las hace poderosas para tareas de modelado complejas.
#
# Ventajas:
#
# Capacidad de modelar relaciones no lineales.
#
# Flexibilidad para incorporar múltiples fuentes de datos o características.
#
# Puede manejar arranques en frío al incorporar características de nuevos ítems o usuarios.
#
# Desventajas:
#
# Mayor costo computacional en comparación con los sistemas basados únicamente en embeddings.
#
# Riesgo de sobreajuste si no se tiene un conjunto de datos lo suficientemente grande.

# %% [markdown]
# Ahora el código incluye regularización en los embeddings, early stopping para detener el entrenamiento si el modelo deja de mejorar en el conjunto de validación, y reducción de la tasa de aprendizaje si el error en el conjunto de validación no mejora después de algunas épocas. Estas adiciones deberían ayudar a mejorar la capacidad de generalización del modelo.

# %%
df['user_id'] = df['reviewerID'].astype('category').cat.codes.values
df['item_id'] = df['asin'].astype('category').cat.codes.values

# Número de usuarios e ítems
n_users = df['user_id'].nunique()
n_items = df['item_id'].nunique()

# Hiperparámetros
hidden_units = [128, 64, 32]
dropout_rate = 0.2
l2_reg = 1e-6

# Arquitectura del modelo
user_input = Input(shape=[1], name='user_input')
item_input = Input(shape=[1], name='item_input')
concat = Concatenate()([user_input, item_input])
dense = concat
for units in hidden_units:
    dense = Dense(units, activation='relu', kernel_regularizer=l2(l2_reg))(dense)
    dense = Dropout(dropout_rate)(dense)
output = Dense(1, kernel_regularizer=l2(l2_reg))(dense)  # También puedes aplicar regularización L2 aquí
model = Model(inputs=[user_input, item_input], outputs=output)
model.compile(optimizer=Adam(0.001), loss='mean_squared_error')

# %%
# Callbacks
early_stop = EarlyStopping(monitor='val_loss', patience=50)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=50, min_lr=1e-5)

# %%
# Datos para entrenamiento
user_data = df['user_id'].values
item_data = df['item_id'].values
rating_data = df['overall'].values

# División en entrenamiento y prueba
(user_ids_temp, user_ids_test, item_ids_temp, item_ids_test, ratings_temp, ratings_test) = train_test_split(
    user_ids, item_ids, ratings, test_size=0.2, random_state=42)

# División del conjunto de entrenamiento en entrenamiento y validación
(user_ids_train, user_ids_val, item_ids_train, item_ids_val, ratings_train, ratings_val) = train_test_split(
    user_ids_temp, item_ids_temp, ratings_temp, test_size=0.25, random_state=42)  # 0.25 x 0.8 = 0.2

# %%
# %%time
# Entrenamiento del modelo
history = model.fit([user_ids_train, item_ids_train], ratings_train,
    epochs=500,validation_data=([user_ids_val, item_ids_val], ratings_val),
    batch_size=800000,verbose=1,callbacks=[early_stop, reduce_lr])
# Out:
# Epoch 1/500
# 4/4 [==============================] - 2s 171ms/step - loss: 6219594752.0000 - val_loss: 18189408.0000 - lr: 0.0010
# Epoch 2/500
# 4/4 [==============================] - 0s 109ms/step - loss: 2213936640.0000 - val_loss: 1111966848.0000 - lr: 0.0010
# Epoch 3/500
# 4/4 [==============================] - 0s 107ms/step - loss: 2146873344.0000 - val_loss: 530549856.0000 - lr: 0.0010
# Epoch 4/500
# 4/4 [==============================] - 0s 108ms/step - loss: 1224702720.0000 - val_loss: 181505744.0000 - lr: 0.0010
# Epoch 5/500
# 4/4 [==============================] - 0s 105ms/step - loss: 695249920.0000 - val_loss: 38696456.0000 - lr: 0.0010
# Epoch 6/500
# 4/4 [==============================] - 0s 103ms/step - loss: 547818944.0000 - val_loss: 3005744.5000 - lr: 0.0010
# Epoch 7/500
# 4/4 [==============================] - 0s 106ms/step - loss: 488998144.0000 - val_loss: 1629905.2500 - lr: 0.0010
# Epoch 8/500
# 4/4 [==============================] - 0s 103ms/step - loss: 392994944.0000 - val_loss: 9654560.0000 - lr: 0.0010
# Epoch 9/500
# 4/4 [==============================] - 0s 104ms/step - loss: 307708736.0000 - val_loss: 16934786.0000 - lr: 0.0010
# Epoch 10/500
# 4/4 [==============================] - 0s 105ms/step - loss: 257089488.0000 - val_loss: 7473872.5000 - lr: 0.0010
# Epoch 11/500
# 4/4 [==============================] - 0s 103ms/step - loss: 221654944.0000 - val_loss: 644322.4375 - lr: 0.0010
# Epoch 12/500
# 4/4 [==============================] - 0s 103ms/step - loss: 186050576.0000 - val_loss: 556936.8125 - lr: 0.0010
# Epoch 13/500
# 4/4 [==============================] - 0s 105ms/step - loss: 154478064.0000 - val_loss: 736131.0625 - lr: 0.0010
# Epoch 14/500
# 4/4 [==============================] - 0s 104ms/step - loss: 128767152.0000 - val_loss: 3021738.2500 - lr: 0.0010
# Epoch 15/500
# 4/4 [==============================] - 0s 103ms/step - loss: 106530288.0000 - val_loss: 4075405.7500 - lr: 0.0010
# Epoch 16/500
# 4/4 [==============================] - 0s 103ms/step - loss: 87551584.0000 - val_loss: 3890101.7500 - lr: 0.0010
# Epoch 17/500
# 4/4 [==============================] - 0s 103ms/step - loss: 72874872.0000 - val_loss: 3423360.5000 - lr: 0.0010
# Epoch 18/500
# 4/4 [==============================] - 0s 105ms/step - loss: 60861924.0000 - val_loss: 2414363.5000 - lr: 0.0010
# Epoch 19/500
# 4/4 [==============================] - 0s 103ms/step - loss: 50531112.0000 - val_loss: 789450.1875 - lr: 0.0010
# Epoch 20/500
# 4/4 [==============================] - 0s 103ms/step - loss: 42186000.0000 - val_loss: 121007.6172 - lr: 0.0010
# Epoch 21/500
# 4/4 [==============================] - 0s 105ms/step - loss: 35640092.0000 - val_loss: 21602.4004 - lr: 0.0010
# Epoch 22/500
# 4/4 [==============================] - 0s 104ms/step - loss: 30296532.0000 - val_loss: 8073.3599 - lr: 0.0010
# Epoch 23/500
# 4/4 [==============================] - 0s 104ms/step - loss: 26000150.0000 - val_loss: 2232.5488 - lr: 0.0010
# Epoch 24/500
# 4/4 [==============================] - 0s 102ms/step - loss: 22570552.0000 - val_loss: 1411.6519 - lr: 0.0010
# Epoch 25/500
# 4/4 [==============================] - 0s 103ms/step - loss: 19733080.0000 - val_loss: 1471.2987 - lr: 0.0010
# Epoch 26/500
# 4/4 [==============================] - 0s 105ms/step - loss: 17527368.0000 - val_loss: 1301.1702 - lr: 0.0010
# Epoch 27/500
# 4/4 [==============================] - 0s 103ms/step - loss: 15575380.0000 - val_loss: 870.7405 - lr: 0.0010
# Epoch 28/500
# 4/4 [==============================] - 0s 105ms/step - loss: 13881920.0000 - val_loss: 449.1926 - lr: 0.0010
# Epoch 29/500
# 4/4 [==============================] - 0s 103ms/step - loss: 12683952.0000 - val_loss: 195.3521 - lr: 0.0010
# Epoch 30/500
# 4/4 [==============================] - 0s 107ms/step - loss: 11403800.0000 - val_loss: 184.1361 - lr: 0.0010
# Epoch 31/500
# 4/4 [==============================] - 0s 105ms/step - loss: 10446659.0000 - val_loss: 306.6328 - lr: 0.0010
# Epoch 32/500
# 4/4 [==============================] - 0s 105ms/step - loss: 9548731.0000 - val_loss: 475.9734 - lr: 0.0010
# Epoch 33/500
# 4/4 [==============================] - 0s 106ms/step - loss: 8815307.0000 - val_loss: 705.0348 - lr: 0.0010
# Epoch 34/500
# 4/4 [==============================] - 0s 105ms/step - loss: 8155345.5000 - val_loss: 1072.7527 - lr: 0.0010
# Epoch 35/500
# 4/4 [==============================] - 0s 105ms/step - loss: 7584033.0000 - val_loss: 1519.9899 - lr: 0.0010
# Epoch 36/500
# 4/4 [==============================] - 0s 106ms/step - loss: 6983517.0000 - val_loss: 1899.9595 - lr: 0.0010
# Epoch 37/500
# 4/4 [==============================] - 0s 106ms/step - loss: 6441461.0000 - val_loss: 1983.9772 - lr: 0.0010
# Epoch 38/500
# 4/4 [==============================] - 0s 106ms/step - loss: 5993168.0000 - val_loss: 1677.0443 - lr: 0.0010
# Epoch 39/500
# 4/4 [==============================] - 0s 105ms/step - loss: 5546819.5000 - val_loss: 1181.7540 - lr: 0.0010
# Epoch 40/500
# 4/4 [==============================] - 0s 104ms/step - loss: 5118016.0000 - val_loss: 771.8337 - lr: 0.0010
# Epoch 41/500
# 4/4 [==============================] - 0s 106ms/step - loss: 4720465.0000 - val_loss: 582.0973 - lr: 0.0010
# Epoch 42/500
# 4/4 [==============================] - 0s 105ms/step - loss: 4337477.5000 - val_loss: 523.0187 - lr: 0.0010
# Epoch 43/500
# 4/4 [==============================] - 0s 105ms/step - loss: 4003076.7500 - val_loss: 528.2128 - lr: 0.0010
# Epoch 44/500
# 4/4 [==============================] - 0s 103ms/step - loss: 3688203.0000 - val_loss: 559.2404 - lr: 0.0010
# Epoch 45/500
# 4/4 [==============================] - 0s 105ms/step - loss: 3379978.2500 - val_loss: 542.1404 - lr: 0.0010
# Epoch 46/500
# 4/4 [==============================] - 0s 104ms/step - loss: 3151778.7500 - val_loss: 444.2176 - lr: 0.0010
# Epoch 47/500
# 4/4 [==============================] - 0s 103ms/step - loss: 2879049.7500 - val_loss: 295.5645 - lr: 0.0010
# Epoch 48/500
# 4/4 [==============================] - 0s 105ms/step - loss: 2692278.2500 - val_loss: 174.3901 - lr: 0.0010
# Epoch 49/500
# 4/4 [==============================] - 0s 105ms/step - loss: 2524286.5000 - val_loss: 99.3207 - lr: 0.0010
# Epoch 50/500
# 4/4 [==============================] - 0s 105ms/step - loss: 2375021.2500 - val_loss: 64.6587 - lr: 0.0010
# Epoch 51/500
# 4/4 [==============================] - 0s 103ms/step - loss: 2228172.5000 - val_loss: 50.0215 - lr: 0.0010
# Epoch 52/500
# 4/4 [==============================] - 0s 105ms/step - loss: 2112225.5000 - val_loss: 40.3543 - lr: 0.0010
# Epoch 53/500
# 4/4 [==============================] - 0s 103ms/step - loss: 2018632.2500 - val_loss: 29.3773 - lr: 0.0010
# Epoch 54/500
# 4/4 [==============================] - 0s 105ms/step - loss: 1915569.0000 - val_loss: 23.5674 - lr: 0.0010
# Epoch 55/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1841474.7500 - val_loss: 19.2705 - lr: 0.0010
# Epoch 56/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1755223.7500 - val_loss: 18.5189 - lr: 0.0010
# Epoch 57/500
# 4/4 [==============================] - 0s 105ms/step - loss: 1661424.1250 - val_loss: 18.4897 - lr: 0.0010
# Epoch 58/500
# 4/4 [==============================] - 0s 104ms/step - loss: 1618945.2500 - val_loss: 18.9176 - lr: 0.0010
# Epoch 59/500
# 4/4 [==============================] - 0s 105ms/step - loss: 1560549.3750 - val_loss: 19.7568 - lr: 0.0010
# Epoch 60/500
# 4/4 [==============================] - 0s 104ms/step - loss: 1498280.1250 - val_loss: 17.1923 - lr: 0.0010
# Epoch 61/500
# 4/4 [==============================] - 0s 102ms/step - loss: 1428243.3750 - val_loss: 13.7602 - lr: 0.0010
# Epoch 62/500
# 4/4 [==============================] - 0s 105ms/step - loss: 1380695.5000 - val_loss: 12.7143 - lr: 0.0010
# Epoch 63/500
# 4/4 [==============================] - 0s 103ms/step - loss: 1343342.8750 - val_loss: 12.9934 - lr: 0.0010
# Epoch 64/500
# 4/4 [==============================] - 0s 106ms/step - loss: 1322503.7500 - val_loss: 13.8481 - lr: 0.0010
# Epoch 65/500
# 4/4 [==============================] - 0s 108ms/step - loss: 1251367.7500 - val_loss: 15.2618 - lr: 0.0010
# Epoch 66/500
# 4/4 [==============================] - 0s 105ms/step - loss: 1225932.1250 - val_loss: 14.9073 - lr: 0.0010
# Epoch 67/500
# 4/4 [==============================] - 0s 104ms/step - loss: 1177608.3750 - val_loss: 11.6657 - lr: 0.0010
# Epoch 68/500
# 4/4 [==============================] - 0s 106ms/step - loss: 1151574.7500 - val_loss: 8.7846 - lr: 0.0010
# Epoch 69/500
# 4/4 [==============================] - 0s 104ms/step - loss: 1094272.5000 - val_loss: 8.6548 - lr: 0.0010
# Epoch 70/500
# 4/4 [==============================] - 0s 107ms/step - loss: 1076829.1250 - val_loss: 9.4401 - lr: 0.0010
# Epoch 71/500
# 4/4 [==============================] - 0s 105ms/step - loss: 1038166.3125 - val_loss: 9.2136 - lr: 0.0010
# Epoch 72/500
# 4/4 [==============================] - 0s 104ms/step - loss: 1017222.7500 - val_loss: 8.6882 - lr: 0.0010
# Epoch 73/500
# 4/4 [==============================] - 0s 107ms/step - loss: 975542.8125 - val_loss: 9.0668 - lr: 0.0010
# Epoch 74/500
# 4/4 [==============================] - 0s 103ms/step - loss: 951344.9375 - val_loss: 10.1080 - lr: 0.0010
# Epoch 75/500
# 4/4 [==============================] - 0s 105ms/step - loss: 932768.0000 - val_loss: 10.0112 - lr: 0.0010
# Epoch 76/500
# 4/4 [==============================] - 0s 103ms/step - loss: 909316.0625 - val_loss: 8.7411 - lr: 0.0010
# Epoch 77/500
# 4/4 [==============================] - 0s 103ms/step - loss: 879271.8125 - val_loss: 7.6134 - lr: 0.0010
# Epoch 78/500
# 4/4 [==============================] - 0s 105ms/step - loss: 846239.5000 - val_loss: 7.0881 - lr: 0.0010
# Epoch 79/500
# 4/4 [==============================] - 0s 105ms/step - loss: 852377.6875 - val_loss: 6.5823 - lr: 0.0010
# Epoch 80/500
# 4/4 [==============================] - 0s 102ms/step - loss: 823057.0625 - val_loss: 6.3994 - lr: 0.0010
# Epoch 81/500
# 4/4 [==============================] - 0s 103ms/step - loss: 798306.0000 - val_loss: 6.2435 - lr: 0.0010
# Epoch 82/500
# 4/4 [==============================] - 0s 103ms/step - loss: 776977.6250 - val_loss: 6.3505 - lr: 0.0010
# Epoch 83/500
# 4/4 [==============================] - 0s 105ms/step - loss: 762068.8750 - val_loss: 6.6010 - lr: 0.0010
# Epoch 84/500
# 4/4 [==============================] - 0s 103ms/step - loss: 752384.2500 - val_loss: 7.0102 - lr: 0.0010
# Epoch 85/500
# 4/4 [==============================] - 0s 103ms/step - loss: 727995.5000 - val_loss: 6.8298 - lr: 0.0010
# Epoch 86/500
# 4/4 [==============================] - 0s 105ms/step - loss: 712845.8750 - val_loss: 6.3740 - lr: 0.0010
# Epoch 87/500
# 4/4 [==============================] - 0s 104ms/step - loss: 693810.5000 - val_loss: 6.0536 - lr: 0.0010
# Epoch 88/500
# 4/4 [==============================] - 0s 103ms/step - loss: 683797.4375 - val_loss: 5.8820 - lr: 0.0010
# Epoch 89/500
# 4/4 [==============================] - 0s 105ms/step - loss: 656976.2500 - val_loss: 5.9616 - lr: 0.0010
# Epoch 90/500
# 4/4 [==============================] - 0s 102ms/step - loss: 659292.8125 - val_loss: 6.0405 - lr: 0.0010
# Epoch 91/500
# 4/4 [==============================] - 0s 103ms/step - loss: 642722.8750 - val_loss: 5.9689 - lr: 0.0010
# Epoch 92/500
# 4/4 [==============================] - 0s 105ms/step - loss: 641107.6875 - val_loss: 5.8777 - lr: 0.0010
# Epoch 93/500
# 4/4 [==============================] - 0s 103ms/step - loss: 615047.8750 - val_loss: 5.7811 - lr: 0.0010
# Epoch 94/500
# 4/4 [==============================] - 0s 103ms/step - loss: 614030.5625 - val_loss: 5.7212 - lr: 0.0010
# Epoch 95/500
# 4/4 [==============================] - 0s 104ms/step - loss: 597816.6875 - val_loss: 5.7244 - lr: 0.0010
# Epoch 96/500
# 4/4 [==============================] - 0s 104ms/step - loss: 585187.8125 - val_loss: 5.7219 - lr: 0.0010
# Epoch 97/500
# 4/4 [==============================] - 0s 103ms/step - loss: 579257.2500 - val_loss: 5.7208 - lr: 0.0010
# Epoch 98/500
# 4/4 [==============================] - 0s 105ms/step - loss: 570209.0625 - val_loss: 5.7314 - lr: 0.0010
# Epoch 99/500
# 4/4 [==============================] - 0s 107ms/step - loss: 551831.1250 - val_loss: 5.8119 - lr: 0.0010
# Epoch 100/500
# 4/4 [==============================] - 0s 106ms/step - loss: 537671.4375 - val_loss: 5.8492 - lr: 0.0010
# Epoch 101/500
# 4/4 [==============================] - 0s 105ms/step - loss: 535625.3125 - val_loss: 5.7589 - lr: 0.0010
# Epoch 102/500
# 4/4 [==============================] - 0s 107ms/step - loss: 537329.8125 - val_loss: 5.7197 - lr: 0.0010
# Epoch 103/500
# 4/4 [==============================] - 0s 106ms/step - loss: 520400.5312 - val_loss: 5.7305 - lr: 0.0010
# Epoch 104/500
# 4/4 [==============================] - 0s 105ms/step - loss: 511527.9375 - val_loss: 5.9980 - lr: 0.0010
# Epoch 105/500
# 4/4 [==============================] - 0s 104ms/step - loss: 503003.0312 - val_loss: 6.1542 - lr: 0.0010
# Epoch 106/500
# 4/4 [==============================] - 0s 106ms/step - loss: 503824.0312 - val_loss: 5.9493 - lr: 0.0010
# Epoch 107/500
# 4/4 [==============================] - 0s 104ms/step - loss: 487783.5000 - val_loss: 5.8419 - lr: 0.0010
# Epoch 108/500
# 4/4 [==============================] - 0s 106ms/step - loss: 485692.0625 - val_loss: 5.8611 - lr: 0.0010
# Epoch 109/500
# 4/4 [==============================] - 0s 105ms/step - loss: 470989.1562 - val_loss: 5.9768 - lr: 0.0010
# Epoch 110/500
# 4/4 [==============================] - 0s 104ms/step - loss: 460461.8750 - val_loss: 6.1205 - lr: 0.0010
# Epoch 111/500
# 4/4 [==============================] - 0s 103ms/step - loss: 466234.4688 - val_loss: 6.2282 - lr: 0.0010
# Epoch 112/500
# 4/4 [==============================] - 0s 102ms/step - loss: 456630.1562 - val_loss: 6.1101 - lr: 0.0010
# Epoch 113/500
# 4/4 [==============================] - 0s 107ms/step - loss: 454235.2500 - val_loss: 6.0572 - lr: 0.0010
# Epoch 114/500
# 4/4 [==============================] - 0s 105ms/step - loss: 438402.7500 - val_loss: 6.3277 - lr: 0.0010
# Epoch 115/500
# 4/4 [==============================] - 0s 105ms/step - loss: 426806.6875 - val_loss: 6.9245 - lr: 0.0010
# Epoch 116/500
# 4/4 [==============================] - 0s 103ms/step - loss: 436679.9062 - val_loss: 7.3528 - lr: 0.0010
# Epoch 117/500
# 4/4 [==============================] - 0s 104ms/step - loss: 420980.5938 - val_loss: 7.1712 - lr: 0.0010
# Epoch 118/500
# 4/4 [==============================] - 0s 105ms/step - loss: 420200.5312 - val_loss: 6.8469 - lr: 0.0010
# Epoch 119/500
# 4/4 [==============================] - 0s 104ms/step - loss: 408515.2500 - val_loss: 6.4780 - lr: 0.0010
# Epoch 120/500
# 4/4 [==============================] - 0s 104ms/step - loss: 406961.7188 - val_loss: 6.2264 - lr: 0.0010
# Epoch 121/500
# 4/4 [==============================] - 0s 105ms/step - loss: 399896.5000 - val_loss: 6.7403 - lr: 0.0010
# Epoch 122/500
# 4/4 [==============================] - 0s 103ms/step - loss: 396968.6875 - val_loss: 7.4312 - lr: 0.0010
# Epoch 123/500
# 4/4 [==============================] - 0s 105ms/step - loss: 386841.1875 - val_loss: 7.4061 - lr: 0.0010
# Epoch 124/500
# 4/4 [==============================] - 0s 102ms/step - loss: 384142.9375 - val_loss: 7.0574 - lr: 0.0010
# Epoch 125/500
# 4/4 [==============================] - 0s 105ms/step - loss: 376918.3125 - val_loss: 6.6479 - lr: 0.0010
# Epoch 126/500
# 4/4 [==============================] - 0s 103ms/step - loss: 373230.5938 - val_loss: 6.8891 - lr: 0.0010
# Epoch 127/500
# 4/4 [==============================] - 0s 102ms/step - loss: 367676.6562 - val_loss: 7.5702 - lr: 0.0010
# Epoch 128/500
# 4/4 [==============================] - 0s 104ms/step - loss: 373141.7500 - val_loss: 7.9462 - lr: 0.0010
# Epoch 129/500
# 4/4 [==============================] - 0s 104ms/step - loss: 360130.9688 - val_loss: 7.5783 - lr: 0.0010
# Epoch 130/500
# 4/4 [==============================] - 0s 103ms/step - loss: 359245.3125 - val_loss: 7.4813 - lr: 0.0010
# Epoch 131/500
# 4/4 [==============================] - 0s 103ms/step - loss: 355703.5938 - val_loss: 7.3782 - lr: 0.0010
# Epoch 132/500
# 4/4 [==============================] - 0s 102ms/step - loss: 346622.6875 - val_loss: 7.7864 - lr: 0.0010
# Epoch 133/500
# 4/4 [==============================] - 0s 105ms/step - loss: 335302.3125 - val_loss: 8.0549 - lr: 0.0010
# Epoch 134/500
# 4/4 [==============================] - 0s 106ms/step - loss: 341377.5938 - val_loss: 7.7391 - lr: 0.0010
# Epoch 135/500
# 4/4 [==============================] - 0s 104ms/step - loss: 334095.7500 - val_loss: 7.7573 - lr: 0.0010
# Epoch 136/500
# 4/4 [==============================] - 0s 105ms/step - loss: 330607.9062 - val_loss: 7.9757 - lr: 0.0010
# Epoch 137/500
# 4/4 [==============================] - 0s 106ms/step - loss: 330872.4375 - val_loss: 8.3484 - lr: 0.0010
# Epoch 138/500
# 4/4 [==============================] - 0s 107ms/step - loss: 326046.3438 - val_loss: 8.3040 - lr: 0.0010
# Epoch 139/500
# 4/4 [==============================] - 0s 103ms/step - loss: 317451.3750 - val_loss: 7.8310 - lr: 0.0010
# Epoch 140/500
# 4/4 [==============================] - 0s 105ms/step - loss: 314820.7188 - val_loss: 7.9438 - lr: 0.0010
# Epoch 141/500
# 4/4 [==============================] - 0s 104ms/step - loss: 314565.0312 - val_loss: 8.1988 - lr: 0.0010
# Epoch 142/500
# 4/4 [==============================] - 0s 106ms/step - loss: 309635.0938 - val_loss: 8.1458 - lr: 0.0010
# Epoch 143/500
# 4/4 [==============================] - 0s 103ms/step - loss: 304221.6562 - val_loss: 8.4738 - lr: 0.0010
# Epoch 144/500
# 4/4 [==============================] - 0s 104ms/step - loss: 303838.8750 - val_loss: 8.5453 - lr: 0.0010
# Epoch 145/500
# 4/4 [==============================] - 0s 104ms/step - loss: 298185.7500 - val_loss: 8.3152 - lr: 0.0010
# Epoch 146/500
# 4/4 [==============================] - 0s 105ms/step - loss: 292993.0000 - val_loss: 8.2909 - lr: 0.0010
# Epoch 147/500
# 4/4 [==============================] - 0s 104ms/step - loss: 295678.6250 - val_loss: 8.5533 - lr: 0.0010
# Epoch 148/500
# 4/4 [==============================] - 0s 102ms/step - loss: 296165.4688 - val_loss: 8.9822 - lr: 0.0010
# Epoch 149/500
# 4/4 [==============================] - 0s 103ms/step - loss: 284692.2500 - val_loss: 8.8271 - lr: 0.0010
# Epoch 150/500
# 4/4 [==============================] - 0s 103ms/step - loss: 286502.7188 - val_loss: 8.8104 - lr: 0.0010
# Epoch 151/500
# 4/4 [==============================] - 0s 105ms/step - loss: 281518.7500 - val_loss: 9.1641 - lr: 0.0010
# Epoch 152/500
# 4/4 [==============================] - 0s 104ms/step - loss: 275935.8125 - val_loss: 9.5389 - lr: 0.0010
# CPU times: user 1min 39s, sys: 3.69 s, total: 1min 43s
# Wall time: 1min 3s

# %%
# Evaluar el modelo
y_true = ratings_test
predictions = model.predict([user_ids_test, item_ids_test])
# Out:
# 30004/30004 [==============================] - 44s 1ms/step

# %%
# MSE y RMSE
mse = mean_squared_error(y_true, predictions)
rmse = np.sqrt(mse)

# MAE
mae = mean_absolute_error(y_true, predictions)

# Funciones MAPE
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    non_zero_idx = y_true != 0  # Para evitar divisiones por cero
    return np.mean(np.abs((y_true[non_zero_idx] - y_pred[non_zero_idx]) / y_true[non_zero_idx])) * 100

def compute_mape_by_batch(y_true, predictions, batch_size=50000):
    mape_sum = 0
    num_batches = int(np.ceil(len(y_true) / batch_size))

    for i in range(num_batches):
        start_idx = i * batch_size
        end_idx = start_idx + batch_size

        batch_y_true = y_true[start_idx:end_idx]
        batch_predictions = predictions[start_idx:end_idx]

        mape_sum += mean_absolute_percentage_error(batch_y_true, batch_predictions)

    return mape_sum / num_batches

# Luego llamas a la función
mape = compute_mape_by_batch(y_true, predictions)

print(f'MSE: {mse}')
print(f'RMSE: {rmse}')
print(f'MAE: {mae}')
print(f'MAPE: {mape}%')
# Out:
# MSE: 9.525408009457713
# RMSE: 3.0863259726506067
# MAE: 2.819180513543005
# MAPE: 65.38432883037841%

# %% [markdown]
# # Recomendación

# %%
# Seleccionar un usuario al azar del conjunto de prueba
usuario_id_test_encoded = random.choice(user_ids_test)

# Decodificar el ID del usuario para obtener el ID original
usuario_id_test = reviewerID_encoder.inverse_transform([usuario_id_test_encoded])[0]

# Identificar los ítems que el usuario ha calificado en el conjunto de prueba
indices_usuario = np.where(user_ids_test == usuario_id_test_encoded)[0]
items_calificados_test_encoded = item_ids_test[indices_usuario]
calificaciones_reales_test = ratings_test[indices_usuario]

# Predecir las calificaciones para estos ítems
calificaciones_predichas = model.predict([np.array([usuario_id_test_encoded] * len(items_calificados_test_encoded)), items_calificados_test_encoded])

# Decodificar los ítems para obtener los ID originales
items_calificados_test = asin_encoder.inverse_transform(items_calificados_test_encoded)

# Comparar las calificaciones predichas con las reales
comparacion = list(zip(items_calificados_test, calificaciones_reales_test, calificaciones_predichas.flatten()))

# Mostrar las comparaciones
print(f"Recomendaciones para el usuario {usuario_id_test}:")
for item, real, predicha in comparacion:
    print(f"Ítem: {item}, Calificación Real: {real}, Calificación Predicha: {predicha}")
# Out:
# 1/1 [==============================] - 0s 18ms/step
# Recomendaciones para el usuario AEBZKVMNGSEAM:
# Ítem: B000Q7ESQY, Calificación Real: 5.0, Calificación Predicha: 2.5750832557678223

# %%
# Seleccionar un usuario al azar del conjunto de prueba
usuario_id_test_encoded = random.choice(user_ids_test)

# Decodificar el ID del usuario para obtener el ID original
usuario_id = reviewerID_encoder.inverse_transform([usuario_id_test_encoded])[0]

# Lista de todos los ítems únicos en el dataset
items_unicos = np.unique(data['asin'].values)

# Ítems que el usuario ya ha calificado
items_calificados = data[data['reviewerID_encoded'] == usuario_id_test_encoded]['asin'].tolist()

# Ítems para predecir
items_a_predecir = [item for item in items_unicos if item not in items_calificados]

# Convierte los ítems a su representación codificada
items_a_predecir_encoded = asin_encoder.transform(items_a_predecir)

# Predecir la calificación para cada ítem no calificado
predicciones = model.predict([np.array([usuario_id_test_encoded] * len(items_a_predecir_encoded)), items_a_predecir_encoded])

# Emparejar cada ítem con su predicción
items_predicciones = list(zip(items_a_predecir, predicciones.flatten()))

# Ordenar por la calificación predicha más alta
items_recomendados = sorted(items_predicciones, key=lambda x: x[1], reverse=True)

# Tomar los top N recomendaciones
top_n = 5
top_recomendaciones = items_recomendados[:top_n]

# Imprimir las recomendaciones
print(f"Recomendaciones para el usuario {usuario_id}:")
for item, calificacion in top_recomendaciones:
    print(f"Ítem: {item}, Calificación Predicha: {calificacion}")
# Out:
# 4814/4814 [==============================] - 7s 1ms/step
# Recomendaciones para el usuario A3U81C4FDV0IZQ:
# Ítem: 0871167042, Calificación Predicha: 2.2973787784576416
# Ítem: 1519588135, Calificación Predicha: 2.2973785400390625
# Ítem: 1579652956, Calificación Predicha: 2.2973783016204834
# Ítem: 1936023857, Calificación Predicha: 2.2973783016204834
# Ítem: 5120053017, Calificación Predicha: 2.297377824783325

# %% [markdown]
# # Modelo de Filtrado Colaborativo usando Red Neuronal Multicapa y Embedding con Keras:
#
# Otra enfoque popular para filtrado colaborativo es utilizar redes neuronales multicapa, que esencialmente aprenden características no lineales de los datos. Vamos a construir un modelo que fusiona los embeddings de usuarios y artículos (por ejemplo, películas) en una red neuronal densa.
#
# Este enfoque, que combina embeddings y redes neuronales multicapa, puede capturar interacciones más complejas y no lineales entre usuarios y artículos. Sin embargo, es crucial prestar atención al sobreajuste y asegurarse de que el modelo no esté simplemente memorizando los datos. Por lo tanto, es recomendable emplear técnicas de regularización, ajustar hiperparámetros y validar el rendimiento con un conjunto de datos de validación.

# %% [markdown]
# Funcionamiento:
#
# Combina lo mejor de ambos mundos. Primero, se utilizan embeddings para convertir ítems y usuarios en representaciones vectoriales densas. Luego, estas representaciones se pasan a través de una red neuronal para hacer la predicción.
#
# El proceso generalmente comienza con capas de embedding que convierten identificadores de usuarios e ítems en vectores. Estos vectores luego se pasan a través de capas densas para obtener la predicción final.
#
# Ventajas:
#
# Capacidad de capturar patrones subyacentes en los datos mediante embeddings y modelar interacciones no lineales mediante la red neuronal.
#
# Flexibilidad para incorporar características adicionales.
#
# Potencialmente más preciso que cualquiera de los otros dos métodos por separado.
#
# Desventajas:
#
# Mayor complejidad en el modelado y entrenamiento.
#
# Mayor costo computacional.
#
# Requiere un ajuste más cuidadoso y riesgo de sobreajuste si no se gestiona adecuadamente.

# %% [markdown]
# Regularización L2: Agregar una regularización L2 a las capas de embedding y densas para prevenir el sobreajuste.
#
# Early Stopping: Añadir una callback de early stopping para detener el entrenamiento cuando no haya mejora en el conjunto de validación durante un cierto número de épocas.
#
# Ajuste de la tasa de aprendizaje: Utilizar la callback ReduceLROnPlateau para reducir la tasa de aprendizaje cuando no haya mejora en el conjunto de validación.
#
# Métricas adicionales: Puedes monitorizar otras métricas como el error absoluto medio (MAE) durante el entrenamiento.

# %%
# Convertir reviewerID y asin a índices numéricos secuenciales
df['user_id'] = df['reviewerID'].astype('category').cat.codes.values
df['item_id'] = df['asin'].astype('category').cat.codes.values

# Número de usuarios e ítems
n_users = df['user_id'].nunique()
n_items = df['item_id'].nunique()

# Hiperparámetros
n_latent_factors = 50
hidden_units = [128, 64]
dropout_rate = 0.2
l2_reg = 1e-4

# Arquitectura del modelo con regularización L2
user_embedding = Embedding(n_users, n_latent_factors, embeddings_regularizer=l2(l2_reg), name='user_embedding')(user_input)
item_embedding = Embedding(n_items, n_latent_factors, embeddings_regularizer=l2(l2_reg), name='item_embedding')(item_input)

user_vec = Flatten(name='flatten_users')(user_embedding)
item_vec = Flatten(name='flatten_items')(item_embedding)
concat = Concatenate()([user_vec, item_vec])
dense = concat
for units in hidden_units:
    dense = Dense(units, activation='relu', kernel_regularizer=l2(l2_reg))(dense)
    dense = Dropout(dropout_rate)(dense)
output = Dense(1, kernel_regularizer=l2(l2_reg))(dense)
model = Model(inputs=[user_input, item_input], outputs=output)

model.compile(optimizer=Adam(0.001), loss='mean_squared_error', metrics=['mae'])

# %%
# Callbacks
early_stop = EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=50, min_lr=1e-5)

# %%
# Entrenamiento
user_data = df['user_id'].values
item_data = df['item_id'].values
rating_data = df['overall'].values

# División en entrenamiento y prueba
(user_ids_temp, user_ids_test, item_ids_temp, item_ids_test, ratings_temp, ratings_test) = train_test_split(
    user_ids, item_ids, ratings, test_size=0.2, random_state=42)

# División del conjunto de entrenamiento en entrenamiento y validación
(user_ids_train, user_ids_val, item_ids_train, item_ids_val, ratings_train, ratings_val) = train_test_split(
    user_ids_temp, item_ids_temp, ratings_temp, test_size=0.25, random_state=42)  # 0.25 x 0.8 = 0.2

# %%
# %%time
history = model.fit([user_ids_train, item_ids_train], ratings_train,
                    epochs=500,validation_data=([user_ids_val, item_ids_val], ratings_val),
                    batch_size=800000,verbose=1,callbacks=[early_stop, reduce_lr])
# Out:
# Epoch 1/500
# 4/4 [==============================] - 3s 425ms/step - loss: 25.6521 - mae: 4.2314 - val_loss: 24.4744 - val_mae: 4.1801 - lr: 0.0010
# Epoch 2/500
# 4/4 [==============================] - 1s 254ms/step - loss: 23.8425 - mae: 4.1471 - val_loss: 22.6403 - val_mae: 4.0872 - lr: 0.0010
# Epoch 3/500
# 4/4 [==============================] - 1s 260ms/step - loss: 22.0006 - mae: 4.0473 - val_loss: 20.7783 - val_mae: 3.9717 - lr: 0.0010
# Epoch 4/500
# 4/4 [==============================] - 1s 258ms/step - loss: 20.0958 - mae: 3.9184 - val_loss: 18.7897 - val_mae: 3.8155 - lr: 0.0010
# Epoch 5/500
# 4/4 [==============================] - 1s 251ms/step - loss: 18.0061 - mae: 3.7390 - val_loss: 16.5177 - val_mae: 3.5911 - lr: 0.0010
# Epoch 6/500
# 4/4 [==============================] - 1s 252ms/step - loss: 15.5660 - mae: 3.4786 - val_loss: 13.8099 - val_mae: 3.2690 - lr: 0.0010
# Epoch 7/500
# 4/4 [==============================] - 1s 252ms/step - loss: 12.6463 - mae: 3.1127 - val_loss: 10.6220 - val_mae: 2.8339 - lr: 0.0010
# Epoch 8/500
# 4/4 [==============================] - 1s 259ms/step - loss: 9.2871 - mae: 2.6132 - val_loss: 7.1872 - val_mae: 2.2539 - lr: 0.0010
# Epoch 9/500
# 4/4 [==============================] - 1s 253ms/step - loss: 5.9102 - mae: 1.9714 - val_loss: 4.2455 - val_mae: 1.5746 - lr: 0.0010
# Epoch 10/500
# 4/4 [==============================] - 1s 256ms/step - loss: 3.5220 - mae: 1.3114 - val_loss: 2.9759 - val_mae: 1.0552 - lr: 0.0010
# Epoch 11/500
# 4/4 [==============================] - 1s 151ms/step - loss: 3.0982 - mae: 1.0680 - val_loss: 3.2018 - val_mae: 1.0572 - lr: 0.0010
# Epoch 12/500
# 4/4 [==============================] - 1s 261ms/step - loss: 3.3302 - mae: 1.1366 - val_loss: 2.8781 - val_mae: 0.9867 - lr: 0.0010
# Epoch 13/500
# 4/4 [==============================] - 1s 256ms/step - loss: 2.6831 - mae: 0.9844 - val_loss: 2.3437 - val_mae: 0.8992 - lr: 0.0010
# Epoch 14/500
# 4/4 [==============================] - 1s 253ms/step - loss: 2.1216 - mae: 0.8765 - val_loss: 2.2708 - val_mae: 1.0025 - lr: 0.0010
# Epoch 15/500
# 4/4 [==============================] - 1s 150ms/step - loss: 2.0357 - mae: 0.9289 - val_loss: 2.3422 - val_mae: 1.0869 - lr: 0.0010
# Epoch 16/500
# 4/4 [==============================] - 1s 150ms/step - loss: 2.0268 - mae: 0.9616 - val_loss: 2.2740 - val_mae: 1.0653 - lr: 0.0010
# Epoch 17/500
# 4/4 [==============================] - 1s 254ms/step - loss: 1.8984 - mae: 0.9077 - val_loss: 2.1161 - val_mae: 0.9733 - lr: 0.0010
# Epoch 18/500
# 4/4 [==============================] - 1s 255ms/step - loss: 1.7414 - mae: 0.8225 - val_loss: 2.0142 - val_mae: 0.8883 - lr: 0.0010
# Epoch 19/500
# 4/4 [==============================] - 1s 254ms/step - loss: 1.6644 - mae: 0.7759 - val_loss: 1.9825 - val_mae: 0.8554 - lr: 0.0010
# Epoch 20/500
# 4/4 [==============================] - 1s 257ms/step - loss: 1.6234 - mae: 0.7634 - val_loss: 1.9480 - val_mae: 0.8535 - lr: 0.0010
# Epoch 21/500
# 4/4 [==============================] - 1s 254ms/step - loss: 1.5586 - mae: 0.7561 - val_loss: 1.9087 - val_mae: 0.8686 - lr: 0.0010
# Epoch 22/500
# 4/4 [==============================] - 1s 253ms/step - loss: 1.4975 - mae: 0.7559 - val_loss: 1.8897 - val_mae: 0.8927 - lr: 0.0010
# Epoch 23/500
# 4/4 [==============================] - 1s 256ms/step - loss: 1.4607 - mae: 0.7620 - val_loss: 1.8721 - val_mae: 0.9021 - lr: 0.0010
# Epoch 24/500
# 4/4 [==============================] - 1s 254ms/step - loss: 1.4230 - mae: 0.7570 - val_loss: 1.8429 - val_mae: 0.8898 - lr: 0.0010
# Epoch 25/500
# 4/4 [==============================] - 1s 253ms/step - loss: 1.3810 - mae: 0.7424 - val_loss: 1.8162 - val_mae: 0.8724 - lr: 0.0010
# Epoch 26/500
# 4/4 [==============================] - 1s 258ms/step - loss: 1.3456 - mae: 0.7293 - val_loss: 1.7979 - val_mae: 0.8640 - lr: 0.0010
# Epoch 27/500
# 4/4 [==============================] - 1s 255ms/step - loss: 1.3150 - mae: 0.7218 - val_loss: 1.7821 - val_mae: 0.8654 - lr: 0.0010
# Epoch 28/500
# 4/4 [==============================] - 1s 258ms/step - loss: 1.2861 - mae: 0.7186 - val_loss: 1.7685 - val_mae: 0.8724 - lr: 0.0010
# Epoch 29/500
# 4/4 [==============================] - 1s 256ms/step - loss: 1.2602 - mae: 0.7176 - val_loss: 1.7555 - val_mae: 0.8775 - lr: 0.0010
# Epoch 30/500
# 4/4 [==============================] - 1s 256ms/step - loss: 1.2372 - mae: 0.7160 - val_loss: 1.7401 - val_mae: 0.8762 - lr: 0.0010
# Epoch 31/500
# 4/4 [==============================] - 1s 254ms/step - loss: 1.2134 - mae: 0.7113 - val_loss: 1.7241 - val_mae: 0.8718 - lr: 0.0010
# Epoch 32/500
# 4/4 [==============================] - 1s 254ms/step - loss: 1.1926 - mae: 0.7072 - val_loss: 1.7095 - val_mae: 0.8693 - lr: 0.0010
# Epoch 33/500
# 4/4 [==============================] - 1s 253ms/step - loss: 1.1719 - mae: 0.7040 - val_loss: 1.6969 - val_mae: 0.8702 - lr: 0.0010
# Epoch 34/500
# 4/4 [==============================] - 1s 258ms/step - loss: 1.1556 - mae: 0.7033 - val_loss: 1.6855 - val_mae: 0.8724 - lr: 0.0010
# Epoch 35/500
# 4/4 [==============================] - 1s 260ms/step - loss: 1.1398 - mae: 0.7027 - val_loss: 1.6750 - val_mae: 0.8735 - lr: 0.0010
# Epoch 36/500
# 4/4 [==============================] - 1s 255ms/step - loss: 1.1236 - mae: 0.7007 - val_loss: 1.6646 - val_mae: 0.8729 - lr: 0.0010
# Epoch 37/500
# 4/4 [==============================] - 1s 257ms/step - loss: 1.1090 - mae: 0.6991 - val_loss: 1.6543 - val_mae: 0.8719 - lr: 0.0010
# Epoch 38/500
# 4/4 [==============================] - 1s 256ms/step - loss: 1.0961 - mae: 0.6974 - val_loss: 1.6453 - val_mae: 0.8721 - lr: 0.0010
# Epoch 39/500
# 4/4 [==============================] - 1s 255ms/step - loss: 1.0839 - mae: 0.6969 - val_loss: 1.6369 - val_mae: 0.8730 - lr: 0.0010
# Epoch 40/500
# 4/4 [==============================] - 1s 253ms/step - loss: 1.0714 - mae: 0.6956 - val_loss: 1.6287 - val_mae: 0.8736 - lr: 0.0010
# Epoch 41/500
# 4/4 [==============================] - 1s 256ms/step - loss: 1.0602 - mae: 0.6944 - val_loss: 1.6213 - val_mae: 0.8736 - lr: 0.0010
# Epoch 42/500
# 4/4 [==============================] - 1s 260ms/step - loss: 1.0516 - mae: 0.6940 - val_loss: 1.6141 - val_mae: 0.8732 - lr: 0.0010
# Epoch 43/500
# 4/4 [==============================] - 1s 256ms/step - loss: 1.0410 - mae: 0.6927 - val_loss: 1.6082 - val_mae: 0.8734 - lr: 0.0010
# Epoch 44/500
# 4/4 [==============================] - 1s 264ms/step - loss: 1.0318 - mae: 0.6921 - val_loss: 1.6026 - val_mae: 0.8738 - lr: 0.0010
# Epoch 45/500
# 4/4 [==============================] - 1s 255ms/step - loss: 1.0241 - mae: 0.6916 - val_loss: 1.5972 - val_mae: 0.8745 - lr: 0.0010
# Epoch 46/500
# 4/4 [==============================] - 1s 257ms/step - loss: 1.0158 - mae: 0.6908 - val_loss: 1.5914 - val_mae: 0.8745 - lr: 0.0010
# Epoch 47/500
# 4/4 [==============================] - 1s 259ms/step - loss: 1.0084 - mae: 0.6902 - val_loss: 1.5857 - val_mae: 0.8743 - lr: 0.0010
# Epoch 48/500
# 4/4 [==============================] - 1s 252ms/step - loss: 1.0015 - mae: 0.6897 - val_loss: 1.5802 - val_mae: 0.8739 - lr: 0.0010
# Epoch 49/500
# 4/4 [==============================] - 1s 255ms/step - loss: 0.9951 - mae: 0.6891 - val_loss: 1.5751 - val_mae: 0.8738 - lr: 0.0010
# Epoch 50/500
# 4/4 [==============================] - 1s 253ms/step - loss: 0.9880 - mae: 0.6882 - val_loss: 1.5716 - val_mae: 0.8743 - lr: 0.0010
# Epoch 51/500
# 4/4 [==============================] - 1s 259ms/step - loss: 0.9827 - mae: 0.6879 - val_loss: 1.5681 - val_mae: 0.8744 - lr: 0.0010
# Epoch 52/500
# 4/4 [==============================] - 1s 256ms/step - loss: 0.9770 - mae: 0.6875 - val_loss: 1.5646 - val_mae: 0.8745 - lr: 0.0010
# Epoch 53/500
# 4/4 [==============================] - 1s 262ms/step - loss: 0.9718 - mae: 0.6869 - val_loss: 1.5610 - val_mae: 0.8745 - lr: 0.0010
# Epoch 54/500
# 4/4 [==============================] - 1s 255ms/step - loss: 0.9673 - mae: 0.6866 - val_loss: 1.5568 - val_mae: 0.8742 - lr: 0.0010
# Epoch 55/500
# 4/4 [==============================] - 1s 257ms/step - loss: 0.9624 - mae: 0.6860 - val_loss: 1.5532 - val_mae: 0.8738 - lr: 0.0010
# Epoch 56/500
# 4/4 [==============================] - 1s 253ms/step - loss: 0.9582 - mae: 0.6856 - val_loss: 1.5502 - val_mae: 0.8735 - lr: 0.0010
# Epoch 57/500
# 4/4 [==============================] - 1s 262ms/step - loss: 0.9538 - mae: 0.6852 - val_loss: 1.5476 - val_mae: 0.8732 - lr: 0.0010
# Epoch 58/500
# 4/4 [==============================] - 1s 257ms/step - loss: 0.9489 - mae: 0.6843 - val_loss: 1.5455 - val_mae: 0.8733 - lr: 0.0010
# Epoch 59/500
# 4/4 [==============================] - 1s 255ms/step - loss: 0.9443 - mae: 0.6833 - val_loss: 1.5431 - val_mae: 0.8733 - lr: 0.0010
# Epoch 60/500
# 4/4 [==============================] - 1s 259ms/step - loss: 0.9400 - mae: 0.6828 - val_loss: 1.5399 - val_mae: 0.8729 - lr: 0.0010
# Epoch 61/500
# 4/4 [==============================] - 1s 259ms/step - loss: 0.9359 - mae: 0.6823 - val_loss: 1.5367 - val_mae: 0.8722 - lr: 0.0010
# Epoch 62/500
# 4/4 [==============================] - 1s 257ms/step - loss: 0.9326 - mae: 0.6818 - val_loss: 1.5349 - val_mae: 0.8720 - lr: 0.0010
# Epoch 63/500
# 4/4 [==============================] - 1s 256ms/step - loss: 0.9276 - mae: 0.6808 - val_loss: 1.5326 - val_mae: 0.8717 - lr: 0.0010
# Epoch 64/500
# 4/4 [==============================] - 1s 260ms/step - loss: 0.9240 - mae: 0.6805 - val_loss: 1.5300 - val_mae: 0.8710 - lr: 0.0010
# Epoch 65/500
# 4/4 [==============================] - 1s 258ms/step - loss: 0.9198 - mae: 0.6794 - val_loss: 1.5274 - val_mae: 0.8706 - lr: 0.0010
# Epoch 66/500
# 4/4 [==============================] - 1s 256ms/step - loss: 0.9171 - mae: 0.6794 - val_loss: 1.5252 - val_mae: 0.8705 - lr: 0.0010
# Epoch 67/500
# 4/4 [==============================] - 1s 252ms/step - loss: 0.9135 - mae: 0.6789 - val_loss: 1.5238 - val_mae: 0.8703 - lr: 0.0010
# Epoch 68/500
# 4/4 [==============================] - 1s 252ms/step - loss: 0.9103 - mae: 0.6784 - val_loss: 1.5224 - val_mae: 0.8701 - lr: 0.0010
# Epoch 69/500
# 4/4 [==============================] - 1s 261ms/step - loss: 0.9082 - mae: 0.6781 - val_loss: 1.5212 - val_mae: 0.8700 - lr: 0.0010
# Epoch 70/500
# 4/4 [==============================] - 1s 253ms/step - loss: 0.9064 - mae: 0.6780 - val_loss: 1.5197 - val_mae: 0.8701 - lr: 0.0010
# Epoch 71/500
# 4/4 [==============================] - 1s 254ms/step - loss: 0.9041 - mae: 0.6778 - val_loss: 1.5177 - val_mae: 0.8697 - lr: 0.0010
# Epoch 72/500
# 4/4 [==============================] - 1s 255ms/step - loss: 0.9022 - mae: 0.6775 - val_loss: 1.5160 - val_mae: 0.8694 - lr: 0.0010
# Epoch 73/500
# 4/4 [==============================] - 1s 264ms/step - loss: 0.9002 - mae: 0.6772 - val_loss: 1.5146 - val_mae: 0.8692 - lr: 0.0010
# Epoch 74/500
# 4/4 [==============================] - 1s 255ms/step - loss: 0.8982 - mae: 0.6764 - val_loss: 1.5136 - val_mae: 0.8688 - lr: 0.0010
# Epoch 75/500
# 4/4 [==============================] - 1s 257ms/step - loss: 0.8959 - mae: 0.6759 - val_loss: 1.5121 - val_mae: 0.8685 - lr: 0.0010
# Epoch 76/500
# 4/4 [==============================] - 1s 256ms/step - loss: 0.8945 - mae: 0.6753 - val_loss: 1.5107 - val_mae: 0.8681 - lr: 0.0010
# Epoch 77/500
# 4/4 [==============================] - 1s 263ms/step - loss: 0.8932 - mae: 0.6750 - val_loss: 1.5094 - val_mae: 0.8676 - lr: 0.0010
# Epoch 78/500
# 4/4 [==============================] - 1s 258ms/step - loss: 0.8904 - mae: 0.6738 - val_loss: 1.5086 - val_mae: 0.8677 - lr: 0.0010
# Epoch 79/500
# 4/4 [==============================] - 1s 260ms/step - loss: 0.8889 - mae: 0.6736 - val_loss: 1.5077 - val_mae: 0.8672 - lr: 0.0010
# Epoch 80/500
# 4/4 [==============================] - 1s 254ms/step - loss: 0.8868 - mae: 0.6729 - val_loss: 1.5067 - val_mae: 0.8664 - lr: 0.0010
# Epoch 81/500
# 4/4 [==============================] - 1s 253ms/step - loss: 0.8857 - mae: 0.6726 - val_loss: 1.5054 - val_mae: 0.8661 - lr: 0.0010
# Epoch 82/500
# 4/4 [==============================] - 1s 255ms/step - loss: 0.8837 - mae: 0.6717 - val_loss: 1.5046 - val_mae: 0.8661 - lr: 0.0010
# Epoch 83/500
# 4/4 [==============================] - 1s 256ms/step - loss: 0.8823 - mae: 0.6714 - val_loss: 1.5042 - val_mae: 0.8660 - lr: 0.0010
# Epoch 84/500
# 4/4 [==============================] - 1s 253ms/step - loss: 0.8809 - mae: 0.6711 - val_loss: 1.5036 - val_mae: 0.8658 - lr: 0.0010
# Epoch 85/500
# 4/4 [==============================] - 1s 257ms/step - loss: 0.8795 - mae: 0.6705 - val_loss: 1.5027 - val_mae: 0.8657 - lr: 0.0010
# Epoch 86/500
# 4/4 [==============================] - 1s 261ms/step - loss: 0.8784 - mae: 0.6705 - val_loss: 1.5015 - val_mae: 0.8650 - lr: 0.0010
# Epoch 87/500
# 4/4 [==============================] - 1s 253ms/step - loss: 0.8764 - mae: 0.6697 - val_loss: 1.4999 - val_mae: 0.8643 - lr: 0.0010
# Epoch 88/500
# 4/4 [==============================] - 1s 263ms/step - loss: 0.8756 - mae: 0.6696 - val_loss: 1.4987 - val_mae: 0.8637 - lr: 0.0010
# Epoch 89/500
# 4/4 [==============================] - 1s 257ms/step - loss: 0.8742 - mae: 0.6691 - val_loss: 1.4981 - val_mae: 0.8635 - lr: 0.0010
# Epoch 90/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.8736 - mae: 0.6691 - val_loss: 1.4982 - val_mae: 0.8637 - lr: 0.0010
# Epoch 91/500
# 4/4 [==============================] - 1s 262ms/step - loss: 0.8725 - mae: 0.6687 - val_loss: 1.4977 - val_mae: 0.8637 - lr: 0.0010
# Epoch 92/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.8709 - mae: 0.6683 - val_loss: 1.4979 - val_mae: 0.8639 - lr: 0.0010
# Epoch 93/500
# 4/4 [==============================] - 1s 255ms/step - loss: 0.8702 - mae: 0.6681 - val_loss: 1.4975 - val_mae: 0.8636 - lr: 0.0010
# Epoch 94/500
# 4/4 [==============================] - 1s 252ms/step - loss: 0.8691 - mae: 0.6675 - val_loss: 1.4971 - val_mae: 0.8637 - lr: 0.0010
# Epoch 95/500
# 4/4 [==============================] - 1s 256ms/step - loss: 0.8675 - mae: 0.6672 - val_loss: 1.4967 - val_mae: 0.8636 - lr: 0.0010
# Epoch 96/500
# 4/4 [==============================] - 1s 251ms/step - loss: 0.8657 - mae: 0.6664 - val_loss: 1.4960 - val_mae: 0.8631 - lr: 0.0010
# Epoch 97/500
# 4/4 [==============================] - 1s 253ms/step - loss: 0.8654 - mae: 0.6663 - val_loss: 1.4954 - val_mae: 0.8627 - lr: 0.0010
# Epoch 98/500
# 4/4 [==============================] - 1s 261ms/step - loss: 0.8643 - mae: 0.6658 - val_loss: 1.4952 - val_mae: 0.8625 - lr: 0.0010
# Epoch 99/500
# 4/4 [==============================] - 1s 252ms/step - loss: 0.8641 - mae: 0.6662 - val_loss: 1.4945 - val_mae: 0.8623 - lr: 0.0010
# Epoch 100/500
# 4/4 [==============================] - 1s 259ms/step - loss: 0.8627 - mae: 0.6657 - val_loss: 1.4936 - val_mae: 0.8621 - lr: 0.0010
# Epoch 101/500
# 4/4 [==============================] - 1s 257ms/step - loss: 0.8620 - mae: 0.6654 - val_loss: 1.4932 - val_mae: 0.8619 - lr: 0.0010
# Epoch 102/500
# 4/4 [==============================] - 1s 256ms/step - loss: 0.8601 - mae: 0.6646 - val_loss: 1.4932 - val_mae: 0.8621 - lr: 0.0010
# Epoch 103/500
# 4/4 [==============================] - 1s 255ms/step - loss: 0.8605 - mae: 0.6649 - val_loss: 1.4930 - val_mae: 0.8620 - lr: 0.0010
# Epoch 104/500
# 4/4 [==============================] - 1s 151ms/step - loss: 0.8597 - mae: 0.6647 - val_loss: 1.4931 - val_mae: 0.8617 - lr: 0.0010
# Epoch 105/500
# 4/4 [==============================] - 1s 258ms/step - loss: 0.8578 - mae: 0.6641 - val_loss: 1.4927 - val_mae: 0.8615 - lr: 0.0010
# Epoch 106/500
# 4/4 [==============================] - 1s 264ms/step - loss: 0.8578 - mae: 0.6641 - val_loss: 1.4921 - val_mae: 0.8613 - lr: 0.0010
# Epoch 107/500
# 4/4 [==============================] - 1s 255ms/step - loss: 0.8567 - mae: 0.6636 - val_loss: 1.4917 - val_mae: 0.8611 - lr: 0.0010
# Epoch 108/500
# 4/4 [==============================] - 1s 256ms/step - loss: 0.8548 - mae: 0.6627 - val_loss: 1.4907 - val_mae: 0.8608 - lr: 0.0010
# Epoch 109/500
# 4/4 [==============================] - 1s 261ms/step - loss: 0.8553 - mae: 0.6632 - val_loss: 1.4906 - val_mae: 0.8607 - lr: 0.0010
# Epoch 110/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.8543 - mae: 0.6628 - val_loss: 1.4909 - val_mae: 0.8607 - lr: 0.0010
# Epoch 111/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.8534 - mae: 0.6625 - val_loss: 1.4908 - val_mae: 0.8605 - lr: 0.0010
# Epoch 112/500
# 4/4 [==============================] - 1s 256ms/step - loss: 0.8527 - mae: 0.6622 - val_loss: 1.4903 - val_mae: 0.8603 - lr: 0.0010
# Epoch 113/500
# 4/4 [==============================] - 1s 253ms/step - loss: 0.8516 - mae: 0.6617 - val_loss: 1.4898 - val_mae: 0.8602 - lr: 0.0010
# Epoch 114/500
# 4/4 [==============================] - 1s 254ms/step - loss: 0.8510 - mae: 0.6618 - val_loss: 1.4896 - val_mae: 0.8603 - lr: 0.0010
# Epoch 115/500
# 4/4 [==============================] - 1s 152ms/step - loss: 0.8505 - mae: 0.6615 - val_loss: 1.4900 - val_mae: 0.8603 - lr: 0.0010
# Epoch 116/500
# 4/4 [==============================] - 1s 151ms/step - loss: 0.8502 - mae: 0.6613 - val_loss: 1.4903 - val_mae: 0.8604 - lr: 0.0010
# Epoch 117/500
# 4/4 [==============================] - 1s 152ms/step - loss: 0.8481 - mae: 0.6606 - val_loss: 1.4898 - val_mae: 0.8602 - lr: 0.0010
# Epoch 118/500
# 4/4 [==============================] - 1s 255ms/step - loss: 0.8478 - mae: 0.6604 - val_loss: 1.4888 - val_mae: 0.8597 - lr: 0.0010
# Epoch 119/500
# 4/4 [==============================] - 1s 255ms/step - loss: 0.8468 - mae: 0.6600 - val_loss: 1.4879 - val_mae: 0.8593 - lr: 0.0010
# Epoch 120/500
# 4/4 [==============================] - 1s 152ms/step - loss: 0.8459 - mae: 0.6597 - val_loss: 1.4880 - val_mae: 0.8594 - lr: 0.0010
# Epoch 121/500
# 4/4 [==============================] - 1s 151ms/step - loss: 0.8451 - mae: 0.6594 - val_loss: 1.4883 - val_mae: 0.8597 - lr: 0.0010
# Epoch 122/500
# 4/4 [==============================] - 1s 152ms/step - loss: 0.8446 - mae: 0.6593 - val_loss: 1.4881 - val_mae: 0.8595 - lr: 0.0010
# Epoch 123/500
# 4/4 [==============================] - 1s 257ms/step - loss: 0.8444 - mae: 0.6592 - val_loss: 1.4878 - val_mae: 0.8594 - lr: 0.0010
# Epoch 124/500
# 4/4 [==============================] - 1s 257ms/step - loss: 0.8434 - mae: 0.6588 - val_loss: 1.4878 - val_mae: 0.8594 - lr: 0.0010
# Epoch 125/500
# 4/4 [==============================] - 1s 263ms/step - loss: 0.8428 - mae: 0.6586 - val_loss: 1.4872 - val_mae: 0.8591 - lr: 0.0010
# Epoch 126/500
# 4/4 [==============================] - 1s 255ms/step - loss: 0.8418 - mae: 0.6582 - val_loss: 1.4870 - val_mae: 0.8591 - lr: 0.0010
# Epoch 127/500
# 4/4 [==============================] - 1s 254ms/step - loss: 0.8405 - mae: 0.6577 - val_loss: 1.4869 - val_mae: 0.8591 - lr: 0.0010
# Epoch 128/500
# 4/4 [==============================] - 1s 151ms/step - loss: 0.8407 - mae: 0.6578 - val_loss: 1.4869 - val_mae: 0.8591 - lr: 0.0010
# Epoch 129/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.8400 - mae: 0.6576 - val_loss: 1.4870 - val_mae: 0.8591 - lr: 0.0010
# Epoch 130/500
# 4/4 [==============================] - 1s 152ms/step - loss: 0.8395 - mae: 0.6573 - val_loss: 1.4873 - val_mae: 0.8593 - lr: 0.0010
# Epoch 131/500
# 4/4 [==============================] - 1s 253ms/step - loss: 0.8386 - mae: 0.6570 - val_loss: 1.4866 - val_mae: 0.8592 - lr: 0.0010
# Epoch 132/500
# 4/4 [==============================] - 1s 252ms/step - loss: 0.8382 - mae: 0.6570 - val_loss: 1.4857 - val_mae: 0.8586 - lr: 0.0010
# Epoch 133/500
# 4/4 [==============================] - 1s 255ms/step - loss: 0.8371 - mae: 0.6565 - val_loss: 1.4855 - val_mae: 0.8584 - lr: 0.0010
# Epoch 134/500
# 4/4 [==============================] - 1s 151ms/step - loss: 0.8361 - mae: 0.6561 - val_loss: 1.4859 - val_mae: 0.8587 - lr: 0.0010
# Epoch 135/500
# 4/4 [==============================] - 1s 260ms/step - loss: 0.8359 - mae: 0.6561 - val_loss: 1.4855 - val_mae: 0.8585 - lr: 0.0010
# Epoch 136/500
# 4/4 [==============================] - 1s 261ms/step - loss: 0.8350 - mae: 0.6556 - val_loss: 1.4849 - val_mae: 0.8580 - lr: 0.0010
# Epoch 137/500
# 4/4 [==============================] - 1s 261ms/step - loss: 0.8337 - mae: 0.6552 - val_loss: 1.4846 - val_mae: 0.8580 - lr: 0.0010
# Epoch 138/500
# 4/4 [==============================] - 1s 153ms/step - loss: 0.8330 - mae: 0.6547 - val_loss: 1.4853 - val_mae: 0.8582 - lr: 0.0010
# Epoch 139/500
# 4/4 [==============================] - 1s 151ms/step - loss: 0.8327 - mae: 0.6548 - val_loss: 1.4853 - val_mae: 0.8581 - lr: 0.0010
# Epoch 140/500
# 4/4 [==============================] - 1s 153ms/step - loss: 0.8316 - mae: 0.6543 - val_loss: 1.4850 - val_mae: 0.8583 - lr: 0.0010
# Epoch 141/500
# 4/4 [==============================] - 1s 257ms/step - loss: 0.8314 - mae: 0.6543 - val_loss: 1.4843 - val_mae: 0.8582 - lr: 0.0010
# Epoch 142/500
# 4/4 [==============================] - 1s 258ms/step - loss: 0.8310 - mae: 0.6540 - val_loss: 1.4834 - val_mae: 0.8577 - lr: 0.0010
# Epoch 143/500
# 4/4 [==============================] - 1s 257ms/step - loss: 0.8297 - mae: 0.6533 - val_loss: 1.4833 - val_mae: 0.8578 - lr: 0.0010
# Epoch 144/500
# 4/4 [==============================] - 1s 151ms/step - loss: 0.8291 - mae: 0.6533 - val_loss: 1.4834 - val_mae: 0.8577 - lr: 0.0010
# Epoch 145/500
# 4/4 [==============================] - 1s 255ms/step - loss: 0.8277 - mae: 0.6527 - val_loss: 1.4833 - val_mae: 0.8575 - lr: 0.0010
# Epoch 146/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.8285 - mae: 0.6532 - val_loss: 1.4833 - val_mae: 0.8579 - lr: 0.0010
# Epoch 147/500
# 4/4 [==============================] - 1s 151ms/step - loss: 0.8267 - mae: 0.6522 - val_loss: 1.4837 - val_mae: 0.8576 - lr: 0.0010
# Epoch 148/500
# 4/4 [==============================] - 1s 259ms/step - loss: 0.8265 - mae: 0.6523 - val_loss: 1.4830 - val_mae: 0.8574 - lr: 0.0010
# Epoch 149/500
# 4/4 [==============================] - 1s 257ms/step - loss: 0.8252 - mae: 0.6518 - val_loss: 1.4822 - val_mae: 0.8573 - lr: 0.0010
# Epoch 150/500
# 4/4 [==============================] - 1s 255ms/step - loss: 0.8252 - mae: 0.6517 - val_loss: 1.4816 - val_mae: 0.8567 - lr: 0.0010
# Epoch 151/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.8241 - mae: 0.6513 - val_loss: 1.4820 - val_mae: 0.8570 - lr: 0.0010
# Epoch 152/500
# 4/4 [==============================] - 1s 149ms/step - loss: 0.8233 - mae: 0.6507 - val_loss: 1.4827 - val_mae: 0.8575 - lr: 0.0010
# Epoch 153/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.8227 - mae: 0.6507 - val_loss: 1.4834 - val_mae: 0.8576 - lr: 0.0010
# Epoch 154/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.8224 - mae: 0.6505 - val_loss: 1.4828 - val_mae: 0.8572 - lr: 0.0010
# Epoch 155/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.8213 - mae: 0.6501 - val_loss: 1.4817 - val_mae: 0.8568 - lr: 0.0010
# Epoch 156/500
# 4/4 [==============================] - 1s 254ms/step - loss: 0.8206 - mae: 0.6498 - val_loss: 1.4811 - val_mae: 0.8563 - lr: 0.0010
# Epoch 157/500
# 4/4 [==============================] - 1s 259ms/step - loss: 0.8198 - mae: 0.6495 - val_loss: 1.4805 - val_mae: 0.8561 - lr: 0.0010
# Epoch 158/500
# 4/4 [==============================] - 1s 254ms/step - loss: 0.8194 - mae: 0.6493 - val_loss: 1.4802 - val_mae: 0.8561 - lr: 0.0010
# Epoch 159/500
# 4/4 [==============================] - 1s 258ms/step - loss: 0.8181 - mae: 0.6487 - val_loss: 1.4802 - val_mae: 0.8559 - lr: 0.0010
# Epoch 160/500
# 4/4 [==============================] - 1s 256ms/step - loss: 0.8175 - mae: 0.6484 - val_loss: 1.4800 - val_mae: 0.8561 - lr: 0.0010
# Epoch 161/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.8166 - mae: 0.6482 - val_loss: 1.4807 - val_mae: 0.8564 - lr: 0.0010
# Epoch 162/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.8160 - mae: 0.6480 - val_loss: 1.4812 - val_mae: 0.8563 - lr: 0.0010
# Epoch 163/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.8153 - mae: 0.6477 - val_loss: 1.4810 - val_mae: 0.8564 - lr: 0.0010
# Epoch 164/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.8148 - mae: 0.6475 - val_loss: 1.4805 - val_mae: 0.8565 - lr: 0.0010
# Epoch 165/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.8141 - mae: 0.6473 - val_loss: 1.4800 - val_mae: 0.8560 - lr: 0.0010
# Epoch 166/500
# 4/4 [==============================] - 1s 254ms/step - loss: 0.8130 - mae: 0.6467 - val_loss: 1.4790 - val_mae: 0.8558 - lr: 0.0010
# Epoch 167/500
# 4/4 [==============================] - 1s 254ms/step - loss: 0.8133 - mae: 0.6470 - val_loss: 1.4783 - val_mae: 0.8556 - lr: 0.0010
# Epoch 168/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.8127 - mae: 0.6468 - val_loss: 1.4783 - val_mae: 0.8552 - lr: 0.0010
# Epoch 169/500
# 4/4 [==============================] - 1s 149ms/step - loss: 0.8111 - mae: 0.6459 - val_loss: 1.4787 - val_mae: 0.8556 - lr: 0.0010
# Epoch 170/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.8107 - mae: 0.6459 - val_loss: 1.4790 - val_mae: 0.8560 - lr: 0.0010
# Epoch 171/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.8094 - mae: 0.6453 - val_loss: 1.4789 - val_mae: 0.8556 - lr: 0.0010
# Epoch 172/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.8093 - mae: 0.6452 - val_loss: 1.4784 - val_mae: 0.8556 - lr: 0.0010
# Epoch 173/500
# 4/4 [==============================] - 1s 254ms/step - loss: 0.8081 - mae: 0.6447 - val_loss: 1.4777 - val_mae: 0.8554 - lr: 0.0010
# Epoch 174/500
# 4/4 [==============================] - 1s 257ms/step - loss: 0.8073 - mae: 0.6445 - val_loss: 1.4774 - val_mae: 0.8551 - lr: 0.0010
# Epoch 175/500
# 4/4 [==============================] - 1s 256ms/step - loss: 0.8065 - mae: 0.6440 - val_loss: 1.4770 - val_mae: 0.8549 - lr: 0.0010
# Epoch 176/500
# 4/4 [==============================] - 1s 256ms/step - loss: 0.8054 - mae: 0.6434 - val_loss: 1.4769 - val_mae: 0.8546 - lr: 0.0010
# Epoch 177/500
# 4/4 [==============================] - 1s 257ms/step - loss: 0.8058 - mae: 0.6437 - val_loss: 1.4768 - val_mae: 0.8551 - lr: 0.0010
# Epoch 178/500
# 4/4 [==============================] - 1s 151ms/step - loss: 0.8048 - mae: 0.6434 - val_loss: 1.4771 - val_mae: 0.8552 - lr: 0.0010
# Epoch 179/500
# 4/4 [==============================] - 1s 152ms/step - loss: 0.8042 - mae: 0.6432 - val_loss: 1.4770 - val_mae: 0.8547 - lr: 0.0010
# Epoch 180/500
# 4/4 [==============================] - 1s 256ms/step - loss: 0.8033 - mae: 0.6427 - val_loss: 1.4767 - val_mae: 0.8552 - lr: 0.0010
# Epoch 181/500
# 4/4 [==============================] - 1s 256ms/step - loss: 0.8025 - mae: 0.6426 - val_loss: 1.4762 - val_mae: 0.8544 - lr: 0.0010
# Epoch 182/500
# 4/4 [==============================] - 1s 254ms/step - loss: 0.8022 - mae: 0.6422 - val_loss: 1.4750 - val_mae: 0.8540 - lr: 0.0010
# Epoch 183/500
# 4/4 [==============================] - 1s 255ms/step - loss: 0.8006 - mae: 0.6416 - val_loss: 1.4746 - val_mae: 0.8542 - lr: 0.0010
# Epoch 184/500
# 4/4 [==============================] - 1s 253ms/step - loss: 0.8003 - mae: 0.6414 - val_loss: 1.4743 - val_mae: 0.8537 - lr: 0.0010
# Epoch 185/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.7994 - mae: 0.6411 - val_loss: 1.4744 - val_mae: 0.8542 - lr: 0.0010
# Epoch 186/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.7987 - mae: 0.6410 - val_loss: 1.4749 - val_mae: 0.8540 - lr: 0.0010
# Epoch 187/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.7981 - mae: 0.6408 - val_loss: 1.4749 - val_mae: 0.8539 - lr: 0.0010
# Epoch 188/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.7973 - mae: 0.6403 - val_loss: 1.4750 - val_mae: 0.8543 - lr: 0.0010
# Epoch 189/500
# 4/4 [==============================] - 1s 149ms/step - loss: 0.7969 - mae: 0.6402 - val_loss: 1.4750 - val_mae: 0.8537 - lr: 0.0010
# Epoch 190/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.7963 - mae: 0.6400 - val_loss: 1.4748 - val_mae: 0.8540 - lr: 0.0010
# Epoch 191/500
# 4/4 [==============================] - 1s 151ms/step - loss: 0.7954 - mae: 0.6398 - val_loss: 1.4744 - val_mae: 0.8536 - lr: 0.0010
# Epoch 192/500
# 4/4 [==============================] - 1s 252ms/step - loss: 0.7950 - mae: 0.6394 - val_loss: 1.4742 - val_mae: 0.8532 - lr: 0.0010
# Epoch 193/500
# 4/4 [==============================] - 1s 257ms/step - loss: 0.7939 - mae: 0.6388 - val_loss: 1.4741 - val_mae: 0.8538 - lr: 0.0010
# Epoch 194/500
# 4/4 [==============================] - 1s 257ms/step - loss: 0.7935 - mae: 0.6387 - val_loss: 1.4739 - val_mae: 0.8536 - lr: 0.0010
# Epoch 195/500
# 4/4 [==============================] - 1s 256ms/step - loss: 0.7926 - mae: 0.6384 - val_loss: 1.4736 - val_mae: 0.8533 - lr: 0.0010
# Epoch 196/500
# 4/4 [==============================] - 1s 257ms/step - loss: 0.7918 - mae: 0.6379 - val_loss: 1.4733 - val_mae: 0.8537 - lr: 0.0010
# Epoch 197/500
# 4/4 [==============================] - 1s 255ms/step - loss: 0.7917 - mae: 0.6381 - val_loss: 1.4728 - val_mae: 0.8530 - lr: 0.0010
# Epoch 198/500
# 4/4 [==============================] - 1s 255ms/step - loss: 0.7911 - mae: 0.6377 - val_loss: 1.4724 - val_mae: 0.8529 - lr: 0.0010
# Epoch 199/500
# 4/4 [==============================] - 1s 258ms/step - loss: 0.7901 - mae: 0.6374 - val_loss: 1.4720 - val_mae: 0.8530 - lr: 0.0010
# Epoch 200/500
# 4/4 [==============================] - 1s 256ms/step - loss: 0.7894 - mae: 0.6372 - val_loss: 1.4718 - val_mae: 0.8528 - lr: 0.0010
# Epoch 201/500
# 4/4 [==============================] - 1s 254ms/step - loss: 0.7890 - mae: 0.6369 - val_loss: 1.4716 - val_mae: 0.8533 - lr: 0.0010
# Epoch 202/500
# 4/4 [==============================] - 1s 253ms/step - loss: 0.7881 - mae: 0.6367 - val_loss: 1.4714 - val_mae: 0.8531 - lr: 0.0010
# Epoch 203/500
# 4/4 [==============================] - 1s 255ms/step - loss: 0.7871 - mae: 0.6364 - val_loss: 1.4713 - val_mae: 0.8530 - lr: 0.0010
# Epoch 204/500
# 4/4 [==============================] - 1s 258ms/step - loss: 0.7864 - mae: 0.6360 - val_loss: 1.4712 - val_mae: 0.8530 - lr: 0.0010
# Epoch 205/500
# 4/4 [==============================] - 1s 252ms/step - loss: 0.7865 - mae: 0.6360 - val_loss: 1.4712 - val_mae: 0.8527 - lr: 0.0010
# Epoch 206/500
# 4/4 [==============================] - 1s 253ms/step - loss: 0.7853 - mae: 0.6356 - val_loss: 1.4710 - val_mae: 0.8529 - lr: 0.0010
# Epoch 207/500
# 4/4 [==============================] - 1s 152ms/step - loss: 0.7845 - mae: 0.6350 - val_loss: 1.4714 - val_mae: 0.8525 - lr: 0.0010
# Epoch 208/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.7839 - mae: 0.6349 - val_loss: 1.4712 - val_mae: 0.8527 - lr: 0.0010
# Epoch 209/500
# 4/4 [==============================] - 1s 259ms/step - loss: 0.7837 - mae: 0.6349 - val_loss: 1.4706 - val_mae: 0.8525 - lr: 0.0010
# Epoch 210/500
# 4/4 [==============================] - 1s 256ms/step - loss: 0.7831 - mae: 0.6346 - val_loss: 1.4700 - val_mae: 0.8522 - lr: 0.0010
# Epoch 211/500
# 4/4 [==============================] - 1s 255ms/step - loss: 0.7829 - mae: 0.6347 - val_loss: 1.4699 - val_mae: 0.8525 - lr: 0.0010
# Epoch 212/500
# 4/4 [==============================] - 1s 152ms/step - loss: 0.7819 - mae: 0.6342 - val_loss: 1.4701 - val_mae: 0.8522 - lr: 0.0010
# Epoch 213/500
# 4/4 [==============================] - 1s 261ms/step - loss: 0.7810 - mae: 0.6337 - val_loss: 1.4698 - val_mae: 0.8525 - lr: 0.0010
# Epoch 214/500
# 4/4 [==============================] - 1s 256ms/step - loss: 0.7800 - mae: 0.6335 - val_loss: 1.4696 - val_mae: 0.8521 - lr: 0.0010
# Epoch 215/500
# 4/4 [==============================] - 1s 255ms/step - loss: 0.7802 - mae: 0.6336 - val_loss: 1.4689 - val_mae: 0.8523 - lr: 0.0010
# Epoch 216/500
# 4/4 [==============================] - 1s 252ms/step - loss: 0.7788 - mae: 0.6330 - val_loss: 1.4688 - val_mae: 0.8520 - lr: 0.0010
# Epoch 217/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.7787 - mae: 0.6330 - val_loss: 1.4689 - val_mae: 0.8522 - lr: 0.0010
# Epoch 218/500
# 4/4 [==============================] - 1s 151ms/step - loss: 0.7783 - mae: 0.6329 - val_loss: 1.4694 - val_mae: 0.8523 - lr: 0.0010
# Epoch 219/500
# 4/4 [==============================] - 1s 151ms/step - loss: 0.7776 - mae: 0.6323 - val_loss: 1.4695 - val_mae: 0.8522 - lr: 0.0010
# Epoch 220/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.7773 - mae: 0.6323 - val_loss: 1.4695 - val_mae: 0.8521 - lr: 0.0010
# Epoch 221/500
# 4/4 [==============================] - 1s 152ms/step - loss: 0.7762 - mae: 0.6319 - val_loss: 1.4693 - val_mae: 0.8522 - lr: 0.0010
# Epoch 222/500
# 4/4 [==============================] - 1s 260ms/step - loss: 0.7763 - mae: 0.6320 - val_loss: 1.4686 - val_mae: 0.8519 - lr: 0.0010
# Epoch 223/500
# 4/4 [==============================] - 1s 253ms/step - loss: 0.7758 - mae: 0.6319 - val_loss: 1.4684 - val_mae: 0.8518 - lr: 0.0010
# Epoch 224/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.7750 - mae: 0.6316 - val_loss: 1.4686 - val_mae: 0.8517 - lr: 0.0010
# Epoch 225/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.7749 - mae: 0.6315 - val_loss: 1.4690 - val_mae: 0.8519 - lr: 0.0010
# Epoch 226/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.7738 - mae: 0.6311 - val_loss: 1.4693 - val_mae: 0.8520 - lr: 0.0010
# Epoch 227/500
# 4/4 [==============================] - 1s 152ms/step - loss: 0.7741 - mae: 0.6311 - val_loss: 1.4690 - val_mae: 0.8519 - lr: 0.0010
# Epoch 228/500
# 4/4 [==============================] - 1s 263ms/step - loss: 0.7731 - mae: 0.6310 - val_loss: 1.4684 - val_mae: 0.8519 - lr: 0.0010
# Epoch 229/500
# 4/4 [==============================] - 1s 257ms/step - loss: 0.7719 - mae: 0.6303 - val_loss: 1.4683 - val_mae: 0.8516 - lr: 0.0010
# Epoch 230/500
# 4/4 [==============================] - 1s 265ms/step - loss: 0.7721 - mae: 0.6304 - val_loss: 1.4674 - val_mae: 0.8519 - lr: 0.0010
# Epoch 231/500
# 4/4 [==============================] - 1s 263ms/step - loss: 0.7717 - mae: 0.6302 - val_loss: 1.4673 - val_mae: 0.8512 - lr: 0.0010
# Epoch 232/500
# 4/4 [==============================] - 1s 263ms/step - loss: 0.7707 - mae: 0.6297 - val_loss: 1.4670 - val_mae: 0.8515 - lr: 0.0010
# Epoch 233/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.7708 - mae: 0.6300 - val_loss: 1.4670 - val_mae: 0.8513 - lr: 0.0010
# Epoch 234/500
# 4/4 [==============================] - 1s 255ms/step - loss: 0.7701 - mae: 0.6296 - val_loss: 1.4666 - val_mae: 0.8511 - lr: 0.0010
# Epoch 235/500
# 4/4 [==============================] - 1s 256ms/step - loss: 0.7700 - mae: 0.6296 - val_loss: 1.4664 - val_mae: 0.8513 - lr: 0.0010
# Epoch 236/500
# 4/4 [==============================] - 1s 153ms/step - loss: 0.7693 - mae: 0.6293 - val_loss: 1.4666 - val_mae: 0.8513 - lr: 0.0010
# Epoch 237/500
# 4/4 [==============================] - 1s 151ms/step - loss: 0.7687 - mae: 0.6290 - val_loss: 1.4666 - val_mae: 0.8513 - lr: 0.0010
# Epoch 238/500
# 4/4 [==============================] - 1s 152ms/step - loss: 0.7684 - mae: 0.6291 - val_loss: 1.4668 - val_mae: 0.8511 - lr: 0.0010
# Epoch 239/500
# 4/4 [==============================] - 1s 152ms/step - loss: 0.7683 - mae: 0.6290 - val_loss: 1.4667 - val_mae: 0.8512 - lr: 0.0010
# Epoch 240/500
# 4/4 [==============================] - 1s 152ms/step - loss: 0.7677 - mae: 0.6287 - val_loss: 1.4665 - val_mae: 0.8515 - lr: 0.0010
# Epoch 241/500
# 4/4 [==============================] - 1s 256ms/step - loss: 0.7678 - mae: 0.6289 - val_loss: 1.4662 - val_mae: 0.8510 - lr: 0.0010
# Epoch 242/500
# 4/4 [==============================] - 1s 255ms/step - loss: 0.7670 - mae: 0.6287 - val_loss: 1.4659 - val_mae: 0.8515 - lr: 0.0010
# Epoch 243/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.7659 - mae: 0.6282 - val_loss: 1.4662 - val_mae: 0.8513 - lr: 0.0010
# Epoch 244/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.7658 - mae: 0.6280 - val_loss: 1.4663 - val_mae: 0.8515 - lr: 0.0010
# Epoch 245/500
# 4/4 [==============================] - 1s 153ms/step - loss: 0.7648 - mae: 0.6276 - val_loss: 1.4665 - val_mae: 0.8514 - lr: 0.0010
# Epoch 246/500
# 4/4 [==============================] - 1s 152ms/step - loss: 0.7651 - mae: 0.6279 - val_loss: 1.4663 - val_mae: 0.8517 - lr: 0.0010
# Epoch 247/500
# 4/4 [==============================] - 1s 152ms/step - loss: 0.7647 - mae: 0.6275 - val_loss: 1.4664 - val_mae: 0.8511 - lr: 0.0010
# Epoch 248/500
# 4/4 [==============================] - 1s 152ms/step - loss: 0.7646 - mae: 0.6275 - val_loss: 1.4661 - val_mae: 0.8515 - lr: 0.0010
# Epoch 249/500
# 4/4 [==============================] - 1s 153ms/step - loss: 0.7639 - mae: 0.6274 - val_loss: 1.4666 - val_mae: 0.8510 - lr: 0.0010
# Epoch 250/500
# 4/4 [==============================] - 1s 153ms/step - loss: 0.7641 - mae: 0.6275 - val_loss: 1.4668 - val_mae: 0.8517 - lr: 0.0010
# Epoch 251/500
# 4/4 [==============================] - 1s 152ms/step - loss: 0.7627 - mae: 0.6270 - val_loss: 1.4671 - val_mae: 0.8513 - lr: 0.0010
# Epoch 252/500
# 4/4 [==============================] - 1s 151ms/step - loss: 0.7624 - mae: 0.6268 - val_loss: 1.4663 - val_mae: 0.8517 - lr: 0.0010
# Epoch 253/500
# 4/4 [==============================] - 1s 153ms/step - loss: 0.7622 - mae: 0.6269 - val_loss: 1.4660 - val_mae: 0.8512 - lr: 0.0010
# Epoch 254/500
# 4/4 [==============================] - 1s 256ms/step - loss: 0.7617 - mae: 0.6264 - val_loss: 1.4656 - val_mae: 0.8512 - lr: 0.0010
# Epoch 255/500
# 4/4 [==============================] - 1s 152ms/step - loss: 0.7618 - mae: 0.6267 - val_loss: 1.4657 - val_mae: 0.8513 - lr: 0.0010
# Epoch 256/500
# 4/4 [==============================] - 1s 151ms/step - loss: 0.7612 - mae: 0.6263 - val_loss: 1.4657 - val_mae: 0.8513 - lr: 0.0010
# Epoch 257/500
# 4/4 [==============================] - 1s 257ms/step - loss: 0.7609 - mae: 0.6263 - val_loss: 1.4655 - val_mae: 0.8514 - lr: 0.0010
# Epoch 258/500
# 4/4 [==============================] - 1s 151ms/step - loss: 0.7606 - mae: 0.6263 - val_loss: 1.4656 - val_mae: 0.8509 - lr: 0.0010
# Epoch 259/500
# 4/4 [==============================] - 1s 253ms/step - loss: 0.7602 - mae: 0.6259 - val_loss: 1.4655 - val_mae: 0.8514 - lr: 0.0010
# Epoch 260/500
# 4/4 [==============================] - 1s 149ms/step - loss: 0.7598 - mae: 0.6258 - val_loss: 1.4657 - val_mae: 0.8509 - lr: 0.0010
# Epoch 261/500
# 4/4 [==============================] - 1s 253ms/step - loss: 0.7596 - mae: 0.6259 - val_loss: 1.4655 - val_mae: 0.8512 - lr: 0.0010
# Epoch 262/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.7598 - mae: 0.6260 - val_loss: 1.4657 - val_mae: 0.8510 - lr: 0.0010
# Epoch 263/500
# 4/4 [==============================] - 1s 151ms/step - loss: 0.7589 - mae: 0.6255 - val_loss: 1.4658 - val_mae: 0.8511 - lr: 0.0010
# Epoch 264/500
# 4/4 [==============================] - 1s 152ms/step - loss: 0.7585 - mae: 0.6255 - val_loss: 1.4658 - val_mae: 0.8511 - lr: 0.0010
# Epoch 265/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.7582 - mae: 0.6253 - val_loss: 1.4656 - val_mae: 0.8513 - lr: 0.0010
# Epoch 266/500
# 4/4 [==============================] - 1s 151ms/step - loss: 0.7581 - mae: 0.6254 - val_loss: 1.4659 - val_mae: 0.8513 - lr: 0.0010
# Epoch 267/500
# 4/4 [==============================] - 1s 152ms/step - loss: 0.7581 - mae: 0.6253 - val_loss: 1.4656 - val_mae: 0.8512 - lr: 0.0010
# Epoch 268/500
# 4/4 [==============================] - 1s 255ms/step - loss: 0.7572 - mae: 0.6248 - val_loss: 1.4654 - val_mae: 0.8511 - lr: 0.0010
# Epoch 269/500
# 4/4 [==============================] - 1s 257ms/step - loss: 0.7573 - mae: 0.6251 - val_loss: 1.4652 - val_mae: 0.8511 - lr: 0.0010
# Epoch 270/500
# 4/4 [==============================] - 1s 152ms/step - loss: 0.7569 - mae: 0.6247 - val_loss: 1.4653 - val_mae: 0.8511 - lr: 0.0010
# Epoch 271/500
# 4/4 [==============================] - 1s 151ms/step - loss: 0.7564 - mae: 0.6247 - val_loss: 1.4657 - val_mae: 0.8514 - lr: 0.0010
# Epoch 272/500
# 4/4 [==============================] - 1s 153ms/step - loss: 0.7564 - mae: 0.6246 - val_loss: 1.4659 - val_mae: 0.8516 - lr: 0.0010
# Epoch 273/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.7564 - mae: 0.6247 - val_loss: 1.4660 - val_mae: 0.8515 - lr: 0.0010
# Epoch 274/500
# 4/4 [==============================] - 1s 152ms/step - loss: 0.7553 - mae: 0.6242 - val_loss: 1.4660 - val_mae: 0.8514 - lr: 0.0010
# Epoch 275/500
# 4/4 [==============================] - 1s 153ms/step - loss: 0.7551 - mae: 0.6242 - val_loss: 1.4658 - val_mae: 0.8516 - lr: 0.0010
# Epoch 276/500
# 4/4 [==============================] - 1s 151ms/step - loss: 0.7547 - mae: 0.6241 - val_loss: 1.4657 - val_mae: 0.8513 - lr: 0.0010
# Epoch 277/500
# 4/4 [==============================] - 1s 151ms/step - loss: 0.7550 - mae: 0.6243 - val_loss: 1.4657 - val_mae: 0.8513 - lr: 0.0010
# Epoch 278/500
# 4/4 [==============================] - 1s 152ms/step - loss: 0.7545 - mae: 0.6240 - val_loss: 1.4658 - val_mae: 0.8515 - lr: 0.0010
# Epoch 279/500
# 4/4 [==============================] - 1s 152ms/step - loss: 0.7540 - mae: 0.6237 - val_loss: 1.4661 - val_mae: 0.8516 - lr: 0.0010
# Epoch 280/500
# 4/4 [==============================] - 1s 151ms/step - loss: 0.7541 - mae: 0.6239 - val_loss: 1.4662 - val_mae: 0.8515 - lr: 0.0010
# Epoch 281/500
# 4/4 [==============================] - 1s 154ms/step - loss: 0.7535 - mae: 0.6235 - val_loss: 1.4659 - val_mae: 0.8518 - lr: 0.0010
# Epoch 282/500
# 4/4 [==============================] - 1s 152ms/step - loss: 0.7531 - mae: 0.6235 - val_loss: 1.4656 - val_mae: 0.8512 - lr: 0.0010
# Epoch 283/500
# 4/4 [==============================] - 1s 151ms/step - loss: 0.7532 - mae: 0.6235 - val_loss: 1.4653 - val_mae: 0.8513 - lr: 0.0010
# Epoch 284/500
# 4/4 [==============================] - 1s 262ms/step - loss: 0.7528 - mae: 0.6232 - val_loss: 1.4651 - val_mae: 0.8512 - lr: 0.0010
# Epoch 285/500
# 4/4 [==============================] - 1s 254ms/step - loss: 0.7527 - mae: 0.6234 - val_loss: 1.4649 - val_mae: 0.8514 - lr: 0.0010
# Epoch 286/500
# 4/4 [==============================] - 1s 261ms/step - loss: 0.7523 - mae: 0.6232 - val_loss: 1.4646 - val_mae: 0.8511 - lr: 0.0010
# Epoch 287/500
# 4/4 [==============================] - 1s 257ms/step - loss: 0.7523 - mae: 0.6234 - val_loss: 1.4645 - val_mae: 0.8513 - lr: 0.0010
# Epoch 288/500
# 4/4 [==============================] - 1s 152ms/step - loss: 0.7522 - mae: 0.6232 - val_loss: 1.4647 - val_mae: 0.8513 - lr: 0.0010
# Epoch 289/500
# 4/4 [==============================] - 1s 153ms/step - loss: 0.7524 - mae: 0.6235 - val_loss: 1.4649 - val_mae: 0.8512 - lr: 0.0010
# Epoch 290/500
# 4/4 [==============================] - 1s 152ms/step - loss: 0.7513 - mae: 0.6228 - val_loss: 1.4648 - val_mae: 0.8513 - lr: 0.0010
# Epoch 291/500
# 4/4 [==============================] - 1s 152ms/step - loss: 0.7507 - mae: 0.6227 - val_loss: 1.4650 - val_mae: 0.8513 - lr: 0.0010
# Epoch 292/500
# 4/4 [==============================] - 1s 153ms/step - loss: 0.7507 - mae: 0.6226 - val_loss: 1.4646 - val_mae: 0.8516 - lr: 0.0010
# Epoch 293/500
# 4/4 [==============================] - 1s 263ms/step - loss: 0.7503 - mae: 0.6225 - val_loss: 1.4644 - val_mae: 0.8511 - lr: 0.0010
# Epoch 294/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.7504 - mae: 0.6226 - val_loss: 1.4644 - val_mae: 0.8515 - lr: 0.0010
# Epoch 295/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.7504 - mae: 0.6227 - val_loss: 1.4651 - val_mae: 0.8511 - lr: 0.0010
# Epoch 296/500
# 4/4 [==============================] - 1s 151ms/step - loss: 0.7500 - mae: 0.6223 - val_loss: 1.4648 - val_mae: 0.8516 - lr: 0.0010
# Epoch 297/500
# 4/4 [==============================] - 1s 151ms/step - loss: 0.7495 - mae: 0.6224 - val_loss: 1.4646 - val_mae: 0.8509 - lr: 0.0010
# Epoch 298/500
# 4/4 [==============================] - 1s 254ms/step - loss: 0.7494 - mae: 0.6222 - val_loss: 1.4639 - val_mae: 0.8514 - lr: 0.0010
# Epoch 299/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.7489 - mae: 0.6221 - val_loss: 1.4644 - val_mae: 0.8510 - lr: 0.0010
# Epoch 300/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.7490 - mae: 0.6219 - val_loss: 1.4648 - val_mae: 0.8520 - lr: 0.0010
# Epoch 301/500
# 4/4 [==============================] - 1s 152ms/step - loss: 0.7480 - mae: 0.6217 - val_loss: 1.4655 - val_mae: 0.8512 - lr: 0.0010
# Epoch 302/500
# 4/4 [==============================] - 1s 151ms/step - loss: 0.7482 - mae: 0.6218 - val_loss: 1.4651 - val_mae: 0.8518 - lr: 0.0010
# Epoch 303/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.7482 - mae: 0.6220 - val_loss: 1.4651 - val_mae: 0.8513 - lr: 0.0010
# Epoch 304/500
# 4/4 [==============================] - 1s 149ms/step - loss: 0.7475 - mae: 0.6216 - val_loss: 1.4647 - val_mae: 0.8518 - lr: 0.0010
# Epoch 305/500
# 4/4 [==============================] - 1s 151ms/step - loss: 0.7479 - mae: 0.6217 - val_loss: 1.4649 - val_mae: 0.8513 - lr: 0.0010
# Epoch 306/500
# 4/4 [==============================] - 1s 152ms/step - loss: 0.7475 - mae: 0.6216 - val_loss: 1.4644 - val_mae: 0.8516 - lr: 0.0010
# Epoch 307/500
# 4/4 [==============================] - 1s 152ms/step - loss: 0.7469 - mae: 0.6215 - val_loss: 1.4642 - val_mae: 0.8509 - lr: 0.0010
# Epoch 308/500
# 4/4 [==============================] - 1s 264ms/step - loss: 0.7469 - mae: 0.6213 - val_loss: 1.4638 - val_mae: 0.8514 - lr: 0.0010
# Epoch 309/500
# 4/4 [==============================] - 1s 151ms/step - loss: 0.7465 - mae: 0.6211 - val_loss: 1.4640 - val_mae: 0.8511 - lr: 0.0010
# Epoch 310/500
# 4/4 [==============================] - 1s 153ms/step - loss: 0.7464 - mae: 0.6213 - val_loss: 1.4639 - val_mae: 0.8515 - lr: 0.0010
# Epoch 311/500
# 4/4 [==============================] - 1s 153ms/step - loss: 0.7466 - mae: 0.6213 - val_loss: 1.4639 - val_mae: 0.8512 - lr: 0.0010
# Epoch 312/500
# 4/4 [==============================] - 1s 257ms/step - loss: 0.7456 - mae: 0.6209 - val_loss: 1.4637 - val_mae: 0.8516 - lr: 0.0010
# Epoch 313/500
# 4/4 [==============================] - 1s 154ms/step - loss: 0.7453 - mae: 0.6210 - val_loss: 1.4639 - val_mae: 0.8512 - lr: 0.0010
# Epoch 314/500
# 4/4 [==============================] - 1s 153ms/step - loss: 0.7445 - mae: 0.6204 - val_loss: 1.4638 - val_mae: 0.8515 - lr: 0.0010
# Epoch 315/500
# 4/4 [==============================] - 1s 153ms/step - loss: 0.7451 - mae: 0.6209 - val_loss: 1.4644 - val_mae: 0.8511 - lr: 0.0010
# Epoch 316/500
# 4/4 [==============================] - 1s 151ms/step - loss: 0.7447 - mae: 0.6205 - val_loss: 1.4644 - val_mae: 0.8517 - lr: 0.0010
# Epoch 317/500
# 4/4 [==============================] - 1s 152ms/step - loss: 0.7449 - mae: 0.6209 - val_loss: 1.4642 - val_mae: 0.8513 - lr: 0.0010
# Epoch 318/500
# 4/4 [==============================] - 1s 152ms/step - loss: 0.7444 - mae: 0.6206 - val_loss: 1.4639 - val_mae: 0.8513 - lr: 0.0010
# Epoch 319/500
# 4/4 [==============================] - 1s 153ms/step - loss: 0.7440 - mae: 0.6203 - val_loss: 1.4638 - val_mae: 0.8515 - lr: 0.0010
# Epoch 320/500
# 4/4 [==============================] - 1s 261ms/step - loss: 0.7437 - mae: 0.6202 - val_loss: 1.4636 - val_mae: 0.8513 - lr: 0.0010
# Epoch 321/500
# 4/4 [==============================] - 1s 153ms/step - loss: 0.7432 - mae: 0.6200 - val_loss: 1.4638 - val_mae: 0.8513 - lr: 0.0010
# Epoch 322/500
# 4/4 [==============================] - 1s 151ms/step - loss: 0.7434 - mae: 0.6201 - val_loss: 1.4639 - val_mae: 0.8516 - lr: 0.0010
# Epoch 323/500
# 4/4 [==============================] - 1s 151ms/step - loss: 0.7431 - mae: 0.6201 - val_loss: 1.4645 - val_mae: 0.8512 - lr: 0.0010
# Epoch 324/500
# 4/4 [==============================] - 1s 152ms/step - loss: 0.7426 - mae: 0.6198 - val_loss: 1.4645 - val_mae: 0.8518 - lr: 0.0010
# Epoch 325/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.7428 - mae: 0.6199 - val_loss: 1.4639 - val_mae: 0.8515 - lr: 0.0010
# Epoch 326/500
# 4/4 [==============================] - 1s 254ms/step - loss: 0.7423 - mae: 0.6198 - val_loss: 1.4635 - val_mae: 0.8515 - lr: 0.0010
# Epoch 327/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.7428 - mae: 0.6201 - val_loss: 1.4638 - val_mae: 0.8515 - lr: 0.0010
# Epoch 328/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.7416 - mae: 0.6194 - val_loss: 1.4637 - val_mae: 0.8517 - lr: 0.0010
# Epoch 329/500
# 4/4 [==============================] - 1s 152ms/step - loss: 0.7412 - mae: 0.6191 - val_loss: 1.4638 - val_mae: 0.8518 - lr: 0.0010
# Epoch 330/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.7415 - mae: 0.6195 - val_loss: 1.4640 - val_mae: 0.8519 - lr: 0.0010
# Epoch 331/500
# 4/4 [==============================] - 1s 152ms/step - loss: 0.7410 - mae: 0.6194 - val_loss: 1.4640 - val_mae: 0.8520 - lr: 0.0010
# Epoch 332/500
# 4/4 [==============================] - 1s 151ms/step - loss: 0.7406 - mae: 0.6191 - val_loss: 1.4644 - val_mae: 0.8518 - lr: 0.0010
# Epoch 333/500
# 4/4 [==============================] - 1s 151ms/step - loss: 0.7406 - mae: 0.6189 - val_loss: 1.4645 - val_mae: 0.8519 - lr: 0.0010
# Epoch 334/500
# 4/4 [==============================] - 1s 151ms/step - loss: 0.7403 - mae: 0.6190 - val_loss: 1.4643 - val_mae: 0.8520 - lr: 0.0010
# Epoch 335/500
# 4/4 [==============================] - 1s 151ms/step - loss: 0.7400 - mae: 0.6187 - val_loss: 1.4644 - val_mae: 0.8516 - lr: 0.0010
# Epoch 336/500
# 4/4 [==============================] - 1s 152ms/step - loss: 0.7393 - mae: 0.6185 - val_loss: 1.4639 - val_mae: 0.8519 - lr: 0.0010
# Epoch 337/500
# 4/4 [==============================] - 1s 151ms/step - loss: 0.7395 - mae: 0.6187 - val_loss: 1.4638 - val_mae: 0.8516 - lr: 0.0010
# Epoch 338/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.7390 - mae: 0.6185 - val_loss: 1.4639 - val_mae: 0.8520 - lr: 0.0010
# Epoch 339/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.7380 - mae: 0.6178 - val_loss: 1.4644 - val_mae: 0.8520 - lr: 0.0010
# Epoch 340/500
# 4/4 [==============================] - 1s 152ms/step - loss: 0.7380 - mae: 0.6179 - val_loss: 1.4649 - val_mae: 0.8519 - lr: 0.0010
# Epoch 341/500
# 4/4 [==============================] - 1s 151ms/step - loss: 0.7374 - mae: 0.6174 - val_loss: 1.4651 - val_mae: 0.8521 - lr: 0.0010
# Epoch 342/500
# 4/4 [==============================] - 1s 152ms/step - loss: 0.7371 - mae: 0.6174 - val_loss: 1.4649 - val_mae: 0.8515 - lr: 0.0010
# Epoch 343/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.7364 - mae: 0.6170 - val_loss: 1.4649 - val_mae: 0.8518 - lr: 0.0010
# Epoch 344/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.7358 - mae: 0.6166 - val_loss: 1.4649 - val_mae: 0.8519 - lr: 0.0010
# Epoch 345/500
# 4/4 [==============================] - 1s 152ms/step - loss: 0.7353 - mae: 0.6165 - val_loss: 1.4650 - val_mae: 0.8518 - lr: 0.0010
# Epoch 346/500
# 4/4 [==============================] - 1s 152ms/step - loss: 0.7349 - mae: 0.6163 - val_loss: 1.4650 - val_mae: 0.8520 - lr: 0.0010
# Epoch 347/500
# 4/4 [==============================] - 1s 151ms/step - loss: 0.7337 - mae: 0.6156 - val_loss: 1.4652 - val_mae: 0.8517 - lr: 0.0010
# Epoch 348/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.7334 - mae: 0.6155 - val_loss: 1.4654 - val_mae: 0.8517 - lr: 0.0010
# Epoch 349/500
# 4/4 [==============================] - 1s 151ms/step - loss: 0.7328 - mae: 0.6152 - val_loss: 1.4655 - val_mae: 0.8519 - lr: 0.0010
# Epoch 350/500
# 4/4 [==============================] - 1s 151ms/step - loss: 0.7317 - mae: 0.6145 - val_loss: 1.4656 - val_mae: 0.8517 - lr: 0.0010
# Epoch 351/500
# 4/4 [==============================] - 1s 152ms/step - loss: 0.7304 - mae: 0.6137 - val_loss: 1.4654 - val_mae: 0.8520 - lr: 0.0010
# Epoch 352/500
# 4/4 [==============================] - 1s 153ms/step - loss: 0.7302 - mae: 0.6134 - val_loss: 1.4659 - val_mae: 0.8514 - lr: 0.0010
# Epoch 353/500
# 4/4 [==============================] - 1s 151ms/step - loss: 0.7287 - mae: 0.6127 - val_loss: 1.4658 - val_mae: 0.8516 - lr: 0.0010
# Epoch 354/500
# 4/4 [==============================] - 1s 156ms/step - loss: 0.7273 - mae: 0.6119 - val_loss: 1.4664 - val_mae: 0.8511 - lr: 0.0010
# Epoch 355/500
# 4/4 [==============================] - 1s 153ms/step - loss: 0.7260 - mae: 0.6109 - val_loss: 1.4668 - val_mae: 0.8511 - lr: 0.0010
# Epoch 356/500
# 4/4 [==============================] - 1s 152ms/step - loss: 0.7247 - mae: 0.6100 - val_loss: 1.4674 - val_mae: 0.8509 - lr: 0.0010
# Epoch 357/500
# 4/4 [==============================] - 1s 152ms/step - loss: 0.7228 - mae: 0.6090 - val_loss: 1.4676 - val_mae: 0.8510 - lr: 0.0010
# Epoch 358/500
# 4/4 [==============================] - 1s 152ms/step - loss: 0.7215 - mae: 0.6081 - val_loss: 1.4680 - val_mae: 0.8506 - lr: 0.0010
# Epoch 359/500
# 4/4 [==============================] - 1s 153ms/step - loss: 0.7201 - mae: 0.6069 - val_loss: 1.4682 - val_mae: 0.8504 - lr: 0.0010
# Epoch 360/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.7183 - mae: 0.6058 - val_loss: 1.4684 - val_mae: 0.8502 - lr: 0.0010
# Epoch 361/500
# 4/4 [==============================] - 1s 151ms/step - loss: 0.7159 - mae: 0.6043 - val_loss: 1.4688 - val_mae: 0.8494 - lr: 0.0010
# Epoch 362/500
# 4/4 [==============================] - 1s 152ms/step - loss: 0.7142 - mae: 0.6027 - val_loss: 1.4692 - val_mae: 0.8498 - lr: 0.0010
# Epoch 363/500
# 4/4 [==============================] - 1s 152ms/step - loss: 0.7120 - mae: 0.6014 - val_loss: 1.4710 - val_mae: 0.8490 - lr: 0.0010
# Epoch 364/500
# 4/4 [==============================] - 1s 152ms/step - loss: 0.7084 - mae: 0.5991 - val_loss: 1.4720 - val_mae: 0.8494 - lr: 0.0010
# Epoch 365/500
# 4/4 [==============================] - 1s 151ms/step - loss: 0.7065 - mae: 0.5977 - val_loss: 1.4728 - val_mae: 0.8486 - lr: 0.0010
# Epoch 366/500
# 4/4 [==============================] - 1s 152ms/step - loss: 0.7032 - mae: 0.5952 - val_loss: 1.4734 - val_mae: 0.8482 - lr: 0.0010
# Epoch 367/500
# 4/4 [==============================] - 1s 151ms/step - loss: 0.7003 - mae: 0.5930 - val_loss: 1.4749 - val_mae: 0.8478 - lr: 0.0010
# Epoch 368/500
# 4/4 [==============================] - 1s 152ms/step - loss: 0.6982 - mae: 0.5914 - val_loss: 1.4772 - val_mae: 0.8479 - lr: 0.0010
# Epoch 369/500
# 4/4 [==============================] - 1s 151ms/step - loss: 0.6951 - mae: 0.5889 - val_loss: 1.4794 - val_mae: 0.8477 - lr: 0.0010
# Epoch 370/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.6923 - mae: 0.5872 - val_loss: 1.4815 - val_mae: 0.8480 - lr: 0.0010
# Epoch 371/500
# 4/4 [==============================] - 1s 151ms/step - loss: 0.6825 - mae: 0.5817 - val_loss: 1.4803 - val_mae: 0.8468 - lr: 2.0000e-04
# Epoch 372/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.6783 - mae: 0.5790 - val_loss: 1.4773 - val_mae: 0.8444 - lr: 2.0000e-04
# Epoch 373/500
# 4/4 [==============================] - 1s 153ms/step - loss: 0.6719 - mae: 0.5750 - val_loss: 1.4741 - val_mae: 0.8422 - lr: 2.0000e-04
# Epoch 374/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.6661 - mae: 0.5717 - val_loss: 1.4714 - val_mae: 0.8405 - lr: 2.0000e-04
# Epoch 375/500
# 4/4 [==============================] - 1s 150ms/step - loss: 0.6604 - mae: 0.5682 - val_loss: 1.4695 - val_mae: 0.8390 - lr: 2.0000e-04
# Epoch 376/500
# 4/4 [==============================] - 1s 284ms/step - loss: 0.6565 - mae: 0.5661 - val_loss: 1.4684 - val_mae: 0.8376 - lr: 2.0000e-04
# CPU times: user 5min 22s, sys: 45.2 s, total: 6min 7s
# Wall time: 4min 44s

# %%
# Predicciones
y_true = ratings_test
predictions = model.predict([user_ids_test, item_ids_test])
# Out:
# 30004/30004 [==============================] - 44s 1ms/step

# %%
# MSE y RMSE
mse = mean_squared_error(y_true, predictions)
rmse = np.sqrt(mse)

# MAE
mae = mean_absolute_error(y_true, predictions)

# MAPE
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    non_zero_idx = y_true != 0  # Para evitar divisiones por cero
    return np.mean(np.abs((y_true[non_zero_idx] - y_pred[non_zero_idx]) / y_true[non_zero_idx])) * 100

def compute_mape_by_batch(y_true, predictions, batch_size=50000):
    mape_sum = 0
    num_batches = int(np.ceil(len(y_true) / batch_size))

    for i in range(num_batches):
        start_idx = i * batch_size
        end_idx = start_idx + batch_size

        batch_y_true = y_true[start_idx:end_idx]
        batch_predictions = predictions[start_idx:end_idx]

        mape_sum += mean_absolute_percentage_error(batch_y_true, batch_predictions)

    return mape_sum / num_batches

# Luego llamas a la función
mape = compute_mape_by_batch(y_true, predictions)

print(f'MSE: {mse}')
print(f'RMSE: {rmse}')
print(f'MAE: {mae}')
print(f'MAPE: {mape}%')
# Out:
# MSE: 1.3977298878901843
# RMSE: 1.1822562699728787
# MAE: 0.8524683509013015
# MAPE: 41.89489725930722%

# %% [markdown]
# # Recomendación

# %%
# Seleccionar un usuario al azar del conjunto de prueba
usuario_id_test_encoded = random.choice(user_ids_test)

# Decodificar el ID del usuario para obtener el ID original
usuario_id_test = reviewerID_encoder.inverse_transform([usuario_id_test_encoded])[0]

# Identificar los ítems que el usuario ha calificado en el conjunto de prueba
indices_usuario = np.where(user_ids_test == usuario_id_test_encoded)[0]
items_calificados_test_encoded = item_ids_test[indices_usuario]
calificaciones_reales_test = ratings_test[indices_usuario]

# Predecir las calificaciones para estos ítems
calificaciones_predichas = model.predict([np.array([usuario_id_test_encoded] * len(items_calificados_test_encoded)), items_calificados_test_encoded])

# Decodificar los ítems para obtener los ID originales
items_calificados_test = asin_encoder.inverse_transform(items_calificados_test_encoded)

# Comparar las calificaciones predichas con las reales
comparacion = list(zip(items_calificados_test, calificaciones_reales_test, calificaciones_predichas.flatten()))

# Mostrar las comparaciones
print(f"Recomendaciones para el usuario {usuario_id_test}:")
for item, real, predicha in comparacion:
    print(f"Ítem: {item}, Calificación Real: {real}, Calificación Predicha: {predicha}")
# Out:
# 1/1 [==============================] - 0s 20ms/step
# Recomendaciones para el usuario A2DMQMWNB2G2IL:
# Ítem: B010HDQJIG, Calificación Real: 5.0, Calificación Predicha: 4.178380966186523

# %%
# Seleccionar un usuario al azar del conjunto de prueba
usuario_id_test_encoded = random.choice(user_ids_test)

# Decodificar el ID del usuario para obtener el ID original
usuario_id = reviewerID_encoder.inverse_transform([usuario_id_test_encoded])[0]

# Lista de todos los ítems únicos en el dataset
items_unicos = np.unique(data['asin'].values)

# Ítems que el usuario ya ha calificado
items_calificados = data[data['reviewerID_encoded'] == usuario_id_test_encoded]['asin'].tolist()

# Ítems para predecir
items_a_predecir = [item for item in items_unicos if item not in items_calificados]

# Convierte los ítems a su representación codificada
items_a_predecir_encoded = asin_encoder.transform(items_a_predecir)

# Predecir la calificación para cada ítem no calificado
predicciones = model.predict([np.array([usuario_id_test_encoded] * len(items_a_predecir_encoded)), items_a_predecir_encoded])

# Emparejar cada ítem con su predicción
items_predicciones = list(zip(items_a_predecir, predicciones.flatten()))

# Ordenar por la calificación predicha más alta
items_recomendados = sorted(items_predicciones, key=lambda x: x[1], reverse=True)

# Tomar los top N recomendaciones
top_n = 5
top_recomendaciones = items_recomendados[:top_n]

# Imprimir las recomendaciones
print(f"Recomendaciones para el usuario {usuario_id}:")
for item, calificacion in top_recomendaciones:
    print(f"Ítem: {item}, Calificación Predicha: {calificacion}")
# Out:
# 4813/4813 [==============================] - 7s 2ms/step
# Recomendaciones para el usuario A1D9WN3AHN716:
# Ítem: B00N586US0, Calificación Predicha: 6.999874114990234
# Ítem: B007LSEES8, Calificación Predicha: 6.89541482925415
# Ítem: B00NMXWW9E, Calificación Predicha: 6.857378959655762
# Ítem: B01DKIAAJ4, Calificación Predicha: 6.843332767486572
# Ítem: B0172XZO12, Calificación Predicha: 6.825898170471191

# %% [markdown]
# Estas métricas te ayudarán a tener una mejor idea del desempeño de tu modelo. Por ejemplo:
#
# MSE y RMSE son útiles cuando quieres penalizar grandes errores.
#
# MAE te da una idea del error medio sin considerar la dirección del error.
#
# MAPE es útil cuando quieres representar el error en términos porcentuales.
#
# Para una evaluación completa, es recomendable utilizar un conjunto de validación aparte (es decir, no solo depender del validation_split). Esto asegura que estás evaluando el desempeño en datos que el modelo nunca ha visto durante el entrenamiento.

# %% [markdown]
# En resumen, la elección del tipo de sistema de recomendación dependerá de la naturaleza del conjunto de datos, las características disponibles, las capacidades computacionales y el tipo de relaciones o interacciones que se desean capturar. A menudo, un enfoque híbrido (como el sistema que combina embeddings y redes neuronales) ofrece un buen equilibrio entre precisión y eficiencia.
